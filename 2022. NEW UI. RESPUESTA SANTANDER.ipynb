# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## READING FILES

# %%
excel_name = 'Dispersión-20220823.xlsx'
date_respuesta = '2022-08-23'
date_respuesta = pd.to_datetime(date_respuesta)

# %%
names_resp = ['report_id','status','report_date_local','amount','disbursement_batch_id','merchant_id','bank_account_number',
             'bank_name','bank_account_owner_name','execution_date','aplication_date','disbursement_tracking_key',
             'error_description','reference_number','cep']

# %%
disp = pd.read_csv(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2022\08. AUGUST\SANT 2022-08-23.csv')
rs1 = pd.read_excel(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2022\08. AGOSTO\Respuesta-SANT 2022-08-23.xlsx',
                    sheet_name='Report',names=names_resp,
                    converters={'bank_account_number':str,'disbursement_tracking_key':str,'report_id':str})
bin1 = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\Catalogo_Bancos.csv'
                  ,dtype={'BIN':object,'Clave de la institución':object,'Nombre de la institución':object})
# Out:
# C:\Users\Cristian.Aparicio\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# # BIN

# %%
bin1.head()
# Out:
#    BIN Clave de la institución Nombre de la institución
# 0  138                   40138              ABC CAPITAL
# 1  102                   40102            ACCENDO BANCO
# 2  133                   40133                 ACTINVER
# 3  062                   40062                   AFIRME
# 4  638                   90638                    AKALA

# %%
bin1.shape
# Out:
# (90, 3)

# %% [markdown]
# # ARCHIVO RESPUESTA

# %%
rs1['Date_respuesta'] = date_respuesta
rs1['BIN'] = rs1['bank_account_number'].str[:3]
rs1.rename(columns ={'bank_account_number':'CLABE'}, inplace=True)
rs1['Metodo de dispersion'] = 'SANTANDER'
rs1.head()
# Out:
#    report_id status report_date_local   amount  \
# 0  TT5899MSH   PAID  2022-08-23T00:00 5,653.62
# 1  JN7493JY4   PAID  2022-08-23T00:00     4.79
# 2  J9T9MCL3X   PAID  2022-08-23T00:00   192.60
# 3  W5YK2YDLM   PAID  2022-08-23T00:00 3,449.36
# 4  PN7BXRJ6W   PAID  2022-08-23T00:00   349.76
#
#                   disbursement_batch_id                           merchant_id  \
# 0  eeb3b711-4ac2-4245-b2c9-980a40557d38  789e3e85-5fe8-41dd-ac03-9af6014dd9dd
# 1  eeb3b711-4ac2-4245-b2c9-980a40557d38  dcf51273-55ff-49df-af22-2286605324d5
# 2  eeb3b711-4ac2-4245-b2c9-980a40557d38  522ea0a4-0a91-426a-819f-7374320e51c9
# 3  eeb3b711-4ac2-4245-b2c9-980a40557d38  4b1fbe48-524f-49aa-aee9-38f7ca88ecb4
# 4  eeb3b711-4ac2-4245-b2c9-980a40557d38  cd3f18ca-c688-4990-99cc-a6e555d8494b
#
#                 CLABE                        bank_name  \
# 0  002180700433258663  Banco Nacional de MÃ©xico, S.A.
# 1  012456015691079750              BBVA Bancomer, S.A.
# 2  127180013315020086               Banco Azteca, S.A.
# 3  002375034170661780   Banco Nacional de México, S.A.
# 4  002040701757130328   Banco Nacional de México, S.A.
#
#            bank_account_owner_name       execution_date      aplication_date  \
# 0  Maria del Rocio Duarte Aguirre   2022-08-23T13:09:50  2022-08-23T08:07:18
# 1   Jose De Jesus Mojica Rodrguez   2022-08-23T13:14:12  2022-08-23T08:12:42
# 2          Hector Galvan Hernandez  2022-08-23T13:08:11  2022-08-23T08:07:18
# 3         Santos Gloria Joya Rubio  2022-08-23T13:07:52  2022-08-23T08:07:18
# 4               Midori Shiba Cosio  2022-08-23T13:13:31  2022-08-23T08:12:42
#
#         disbursement_tracking_key error_description  reference_number  \
# 0  2022082340014 HDH0001420224870               NaN            338729
# 1  2022082340014 HDH0001420487250               NaN            371095
# 2  2022082340014 HDH0001419891920               NaN            326477
# 3  2022082340014 HDH0001419850510               NaN            324164
# 4  2022082340014 HDH0001420348320               NaN            365960
#
#                                                  cep Date_respuesta  BIN  \
# 0  2022-08-23,2022082340014 HDH0001420224870,4001...     2022-08-23  002
# 1  2022-08-23,2022082340014 HDH0001420487250,4001...     2022-08-23  012
# 2  2022-08-23,2022082340014 HDH0001419891920,4001...     2022-08-23  127
# 3  2022-08-23,2022082340014 HDH0001419850510,4001...     2022-08-23  002
# 4  2022-08-23,2022082340014 HDH0001420348320,4001...     2022-08-23  002
#
#   Metodo de dispersion
# 0            SANTANDER
# 1            SANTANDER
# 2            SANTANDER
# 3            SANTANDER
# 4            SANTANDER

# %%
rs1.shape
# Out:
# (82221, 18)

# %%
rs1['report_id'] = rs1['report_id'].str.strip()

# %%
rs2 = rs1.merge(bin1[['BIN','Clave de la institución','Nombre de la institución']] ,on='BIN', how='left')
rs2['Banco emisor'] = '40014'
rs2['Banco_emisor'] = 'SANTANDER'
rs2['Comision'] = ''
rs2['LINEA CEP'] = (rs2['Date_respuesta'].astype(str).replace(' ', '',regex=True)+','
                    +rs2['disbursement_tracking_key'].astype(str)+','
                    +rs2['Banco emisor'].astype(str).replace(' ', '',regex=True)+','
                    +rs2['Clave de la institución'].astype(str).replace(' ', '',regex=True)+','
                    +rs2['CLABE'].astype(str).replace(' ', '',regex=True)+','
                    +rs2['amount'].astype(str).replace(' ', '',regex=True))
rs2.head()
# Out:
#    report_id status report_date_local   amount  \
# 0  TT5899MSH   PAID  2022-08-23T00:00 5,653.62
# 1  JN7493JY4   PAID  2022-08-23T00:00     4.79
# 2  J9T9MCL3X   PAID  2022-08-23T00:00   192.60
# 3  W5YK2YDLM   PAID  2022-08-23T00:00 3,449.36
# 4  PN7BXRJ6W   PAID  2022-08-23T00:00   349.76
#
#                   disbursement_batch_id                           merchant_id  \
# 0  eeb3b711-4ac2-4245-b2c9-980a40557d38  789e3e85-5fe8-41dd-ac03-9af6014dd9dd
# 1  eeb3b711-4ac2-4245-b2c9-980a40557d38  dcf51273-55ff-49df-af22-2286605324d5
# 2  eeb3b711-4ac2-4245-b2c9-980a40557d38  522ea0a4-0a91-426a-819f-7374320e51c9
# 3  eeb3b711-4ac2-4245-b2c9-980a40557d38  4b1fbe48-524f-49aa-aee9-38f7ca88ecb4
# 4  eeb3b711-4ac2-4245-b2c9-980a40557d38  cd3f18ca-c688-4990-99cc-a6e555d8494b
#
#                 CLABE                        bank_name  \
# 0  002180700433258663  Banco Nacional de MÃ©xico, S.A.
# 1  012456015691079750              BBVA Bancomer, S.A.
# 2  127180013315020086               Banco Azteca, S.A.
# 3  002375034170661780   Banco Nacional de México, S.A.
# 4  002040701757130328   Banco Nacional de México, S.A.
#
#            bank_account_owner_name       execution_date  ...  \
# 0  Maria del Rocio Duarte Aguirre   2022-08-23T13:09:50  ...
# 1   Jose De Jesus Mojica Rodrguez   2022-08-23T13:14:12  ...
# 2          Hector Galvan Hernandez  2022-08-23T13:08:11  ...
# 3         Santos Gloria Joya Rubio  2022-08-23T13:07:52  ...
# 4               Midori Shiba Cosio  2022-08-23T13:13:31  ...
#
#                                                  cep Date_respuesta  BIN  \
# 0  2022-08-23,2022082340014 HDH0001420224870,4001...     2022-08-23  002
# 1  2022-08-23,2022082340014 HDH0001420487250,4001...     2022-08-23  012
# 2  2022-08-23,2022082340014 HDH0001419891920,4001...     2022-08-23  127
# 3  2022-08-23,2022082340014 HDH0001419850510,4001...     2022-08-23  002
# 4  2022-08-23,2022082340014 HDH0001420348320,4001...     2022-08-23  002
#
#    Metodo de dispersion Clave de la institución Nombre de la institución  \
# 0             SANTANDER                   40002                  BANAMEX
# 1             SANTANDER                   40012            BBVA BANCOMER
# 2             SANTANDER                   40127                   AZTECA
# 3             SANTANDER                   40002                  BANAMEX
# 4             SANTANDER                   40002                  BANAMEX
#
#   Banco emisor Banco_emisor Comision  \
# 0        40014    SANTANDER
# 1        40014    SANTANDER
# 2        40014    SANTANDER
# 3        40014    SANTANDER
# 4        40014    SANTANDER
#
#                                            LINEA CEP
# 0  2022-08-23,2022082340014 HDH0001420224870,4001...
# 1  2022-08-23,2022082340014 HDH0001420487250,4001...
# 2  2022-08-23,2022082340014 HDH0001419891920,4001...
# 3  2022-08-23,2022082340014 HDH0001419850510,4001...
# 4  2022-08-23,2022082340014 HDH0001420348320,4001...
#
# [5 rows x 24 columns]

# %%
rs2.shape
# Out:
# (82221, 24)

# %% [markdown]
# # ARCHIVO DISPERSION

# %%
disp['date_disbursement'] = date_respuesta
disp['report_id'] = disp['report_id'].str.strip()
disp['report_date_local'] = pd.to_datetime(disp['report_date_local'])

# %%
disp.loc[disp['report_date_local'] == date_respuesta, 'tipo'] = 'Pago del día'
disp.loc[disp['report_date_local'] != date_respuesta, 'tipo'] = 'Reprogramación'
disp.drop(['bank_name','bank_account_number','status','swap','payment_date_local'],axis=1,inplace=True)
disp.head()
# Out:
#     type                           merchant_id                merchant_name  \
# 0  DAILY  0000d758-84b4-4cb0-a165-4f0d3c44864d  MAHARISHI PANTJALI SA DE CV
# 1  DAILY  0000e953-6b2c-44d0-a798-9dac1abf24ea                  Super Kandy
# 2  DAILY  00016126-0052-402d-ba8a-95e5e1a1c673      Seguridad Industrial OM
# 3  DAILY  00023bd5-6149-4ef9-95be-edb61d22588d                    LAS PEKES
# 4  DAILY  0003bb43-38fc-4893-bf1c-d287f8b41fd4                     Burgetto
#
#                    user_email  report_id report_date_local   amount  \
# 0     maharishiclip@gmail.com  PYBYG4S8S        2022-08-23   610.33
# 1  yanellysegovia18@gmail.com  8PF859N38        2022-08-23   998.45
# 2       jocabetolan@gmail.com  ZGG995FCC        2022-08-23 2,217.37
# 3    alebarradas1@hotmail.com  QQWZ7XGFR        2022-08-23   258.25
# 4         lh1162921@gmail.com  6NCWSWDV4        2022-08-23   809.71
#
#             bank_account_owner_name   batch_created_date disbursement_method  \
# 0   MAHARISHI PANTJALI S.A. DE C.V.  2022-08-23 08:03:24           SANTANDER
# 1      Ana Yanelly Puente Gutierrez  2022-08-23 08:03:24           SANTANDER
# 2    CYNTHIA JOCABET OLAN RODRIGUEZ  2022-08-23 08:03:24           SANTANDER
# 3  Virginia Alejandra Barradas Prez  2022-08-23 08:03:24           SANTANDER
# 4  Elia Gabriela Sandoval Tassinari  2022-08-23 08:03:24           SANTANDER
#
#   date_disbursement          tipo
# 0        2022-08-23  Pago del día
# 1        2022-08-23  Pago del día
# 2        2022-08-23  Pago del día
# 3        2022-08-23  Pago del día
# 4        2022-08-23  Pago del día

# %%
disp.shape
# Out:
# (82221, 12)

# %%
disp_2 = disp.merge(rs2[['report_id','status','Nombre de la institución','CLABE','LINEA CEP','Banco_emisor']]
                    ,on='report_id', how='left')
disp_2.loc[disp_2['status'] != 'PAID', 'status'] = 'ERROR'
disp_2.sort_values(by=['status'])
disp_2.head()
# Out:
#     type                           merchant_id                merchant_name  \
# 0  DAILY  0000d758-84b4-4cb0-a165-4f0d3c44864d  MAHARISHI PANTJALI SA DE CV
# 1  DAILY  0000e953-6b2c-44d0-a798-9dac1abf24ea                  Super Kandy
# 2  DAILY  00016126-0052-402d-ba8a-95e5e1a1c673      Seguridad Industrial OM
# 3  DAILY  00023bd5-6149-4ef9-95be-edb61d22588d                    LAS PEKES
# 4  DAILY  0003bb43-38fc-4893-bf1c-d287f8b41fd4                     Burgetto
#
#                    user_email  report_id report_date_local   amount  \
# 0     maharishiclip@gmail.com  PYBYG4S8S        2022-08-23   610.33
# 1  yanellysegovia18@gmail.com  8PF859N38        2022-08-23   998.45
# 2       jocabetolan@gmail.com  ZGG995FCC        2022-08-23 2,217.37
# 3    alebarradas1@hotmail.com  QQWZ7XGFR        2022-08-23   258.25
# 4         lh1162921@gmail.com  6NCWSWDV4        2022-08-23   809.71
#
#             bank_account_owner_name   batch_created_date disbursement_method  \
# 0   MAHARISHI PANTJALI S.A. DE C.V.  2022-08-23 08:03:24           SANTANDER
# 1      Ana Yanelly Puente Gutierrez  2022-08-23 08:03:24           SANTANDER
# 2    CYNTHIA JOCABET OLAN RODRIGUEZ  2022-08-23 08:03:24           SANTANDER
# 3  Virginia Alejandra Barradas Prez  2022-08-23 08:03:24           SANTANDER
# 4  Elia Gabriela Sandoval Tassinari  2022-08-23 08:03:24           SANTANDER
#
#   date_disbursement          tipo status Nombre de la institución  \
# 0        2022-08-23  Pago del día   PAID                 BANREGIO
# 1        2022-08-23  Pago del día   PAID                  BANAMEX
# 2        2022-08-23  Pago del día   PAID                  BANAMEX
# 3        2022-08-23  Pago del día   PAID                BANCOPPEL
# 4        2022-08-23  Pago del día   PAID            BBVA BANCOMER
#
#                 CLABE                                          LINEA CEP  \
# 0  058375000003160831  2022-08-23,2022082340014 HDH0001419962540,4001...
# 1  002580701334955664  2022-08-23,2022082340014 HDH0001419962440,4001...
# 2  002045701331339825  2022-08-23,2022082340014 HDH0001419962480,4001...
# 3  137463103868892825  2022-08-23,2022082340014 HDH0001419962580,4001...
# 4  012730015122265937  2022-08-23,2022082340014 HDH0001419962490,4001...
#
#   Banco_emisor
# 0    SANTANDER
# 1    SANTANDER
# 2    SANTANDER
# 3    SANTANDER
# 4    SANTANDER

# %%
disp_2.loc[disp_2['Nombre de la institución'] == 'SANTANDER', 'LINEA CEP'] = 'COMPROBANTE MISMO BANCO SANTANDER'
disp_2.loc[disp_2['status'] == 'ERROR', 'LINEA CEP'] = ''
disp_2.loc[disp_2['status'] == 'ERROR', 'Banco_emisor'] = ''

# %%
for col in disp_2.columns: 
    print(col)
# Out:
# type
# merchant_id
# merchant_name
# user_email
# report_id
# report_date_local
# amount
# bank_account_owner_name
# batch_created_date
# disbursement_method
# date_disbursement
# tipo
# status
# Nombre de la institución
# CLABE
# LINEA CEP
# Banco_emisor

# %%
disp_final = disp_2[['type','merchant_id','merchant_name','user_email','report_id','report_date_local','amount','tipo'
                    ,'Nombre de la institución','bank_account_owner_name','CLABE','status','LINEA CEP','Banco_emisor']]
disp_final.rename(columns ={'Nombre de la institución':'bank','amount':'total_due'}, inplace=True)
disp_final.sort_values(by=['status'], ascending=True, inplace=True)
disp_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_14320\1936322415.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disp_final.rename(columns ={'Nombre de la institución':'bank','amount':'total_due'}, inplace=True)
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_14320\1936322415.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disp_final.sort_values(by=['status'], ascending=True, inplace=True)
#         type                           merchant_id  \
# 66710  DAILY  cf842c28-eee3-43ae-9f9a-694c82ba1ba4
# 57057  DAILY  b1aed04f-2450-46a2-8b35-f8bf86e499d6
# 11089  DAILY  22bb083a-331e-4c5e-9440-98abddd927c3
# 43375  DAILY  86df6ed2-37d6-4db8-aa11-3309cf2c0f05
# 81552  DAILY  fdfb116c-0a62-4d91-9993-2916a47bf227
#
#                          merchant_name                    user_email  \
# 66710  Artesanias Y Articulos De Playa        jaime_rb31@hotmail.com
# 57057                Grupo AMI Angeles        gpe_gago79@hotmail.com
# 11089                Abarrotes claudia  abarrotesclaudia28@gmail.com
# 43375                        Limoncito           karelygat@gmail.com
# 81552                          Sb Lash          shaday002@icloud.com
#
#        report_id report_date_local  total_due          tipo           bank  \
# 66710  CGQDLX425        2022-08-23     939.08  Pago del día      SANTANDER
# 57057  4HTCC9FXS        2022-08-23   1,097.18  Pago del día    BANORTE/IXE
# 11089  CFW559WHT        2022-08-23     186.16  Pago del día  BBVA BANCOMER
# 43375  PPK7H863X        2022-08-23     335.38  Pago del día  BBVA BANCOMER
# 81552  B74FD8WTZ        2022-08-23   1,066.44  Pago del día       BANREGIO
#
#                bank_account_owner_name               CLABE status LINEA CEP  \
# 66710           Jaime Roman Bousieguez  014744605746307086  ERROR
# 57057            Guadalupe Garca Gomez  072010011473269142  ERROR
# 11089     Norma Aracely Camacho Nuncio  012580015927751045  ERROR
# 43375   Jess Missael Guardado Alvarado  012190015402793044  ERROR
# 81552  Shasta Lorena de la Cerda Lopez  058597000023174410  ERROR
#
#       Banco_emisor
# 66710
# 57057
# 11089
# 43375
# 81552

# %%
disp_final.shape
# Out:
# (82221, 14)

# %% [markdown]
# # ERROR

# %%
error = disp_final[(disp_final['status'] != 'PAID')]
error.head()
# Out:
#         type                           merchant_id  \
# 66710  DAILY  cf842c28-eee3-43ae-9f9a-694c82ba1ba4
# 57057  DAILY  b1aed04f-2450-46a2-8b35-f8bf86e499d6
# 11089  DAILY  22bb083a-331e-4c5e-9440-98abddd927c3
# 43375  DAILY  86df6ed2-37d6-4db8-aa11-3309cf2c0f05
# 81552  DAILY  fdfb116c-0a62-4d91-9993-2916a47bf227
#
#                          merchant_name                    user_email  \
# 66710  Artesanias Y Articulos De Playa        jaime_rb31@hotmail.com
# 57057                Grupo AMI Angeles        gpe_gago79@hotmail.com
# 11089                Abarrotes claudia  abarrotesclaudia28@gmail.com
# 43375                        Limoncito           karelygat@gmail.com
# 81552                          Sb Lash          shaday002@icloud.com
#
#        report_id report_date_local  total_due          tipo           bank  \
# 66710  CGQDLX425        2022-08-23     939.08  Pago del día      SANTANDER
# 57057  4HTCC9FXS        2022-08-23   1,097.18  Pago del día    BANORTE/IXE
# 11089  CFW559WHT        2022-08-23     186.16  Pago del día  BBVA BANCOMER
# 43375  PPK7H863X        2022-08-23     335.38  Pago del día  BBVA BANCOMER
# 81552  B74FD8WTZ        2022-08-23   1,066.44  Pago del día       BANREGIO
#
#                bank_account_owner_name               CLABE status LINEA CEP  \
# 66710           Jaime Roman Bousieguez  014744605746307086  ERROR
# 57057            Guadalupe Garca Gomez  072010011473269142  ERROR
# 11089     Norma Aracely Camacho Nuncio  012580015927751045  ERROR
# 43375   Jess Missael Guardado Alvarado  012190015402793044  ERROR
# 81552  Shasta Lorena de la Cerda Lopez  058597000023174410  ERROR
#
#       Banco_emisor
# 66710
# 57057
# 11089
# 43375
# 81552

# %%
error.shape
# Out:
# (402, 14)

# %%
error.drop(['bank_account_owner_name','CLABE','status','LINEA CEP','Banco_emisor'],axis=1,inplace=True)
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_14320\1215281788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   error.drop(['bank_account_owner_name','CLABE','status','LINEA CEP','Banco_emisor'],axis=1,inplace=True)

# %%
error.loc[error['bank'] == 'SANTANDER', 'Check'] = 'SPEI DEVUELTO MISMO BANCO'
error.loc[error['bank'] != 'SANTANDER', 'Check'] = 'SPEI DEVUELTO'
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_14320\2883469485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   error.loc[error['bank'] == 'SANTANDER', 'Check'] = 'SPEI DEVUELTO MISMO BANCO'

# %%
error_final = error.merge(rs2[['report_id','error_description']] ,on='report_id', how='left')
error_final.head()
# Out:
#     type                           merchant_id  \
# 0  DAILY  cf842c28-eee3-43ae-9f9a-694c82ba1ba4
# 1  DAILY  b1aed04f-2450-46a2-8b35-f8bf86e499d6
# 2  DAILY  22bb083a-331e-4c5e-9440-98abddd927c3
# 3  DAILY  86df6ed2-37d6-4db8-aa11-3309cf2c0f05
# 4  DAILY  fdfb116c-0a62-4d91-9993-2916a47bf227
#
#                      merchant_name                    user_email  report_id  \
# 0  Artesanias Y Articulos De Playa        jaime_rb31@hotmail.com  CGQDLX425
# 1                Grupo AMI Angeles        gpe_gago79@hotmail.com  4HTCC9FXS
# 2                Abarrotes claudia  abarrotesclaudia28@gmail.com  CFW559WHT
# 3                        Limoncito           karelygat@gmail.com  PPK7H863X
# 4                          Sb Lash          shaday002@icloud.com  B74FD8WTZ
#
#   report_date_local  total_due          tipo           bank  \
# 0        2022-08-23     939.08  Pago del día      SANTANDER
# 1        2022-08-23   1,097.18  Pago del día    BANORTE/IXE
# 2        2022-08-23     186.16  Pago del día  BBVA BANCOMER
# 3        2022-08-23     335.38  Pago del día  BBVA BANCOMER
# 4        2022-08-23   1,066.44  Pago del día       BANREGIO
#
#                        Check error_description
# 0  SPEI DEVUELTO MISMO BANCO                P6
# 1              SPEI DEVUELTO                DN
# 2              SPEI DEVUELTO                DM
# 3              SPEI DEVUELTO                DM
# 4              SPEI DEVUELTO                DA

# %%
error_final.shape
# Out:
# (402, 11)

# %% [markdown]
# # ARCHIVOS FINALES

# %% [markdown]
# ### ARCHIVO DISPERSION

# %%
writer = pd.ExcelWriter(excel_name, engine='xlsxwriter', engine_kwargs={'options': {'encoding':'utf-8'}})
disp_final.to_excel(writer, sheet_name='Swap del día',index=False)
error_final.to_excel(writer, sheet_name='ERROR',index=False)
writer.close()

# %% [markdown]
# ### ARCHIVO RESPUESTA

# %%
rs2.head()
# Out:
#    report_id status report_date_local   amount  \
# 0  TT5899MSH   PAID  2022-08-23T00:00 5,653.62
# 1  JN7493JY4   PAID  2022-08-23T00:00     4.79
# 2  J9T9MCL3X   PAID  2022-08-23T00:00   192.60
# 3  W5YK2YDLM   PAID  2022-08-23T00:00 3,449.36
# 4  PN7BXRJ6W   PAID  2022-08-23T00:00   349.76
#
#                   disbursement_batch_id                           merchant_id  \
# 0  eeb3b711-4ac2-4245-b2c9-980a40557d38  789e3e85-5fe8-41dd-ac03-9af6014dd9dd
# 1  eeb3b711-4ac2-4245-b2c9-980a40557d38  dcf51273-55ff-49df-af22-2286605324d5
# 2  eeb3b711-4ac2-4245-b2c9-980a40557d38  522ea0a4-0a91-426a-819f-7374320e51c9
# 3  eeb3b711-4ac2-4245-b2c9-980a40557d38  4b1fbe48-524f-49aa-aee9-38f7ca88ecb4
# 4  eeb3b711-4ac2-4245-b2c9-980a40557d38  cd3f18ca-c688-4990-99cc-a6e555d8494b
#
#                 CLABE                        bank_name  \
# 0  002180700433258663  Banco Nacional de MÃ©xico, S.A.
# 1  012456015691079750              BBVA Bancomer, S.A.
# 2  127180013315020086               Banco Azteca, S.A.
# 3  002375034170661780   Banco Nacional de México, S.A.
# 4  002040701757130328   Banco Nacional de México, S.A.
#
#            bank_account_owner_name       execution_date  ...  \
# 0  Maria del Rocio Duarte Aguirre   2022-08-23T13:09:50  ...
# 1   Jose De Jesus Mojica Rodrguez   2022-08-23T13:14:12  ...
# 2          Hector Galvan Hernandez  2022-08-23T13:08:11  ...
# 3         Santos Gloria Joya Rubio  2022-08-23T13:07:52  ...
# 4               Midori Shiba Cosio  2022-08-23T13:13:31  ...
#
#                                                  cep Date_respuesta  BIN  \
# 0  2022-08-23,2022082340014 HDH0001420224870,4001...     2022-08-23  002
# 1  2022-08-23,2022082340014 HDH0001420487250,4001...     2022-08-23  012
# 2  2022-08-23,2022082340014 HDH0001419891920,4001...     2022-08-23  127
# 3  2022-08-23,2022082340014 HDH0001419850510,4001...     2022-08-23  002
# 4  2022-08-23,2022082340014 HDH0001420348320,4001...     2022-08-23  002
#
#    Metodo de dispersion Clave de la institución Nombre de la institución  \
# 0             SANTANDER                   40002                  BANAMEX
# 1             SANTANDER                   40012            BBVA BANCOMER
# 2             SANTANDER                   40127                   AZTECA
# 3             SANTANDER                   40002                  BANAMEX
# 4             SANTANDER                   40002                  BANAMEX
#
#   Banco emisor Banco_emisor Comision  \
# 0        40014    SANTANDER
# 1        40014    SANTANDER
# 2        40014    SANTANDER
# 3        40014    SANTANDER
# 4        40014    SANTANDER
#
#                                            LINEA CEP
# 0  2022-08-23,2022082340014 HDH0001420224870,4001...
# 1  2022-08-23,2022082340014 HDH0001420487250,4001...
# 2  2022-08-23,2022082340014 HDH0001419891920,4001...
# 3  2022-08-23,2022082340014 HDH0001419850510,4001...
# 4  2022-08-23,2022082340014 HDH0001420348320,4001...
#
# [5 rows x 24 columns]

# %%
rs_final = rs2[['disbursement_tracking_key','bank_account_owner_name','report_id','CLABE',
                'Nombre de la institución','amount','Comision','status','error_description','Date_respuesta',
                'Metodo de dispersion']]
rs_final.rename(columns = {'disbursement_tracking_key':'Rastreo CEP'
                           ,'bank_account_owner_name':'Nombre','CLABE':'Cuenta'
                           ,'Nombre de la institución':'Banco','amount':'Importe','status':'Estatus'
                           ,'error_description':'Mensaje'}, inplace=True)
rs_final['Cuenta'] = "'"+rs_final['Cuenta']
rs_final.sort_values(by=['Estatus'], ascending=True, inplace=True)
rs_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_14320\828709770.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rs_final.rename(columns = {'disbursement_tracking_key':'Rastreo CEP'
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_14320\828709770.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rs_final['Cuenta'] = "'"+rs_final['Cuenta']
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_14320\828709770.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rs_final.sort_values(by=['Estatus'], ascending=True, inplace=True)
#                           Rastreo CEP                        Nombre  \
# 38473  2022082340014 HDH0001420176780    JANNELY SARAHI LOPEZ OBESO
# 8208   2022082340014 HDH0001420208730        Ana Karen Ortega Nunez
# 60526  2022082340014 HDH0001420436090       Alondra Figueroa Huerta
# 10002  2022082340014 HDH0001420503560           Rebeca Vidal Terron
# 4285   2022082340014 HDH0001420070680  Iris Zoraina Alvarez Delgado
#
#        report_id               Cuenta          Banco  Importe Comision  \
# 38473  LW25NQ83V  '012730015192380648  BBVA BANCOMER 2,654.32
# 8208   WGXH3XQQ5  '012180015593249022  BBVA BANCOMER 1,471.18
# 60526  8PSQXX24B  '012180029393733494  BBVA BANCOMER 1,835.28
# 10002  8NBD72FPD  '130877001047848903    COMPARTAMOS     1.20
# 4285   335NK72HX  '012818015197476369  BBVA BANCOMER   536.62
#
#       Estatus Mensaje Date_respuesta Metodo de dispersion
# 38473   ERROR      DM     2022-08-23            SANTANDER
# 8208    ERROR      DM     2022-08-23            SANTANDER
# 60526   ERROR      DA     2022-08-23            SANTANDER
# 10002   ERROR      DI     2022-08-23            SANTANDER
# 4285    ERROR      DM     2022-08-23            SANTANDER

# %%
rs_final.shape
# Out:
# (82221, 11)

# %%
rs_final.to_csv(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\Respuestas Swap\2022\08. Agosto 2022\Respuesta 2022-08-23.csv',index=False)
