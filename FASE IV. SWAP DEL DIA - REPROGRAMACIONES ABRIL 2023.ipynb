# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # MES AÑO DE CONCILIACIÓN

# %%
month_conc = 'April'
year_conc = '2023'

# %% [markdown]
# # RUTAS DE ACCESO

# %% [markdown]
# ### SWAP DEL DIA

# %%
allfiles_disp_trad = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2023\04. ABRIL\ARCHIVO DISPERSIONES\Dispersión*.xlsx', recursive=False)
allfiles_disp_trad
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230401.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230402.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230403.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230404.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230405.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230406.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230407.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230408.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230409.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230410.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230411.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230412.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230413.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230414.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230415.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230416.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230417.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230418.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230419.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230420.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230421.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230422.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230423.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230424.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230425.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230426.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230427.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230428.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230429.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES\\Dispersión-20230430.xlsx']

# %% [markdown]
# ### FAST PAYMENTS

# %%
allfiles_fp = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2023\04. ABRIL\ARCHIVO DISPERSIONES FP\Dispersión-FP*.xlsx',recursive=False)
allfiles_fp
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-01.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-02.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-03.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-04.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-05.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-06.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-07.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-08.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-09.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-10.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-11.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-12.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-13.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-14.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-15.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-16.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-17.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-18.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-19.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-20.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-21.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-22.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-23.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-24.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-25.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-26.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-27.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-28.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-29.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\04. ABRIL\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-04-30.xlsx']

# %% [markdown]
# # SWAP DEL DIA

# %%
swap_dia_total = pd.concat([pd.read_excel(f,sheet_name = 'Swap del día')
                            .assign(file_name=os.path.basename(f)) for f in allfiles_disp_trad])
swap_dia_total['Date'] = swap_dia_total["file_name"].str[-13:-5]
swap_dia_total['Date']= pd.to_datetime(swap_dia_total['Date'], format='%Y%m%d').dt.date
swap_dia_total['Date']= pd.to_datetime(swap_dia_total['Date'])
swap_dia_total.sort_values(by=['Date'],ascending=True,inplace=True)
swap_dia_total['report_date_local']= pd.to_datetime(swap_dia_total['report_date_local'])
swap_dia_total['month_conc'] = month_conc
swap_dia_total['year_conc'] = year_conc
swap_dia_total['month_report'] = swap_dia_total['report_date_local'].dt.strftime('%B')
swap_dia_total['year_report'] = swap_dia_total['report_date_local'].dt.year.astype(str)
swap_dia_total.head()
# Out:
#               type                           merchant_id merchant_name  \
# 0      LEDGER_TRAD  00e3f30a-d0f3-4899-afa6-ad9fcb61bca6           NaN
# 77115  LEDGER_TRAD  aa403b22-4da1-4632-9516-5af6e9121c1e           NaN
# 77114  LEDGER_TRAD  aa40151a-55fe-45d1-af1d-5d388b17f7aa           NaN
# 77113  LEDGER_TRAD  aa3f5789-e40d-4d48-a984-ac2e03ff7505           NaN
# 77112  LEDGER_TRAD  aa3ed455-10a2-4f9a-9b07-f9d945f9b4ac           NaN
#
#       user_email  report_id report_date_local  total_due          tipo  \
# 0            NaN  A3HQ5QWZS        2023-04-01       4.00  Pago del día
# 77115        NaN  AMB5BNLBR        2023-04-01     209.85  Pago del día
# 77114        NaN  ARPJ268MM        2023-04-01   1,705.67  Pago del día
# 77113        NaN  ATHWYQX6C        2023-04-01   4,588.04  Pago del día
# 77112        NaN  A4YVLQLDW        2023-04-01     943.86  Pago del día
#
#                 bank     bank_account_owner_name  ...  status  \
# 0      BBVA BANCOMER              Daniel Vasquez  ...   ERROR
# 77115  BBVA BANCOMER   Jose David Ruiz Dominguez  ...    PAID
# 77114  BBVA BANCOMER      Ega Creativos SA De CV  ...    PAID
# 77113         AZTECA  Maricela Antonio Florente   ...    PAID
# 77112         AZTECA    Ricardo Ruvalcaba Lomeli  ...    PAID
#
#                                                LINEA CEP       Batch_time  \
# 0                                                    NaN  01. First_batch
# 77115  2023-04-01,42644264202304012215759817,40072,40...  01. First_batch
# 77114  2023-04-01,42644264202304012215676750,40072,40...  01. First_batch
# 77113  2023-04-01,42644264202304012215733238,40072,40...  01. First_batch
# 77112  2023-04-01,42644264202304012215787291,40072,40...  01. First_batch
#
#       Banco_emisor                 file_name       Date month_conc year_conc  \
# 0          BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77115      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77114      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77113      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77112      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
#
#       month_report year_report
# 0            April        2023
# 77115        April        2023
# 77114        April        2023
# 77113        April        2023
# 77112        April        2023
#
# [5 rows x 21 columns]

# %%
swap_dia_total.shape
# Out:
# (2916668, 21)

# %%
swap_dia_total.dtypes
# Out:
# type                               object
# merchant_id                        object
# merchant_name                      object
# user_email                         object
# report_id                          object
# report_date_local          datetime64[ns]
# total_due                         float64
# tipo                               object
# bank                               object
# bank_account_owner_name            object
# CLABE                             float64
# status                             object
# LINEA CEP                          object
# Batch_time                         object
# Banco_emisor                       object
# file_name                          object
# Date                       datetime64[ns]
# month_conc                         object
# year_conc                          object
# month_report                       object
# year_report                        object
# dtype: object

# %% [markdown]
# # FAST PAYMENTS

# %%
fp_dia_total = pd.concat([pd.read_excel(f,sheet_name='FAST PAYMENTS')
                          .assign(file_name=os.path.basename(f)) for f in allfiles_fp])
fp_dia_total['Date'] = fp_dia_total["file_name"].str[-15:-5]
fp_dia_total['Date']= pd.to_datetime(fp_dia_total['Date'])
fp_dia_total['report_date_local']= pd.to_datetime(fp_dia_total['report_date_local'])
fp_dia_total['month_conc'] = month_conc
fp_dia_total['year_conc'] = year_conc
fp_dia_total['month_report'] = fp_dia_total['report_date_local'].dt.strftime('%B')
fp_dia_total['year_report'] = fp_dia_total['report_date_local'].dt.year.astype(str)
fp_dia_total.head()
# Out:
#         type                           merchant_id merchant_name user_email  \
# 0  LEDGER_FP  0f597b97-f5ad-4f28-9ded-ad443697e60c           NaN        NaN
# 1  LEDGER_FP  2304f819-d1fd-4253-a877-394ea269c4c6           NaN        NaN
# 2  LEDGER_FP  987b5d05-f330-4462-9d7e-214c010754bf           NaN        NaN
# 3  LEDGER_FP  ba76e989-812a-4ad8-a5e7-b44f49cce6c7           NaN        NaN
# 4  LEDGER_FP  1ac019e2-402e-49ea-87cc-11bc1dcc8e48           NaN        NaN
#
#    report_id report_date_local  total_due          tipo             bank  \
# 0  AZZJ3RRYR        2023-04-01       6.00  Pago del día  ASP INTEGRA OPC
# 1  AZS934LLS        2023-04-01     191.65  Pago del día  ASP INTEGRA OPC
# 2  A9ZQZ5NBZ        2023-04-01     173.44  Pago del día  ASP INTEGRA OPC
# 3  AP5Q4BRFS        2023-04-01       0.40  Pago del día  ASP INTEGRA OPC
# 4  AYKC6FKBQ        2023-04-01     191.65  Pago del día  ASP INTEGRA OPC
#
#                                 swap  ...  status LINEA CEP        Batch_time  \
# 0    Ricardo Aurelio Bojorquez Ceron  ...   ERROR       NaN  02. Second_batch
# 1  Norma Margarita Delgado Rodriguez  ...   ERROR       NaN  02. Second_batch
# 2     Juan Ricardo Rodriguez Tenorio  ...   ERROR       NaN  02. Second_batch
# 3                          Ivn Arias  ...   ERROR       NaN  02. Second_batch
# 4          Victor Hugo Perez Montero  ...   ERROR       NaN   03. Third_batch
#
#   Banco_emisor                      file_name       Date month_conc year_conc  \
# 0      BANORTE  Dispersión-FP 2023-04-01.xlsx 2023-04-01      April      2023
# 1      BANORTE  Dispersión-FP 2023-04-01.xlsx 2023-04-01      April      2023
# 2      BANORTE  Dispersión-FP 2023-04-01.xlsx 2023-04-01      April      2023
# 3      BANORTE  Dispersión-FP 2023-04-01.xlsx 2023-04-01      April      2023
# 4      BANORTE  Dispersión-FP 2023-04-01.xlsx 2023-04-01      April      2023
#
#   month_report year_report
# 0        April        2023
# 1        April        2023
# 2        April        2023
# 3        April        2023
# 4        April        2023
#
# [5 rows x 21 columns]

# %%
fp_dia_total.shape
# Out:
# (91638, 21)

# %%
fp_dia_total.dtypes
# Out:
# type                         object
# merchant_id                  object
# merchant_name                object
# user_email                   object
# report_id                    object
# report_date_local    datetime64[ns]
# total_due                   float64
# tipo                         object
# bank                         object
# swap                         object
# CLABE                         int64
# status                       object
# LINEA CEP                    object
# Batch_time                   object
# Banco_emisor                 object
# file_name                    object
# Date                 datetime64[ns]
# month_conc                   object
# year_conc                    object
# month_report                 object
# year_report                  object
# dtype: object

# %% [markdown]
# # ALL DISPERSIONES

# %%
all_disp = pd.concat([swap_dia_total,fp_dia_total])
all_disp.loc[all_disp['type'].str.contains('LEDGER'), 'type'] = 'LEDGER'
all_disp.head()
# Out:
#          type                           merchant_id merchant_name user_email  \
# 0      LEDGER  00e3f30a-d0f3-4899-afa6-ad9fcb61bca6           NaN        NaN
# 77115  LEDGER  aa403b22-4da1-4632-9516-5af6e9121c1e           NaN        NaN
# 77114  LEDGER  aa40151a-55fe-45d1-af1d-5d388b17f7aa           NaN        NaN
# 77113  LEDGER  aa3f5789-e40d-4d48-a984-ac2e03ff7505           NaN        NaN
# 77112  LEDGER  aa3ed455-10a2-4f9a-9b07-f9d945f9b4ac           NaN        NaN
#
#        report_id report_date_local  total_due          tipo           bank  \
# 0      A3HQ5QWZS        2023-04-01       4.00  Pago del día  BBVA BANCOMER
# 77115  AMB5BNLBR        2023-04-01     209.85  Pago del día  BBVA BANCOMER
# 77114  ARPJ268MM        2023-04-01   1,705.67  Pago del día  BBVA BANCOMER
# 77113  ATHWYQX6C        2023-04-01   4,588.04  Pago del día         AZTECA
# 77112  A4YVLQLDW        2023-04-01     943.86  Pago del día         AZTECA
#
#           bank_account_owner_name  ...  \
# 0                  Daniel Vasquez  ...
# 77115   Jose David Ruiz Dominguez  ...
# 77114      Ega Creativos SA De CV  ...
# 77113  Maricela Antonio Florente   ...
# 77112    Ricardo Ruvalcaba Lomeli  ...
#
#                                                LINEA CEP       Batch_time  \
# 0                                                    NaN  01. First_batch
# 77115  2023-04-01,42644264202304012215759817,40072,40...  01. First_batch
# 77114  2023-04-01,42644264202304012215676750,40072,40...  01. First_batch
# 77113  2023-04-01,42644264202304012215733238,40072,40...  01. First_batch
# 77112  2023-04-01,42644264202304012215787291,40072,40...  01. First_batch
#
#       Banco_emisor                 file_name       Date month_conc year_conc  \
# 0          BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77115      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77114      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77113      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77112      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
#
#       month_report year_report swap
# 0            April        2023  NaN
# 77115        April        2023  NaN
# 77114        April        2023  NaN
# 77113        April        2023  NaN
# 77112        April        2023  NaN
#
# [5 rows x 22 columns]

# %%
all_disp.shape
# Out:
# (3008306, 22)

# %%
all_disp['type'].unique()
# Out:
# array(['LEDGER', 'DAILY', 'INSTANT'], dtype=object)

# %% [markdown]
# # TRADICIONAL

# %%
all_disp_trad = all_disp[(all_disp['type'] == 'DAILY')]
all_disp_trad.head()
# Out:
#         type                           merchant_id  \
# 76916  DAILY  a9d6d5b9-05a6-4e3d-a683-019b6e9f562e
# 76899  DAILY  a9d21b0d-9eac-479b-8e29-2a8108097170
# 76820  DAILY  a9a47c8f-9292-44ec-85ec-81df6fc5bdcc
# 76836  DAILY  a9ad34a3-8b4e-42db-9a06-e505474db2c4
# 76924  DAILY  a9da74ea-051f-445e-ac8e-e13cd6e50183
#
#                              merchant_name                      user_email  \
# 76916                                  Joy          flaquita1785@gmail.com
# 76899                       Escena Tapatia         escenatapatia@gmail.com
# 76820  Proveedores Y Servicios Industriale    sergiodominguez297@gmail.com
# 76836                 Los Dulces del Norte        p.mondragon.dl@gmail.com
# 76924           Deposito Los Tres Carnales  brayan_sanchez_2002@outlook.es
#
#        report_id report_date_local  total_due          tipo           bank  \
# 76916  F9TVWH7MB        2023-04-01       3.00  Pago del día  BBVA BANCOMER
# 76899  KWGW4G5FX        2023-04-01       1.20  Pago del día      SANTANDER
# 76820  XBLDGZ588        2023-04-01       4.00  Pago del día      SANTANDER
# 76836  442JLFPQ7        2023-04-01       6.00  Pago del día  BBVA BANCOMER
# 76924  B4X2TPZTC        2023-04-01       3.00  Pago del día      BANCOPPEL
#
#                     bank_account_owner_name  ...  \
# 76916                 Raquel Jimenez Garcia  ...
# 76899  Montserrat Alejandra Bellomo Sanchez  ...
# 76820                 Angelina Castro Gomez  ...
# 76836        Paulina Mondragon Diaz de Leon  ...
# 76924                        Adrian Sanchez  ...
#
#                                                LINEA CEP       Batch_time  \
# 76916  2023-04-01,42644264202304012215705548,40072,40...  01. First_batch
# 76899  2023-04-01,42644264202304012215676493,40072,40...  01. First_batch
# 76820  2023-04-01,42644264202304012215759600,40072,40...  01. First_batch
# 76836  2023-04-01,42644264202304012215705489,40072,40...  01. First_batch
# 76924  2023-04-01,42644264202304012215676514,40072,40...  01. First_batch
#
#       Banco_emisor                 file_name       Date month_conc year_conc  \
# 76916      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 76899      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 76820      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 76836      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 76924      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
#
#       month_report year_report swap
# 76916        April        2023  NaN
# 76899        April        2023  NaN
# 76820        April        2023  NaN
# 76836        April        2023  NaN
# 76924        April        2023  NaN
#
# [5 rows x 22 columns]

# %%
all_disp_trad.shape
# Out:
# (40552, 22)

# %%
pivot_total_trad = pd.pivot_table(all_disp_trad,index=['type','Date'],values=['total_due'],
                                  aggfunc = ['sum', len],
                                  margins=True)
pivot_total_trad.reset_index(drop=False, inplace=True)
pivot_total_trad.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1759428005.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_total_trad = pd.pivot_table(all_disp_trad,index=['type','Date'],values=['total_due'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1759428005.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_total_trad = pd.pivot_table(all_disp_trad,index=['type','Date'],values=['total_due'],
#     type       Date        sum       len
#                      total_due total_due
# 0  DAILY 2023-04-01 788,566.27      1672
# 1  DAILY 2023-04-02 919,971.13      1477
# 2  DAILY 2023-04-03 358,936.99       975
# 3  DAILY 2023-04-04 702,130.86      1656
# 4  DAILY 2023-04-05 378,716.79      1301

# %%
pivot_parcial_trad = pd.pivot_table(all_disp_trad,index=['type','tipo','Date'],
                               columns=['status'],values=['total_due'],aggfunc = ['sum', len],margins=True)
pivot_parcial_trad.reset_index(drop=False, inplace=True)
pivot_parcial_trad.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3208080861.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_parcial_trad = pd.pivot_table(all_disp_trad,index=['type','tipo','Date'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3208080861.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_parcial_trad = pd.pivot_table(all_disp_trad,index=['type','tipo','Date'],
#          type          tipo       Date       sum                        \
#                                        total_due
# status                                     ERROR       PAID        All
# 0       DAILY  Pago del día 2023-04-01     34.00 148,015.63 148,049.63
# 1       DAILY  Pago del día 2023-04-02     54.00 762,873.01 762,927.01
# 2       DAILY  Pago del día 2023-04-03     23.60 250,912.07 250,935.67
# 3       DAILY  Pago del día 2023-04-04    107.60  60,927.78  61,035.38
# 4       DAILY  Pago del día 2023-04-05     30.20 201,082.48 201,112.68
#
#              len
#        total_due
# status     ERROR     PAID   All
# 0           6.00 1,369.00  1375
# 1          10.00 1,228.00  1238
# 2           7.00   865.00   872
# 3           6.00 1,464.00  1470
# 4           3.00 1,144.00  1147

# %% [markdown]
# ## CATEGORIZACIÓN DE REPROGRAMACIONES

# %%
swap_dia_total_repro = all_disp_trad[(all_disp_trad['tipo'] == 'Reprogramación')]
swap_dia_total_repro.head()
# Out:
#         type                           merchant_id       merchant_name  \
# 78701  DAILY  adac632a-4b27-4484-b9a1-57b9a91f1a32       La wera sport
# 74597  DAILY  a475daa4-44c5-4f3a-8f1a-71da255f4331           Sushi mi
# 80866  DAILY  b269fe1a-8eb7-41aa-9395-c54c5e00506c  Rosticeria La Loma
# 82403  DAILY  b5da41ec-b915-4ead-9379-8fbe5e724fb6              ventas
# 62176  DAILY  893e99fc-b70e-4c02-83f9-a8a653f71766            MC STORE
#
#                            user_email  report_id report_date_local  total_due  \
# 78701  carmencalderon121704@gmail.com  ZPRHMNPRR        2023-03-23       0.01
# 74597          20223ct023@utez.edu.mx  J5NPVKCMV        2023-03-31       0.40
# 80866           alderglxya5@gmail.com  WCYZDNNCV        2023-03-23       0.95
# 82403       addybasterisc@hotmail.com  6XJH5D4FP        2022-10-26   1,188.81
# 62176   conchitaruizrosas@hotmail.com  N8RBDG9RD        2023-03-22   6,707.68
#
#                  tipo           bank            bank_account_owner_name  ...  \
# 78701  Reprogramación  BBVA BANCOMER          Jose Alberto Lopez Romero  ...
# 74597  Reprogramación           HSBC                           Santiago  ...
# 80866  Reprogramación  BBVA BANCOMER  Hector Manuel Valenzuela Gonzales  ...
# 82403  Reprogramación  BBVA BANCOMER               GRUPO BACMO SA DE CV  ...
# 62176  Reprogramación  BBVA BANCOMER        MARIA CONCEPCION RUIZ ROSAS  ...
#
#                                                LINEA CEP       Batch_time  \
# 78701  2023-04-01,42644264202304012215734486,40072,40...  01. First_batch
# 74597  2023-04-01,42644264202304012215757755,40072,40...  01. First_batch
# 80866  2023-04-01,42644264202304012215709345,40072,40...  01. First_batch
# 82403  2023-04-01,42644264202304012215681461,40072,40...  01. First_batch
# 62176  2023-04-01,42644264202304012215800689,40072,40...  01. First_batch
#
#       Banco_emisor                 file_name       Date month_conc year_conc  \
# 78701      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 74597      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 80866      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 82403      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 62176      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
#
#       month_report year_report swap
# 78701        March        2023  NaN
# 74597        March        2023  NaN
# 80866        March        2023  NaN
# 82403      October        2022  NaN
# 62176        March        2023  NaN
#
# [5 rows x 22 columns]

# %%
swap_dia_total_repro.shape
# Out:
# (4470, 22)

# %%
swap_dia_total_repro.to_excel('Reprogramaciones_daily.xlsx',index=False)

# %%
swap_dia_total_repro.loc[(swap_dia_total_repro['tipo'] == 'Reprogramación')
                   & (swap_dia_total_repro['month_report'] == month_conc) 
                   & (swap_dia_total_repro['year_report'] == year_conc),'tipo_reprogramacion'] = 'repro_mismo_mes'
swap_dia_total_repro['tipo_reprogramacion'].fillna('repro_otro_mes',inplace=True)
swap_dia_total_repro.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\2042991903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swap_dia_total_repro.loc[(swap_dia_total_repro['tipo'] == 'Reprogramación')
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\2042991903.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swap_dia_total_repro['tipo_reprogramacion'].fillna('repro_otro_mes',inplace=True)
#         type                           merchant_id       merchant_name  \
# 78701  DAILY  adac632a-4b27-4484-b9a1-57b9a91f1a32       La wera sport
# 74597  DAILY  a475daa4-44c5-4f3a-8f1a-71da255f4331           Sushi mi
# 80866  DAILY  b269fe1a-8eb7-41aa-9395-c54c5e00506c  Rosticeria La Loma
# 82403  DAILY  b5da41ec-b915-4ead-9379-8fbe5e724fb6              ventas
# 62176  DAILY  893e99fc-b70e-4c02-83f9-a8a653f71766            MC STORE
#
#                            user_email  report_id report_date_local  total_due  \
# 78701  carmencalderon121704@gmail.com  ZPRHMNPRR        2023-03-23       0.01
# 74597          20223ct023@utez.edu.mx  J5NPVKCMV        2023-03-31       0.40
# 80866           alderglxya5@gmail.com  WCYZDNNCV        2023-03-23       0.95
# 82403       addybasterisc@hotmail.com  6XJH5D4FP        2022-10-26   1,188.81
# 62176   conchitaruizrosas@hotmail.com  N8RBDG9RD        2023-03-22   6,707.68
#
#                  tipo           bank            bank_account_owner_name  ...  \
# 78701  Reprogramación  BBVA BANCOMER          Jose Alberto Lopez Romero  ...
# 74597  Reprogramación           HSBC                           Santiago  ...
# 80866  Reprogramación  BBVA BANCOMER  Hector Manuel Valenzuela Gonzales  ...
# 82403  Reprogramación  BBVA BANCOMER               GRUPO BACMO SA DE CV  ...
# 62176  Reprogramación  BBVA BANCOMER        MARIA CONCEPCION RUIZ ROSAS  ...
#
#             Batch_time Banco_emisor                 file_name       Date  \
# 78701  01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 74597  01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 80866  01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 82403  01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 62176  01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
#
#       month_conc year_conc month_report year_report swap tipo_reprogramacion
# 78701      April      2023        March        2023  NaN      repro_otro_mes
# 74597      April      2023        March        2023  NaN      repro_otro_mes
# 80866      April      2023        March        2023  NaN      repro_otro_mes
# 82403      April      2023      October        2022  NaN      repro_otro_mes
# 62176      April      2023        March        2023  NaN      repro_otro_mes
#
# [5 rows x 23 columns]

# %%
pivot_tipo_repro = pd.pivot_table(swap_dia_total_repro,index=['type','Date'],
                                  columns=['tipo_reprogramacion'],
                                  values=['total_due']
                                  ,aggfunc = ['sum', len],margins=True)
pivot_tipo_repro.reset_index(drop=False, inplace=True)
pivot_tipo_repro.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3187504787.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_tipo_repro = pd.pivot_table(swap_dia_total_repro,index=['type','Date'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3187504787.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_tipo_repro = pd.pivot_table(swap_dia_total_repro,index=['type','Date'],
#                       type       Date             sum                 \
#                                             total_due
# tipo_reprogramacion                   repro_mismo_mes repro_otro_mes
# 0                    DAILY 2023-04-01             NaN     640,516.64
# 1                    DAILY 2023-04-02            1.20     157,042.92
# 2                    DAILY 2023-04-03           54.72     107,946.60
# 3                    DAILY 2023-04-04           16.60     641,078.88
# 4                    DAILY 2023-04-05           43.00     177,561.11
#
#                                            len
#                                      total_due
# tipo_reprogramacion        All repro_mismo_mes repro_otro_mes  All
# 0                   640,516.64             NaN         297.00  297
# 1                   157,044.12            1.00         238.00  239
# 2                   108,001.32           21.00          82.00  103
# 3                   641,095.48            5.00         181.00  186
# 4                   177,604.11           10.00         144.00  154

# %% [markdown]
# # FAST PAYMENTS

# %%
all_disp_fp = all_disp[(all_disp['type'] == 'INSTANT')]
all_disp_fp.head()
# Out:
#            type                           merchant_id    merchant_name  \
# 69161   INSTANT  986a86e9-b775-4cc8-881a-aff2dae3f623      Tienda Lety
# 114880  INSTANT  fe3744fa-eefe-4ae5-be45-f497e55d6cc2  Plan B SA de CV
# 24257   INSTANT  3585b3b9-7179-458b-bcab-bdf959febe62         Nukumori
# 24258   INSTANT  3585b3b9-7179-458b-bcab-bdf959febe62         Nukumori
# 111906  INSTANT  eae670dc-d948-4f27-96c4-2bc7e1e61a68         Polleria
#
#                          user_email  report_id report_date_local  total_due  \
# 69161   javierpacheco1004@gmail.com  9KGBR5ZTN        2022-01-20      33.54
# 114880          marebrica@yahoo.com  FRM8CCCCW        2023-03-22   2,874.72
# 24257        emma.mendoza@gmail.com  QYKFWZ8KL        2023-03-19   1,130.72
# 24258        emma.mendoza@gmail.com  WZ35TGBXQ        2023-03-19       0.95
# 111906    reynaargueyes12@gmail.com  34SL6MBSW        2022-01-07     145.08
#
#                   tipo           bank        bank_account_owner_name  ...  \
# 69161   Reprogramación         AZTECA          Javier Rivera Pacheco  ...
# 114880  Reprogramación       BANREGIO  Carlos Gustavo Quintero Ramos  ...
# 24257   Reprogramación  BBVA BANCOMER          Emma Mendoza Martinez  ...
# 24258   Reprogramación  BBVA BANCOMER          Emma Mendoza Martinez  ...
# 111906  Reprogramación       BANREGIO    Reyna Esther Arias Argueyes  ...
#
#                                                 LINEA CEP        Batch_time  \
# 69161   2023-04-01,42644264202304012215698459,40072,40...   01. First_batch
# 114880  2023-04-01,42644264202304012215812706,40072,40...  02. Second_batch
# 24257   2023-04-01,42644264202304012215686060,40072,40...   01. First_batch
# 24258   2023-04-01,42644264202304012215768175,40072,40...   01. First_batch
# 111906  2023-04-02,42644264202304022217259049,40072,40...  02. Second_batch
#
#        Banco_emisor                 file_name       Date month_conc year_conc  \
# 69161       BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 114880      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 24257       BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 24258       BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 111906      BANORTE  Dispersión-20230402.xlsx 2023-04-02      April      2023
#
#        month_report year_report swap
# 69161       January        2022  NaN
# 114880        March        2023  NaN
# 24257         March        2023  NaN
# 24258         March        2023  NaN
# 111906      January        2022  NaN
#
# [5 rows x 22 columns]

# %%
all_disp_fp.shape
# Out:
# (298, 22)

# %%
pivot_total_fp = pd.pivot_table(all_disp_fp,index=['type','Date'],values=['total_due'],
                                  aggfunc = ['sum', len],
                                  margins=True)
pivot_total_fp.reset_index(drop=False, inplace=True)
pivot_total_fp.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1055904135.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_total_fp = pd.pivot_table(all_disp_fp,index=['type','Date'],values=['total_due'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1055904135.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_total_fp = pd.pivot_table(all_disp_fp,index=['type','Date'],values=['total_due'],
#       type       Date       sum       len
#                       total_due total_due
# 0  INSTANT 2023-04-01  4,411.73         5
# 1  INSTANT 2023-04-02  9,942.01        10
# 2  INSTANT 2023-04-03 27,885.66        27
# 3  INSTANT 2023-04-04 37,937.54        11
# 4  INSTANT 2023-04-05 24,035.58        13

# %%
pivot_parcial_fp = pd.pivot_table(all_disp_fp,index=['type','tipo','Date'],
                               columns=['status'],values=['total_due'],aggfunc = ['sum', len],margins=True)
pivot_parcial_fp.reset_index(drop=False, inplace=True)
pivot_parcial_fp.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1899252320.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_parcial_fp = pd.pivot_table(all_disp_fp,index=['type','tipo','Date'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1899252320.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_parcial_fp = pd.pivot_table(all_disp_fp,index=['type','tipo','Date'],
#            type            tipo       Date       sum                      \
#                                            total_due
# status                                         ERROR      PAID       All
# 0       INSTANT    Pago del día 2023-04-17       NaN    287.47    287.47
# 1       INSTANT  Reprogramación 2023-04-01       NaN  4,411.73  4,411.73
# 2       INSTANT  Reprogramación 2023-04-02       NaN  9,942.01  9,942.01
# 3       INSTANT  Reprogramación 2023-04-03    275.49 27,610.17 27,885.66
# 4       INSTANT  Reprogramación 2023-04-04       NaN 37,937.54 37,937.54
#
#              len
#        total_due
# status     ERROR  PAID All
# 0            NaN  1.00   1
# 1            NaN  5.00   5
# 2            NaN 10.00  10
# 3           4.00 23.00  27
# 4            NaN 11.00  11

# %% [markdown]
# ## CATEGORIZACIÓN DE REPROGRAMACIONES - FAST PAYMENTS

# %%
fp_dia_total_repro = all_disp_fp[(all_disp_fp['tipo'] == 'Reprogramación')]
fp_dia_total_repro.head()
# Out:
#            type                           merchant_id    merchant_name  \
# 69161   INSTANT  986a86e9-b775-4cc8-881a-aff2dae3f623      Tienda Lety
# 114880  INSTANT  fe3744fa-eefe-4ae5-be45-f497e55d6cc2  Plan B SA de CV
# 24257   INSTANT  3585b3b9-7179-458b-bcab-bdf959febe62         Nukumori
# 24258   INSTANT  3585b3b9-7179-458b-bcab-bdf959febe62         Nukumori
# 111906  INSTANT  eae670dc-d948-4f27-96c4-2bc7e1e61a68         Polleria
#
#                          user_email  report_id report_date_local  total_due  \
# 69161   javierpacheco1004@gmail.com  9KGBR5ZTN        2022-01-20      33.54
# 114880          marebrica@yahoo.com  FRM8CCCCW        2023-03-22   2,874.72
# 24257        emma.mendoza@gmail.com  QYKFWZ8KL        2023-03-19   1,130.72
# 24258        emma.mendoza@gmail.com  WZ35TGBXQ        2023-03-19       0.95
# 111906    reynaargueyes12@gmail.com  34SL6MBSW        2022-01-07     145.08
#
#                   tipo           bank        bank_account_owner_name  ...  \
# 69161   Reprogramación         AZTECA          Javier Rivera Pacheco  ...
# 114880  Reprogramación       BANREGIO  Carlos Gustavo Quintero Ramos  ...
# 24257   Reprogramación  BBVA BANCOMER          Emma Mendoza Martinez  ...
# 24258   Reprogramación  BBVA BANCOMER          Emma Mendoza Martinez  ...
# 111906  Reprogramación       BANREGIO    Reyna Esther Arias Argueyes  ...
#
#                                                 LINEA CEP        Batch_time  \
# 69161   2023-04-01,42644264202304012215698459,40072,40...   01. First_batch
# 114880  2023-04-01,42644264202304012215812706,40072,40...  02. Second_batch
# 24257   2023-04-01,42644264202304012215686060,40072,40...   01. First_batch
# 24258   2023-04-01,42644264202304012215768175,40072,40...   01. First_batch
# 111906  2023-04-02,42644264202304022217259049,40072,40...  02. Second_batch
#
#        Banco_emisor                 file_name       Date month_conc year_conc  \
# 69161       BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 114880      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 24257       BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 24258       BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 111906      BANORTE  Dispersión-20230402.xlsx 2023-04-02      April      2023
#
#        month_report year_report swap
# 69161       January        2022  NaN
# 114880        March        2023  NaN
# 24257         March        2023  NaN
# 24258         March        2023  NaN
# 111906      January        2022  NaN
#
# [5 rows x 22 columns]

# %%
fp_dia_total_repro.shape
# Out:
# (297, 22)

# %%
fp_dia_total_repro.to_excel('Reprogramaciones_instant.xlsx',index=False)

# %%
fp_dia_total_repro.loc[(fp_dia_total_repro['tipo'] == 'Reprogramación')
                   & (fp_dia_total_repro['month_report'] == month_conc) 
                   & (fp_dia_total_repro['year_report'] == year_conc),'tipo_reprogramacion'] = 'repro_mismo_mes'
fp_dia_total_repro['tipo_reprogramacion'].fillna('repro_otro_mes',inplace=True)
fp_dia_total_repro.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\939012805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fp_dia_total_repro.loc[(fp_dia_total_repro['tipo'] == 'Reprogramación')
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\939012805.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fp_dia_total_repro['tipo_reprogramacion'].fillna('repro_otro_mes',inplace=True)
#            type                           merchant_id    merchant_name  \
# 69161   INSTANT  986a86e9-b775-4cc8-881a-aff2dae3f623      Tienda Lety
# 114880  INSTANT  fe3744fa-eefe-4ae5-be45-f497e55d6cc2  Plan B SA de CV
# 24257   INSTANT  3585b3b9-7179-458b-bcab-bdf959febe62         Nukumori
# 24258   INSTANT  3585b3b9-7179-458b-bcab-bdf959febe62         Nukumori
# 111906  INSTANT  eae670dc-d948-4f27-96c4-2bc7e1e61a68         Polleria
#
#                          user_email  report_id report_date_local  total_due  \
# 69161   javierpacheco1004@gmail.com  9KGBR5ZTN        2022-01-20      33.54
# 114880          marebrica@yahoo.com  FRM8CCCCW        2023-03-22   2,874.72
# 24257        emma.mendoza@gmail.com  QYKFWZ8KL        2023-03-19   1,130.72
# 24258        emma.mendoza@gmail.com  WZ35TGBXQ        2023-03-19       0.95
# 111906    reynaargueyes12@gmail.com  34SL6MBSW        2022-01-07     145.08
#
#                   tipo           bank        bank_account_owner_name  ...  \
# 69161   Reprogramación         AZTECA          Javier Rivera Pacheco  ...
# 114880  Reprogramación       BANREGIO  Carlos Gustavo Quintero Ramos  ...
# 24257   Reprogramación  BBVA BANCOMER          Emma Mendoza Martinez  ...
# 24258   Reprogramación  BBVA BANCOMER          Emma Mendoza Martinez  ...
# 111906  Reprogramación       BANREGIO    Reyna Esther Arias Argueyes  ...
#
#               Batch_time Banco_emisor                 file_name       Date  \
# 69161    01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 114880  02. Second_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 24257    01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 24258    01. First_batch      BANORTE  Dispersión-20230401.xlsx 2023-04-01
# 111906  02. Second_batch      BANORTE  Dispersión-20230402.xlsx 2023-04-02
#
#        month_conc year_conc month_report year_report swap tipo_reprogramacion
# 69161       April      2023      January        2022  NaN      repro_otro_mes
# 114880      April      2023        March        2023  NaN      repro_otro_mes
# 24257       April      2023        March        2023  NaN      repro_otro_mes
# 24258       April      2023        March        2023  NaN      repro_otro_mes
# 111906      April      2023      January        2022  NaN      repro_otro_mes
#
# [5 rows x 23 columns]

# %%
pivot_tipo_repro_fp = pd.pivot_table(fp_dia_total_repro,index=['type','Date'],
                                  columns=['tipo_reprogramacion'],
                                  values=['total_due']
                                  ,aggfunc = ['sum', len],margins=True)
pivot_tipo_repro_fp.fillna(0,inplace=True)
pivot_tipo_repro_fp.reset_index(drop=False, inplace=True)
pivot_tipo_repro_fp.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\4096176958.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_tipo_repro_fp = pd.pivot_table(fp_dia_total_repro,index=['type','Date'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\4096176958.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_tipo_repro_fp = pd.pivot_table(fp_dia_total_repro,index=['type','Date'],
#                         type       Date            sum            \
#                                              total_due
# tipo_reprogramacion                     repro_otro_mes       All
# 0                    INSTANT 2023-04-01       4,411.73  4,411.73
# 1                    INSTANT 2023-04-02       9,942.01  9,942.01
# 2                    INSTANT 2023-04-03      27,885.66 27,885.66
# 3                    INSTANT 2023-04-04      37,937.54 37,937.54
# 4                    INSTANT 2023-04-05      24,035.58 24,035.58
#
#                                len
#                          total_due
# tipo_reprogramacion repro_otro_mes All
# 0                                5   5
# 1                               10  10
# 2                               27  27
# 3                               11  11
# 4                               13  13

# %% [markdown]
# # LEDGER

# %%
all_disp_ledger = all_disp[(all_disp['type'] == 'LEDGER')]
all_disp_ledger.head()
# Out:
#          type                           merchant_id merchant_name user_email  \
# 0      LEDGER  00e3f30a-d0f3-4899-afa6-ad9fcb61bca6           NaN        NaN
# 77115  LEDGER  aa403b22-4da1-4632-9516-5af6e9121c1e           NaN        NaN
# 77114  LEDGER  aa40151a-55fe-45d1-af1d-5d388b17f7aa           NaN        NaN
# 77113  LEDGER  aa3f5789-e40d-4d48-a984-ac2e03ff7505           NaN        NaN
# 77112  LEDGER  aa3ed455-10a2-4f9a-9b07-f9d945f9b4ac           NaN        NaN
#
#        report_id report_date_local  total_due          tipo           bank  \
# 0      A3HQ5QWZS        2023-04-01       4.00  Pago del día  BBVA BANCOMER
# 77115  AMB5BNLBR        2023-04-01     209.85  Pago del día  BBVA BANCOMER
# 77114  ARPJ268MM        2023-04-01   1,705.67  Pago del día  BBVA BANCOMER
# 77113  ATHWYQX6C        2023-04-01   4,588.04  Pago del día         AZTECA
# 77112  A4YVLQLDW        2023-04-01     943.86  Pago del día         AZTECA
#
#           bank_account_owner_name  ...  \
# 0                  Daniel Vasquez  ...
# 77115   Jose David Ruiz Dominguez  ...
# 77114      Ega Creativos SA De CV  ...
# 77113  Maricela Antonio Florente   ...
# 77112    Ricardo Ruvalcaba Lomeli  ...
#
#                                                LINEA CEP       Batch_time  \
# 0                                                    NaN  01. First_batch
# 77115  2023-04-01,42644264202304012215759817,40072,40...  01. First_batch
# 77114  2023-04-01,42644264202304012215676750,40072,40...  01. First_batch
# 77113  2023-04-01,42644264202304012215733238,40072,40...  01. First_batch
# 77112  2023-04-01,42644264202304012215787291,40072,40...  01. First_batch
#
#       Banco_emisor                 file_name       Date month_conc year_conc  \
# 0          BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77115      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77114      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77113      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 77112      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
#
#       month_report year_report swap
# 0            April        2023  NaN
# 77115        April        2023  NaN
# 77114        April        2023  NaN
# 77113        April        2023  NaN
# 77112        April        2023  NaN
#
# [5 rows x 22 columns]

# %%
all_disp_ledger.shape
# Out:
# (2967456, 22)

# %%
pivot_total_ledger = pd.pivot_table(all_disp_ledger,index=['type','Date'],values=['total_due'],
                                  aggfunc = ['sum', len],
                                  margins=True)
pivot_total_ledger.reset_index(drop=False, inplace=True)
pivot_total_ledger.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1348612958.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_total_ledger = pd.pivot_table(all_disp_ledger,index=['type','Date'],values=['total_due'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1348612958.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_total_ledger = pd.pivot_table(all_disp_ledger,index=['type','Date'],values=['total_due'],
#      type       Date            sum       len
#                           total_due total_due
# 0  LEDGER 2023-04-01 278,276,327.27    117798
# 1  LEDGER 2023-04-02 285,929,524.41    114504
# 2  LEDGER 2023-04-03 204,722,305.28     81926
# 3  LEDGER 2023-04-04 211,347,534.29    100411
# 4  LEDGER 2023-04-05 213,266,642.46    101715

# %%
pivot_total_ledger.shape
# Out:
# (31, 4)

# %%
pivot_parcial_ledger = pd.pivot_table(all_disp_ledger,index=['type','tipo','Date'],
                               columns=['status'],values=['total_due'],aggfunc = ['sum', len],margins=True)
pivot_parcial_ledger.reset_index(drop=False, inplace=True)
pivot_parcial_ledger.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3013629304.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_parcial_ledger = pd.pivot_table(all_disp_ledger,index=['type','tipo','Date'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3013629304.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_parcial_ledger = pd.pivot_table(all_disp_ledger,index=['type','tipo','Date'],
#           type          tipo       Date          sum                 \
#                                            total_due
# status                                         ERROR           PAID
# 0       LEDGER  Pago del día 2023-04-01 2,778,521.71 275,389,337.68
# 1       LEDGER  Pago del día 2023-04-02 8,232,378.81 277,575,211.24
# 2       LEDGER  Pago del día 2023-04-03 4,171,580.14 200,262,541.88
# 3       LEDGER  Pago del día 2023-04-04 3,070,312.73 207,796,154.05
# 4       LEDGER  Pago del día 2023-04-05 2,370,580.54 210,302,772.77
#
#                             len
#                       total_due
# status            All     ERROR       PAID     All
# 0      278,167,859.39    351.00 117,333.00  117684
# 1      285,807,590.05  2,298.00 112,100.00  114398
# 2      204,434,122.02  1,616.00  80,198.00   81814
# 3      210,866,466.78    415.00  99,853.00  100268
# 4      212,673,353.31    386.00 101,158.00  101544

# %% [markdown]
# ## CATEGORIZACION DE REPROGRAMACIONES - LEDGER

# %%
ledger_dia_total_repro = all_disp_ledger[(all_disp_ledger['tipo'] == 'Reprogramación')]
ledger_dia_total_repro.head()
# Out:
#          type                           merchant_id merchant_name user_email  \
# 76849  LEDGER  a9b3b873-0e6a-4316-bfa4-46deec038468           NaN        NaN
# 78722  LEDGER  adb51a37-ad82-4d2e-b4ab-5596606e8114           NaN        NaN
# 75268  LEDGER  a600a332-05cd-4c0e-943e-aad72853b904           NaN        NaN
# 75508  LEDGER  a696d490-a3b8-43ec-a592-d227d2c618a1           NaN        NaN
# 74529  LEDGER  a450135c-e304-4242-8f92-bed72cc81bdd           NaN        NaN
#
#        report_id report_date_local  total_due            tipo           bank  \
# 76849  AN7ZTSBT8        2023-03-31       0.01  Reprogramación  BBVA BANCOMER
# 78722  A3MYNX3WV        2023-03-31     190.69  Reprogramación      SANTANDER
# 75268  ATYW3VG3N        2023-03-28      23.00  Reprogramación  BBVA BANCOMER
# 75508  AZM4SGTZN        2023-03-28     919.04  Reprogramación      SANTANDER
# 74529  APH29Z5ZT        2023-03-30       9.58  Reprogramación        INBURSA
#
#                 bank_account_owner_name  ...  \
# 76849                       Lourdes Rod  ...
# 78722           Jose samuel Rivera soto  ...
# 75268  Miguel Ángel Hernández Hernández  ...
# 75508        Alejandro espinosa Mendoza  ...
# 74529                Ruth Cazares Licea  ...
#
#                                                LINEA CEP       Batch_time  \
# 76849  2023-04-01,42644264202304012215676451,40072,40...  01. First_batch
# 78722  2023-04-01,42644264202304012215678286,40072,40...  01. First_batch
# 75268  2023-04-01,42644264202304012215674885,40072,40...  01. First_batch
# 75508  2023-04-01,42644264202304012215704306,40072,40...  01. First_batch
# 74529  2023-04-01,42644264202304012215784872,40072,40...  01. First_batch
#
#       Banco_emisor                 file_name       Date month_conc year_conc  \
# 76849      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 78722      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 75268      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 75508      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
# 74529      BANORTE  Dispersión-20230401.xlsx 2023-04-01      April      2023
#
#       month_report year_report swap
# 76849        March        2023  NaN
# 78722        March        2023  NaN
# 75268        March        2023  NaN
# 75508        March        2023  NaN
# 74529        March        2023  NaN
#
# [5 rows x 22 columns]

# %%
ledger_dia_total_repro.shape
# Out:
# (6483, 22)

# %%
ledger_dia_total_repro.to_excel('Reprogramaciones_ledger.xlsx',index=False)

# %%
ledger_dia_total_repro.loc[(ledger_dia_total_repro['tipo'] == 'Reprogramación')
                   & (ledger_dia_total_repro['month_report'] == month_conc) 
                   & (ledger_dia_total_repro['year_report'] == year_conc),'tipo_reprogramacion'] = 'repro_mismo_mes'
ledger_dia_total_repro['tipo_reprogramacion'].fillna('repro_otro_mes',inplace=True)
ledger_dia_total_repro.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3563945437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ledger_dia_total_repro.loc[(ledger_dia_total_repro['tipo'] == 'Reprogramación')
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\3563945437.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ledger_dia_total_repro['tipo_reprogramacion'].fillna('repro_otro_mes',inplace=True)
#          type                           merchant_id merchant_name user_email  \
# 76849  LEDGER  a9b3b873-0e6a-4316-bfa4-46deec038468           NaN        NaN
# 78722  LEDGER  adb51a37-ad82-4d2e-b4ab-5596606e8114           NaN        NaN
# 75268  LEDGER  a600a332-05cd-4c0e-943e-aad72853b904           NaN        NaN
# 75508  LEDGER  a696d490-a3b8-43ec-a592-d227d2c618a1           NaN        NaN
# 74529  LEDGER  a450135c-e304-4242-8f92-bed72cc81bdd           NaN        NaN
#
#        report_id report_date_local  total_due            tipo           bank  \
# 76849  AN7ZTSBT8        2023-03-31       0.01  Reprogramación  BBVA BANCOMER
# 78722  A3MYNX3WV        2023-03-31     190.69  Reprogramación      SANTANDER
# 75268  ATYW3VG3N        2023-03-28      23.00  Reprogramación  BBVA BANCOMER
# 75508  AZM4SGTZN        2023-03-28     919.04  Reprogramación      SANTANDER
# 74529  APH29Z5ZT        2023-03-30       9.58  Reprogramación        INBURSA
#
#                 bank_account_owner_name  ...       Batch_time Banco_emisor  \
# 76849                       Lourdes Rod  ...  01. First_batch      BANORTE
# 78722           Jose samuel Rivera soto  ...  01. First_batch      BANORTE
# 75268  Miguel Ángel Hernández Hernández  ...  01. First_batch      BANORTE
# 75508        Alejandro espinosa Mendoza  ...  01. First_batch      BANORTE
# 74529                Ruth Cazares Licea  ...  01. First_batch      BANORTE
#
#                       file_name       Date month_conc year_conc month_report  \
# 76849  Dispersión-20230401.xlsx 2023-04-01      April      2023        March
# 78722  Dispersión-20230401.xlsx 2023-04-01      April      2023        March
# 75268  Dispersión-20230401.xlsx 2023-04-01      April      2023        March
# 75508  Dispersión-20230401.xlsx 2023-04-01      April      2023        March
# 74529  Dispersión-20230401.xlsx 2023-04-01      April      2023        March
#
#       year_report swap tipo_reprogramacion
# 76849        2023  NaN      repro_otro_mes
# 78722        2023  NaN      repro_otro_mes
# 75268        2023  NaN      repro_otro_mes
# 75508        2023  NaN      repro_otro_mes
# 74529        2023  NaN      repro_otro_mes
#
# [5 rows x 23 columns]

# %%
pivot_tipo_repro_ledger = pd.pivot_table(ledger_dia_total_repro,index=['type','Date'],
                                  columns=['tipo_reprogramacion'],
                                  values=['total_due']
                                  ,aggfunc = ['sum', len],margins=True)
pivot_tipo_repro_ledger.fillna(0,inplace=True)
pivot_tipo_repro_ledger.reset_index(drop=False, inplace=True)
pivot_tipo_repro_ledger.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1507184451.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_tipo_repro_ledger = pd.pivot_table(ledger_dia_total_repro,index=['type','Date'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_15896\1507184451.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_tipo_repro_ledger = pd.pivot_table(ledger_dia_total_repro,index=['type','Date'],
#                        type       Date             sum                 \
#                                              total_due
# tipo_reprogramacion                    repro_mismo_mes repro_otro_mes
# 0                    LEDGER 2023-04-01            0.00     108,467.88
# 1                    LEDGER 2023-04-02       35,117.69      86,816.67
# 2                    LEDGER 2023-04-03       46,600.07     241,583.19
# 3                    LEDGER 2023-04-04      263,386.96     217,680.55
# 4                    LEDGER 2023-04-05      438,387.26     154,901.89
#
#                                            len
#                                      total_due
# tipo_reprogramacion        All repro_mismo_mes repro_otro_mes  All
# 0                   108,467.88            0.00         114.00  114
# 1                   121,934.36           36.00          70.00  106
# 2                   288,183.26           40.00          72.00  112
# 3                   481,067.51           85.00          58.00  143
# 4                   593,289.15           90.00          81.00  171

# %% [markdown]
# # EXCEL FINAL

# %%
writer = pd.ExcelWriter('FASE IV. REPROGRAMACIONES ABRIL 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
pivot_total_trad.to_excel(writer, sheet_name='TRADICIONAL TOTAL')
pivot_parcial_trad.to_excel(writer, sheet_name='TRADICIONAL PARCIAL')
pivot_total_fp.to_excel(writer, sheet_name='FP TOTAL')
pivot_parcial_fp.to_excel(writer, sheet_name='FP PARCIAL')
pivot_total_ledger.to_excel(writer, sheet_name='LEDGER TOTAL')
pivot_parcial_ledger.to_excel(writer, sheet_name='LEDGER PARCIAL')
pivot_tipo_repro.to_excel(writer, sheet_name='CATEGORIZACION REPRO TRAD')
pivot_tipo_repro_fp.to_excel(writer, sheet_name='CATEGORIZACION REPRO FP')
pivot_tipo_repro_ledger.to_excel(writer, sheet_name='CATEGORIZACION REPRO LEDGER')
writer.close()
