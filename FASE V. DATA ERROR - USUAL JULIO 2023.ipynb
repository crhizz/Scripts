# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %%
start_date = '2023-07-01'
final_date = '2023-07-31'
query_error_year = 2023
query_error_month = 7

# %% [markdown]
# # INFORMACION DE  CUBETA ERROR

# %%
query_error = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\POLIZAS\2023\07. JULIO\DATA\ERROR JULIO 2023.csv',
                          dtype={'report_id':object})
query_error.rename(columns ={'MAX(report_date_local)':'report_date_local'}, inplace=True)
query_error['report_date_local']= pd.to_datetime(query_error['report_date_local'])
query_error['ultimo_mov'] = pd.to_datetime(query_error['ultimo_mov'])
query_error['merchant_id_query'] = query_error['merchant_id']
query_error['ultimo_mov_date_only']= pd.to_datetime(query_error['ultimo_mov']).dt.date
query_error['day'] = query_error['ultimo_mov'].dt.day
query_error['month'] = query_error['ultimo_mov'].dt.month
query_error['year'] = query_error['ultimo_mov'].dt.year
# query_error.loc[((query_error['day'] == 30 )
#                 & (query_error['month'] == 7)
#                 & (query_error['year'] == 2022)), "mes_cierre"] = 'Actual'
# query_error.loc[(query_error['day'] == 31 )
#             & (query_error['month'] == 7 )
#             & (query_error['year'] == 2022), "mes_cierre"] = 'Actual'
query_error.loc[(query_error['month'] == query_error_month )
            & (query_error['year'] == query_error_year), "mes_cierre"] = 'Actual'
query_error.head()
# Out:
#    Unnamed: 0                           merchant_id  \
# 0           0  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 1           1  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 2           2  d1087b80-5383-4b90-8738-bf309a1ce297
# 3           3  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
# 4           4  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
#
#                        merchant_name  report_id report_date_local   amount  \
# 0              Mscelanea Dulce Maria  GTS92WH86        2015-11-05   734.34
# 1              Mscelanea Dulce Maria  8VQRDV39G        2015-11-06   597.26
# 2                      Grupo Solutec  82G5CYSR7        2015-12-21 9,160.77
# 3  Ediciones Malinalco S de RL de CV  XWRKLC2ZL        2016-02-08 1,216.98
# 4  Ediciones Malinalco S de RL de CV  D9468C7W4        2016-02-16 1,993.14
#
#   status    error_description ultimo_mov  month  year status_cubeta  \
# 0  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 1  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 2  ERROR          failed swap 2017-11-01     11  2017         ERROR
# 3  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
# 4  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
#
#   esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 0   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 1   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 2   ERROR_USUAL  d1087b80-5383-4b90-8738-bf309a1ce297           2017-11-01
# 3   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
# 4   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
#
#    day mes_cierre
# 0   15        NaN
# 1   15        NaN
# 2    1        NaN
# 3   12        NaN
# 4   12        NaN
#    Unnamed: 0                           merchant_id  \
# 0           0  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 1           1  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 2           2  d1087b80-5383-4b90-8738-bf309a1ce297
# 3           3  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
# 4           4  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
#
#                        merchant_name  report_id report_date_local   amount  \
# 0              Mscelanea Dulce Maria  GTS92WH86        2015-11-05   734.34
# 1              Mscelanea Dulce Maria  8VQRDV39G        2015-11-06   597.26
# 2                      Grupo Solutec  82G5CYSR7        2015-12-21 9,160.77
# 3  Ediciones Malinalco S de RL de CV  XWRKLC2ZL        2016-02-08 1,216.98
# 4  Ediciones Malinalco S de RL de CV  D9468C7W4        2016-02-16 1,993.14
#
#   status    error_description ultimo_mov  month  year status_cubeta  \
# 0  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 1  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 2  ERROR          failed swap 2017-11-01     11  2017         ERROR
# 3  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
# 4  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
#
#   esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 0   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 1   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 2   ERROR_USUAL  d1087b80-5383-4b90-8738-bf309a1ce297           2017-11-01
# 3   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
# 4   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
#
#    day mes_cierre
# 0   15        NaN
# 1   15        NaN
# 2    1        NaN
# 3   12        NaN
# 4   12        NaN

# %%
query_error.shape
# Out:
# (138478, 17)
# (138478, 17)

# %%
query_error.dtypes
# Out:
# Unnamed: 0                       int64
# merchant_id                     object
# merchant_name                   object
# report_id                       object
# report_date_local       datetime64[ns]
# amount                         float64
# status                          object
# error_description               object
# ultimo_mov              datetime64[ns]
# month                            int64
# year                             int64
# status_cubeta                   object
# esquema_query                   object
# merchant_id_query               object
# ultimo_mov_date_only            object
# day                              int64
# mes_cierre                      object
# dtype: object
# Unnamed: 0                       int64
# merchant_id                     object
# merchant_name                   object
# report_id                       object
# report_date_local       datetime64[ns]
# amount                         float64
# status                          object
# error_description               object
# ultimo_mov              datetime64[ns]
# month                            int64
# year                             int64
# status_cubeta                   object
# esquema_query                   object
# merchant_id_query               object
# ultimo_mov_date_only            object
# day                              int64
# mes_cierre                      object
# dtype: object

# %%
query_error['esquema_query'].unique()
# Out:
# array(['ERROR_USUAL', 'SIN_CLABE'], dtype=object)
# array(['ERROR_USUAL', 'SIN_CLABE'], dtype=object)

# %%
query_error['status_cubeta'].unique()
# Out:
# array(['ERROR', 'NEW'], dtype=object)
# array(['ERROR', 'NEW'], dtype=object)

# %% [markdown]
# # FILTRAR INFORMACION DE ACUERDO AL MES EN CURSO

# %%
query_error_current_month = query_error[(query_error['mes_cierre'] == 'Actual')]
query_error_current_month.sort_values(by=['day'],inplace=True)
query_error_current_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\3502651561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_error_current_month.sort_values(by=['day'],inplace=True)
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\3502651561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_error_current_month.sort_values(by=['day'],inplace=True)
#         Unnamed: 0                           merchant_id merchant_name  \
# 129205      129205  0489474b-6d97-4116-95a1-6046a22df36e           NaN
# 129260      129260  86f663aa-8670-4195-bb17-f9b739a30cb3           NaN
# 129261      129261  e54fb3d5-83cb-42b2-8aec-c7aee96815b3           NaN
# 129262      129262  8f9e63fd-834d-4c15-ba33-21731d74fbba           NaN
# 129263      129263  98032dad-9c3a-41a4-a34f-3fdc2e751bb8           NaN
#
#         report_id report_date_local   amount status  \
# 129205  ATRX9663Q        2023-07-01     6.20  ERROR
# 129260  A4T34PRV8        2023-07-01 1,629.00  ERROR
# 129261  ANFJCYW7Q        2023-07-01     0.01  ERROR
# 129262  ACK9P6LY3        2023-07-01 1,959.59  ERROR
# 129263  APY86FDSS        2023-07-01     5.00  ERROR
#
#                              error_description ultimo_mov  month  year  \
# 129205  Bank account information not available 2023-07-01      7  2023
# 129260  Bank account information not available 2023-07-01      7  2023
# 129261  Bank account information not available 2023-07-01      7  2023
# 129262  Bank account information not available 2023-07-01      7  2023
# 129263  Bank account information not available 2023-07-01      7  2023
#
#        status_cubeta esquema_query                     merchant_id_query  \
# 129205           NEW     SIN_CLABE  0489474b-6d97-4116-95a1-6046a22df36e
# 129260           NEW     SIN_CLABE  86f663aa-8670-4195-bb17-f9b739a30cb3
# 129261           NEW     SIN_CLABE  e54fb3d5-83cb-42b2-8aec-c7aee96815b3
# 129262           NEW     SIN_CLABE  8f9e63fd-834d-4c15-ba33-21731d74fbba
# 129263           NEW     SIN_CLABE  98032dad-9c3a-41a4-a34f-3fdc2e751bb8
#
#        ultimo_mov_date_only  day mes_cierre
# 129205           2023-07-01    1     Actual
# 129260           2023-07-01    1     Actual
# 129261           2023-07-01    1     Actual
# 129262           2023-07-01    1     Actual
# 129263           2023-07-01    1     Actual
#         Unnamed: 0                           merchant_id merchant_name  \
# 129205      129205  0489474b-6d97-4116-95a1-6046a22df36e           NaN
# 129260      129260  86f663aa-8670-4195-bb17-f9b739a30cb3           NaN
# 129261      129261  e54fb3d5-83cb-42b2-8aec-c7aee96815b3           NaN
# 129262      129262  8f9e63fd-834d-4c15-ba33-21731d74fbba           NaN
# 129263      129263  98032dad-9c3a-41a4-a34f-3fdc2e751bb8           NaN
#
#         report_id report_date_local   amount status  \
# 129205  ATRX9663Q        2023-07-01     6.20  ERROR
# 129260  A4T34PRV8        2023-07-01 1,629.00  ERROR
# 129261  ANFJCYW7Q        2023-07-01     0.01  ERROR
# 129262  ACK9P6LY3        2023-07-01 1,959.59  ERROR
# 129263  APY86FDSS        2023-07-01     5.00  ERROR
#
#                              error_description ultimo_mov  month  year  \
# 129205  Bank account information not available 2023-07-01      7  2023
# 129260  Bank account information not available 2023-07-01      7  2023
# 129261  Bank account information not available 2023-07-01      7  2023
# 129262  Bank account information not available 2023-07-01      7  2023
# 129263  Bank account information not available 2023-07-01      7  2023
#
#        status_cubeta esquema_query                     merchant_id_query  \
# 129205           NEW     SIN_CLABE  0489474b-6d97-4116-95a1-6046a22df36e
# 129260           NEW     SIN_CLABE  86f663aa-8670-4195-bb17-f9b739a30cb3
# 129261           NEW     SIN_CLABE  e54fb3d5-83cb-42b2-8aec-c7aee96815b3
# 129262           NEW     SIN_CLABE  8f9e63fd-834d-4c15-ba33-21731d74fbba
# 129263           NEW     SIN_CLABE  98032dad-9c3a-41a4-a34f-3fdc2e751bb8
#
#        ultimo_mov_date_only  day mes_cierre
# 129205           2023-07-01    1     Actual
# 129260           2023-07-01    1     Actual
# 129261           2023-07-01    1     Actual
# 129262           2023-07-01    1     Actual
# 129263           2023-07-01    1     Actual

# %%
query_error_current_month.shape
# Out:
# (10400, 17)
# (10400, 17)

# %%
query_error_current_month['month'].unique()
# Out:
# array([7], dtype=int64)
# array([7], dtype=int64)

# %%
query_error_current_month.columns
# Out:
# Index(['Unnamed: 0', 'merchant_id', 'merchant_name', 'report_id',
#        'report_date_local', 'amount', 'status', 'error_description',
#        'ultimo_mov', 'month', 'year', 'status_cubeta', 'esquema_query',
#        'merchant_id_query', 'ultimo_mov_date_only', 'day', 'mes_cierre'],
#       dtype='object')
# Index(['Unnamed: 0', 'merchant_id', 'merchant_name', 'report_id',
#        'report_date_local', 'amount', 'status', 'error_description',
#        'ultimo_mov', 'month', 'year', 'status_cubeta', 'esquema_query',
#        'merchant_id_query', 'ultimo_mov_date_only', 'day', 'mes_cierre'],
#       dtype='object')

# %%
duplicates_query_error = query_error_current_month[query_error_current_month.duplicated(['report_id'] , keep=False)]
duplicates_query_error.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []

# %%
duplicates_query_error.shape
# Out:
# (0, 17)
# (0, 17)

# %% [markdown]
# # PAGOS NEW DE MESES ANTERIORES

# %%
query_new_last_month = query_error[(query_error['mes_cierre'] != 'Actual') & (query_error['status_cubeta'] == 'NEW')]
query_new_last_month.sort_values(by=['day'],inplace=True)
query_new_last_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\3381233170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_new_last_month.sort_values(by=['day'],inplace=True)
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\3381233170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_new_last_month.sort_values(by=['day'],inplace=True)
#         Unnamed: 0                           merchant_id        merchant_name  \
# 96528        96528  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 104580      104580  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 103538      103538  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 103309      103309  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 101755      101755  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#         report_id report_date_local   amount    status  \
# 96528   SSL6DGTLG        2022-12-31     8.00  ERROR_TV
# 104580  S92NNTKJ3        2023-03-07 1,724.83  ERROR_TV
# 103538  DCWNBQZC5        2023-02-27     8.00  ERROR_TV
# 103309  9X787BYD8        2023-02-25 3,449.66  ERROR_TV
# 101755  WSM742YZC        2023-02-15     8.00  ERROR_TV
#
#                                         error_description ultimo_mov  month  \
# 96528                      CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6
# 104580  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6
# 103538  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6
# 103309                     CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6
# 101755  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6
#
#         year status_cubeta esquema_query  \
# 96528   2023           NEW   ERROR_USUAL
# 104580  2023           NEW   ERROR_USUAL
# 103538  2023           NEW   ERROR_USUAL
# 103309  2023           NEW   ERROR_USUAL
# 101755  2023           NEW   ERROR_USUAL
#
#                            merchant_id_query ultimo_mov_date_only  day  \
# 96528   41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 104580  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 103538  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 103309  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 101755  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
#
#        mes_cierre
# 96528         NaN
# 104580        NaN
# 103538        NaN
# 103309        NaN
# 101755        NaN
#         Unnamed: 0                           merchant_id        merchant_name  \
# 96528        96528  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 104580      104580  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 103538      103538  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 103309      103309  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 101755      101755  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#         report_id report_date_local   amount    status  \
# 96528   SSL6DGTLG        2022-12-31     8.00  ERROR_TV
# 104580  S92NNTKJ3        2023-03-07 1,724.83  ERROR_TV
# 103538  DCWNBQZC5        2023-02-27     8.00  ERROR_TV
# 103309  9X787BYD8        2023-02-25 3,449.66  ERROR_TV
# 101755  WSM742YZC        2023-02-15     8.00  ERROR_TV
#
#                                         error_description ultimo_mov  month  \
# 96528                      CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6
# 104580  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6
# 103538  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6
# 103309                     CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6
# 101755  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6
#
#         year status_cubeta esquema_query  \
# 96528   2023           NEW   ERROR_USUAL
# 104580  2023           NEW   ERROR_USUAL
# 103538  2023           NEW   ERROR_USUAL
# 103309  2023           NEW   ERROR_USUAL
# 101755  2023           NEW   ERROR_USUAL
#
#                            merchant_id_query ultimo_mov_date_only  day  \
# 96528   41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 104580  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 103538  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 103309  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
# 101755  41483b66-12f7-42e8-8484-26a20dd9a4de           2023-06-01    1
#
#        mes_cierre
# 96528         NaN
# 104580        NaN
# 103538        NaN
# 103309        NaN
# 101755        NaN

# %%
query_new_last_month.shape
# Out:
# (20, 17)
# (20, 17)

# %% [markdown]
# # INFORMACIÓN QUERIES - PAGOS

# %%
name_header = ['merchant_id','merchant_name','user_email','report_id','report_date_local','amount','status','bank_name'
               ,'payment_date_local','bank_account_owner_name','bank_account_number','swap']

# %% [markdown]
# ### NEXT MONTH

# %%
# TRADICIONAL
# trad_files_csv_2021_may = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\06. JUNE\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
# fp_files_csv_2021_may = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\06. JUNE\QUERIES\*.csv', recursive=False)

# %%
# disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_may])
# disp_files_csv_2021_may['date_query'] = disp_files_csv_2021_may["file_name"].str[-14:-4]
# disp_files_csv_2021_may['date_query']= pd.to_datetime(disp_files_csv_2021_may['date_query'])

# %%
# fp_disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_may])
# fp_disp_files_csv_2021_may['date_query'] = fp_disp_files_csv_2021_may["file_name"].str[-14:-4]
# fp_disp_files_csv_2021_may['date_query']= pd.to_datetime(fp_disp_files_csv_2021_may['date_query'])

# %% [markdown]
# ### CURRENT MONTH

# %%
# TRADICIONAL
trad_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\07. JULY\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\07. JULIO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2022_current])
disp_files_csv_2022_current['date_query'] = disp_files_csv_2022_current["file_name"].str[-14:-4]
disp_files_csv_2022_current['date_query']= pd.to_datetime(disp_files_csv_2022_current['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2022_current])
fp_disp_files_csv_2022_current['date_query'] = fp_disp_files_csv_2022_current["file_name"].str[-14:-4]
fp_disp_files_csv_2022_current['date_query']= pd.to_datetime(fp_disp_files_csv_2022_current['date_query'])

# %% [markdown]
# ### LAST MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\06. JUNE\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\06. JUNIO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_last])
disp_files_csv_2021_last['date_query'] = disp_files_csv_2021_last["file_name"].str[-14:-4]
disp_files_csv_2021_last['date_query']= pd.to_datetime(disp_files_csv_2021_last['date_query'])

# %%
fp_disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_last])
fp_disp_files_csv_2021_last['date_query'] = fp_disp_files_csv_2021_last["file_name"].str[-14:-4]
fp_disp_files_csv_2021_last['date_query']= pd.to_datetime(fp_disp_files_csv_2021_last['date_query'])

# %% [markdown]
# ### SPECIAL MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\05. MAY\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\05. MAYO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_spec])
disp_files_csv_2021_spec['date_query'] = disp_files_csv_2021_spec["file_name"].str[-14:-4]
disp_files_csv_2021_spec['date_query']= pd.to_datetime(disp_files_csv_2021_spec['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_spec])
fp_disp_files_csv_2021_spec['date_query'] = fp_disp_files_csv_2021_spec["file_name"].str[-14:-4]
fp_disp_files_csv_2021_spec['date_query']= pd.to_datetime(fp_disp_files_csv_2021_spec['date_query'])

# %% [markdown]
# ## ALL FILES

# %%
allfiles = pd.concat([disp_files_csv_2022_current,fp_disp_files_csv_2022_current
                     ,disp_files_csv_2021_last,fp_disp_files_csv_2021_last,
                     disp_files_csv_2021_spec,fp_disp_files_csv_2021_spec])
allfiles.reset_index()
allfiles.fillna('BLANK',inplace=True)
allfiles['date_query']= pd.to_datetime(allfiles['date_query'])
allfiles['report_date_local']= pd.to_datetime(allfiles['report_date_local'])
allfiles.loc[(allfiles['file_name'].str.contains('FP'),'tipo_dispersion')] = 'FP'
allfiles.loc[(allfiles['file_name'].str.contains('SWAP'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('BNTE'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('SANT'),'tipo_dispersion')] = 'TRAD'
allfiles.sort_values(by=['date_query','report_id'],inplace=True)
allfiles.drop(['status'],axis=1,inplace=True)
allfiles.head()
# Out:
#         type                           merchant_id  \
# 18507  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 62610  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 44051  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 2087   DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 67173  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                              merchant_token       merchant_name  \
# 18507  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 62610  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 44051  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 2087   5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 67173  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                                 user_email  report_id report_date_local  \
# 18507  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01
# 62610              marina.riverp@gmail.com  22DCMNLS6        2023-05-01
# 44051          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01
# 2087                angel.mtx5@outlook.com  23T5GKLP7        2023-05-01
# 67173                delarosa16@hotmail.es  25YPZJTWW        2023-05-01
#
#        amount                 bank_name   payment_date_local  \
# 18507   21.00                 BANCOPPEL  2023-05-01 14:24:35
# 62610    2.00  Banco Nacional de México  2023-05-01 14:19:32
# 44051    1.20  Banco Nacional de México  2023-05-01 14:22:15
# 2087     4.00             BBVA Bancomer  2023-05-01 14:23:54
# 67173    3.00             BBVA Bancomer  2023-05-01 14:30:09
#
#             bank_account_owner_name  bank_account_number   batch_created_date  \
# 18507    Julia Cristina Garca Dciga  '137180103002380395  2023-05-01 11:07:54
# 62610           Marina Rivera Perez  '002685903978855849  2023-05-01 11:22:48
# 44051  Deisy Lizbeth Martinez Garza  '002821701869316000  2023-05-01 11:17:31
# 2087                        Angel T  '012180015198300036  2023-05-01 11:05:54
# 67173  Jose Armando De La Rosa Lpez  '012180015465823110  2023-05-01 11:23:22
#
#       disbursement_method                                               swap  \
# 18507             BANORTE  Julia Cristina Garca Dciga,,21.00,137180103002...
# 62610             BANORTE  Marina Rivera Perez,,2.00,002685903978855849,C...
# 44051             BANORTE  Deisy Lizbeth Martinez Garza,,1.20,00282170186...
# 2087              BANORTE    Angel T,,4.00,012180015198300036,CLIP-23T5GKLP7
# 67173             BANORTE  Jose Armando De La Rosa Lpez,,3.00,01218001546...
#
#                    file_name date_query tipo_dispersion
# 18507  BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 62610  BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 44051  BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 2087   BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 67173  BNTE-1 2023-05-01.csv 2023-05-01            TRAD
#         type                           merchant_id  \
# 18507  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 62610  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 44051  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 2087   DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 67173  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                              merchant_token       merchant_name  \
# 18507  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 62610  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 44051  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 2087   5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 67173  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                                 user_email  report_id report_date_local  \
# 18507  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01
# 62610              marina.riverp@gmail.com  22DCMNLS6        2023-05-01
# 44051          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01
# 2087                angel.mtx5@outlook.com  23T5GKLP7        2023-05-01
# 67173                delarosa16@hotmail.es  25YPZJTWW        2023-05-01
#
#        amount                 bank_name   payment_date_local  \
# 18507   21.00                 BANCOPPEL  2023-05-01 14:24:35
# 62610    2.00  Banco Nacional de México  2023-05-01 14:19:32
# 44051    1.20  Banco Nacional de México  2023-05-01 14:22:15
# 2087     4.00             BBVA Bancomer  2023-05-01 14:23:54
# 67173    3.00             BBVA Bancomer  2023-05-01 14:30:09
#
#             bank_account_owner_name  bank_account_number   batch_created_date  \
# 18507    Julia Cristina Garca Dciga  '137180103002380395  2023-05-01 11:07:54
# 62610           Marina Rivera Perez  '002685903978855849  2023-05-01 11:22:48
# 44051  Deisy Lizbeth Martinez Garza  '002821701869316000  2023-05-01 11:17:31
# 2087                        Angel T  '012180015198300036  2023-05-01 11:05:54
# 67173  Jose Armando De La Rosa Lpez  '012180015465823110  2023-05-01 11:23:22
#
#       disbursement_method                                               swap  \
# 18507             BANORTE  Julia Cristina Garca Dciga,,21.00,137180103002...
# 62610             BANORTE  Marina Rivera Perez,,2.00,002685903978855849,C...
# 44051             BANORTE  Deisy Lizbeth Martinez Garza,,1.20,00282170186...
# 2087              BANORTE    Angel T,,4.00,012180015198300036,CLIP-23T5GKLP7
# 67173             BANORTE  Jose Armando De La Rosa Lpez,,3.00,01218001546...
#
#                    file_name date_query tipo_dispersion
# 18507  BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 62610  BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 44051  BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 2087   BNTE-1 2023-05-01.csv 2023-05-01            TRAD
# 67173  BNTE-1 2023-05-01.csv 2023-05-01            TRAD

# %%
def tipo_pago(allfiles):
    if allfiles['date_query'] == allfiles['report_date_local']:
        return 'Pago del día'
    else:
        return 'Reprogramación'
allfiles['tipo_pago'] = allfiles.apply(tipo_pago, axis=1)

# %%
allfiles.head()
# Out:
#         type                           merchant_id  \
# 18507  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 62610  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 44051  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 2087   DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 67173  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                              merchant_token       merchant_name  \
# 18507  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 62610  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 44051  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 2087   5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 67173  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                                 user_email  report_id report_date_local  \
# 18507  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01
# 62610              marina.riverp@gmail.com  22DCMNLS6        2023-05-01
# 44051          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01
# 2087                angel.mtx5@outlook.com  23T5GKLP7        2023-05-01
# 67173                delarosa16@hotmail.es  25YPZJTWW        2023-05-01
#
#        amount                 bank_name   payment_date_local  \
# 18507   21.00                 BANCOPPEL  2023-05-01 14:24:35
# 62610    2.00  Banco Nacional de México  2023-05-01 14:19:32
# 44051    1.20  Banco Nacional de México  2023-05-01 14:22:15
# 2087     4.00             BBVA Bancomer  2023-05-01 14:23:54
# 67173    3.00             BBVA Bancomer  2023-05-01 14:30:09
#
#             bank_account_owner_name  bank_account_number   batch_created_date  \
# 18507    Julia Cristina Garca Dciga  '137180103002380395  2023-05-01 11:07:54
# 62610           Marina Rivera Perez  '002685903978855849  2023-05-01 11:22:48
# 44051  Deisy Lizbeth Martinez Garza  '002821701869316000  2023-05-01 11:17:31
# 2087                        Angel T  '012180015198300036  2023-05-01 11:05:54
# 67173  Jose Armando De La Rosa Lpez  '012180015465823110  2023-05-01 11:23:22
#
#       disbursement_method                                               swap  \
# 18507             BANORTE  Julia Cristina Garca Dciga,,21.00,137180103002...
# 62610             BANORTE  Marina Rivera Perez,,2.00,002685903978855849,C...
# 44051             BANORTE  Deisy Lizbeth Martinez Garza,,1.20,00282170186...
# 2087              BANORTE    Angel T,,4.00,012180015198300036,CLIP-23T5GKLP7
# 67173             BANORTE  Jose Armando De La Rosa Lpez,,3.00,01218001546...
#
#                    file_name date_query tipo_dispersion     tipo_pago
# 18507  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 62610  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 44051  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 2087   BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 67173  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
#         type                           merchant_id  \
# 18507  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 62610  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 44051  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 2087   DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 67173  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                              merchant_token       merchant_name  \
# 18507  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 62610  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 44051  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 2087   5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 67173  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                                 user_email  report_id report_date_local  \
# 18507  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01
# 62610              marina.riverp@gmail.com  22DCMNLS6        2023-05-01
# 44051          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01
# 2087                angel.mtx5@outlook.com  23T5GKLP7        2023-05-01
# 67173                delarosa16@hotmail.es  25YPZJTWW        2023-05-01
#
#        amount                 bank_name   payment_date_local  \
# 18507   21.00                 BANCOPPEL  2023-05-01 14:24:35
# 62610    2.00  Banco Nacional de México  2023-05-01 14:19:32
# 44051    1.20  Banco Nacional de México  2023-05-01 14:22:15
# 2087     4.00             BBVA Bancomer  2023-05-01 14:23:54
# 67173    3.00             BBVA Bancomer  2023-05-01 14:30:09
#
#             bank_account_owner_name  bank_account_number   batch_created_date  \
# 18507    Julia Cristina Garca Dciga  '137180103002380395  2023-05-01 11:07:54
# 62610           Marina Rivera Perez  '002685903978855849  2023-05-01 11:22:48
# 44051  Deisy Lizbeth Martinez Garza  '002821701869316000  2023-05-01 11:17:31
# 2087                        Angel T  '012180015198300036  2023-05-01 11:05:54
# 67173  Jose Armando De La Rosa Lpez  '012180015465823110  2023-05-01 11:23:22
#
#       disbursement_method                                               swap  \
# 18507             BANORTE  Julia Cristina Garca Dciga,,21.00,137180103002...
# 62610             BANORTE  Marina Rivera Perez,,2.00,002685903978855849,C...
# 44051             BANORTE  Deisy Lizbeth Martinez Garza,,1.20,00282170186...
# 2087              BANORTE    Angel T,,4.00,012180015198300036,CLIP-23T5GKLP7
# 67173             BANORTE  Jose Armando De La Rosa Lpez,,3.00,01218001546...
#
#                    file_name date_query tipo_dispersion     tipo_pago
# 18507  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 62610  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 44051  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 2087   BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día
# 67173  BNTE-1 2023-05-01.csv 2023-05-01            TRAD  Pago del día

# %%
allfiles.shape
# Out:
# (9315586, 19)
# (9315586, 19)

# %% [markdown]
# # CRUCE 1 - MES ACTUAL

# %%
cruce_1 = allfiles.merge(query_error_current_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status'
                                                   ,'error_description','esquema_query','status_cubeta']],on='report_id',how='left')
cruce_1['month'].fillna('Not found',inplace=True)
cruce_1.head()
# Out:
#     type                           merchant_id  \
# 0  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 1  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 2  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 3  DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 4  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                          merchant_token       merchant_name  \
# 0  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 1  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 2  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 3  5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 4  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                             user_email  report_id report_date_local  amount_x  \
# 0  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01     21.00
# 1              marina.riverp@gmail.com  22DCMNLS6        2023-05-01      2.00
# 2          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01      1.20
# 3               angel.mtx5@outlook.com  23T5GKLP7        2023-05-01      4.00
# 4                delarosa16@hotmail.es  25YPZJTWW        2023-05-01      3.00
#
#                   bank_name   payment_date_local  ... tipo_dispersion  \
# 0                 BANCOPPEL  2023-05-01 14:24:35  ...            TRAD
# 1  Banco Nacional de México  2023-05-01 14:19:32  ...            TRAD
# 2  Banco Nacional de México  2023-05-01 14:22:15  ...            TRAD
# 3             BBVA Bancomer  2023-05-01 14:23:54  ...            TRAD
# 4             BBVA Bancomer  2023-05-01 14:30:09  ...            TRAD
#
#       tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 0  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 1  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 3  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#   error_description esquema_query  status_cubeta
# 0               NaN           NaN            NaN
# 1               NaN           NaN            NaN
# 2               NaN           NaN            NaN
# 3               NaN           NaN            NaN
# 4               NaN           NaN            NaN
#
# [5 rows x 27 columns]
#     type                           merchant_id  \
# 0  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 1  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 2  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 3  DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 4  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                          merchant_token       merchant_name  \
# 0  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 1  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 2  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 3  5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 4  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                             user_email  report_id report_date_local  amount_x  \
# 0  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01     21.00
# 1              marina.riverp@gmail.com  22DCMNLS6        2023-05-01      2.00
# 2          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01      1.20
# 3               angel.mtx5@outlook.com  23T5GKLP7        2023-05-01      4.00
# 4                delarosa16@hotmail.es  25YPZJTWW        2023-05-01      3.00
#
#                   bank_name   payment_date_local  ... tipo_dispersion  \
# 0                 BANCOPPEL  2023-05-01 14:24:35  ...            TRAD
# 1  Banco Nacional de México  2023-05-01 14:19:32  ...            TRAD
# 2  Banco Nacional de México  2023-05-01 14:22:15  ...            TRAD
# 3             BBVA Bancomer  2023-05-01 14:23:54  ...            TRAD
# 4             BBVA Bancomer  2023-05-01 14:30:09  ...            TRAD
#
#       tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 0  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 1  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 3  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#   error_description esquema_query  status_cubeta
# 0               NaN           NaN            NaN
# 1               NaN           NaN            NaN
# 2               NaN           NaN            NaN
# 3               NaN           NaN            NaN
# 4               NaN           NaN            NaN
#
# [5 rows x 27 columns]

# %%
cruce_1.shape
# Out:
# (9315586, 27)
# (9315586, 27)

# %%
duplicates_cruce_1_previo = cruce_1[cruce_1.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_previo.head()
# Out:
#        type                           merchant_id merchant_token  \
# 2826  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 2827  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 2828  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 2829  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 5003  BLANK  5eeab96f-5f12-48b4-b577-d88680b2a15a          BLANK
#
#      merchant_name user_email  report_id report_date_local  amount_x  \
# 2826         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 2827         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 2828         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 2829         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 5003         BLANK      BLANK  A3N4YJYM4        2023-05-01 21,700.30
#
#                 bank_name   payment_date_local  ... tipo_dispersion  \
# 2826  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...            TRAD
# 2827  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...            TRAD
# 2828  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...              FP
# 2829  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...              FP
# 5003            BANCOPPEL  2023-05-01 14:28:34  ...            TRAD
#
#          tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 2826  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2827  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2828  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2829  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 5003  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#      error_description esquema_query  status_cubeta
# 2826               NaN           NaN            NaN
# 2827               NaN           NaN            NaN
# 2828               NaN           NaN            NaN
# 2829               NaN           NaN            NaN
# 5003               NaN           NaN            NaN
#
# [5 rows x 27 columns]
#        type                           merchant_id merchant_token  \
# 2826  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 2827  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 2828  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 2829  BLANK  5fe2d0d1-e3a0-44f6-aad5-d3437869629b          BLANK
# 5003  BLANK  5eeab96f-5f12-48b4-b577-d88680b2a15a          BLANK
#
#      merchant_name user_email  report_id report_date_local  amount_x  \
# 2826         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 2827         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 2828         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 2829         BLANK      BLANK  A2WJJJTJB        2023-05-01    323.89
# 5003         BLANK      BLANK  A3N4YJYM4        2023-05-01 21,700.30
#
#                 bank_name   payment_date_local  ... tipo_dispersion  \
# 2826  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...            TRAD
# 2827  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...            TRAD
# 2828  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...              FP
# 2829  Banco Inbursa, S.A.  2023-05-01 17:42:05  ...              FP
# 5003            BANCOPPEL  2023-05-01 14:28:34  ...            TRAD
#
#          tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 2826  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2827  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2828  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2829  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 5003  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#      error_description esquema_query  status_cubeta
# 2826               NaN           NaN            NaN
# 2827               NaN           NaN            NaN
# 2828               NaN           NaN            NaN
# 2829               NaN           NaN            NaN
# 5003               NaN           NaN            NaN
#
# [5 rows x 27 columns]

# %%
duplicates_cruce_1_previo.shape
# Out:
# (85409, 27)
# (85409, 27)

# %%
cruce_1_final = cruce_1[(cruce_1['month'] != 'Not found')]
cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_1_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\1938979547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\1938979547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
#             type                           merchant_id  \
# 1000021    DAILY  dd1f5a70-9dfa-4816-8fd6-e47b1748b50d
# 4146092    BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 4970051    BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 5166056  INSTANT  de16e655-aea3-4c53-9d10-799f3bede6f2
# 6048927    BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03
#
#                                merchant_token        merchant_name  \
# 1000021  d1f6e31a-d551-4ef8-ae72-0592e4799ac4            EL CAMINO
# 4146092                                 BLANK                BLANK
# 4970051                                 BLANK                BLANK
# 5166056  dfa41d56-7736-44e4-b34f-59013ff865e3  Pastelería FlanCake
# 6048927                                 BLANK                BLANK
#
#                      user_email  report_id report_date_local  amount_x  \
# 1000021  purple_aal@hotmail.com  FLH782DDN        2023-03-04      1.90
# 4146092                   BLANK  AV89N82YV        2023-06-10      4.00
# 4970051                   BLANK  AT6J8HZ49        2023-06-18     12.00
# 5166056     flancake9@gmail.com  K7YKC4VFK        2022-05-29    335.38
# 6048927                   BLANK  AX987LVJ5        2023-06-29      0.80
#
#                                                  bank_name  \
# 1000021                                        Banco Fácil
# 4146092  Opciones Empresariales del Noreste, S.A. de C....
# 4970051  Opciones Empresariales del Noreste, S.A. de C....
# 5166056  Opciones Empresariales del Noreste, S.A. de C....
# 6048927  Opciones Empresariales del Noreste, S.A. de C....
#
#           payment_date_local  ... tipo_dispersion       tipo_pago amount_y  \
# 1000021  2023-05-10 19:08:32  ...            TRAD  Reprogramación     1.90
# 4146092  2023-06-11 07:25:29  ...              FP    Pago del día     4.00
# 4970051  2023-06-19 07:35:47  ...              FP    Pago del día    12.00
# 5166056  2023-06-20 20:04:27  ...              FP  Reprogramación   335.38
# 6048927  2023-06-29 20:31:52  ...              FP    Pago del día     0.80
#
#         ultimo_mov ultimo_mov_date_only month    status  \
# 1000021 2023-07-22           2023-07-22  7.00  ERROR_TV
# 4146092 2023-07-01           2023-07-01  7.00  ERROR_TV
# 4970051 2023-07-01           2023-07-01  7.00  ERROR_TV
# 5166056 2023-07-02           2023-07-02  7.00  ERROR_TV
# 6048927 2023-07-01           2023-07-01  7.00  ERROR_TV
#
#                                          error_description esquema_query  \
# 1000021                                    sin_descripcion   ERROR_USUAL
# 4146092                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 4970051                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 5166056  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
# 6048927  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
#
#          status_cubeta
# 1000021          ERROR
# 4146092            NEW
# 4970051            NEW
# 5166056          ERROR
# 6048927            NEW
#
# [5 rows x 27 columns]
#             type                           merchant_id  \
# 1000021    DAILY  dd1f5a70-9dfa-4816-8fd6-e47b1748b50d
# 4146092    BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 4970051    BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 5166056  INSTANT  de16e655-aea3-4c53-9d10-799f3bede6f2
# 6048927    BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03
#
#                                merchant_token        merchant_name  \
# 1000021  d1f6e31a-d551-4ef8-ae72-0592e4799ac4            EL CAMINO
# 4146092                                 BLANK                BLANK
# 4970051                                 BLANK                BLANK
# 5166056  dfa41d56-7736-44e4-b34f-59013ff865e3  Pastelería FlanCake
# 6048927                                 BLANK                BLANK
#
#                      user_email  report_id report_date_local  amount_x  \
# 1000021  purple_aal@hotmail.com  FLH782DDN        2023-03-04      1.90
# 4146092                   BLANK  AV89N82YV        2023-06-10      4.00
# 4970051                   BLANK  AT6J8HZ49        2023-06-18     12.00
# 5166056     flancake9@gmail.com  K7YKC4VFK        2022-05-29    335.38
# 6048927                   BLANK  AX987LVJ5        2023-06-29      0.80
#
#                                                  bank_name  \
# 1000021                                        Banco Fácil
# 4146092  Opciones Empresariales del Noreste, S.A. de C....
# 4970051  Opciones Empresariales del Noreste, S.A. de C....
# 5166056  Opciones Empresariales del Noreste, S.A. de C....
# 6048927  Opciones Empresariales del Noreste, S.A. de C....
#
#           payment_date_local  ... tipo_dispersion       tipo_pago amount_y  \
# 1000021  2023-05-10 19:08:32  ...            TRAD  Reprogramación     1.90
# 4146092  2023-06-11 07:25:29  ...              FP    Pago del día     4.00
# 4970051  2023-06-19 07:35:47  ...              FP    Pago del día    12.00
# 5166056  2023-06-20 20:04:27  ...              FP  Reprogramación   335.38
# 6048927  2023-06-29 20:31:52  ...              FP    Pago del día     0.80
#
#         ultimo_mov ultimo_mov_date_only month    status  \
# 1000021 2023-07-22           2023-07-22  7.00  ERROR_TV
# 4146092 2023-07-01           2023-07-01  7.00  ERROR_TV
# 4970051 2023-07-01           2023-07-01  7.00  ERROR_TV
# 5166056 2023-07-02           2023-07-02  7.00  ERROR_TV
# 6048927 2023-07-01           2023-07-01  7.00  ERROR_TV
#
#                                          error_description esquema_query  \
# 1000021                                    sin_descripcion   ERROR_USUAL
# 4146092                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 4970051                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 5166056  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
# 6048927  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
#
#          status_cubeta
# 1000021          ERROR
# 4146092            NEW
# 4970051            NEW
# 5166056          ERROR
# 6048927            NEW
#
# [5 rows x 27 columns]

# %%
cruce_1_final.shape
# Out:
# (5407, 27)
# (5407, 27)

# %%
duplicates_cruce_1_final = cruce_1_final[cruce_1_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_1_final.shape
# Out:
# (0, 27)
# (0, 27)

# %% [markdown]
# # CRUCE 2 MES ACTUAL

# %%
cruce_2 = query_error_current_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_2['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_2.head()
# Out:
#    Unnamed: 0                           merchant_id merchant_name  report_id  \
# 0      129205  0489474b-6d97-4116-95a1-6046a22df36e           NaN  ATRX9663Q
# 1      129260  86f663aa-8670-4195-bb17-f9b739a30cb3           NaN  A4T34PRV8
# 2      129261  e54fb3d5-83cb-42b2-8aec-c7aee96815b3           NaN  ANFJCYW7Q
# 3      129262  8f9e63fd-834d-4c15-ba33-21731d74fbba           NaN  ACK9P6LY3
# 4      129263  98032dad-9c3a-41a4-a34f-3fdc2e751bb8           NaN  APY86FDSS
#
#   report_date_local   amount status                       error_description  \
# 0        2023-07-01     6.20  ERROR  Bank account information not available
# 1        2023-07-01 1,629.00  ERROR  Bank account information not available
# 2        2023-07-01     0.01  ERROR  Bank account information not available
# 3        2023-07-01 1,959.59  ERROR  Bank account information not available
# 4        2023-07-01     5.00  ERROR  Bank account information not available
#
#   ultimo_mov  month  year status_cubeta esquema_query  \
# 0 2023-07-01      7  2023           NEW     SIN_CLABE
# 1 2023-07-01      7  2023           NEW     SIN_CLABE
# 2 2023-07-01      7  2023           NEW     SIN_CLABE
# 3 2023-07-01      7  2023           NEW     SIN_CLABE
# 4 2023-07-01      7  2023           NEW     SIN_CLABE
#
#                       merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 0  0489474b-6d97-4116-95a1-6046a22df36e           2023-07-01    1     Actual
# 1  86f663aa-8670-4195-bb17-f9b739a30cb3           2023-07-01    1     Actual
# 2  e54fb3d5-83cb-42b2-8aec-c7aee96815b3           2023-07-01    1     Actual
# 3  8f9e63fd-834d-4c15-ba33-21731d74fbba           2023-07-01    1     Actual
# 4  98032dad-9c3a-41a4-a34f-3fdc2e751bb8           2023-07-01    1     Actual
#
#   tipo_dispersion tipo_pago
# 0       Not found       NaN
# 1       Not found       NaN
# 2       Not found       NaN
# 3       Not found       NaN
# 4       Not found       NaN
#    Unnamed: 0                           merchant_id merchant_name  report_id  \
# 0      129205  0489474b-6d97-4116-95a1-6046a22df36e           NaN  ATRX9663Q
# 1      129260  86f663aa-8670-4195-bb17-f9b739a30cb3           NaN  A4T34PRV8
# 2      129261  e54fb3d5-83cb-42b2-8aec-c7aee96815b3           NaN  ANFJCYW7Q
# 3      129262  8f9e63fd-834d-4c15-ba33-21731d74fbba           NaN  ACK9P6LY3
# 4      129263  98032dad-9c3a-41a4-a34f-3fdc2e751bb8           NaN  APY86FDSS
#
#   report_date_local   amount status                       error_description  \
# 0        2023-07-01     6.20  ERROR  Bank account information not available
# 1        2023-07-01 1,629.00  ERROR  Bank account information not available
# 2        2023-07-01     0.01  ERROR  Bank account information not available
# 3        2023-07-01 1,959.59  ERROR  Bank account information not available
# 4        2023-07-01     5.00  ERROR  Bank account information not available
#
#   ultimo_mov  month  year status_cubeta esquema_query  \
# 0 2023-07-01      7  2023           NEW     SIN_CLABE
# 1 2023-07-01      7  2023           NEW     SIN_CLABE
# 2 2023-07-01      7  2023           NEW     SIN_CLABE
# 3 2023-07-01      7  2023           NEW     SIN_CLABE
# 4 2023-07-01      7  2023           NEW     SIN_CLABE
#
#                       merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 0  0489474b-6d97-4116-95a1-6046a22df36e           2023-07-01    1     Actual
# 1  86f663aa-8670-4195-bb17-f9b739a30cb3           2023-07-01    1     Actual
# 2  e54fb3d5-83cb-42b2-8aec-c7aee96815b3           2023-07-01    1     Actual
# 3  8f9e63fd-834d-4c15-ba33-21731d74fbba           2023-07-01    1     Actual
# 4  98032dad-9c3a-41a4-a34f-3fdc2e751bb8           2023-07-01    1     Actual
#
#   tipo_dispersion tipo_pago
# 0       Not found       NaN
# 1       Not found       NaN
# 2       Not found       NaN
# 3       Not found       NaN
# 4       Not found       NaN

# %%
cruce_2.shape
# Out:
# (14118, 19)
# (14118, 19)

# %%
cruce_2_final = cruce_2[(cruce_2['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_2_final.head()
# Out:
#     Unnamed: 0                           merchant_id merchant_name  report_id  \
# 6       129094  fbae86a1-9ef9-4bb9-ba75-09e5c304bad4           NaN  ATQXHXGCK
# 35      129240  a343b5ef-e206-47fa-bac7-8549b24a05a1           NaN  AWYDFY8XB
# 54      129081  f72c876b-c8a4-4685-b1a8-f32bc572db07           NaN  ARHC9KWPR
# 55      129083  54fbc56c-6075-46ca-bbea-23fbe69c182a           NaN  AXKN38BJ5
# 60      129084  29dd15ea-ae79-41f0-a21c-ac425a98a445           NaN  AMFCYGSDR
#
#    report_date_local  amount status                     error_description  \
# 6         2023-06-30  132.37  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
# 35        2023-07-01  766.59  ERROR  NOMBRE DEL RECEPTOR DEBE INFORMARSE.
# 54        2023-06-30  114.03  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
# 55        2023-06-30  140.86  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
# 60        2023-06-30  421.63  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
#
#    ultimo_mov  month  year status_cubeta esquema_query  \
# 6  2023-07-01      7  2023           NEW   ERROR_USUAL
# 35 2023-07-01      7  2023           NEW   ERROR_USUAL
# 54 2023-07-01      7  2023           NEW   ERROR_USUAL
# 55 2023-07-01      7  2023           NEW   ERROR_USUAL
# 60 2023-07-01      7  2023           NEW   ERROR_USUAL
#
#                        merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 6   fbae86a1-9ef9-4bb9-ba75-09e5c304bad4           2023-07-01    1     Actual
# 35  a343b5ef-e206-47fa-bac7-8549b24a05a1           2023-07-01    1     Actual
# 54  f72c876b-c8a4-4685-b1a8-f32bc572db07           2023-07-01    1     Actual
# 55  54fbc56c-6075-46ca-bbea-23fbe69c182a           2023-07-01    1     Actual
# 60  29dd15ea-ae79-41f0-a21c-ac425a98a445           2023-07-01    1     Actual
#
#    tipo_dispersion     tipo_pago
# 6             TRAD  Pago del día
# 35            TRAD  Pago del día
# 54            TRAD  Pago del día
# 55            TRAD  Pago del día
# 60            TRAD  Pago del día
#     Unnamed: 0                           merchant_id merchant_name  report_id  \
# 6       129094  fbae86a1-9ef9-4bb9-ba75-09e5c304bad4           NaN  ATQXHXGCK
# 35      129240  a343b5ef-e206-47fa-bac7-8549b24a05a1           NaN  AWYDFY8XB
# 54      129081  f72c876b-c8a4-4685-b1a8-f32bc572db07           NaN  ARHC9KWPR
# 55      129083  54fbc56c-6075-46ca-bbea-23fbe69c182a           NaN  AXKN38BJ5
# 60      129084  29dd15ea-ae79-41f0-a21c-ac425a98a445           NaN  AMFCYGSDR
#
#    report_date_local  amount status                     error_description  \
# 6         2023-06-30  132.37  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
# 35        2023-07-01  766.59  ERROR  NOMBRE DEL RECEPTOR DEBE INFORMARSE.
# 54        2023-06-30  114.03  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
# 55        2023-06-30  140.86  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
# 60        2023-06-30  421.63  ERROR        DEV.SPEIEXCEDE EL LNMITE DE AB
#
#    ultimo_mov  month  year status_cubeta esquema_query  \
# 6  2023-07-01      7  2023           NEW   ERROR_USUAL
# 35 2023-07-01      7  2023           NEW   ERROR_USUAL
# 54 2023-07-01      7  2023           NEW   ERROR_USUAL
# 55 2023-07-01      7  2023           NEW   ERROR_USUAL
# 60 2023-07-01      7  2023           NEW   ERROR_USUAL
#
#                        merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 6   fbae86a1-9ef9-4bb9-ba75-09e5c304bad4           2023-07-01    1     Actual
# 35  a343b5ef-e206-47fa-bac7-8549b24a05a1           2023-07-01    1     Actual
# 54  f72c876b-c8a4-4685-b1a8-f32bc572db07           2023-07-01    1     Actual
# 55  54fbc56c-6075-46ca-bbea-23fbe69c182a           2023-07-01    1     Actual
# 60  29dd15ea-ae79-41f0-a21c-ac425a98a445           2023-07-01    1     Actual
#
#    tipo_dispersion     tipo_pago
# 6             TRAD  Pago del día
# 35            TRAD  Pago del día
# 54            TRAD  Pago del día
# 55            TRAD  Pago del día
# 60            TRAD  Pago del día

# %%
cruce_2_final.shape
# Out:
# (9125, 19)
# (9125, 19)

# %%
duplicates_cruce_2_final = cruce_2_final[cruce_2_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_2_final.head()
# Out:
#      Unnamed: 0                           merchant_id merchant_name  \
# 109      128350  c360bab1-1acb-4c0a-9c05-fa82a1557a03           NaN
# 110      128350  c360bab1-1acb-4c0a-9c05-fa82a1557a03           NaN
# 126      129149  dc547d79-14b6-484f-9609-4426530da61b           NaN
# 127      129149  dc547d79-14b6-484f-9609-4426530da61b           NaN
# 128      129149  dc547d79-14b6-484f-9609-4426530da61b           NaN
#
#      report_id report_date_local   amount    status  \
# 109  AX987LVJ5        2023-06-29     0.80  ERROR_TV
# 110  AX987LVJ5        2023-06-29     0.80  ERROR_TV
# 126  A585DBV42        2023-07-01 2,345.78     ERROR
# 127  A585DBV42        2023-07-01 2,345.78     ERROR
# 128  A585DBV42        2023-07-01 2,345.78     ERROR
#
#                                      error_description ultimo_mov  month  \
# 109  /21/CB Return Exceeds the limit of credits all... 2023-07-01      7
# 110  /21/CB Return Exceeds the limit of credits all... 2023-07-01      7
# 126                  PLAZA ERRONEA EN CLABE RECEPTORA. 2023-07-01      7
# 127                  PLAZA ERRONEA EN CLABE RECEPTORA. 2023-07-01      7
# 128                  PLAZA ERRONEA EN CLABE RECEPTORA. 2023-07-01      7
#
#      year status_cubeta esquema_query                     merchant_id_query  \
# 109  2023           NEW   ERROR_USUAL  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 110  2023           NEW   ERROR_USUAL  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 126  2023           NEW   ERROR_USUAL  dc547d79-14b6-484f-9609-4426530da61b
# 127  2023           NEW   ERROR_USUAL  dc547d79-14b6-484f-9609-4426530da61b
# 128  2023           NEW   ERROR_USUAL  dc547d79-14b6-484f-9609-4426530da61b
#
#     ultimo_mov_date_only  day mes_cierre tipo_dispersion     tipo_pago
# 109           2023-07-01    1     Actual            TRAD  Pago del día
# 110           2023-07-01    1     Actual              FP  Pago del día
# 126           2023-07-01    1     Actual            TRAD  Pago del día
# 127           2023-07-01    1     Actual              FP  Pago del día
# 128           2023-07-01    1     Actual              FP  Pago del día
#      Unnamed: 0                           merchant_id merchant_name  \
# 109      128350  c360bab1-1acb-4c0a-9c05-fa82a1557a03           NaN
# 110      128350  c360bab1-1acb-4c0a-9c05-fa82a1557a03           NaN
# 126      129149  dc547d79-14b6-484f-9609-4426530da61b           NaN
# 127      129149  dc547d79-14b6-484f-9609-4426530da61b           NaN
# 128      129149  dc547d79-14b6-484f-9609-4426530da61b           NaN
#
#      report_id report_date_local   amount    status  \
# 109  AX987LVJ5        2023-06-29     0.80  ERROR_TV
# 110  AX987LVJ5        2023-06-29     0.80  ERROR_TV
# 126  A585DBV42        2023-07-01 2,345.78     ERROR
# 127  A585DBV42        2023-07-01 2,345.78     ERROR
# 128  A585DBV42        2023-07-01 2,345.78     ERROR
#
#                                      error_description ultimo_mov  month  \
# 109  /21/CB Return Exceeds the limit of credits all... 2023-07-01      7
# 110  /21/CB Return Exceeds the limit of credits all... 2023-07-01      7
# 126                  PLAZA ERRONEA EN CLABE RECEPTORA. 2023-07-01      7
# 127                  PLAZA ERRONEA EN CLABE RECEPTORA. 2023-07-01      7
# 128                  PLAZA ERRONEA EN CLABE RECEPTORA. 2023-07-01      7
#
#      year status_cubeta esquema_query                     merchant_id_query  \
# 109  2023           NEW   ERROR_USUAL  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 110  2023           NEW   ERROR_USUAL  c360bab1-1acb-4c0a-9c05-fa82a1557a03
# 126  2023           NEW   ERROR_USUAL  dc547d79-14b6-484f-9609-4426530da61b
# 127  2023           NEW   ERROR_USUAL  dc547d79-14b6-484f-9609-4426530da61b
# 128  2023           NEW   ERROR_USUAL  dc547d79-14b6-484f-9609-4426530da61b
#
#     ultimo_mov_date_only  day mes_cierre tipo_dispersion     tipo_pago
# 109           2023-07-01    1     Actual            TRAD  Pago del día
# 110           2023-07-01    1     Actual              FP  Pago del día
# 126           2023-07-01    1     Actual            TRAD  Pago del día
# 127           2023-07-01    1     Actual              FP  Pago del día
# 128           2023-07-01    1     Actual              FP  Pago del día

# %%
duplicates_cruce_2_final.shape
# Out:
# (5642, 19)
# (5642, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ACTUAL

# %%
group_tipo_pago = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago.fillna(0,inplace=True)
group_tipo_pago.head()
# Out:
#                 ultimo_mov_date_only       amount_x                 \
# esquema_query                           ERROR_USUAL
# status_cubeta                                 ERROR
# tipo_dispersion                                  FP           TRAD
# tipo_pago                            Reprogramación Reprogramación
# 0                         2023-07-01           0.00           0.00
# 1                         2023-07-02         335.38           0.00
# 2                         2023-07-03      12,774.58           0.00
# 3                         2023-07-04          22.51           0.00
# 4                         2023-07-05           0.00           0.00
#
#                                                                          \
# esquema_query
# status_cubeta            NEW
# tipo_dispersion           FP                        TRAD
# tipo_pago       Pago del día Reprogramación Pago del día Reprogramación
# 0                   2,362.58           0.00    15,540.40           0.00
# 1                   3,045.56           0.00   123,743.63      46,953.76
# 2                   2,667.22       3,740.97   102,324.63           0.00
# 3                  10,564.88           0.00    81,832.11           0.00
# 4                  13,205.64           0.00    41,816.75           0.00
#
#
# esquema_query          All
# status_cubeta
# tipo_dispersion
# tipo_pago
# 0                17,902.98
# 1               174,078.33
# 2               121,507.40
# 3                92,419.50
# 4                55,022.39
#                 ultimo_mov_date_only       amount_x                 \
# esquema_query                           ERROR_USUAL
# status_cubeta                                 ERROR
# tipo_dispersion                                  FP           TRAD
# tipo_pago                            Reprogramación Reprogramación
# 0                         2023-07-01           0.00           0.00
# 1                         2023-07-02         335.38           0.00
# 2                         2023-07-03      12,774.58           0.00
# 3                         2023-07-04          22.51           0.00
# 4                         2023-07-05           0.00           0.00
#
#                                                                          \
# esquema_query
# status_cubeta            NEW
# tipo_dispersion           FP                        TRAD
# tipo_pago       Pago del día Reprogramación Pago del día Reprogramación
# 0                   2,362.58           0.00    15,540.40           0.00
# 1                   3,045.56           0.00   123,743.63      46,953.76
# 2                   2,667.22       3,740.97   102,324.63           0.00
# 3                  10,564.88           0.00    81,832.11           0.00
# 4                  13,205.64           0.00    41,816.75           0.00
#
#
# esquema_query          All
# status_cubeta
# tipo_dispersion
# tipo_pago
# 0                17,902.98
# 1               174,078.33
# 2               121,507.40
# 3                92,419.50
# 4                55,022.39

# %%
group_tipo_pago.shape
# Out:
# (32, 8)
# (32, 8)

# %%
group_esquema = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema.fillna(0,inplace=True)
group_esquema.head()
# Out:
#               ultimo_mov_date_only       amount_x                              \
# esquema_query                         ERROR_USUAL
# status_cubeta                               ERROR          NEW
# tipo_pago                          Reprogramación Pago del día Reprogramación
# 0                       2023-07-01           0.00    17,902.98           0.00
# 1                       2023-07-02         335.38   126,789.19      46,953.76
# 2                       2023-07-03      12,774.58   104,991.85       3,740.97
# 3                       2023-07-04          22.51    92,396.99           0.00
# 4                       2023-07-05           0.00    55,022.39           0.00
#
#
# esquema_query        All
# status_cubeta
# tipo_pago
# 0              17,902.98
# 1             174,078.33
# 2             121,507.40
# 3              92,419.50
# 4              55,022.39
#               ultimo_mov_date_only       amount_x                              \
# esquema_query                         ERROR_USUAL
# status_cubeta                               ERROR          NEW
# tipo_pago                          Reprogramación Pago del día Reprogramación
# 0                       2023-07-01           0.00    17,902.98           0.00
# 1                       2023-07-02         335.38   126,789.19      46,953.76
# 2                       2023-07-03      12,774.58   104,991.85       3,740.97
# 3                       2023-07-04          22.51    92,396.99           0.00
# 4                       2023-07-05           0.00    55,022.39           0.00
#
#
# esquema_query        All
# status_cubeta
# tipo_pago
# 0              17,902.98
# 1             174,078.33
# 2             121,507.40
# 3              92,419.50
# 4              55,022.39

# %%
group_esquema.shape
# Out:
# (32, 5)
# (32, 5)

# %% [markdown]
# # CRUCE 3 - MES ANTERIOR

# %%
cruce_3 = allfiles.merge(query_new_last_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status',
                                               'error_description','esquema_query','status_cubeta']],
                         on='report_id',how='left')
cruce_3['month'].fillna('Not found',inplace=True)
cruce_3.head()
# Out:
#     type                           merchant_id  \
# 0  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 1  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 2  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 3  DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 4  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                          merchant_token       merchant_name  \
# 0  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 1  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 2  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 3  5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 4  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                             user_email  report_id report_date_local  amount_x  \
# 0  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01     21.00
# 1              marina.riverp@gmail.com  22DCMNLS6        2023-05-01      2.00
# 2          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01      1.20
# 3               angel.mtx5@outlook.com  23T5GKLP7        2023-05-01      4.00
# 4                delarosa16@hotmail.es  25YPZJTWW        2023-05-01      3.00
#
#                   bank_name   payment_date_local  ... tipo_dispersion  \
# 0                 BANCOPPEL  2023-05-01 14:24:35  ...            TRAD
# 1  Banco Nacional de México  2023-05-01 14:19:32  ...            TRAD
# 2  Banco Nacional de México  2023-05-01 14:22:15  ...            TRAD
# 3             BBVA Bancomer  2023-05-01 14:23:54  ...            TRAD
# 4             BBVA Bancomer  2023-05-01 14:30:09  ...            TRAD
#
#       tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 0  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 1  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 3  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#   error_description esquema_query  status_cubeta
# 0               NaN           NaN            NaN
# 1               NaN           NaN            NaN
# 2               NaN           NaN            NaN
# 3               NaN           NaN            NaN
# 4               NaN           NaN            NaN
#
# [5 rows x 27 columns]
#     type                           merchant_id  \
# 0  DAILY  3a32f549-9b64-4ba4-98cc-fa7f5b460857
# 1  DAILY  c4bc334c-b81b-46e3-b12c-3ed6bfa17171
# 2  DAILY  8a8c78e3-49dc-44d7-aa25-461d7582a9a5
# 3  DAILY  06721d30-e862-4ee6-9a3d-276325174439
# 4  DAILY  d31c00e6-ed04-4953-a92b-7c443ff6add0
#
#                          merchant_token       merchant_name  \
# 0  292c308e-f888-40f7-9d03-374aebb844ef    Alimentos Deciga
# 1  7b769ba3-ef63-47a5-a5e1-6192a02df812             Al flom
# 2  fc8fba45-e296-4925-a377-d32f447ff372  Pandas Kawaii Shop
# 3  5ab53f86-fd47-4a68-bb27-41b562724305            Wardrobe
# 4  0f1f98cc-5ff7-467c-af35-ac8dbe90f125       Cremeria susy
#
#                             user_email  report_id report_date_local  amount_x  \
# 0  camachogarciakarenlizeth9@gmail.com  22CZN927X        2023-05-01     21.00
# 1              marina.riverp@gmail.com  22DCMNLS6        2023-05-01      2.00
# 2          pandaskawaiishop2@gmail.com  23DDT8YSQ        2023-05-01      1.20
# 3               angel.mtx5@outlook.com  23T5GKLP7        2023-05-01      4.00
# 4                delarosa16@hotmail.es  25YPZJTWW        2023-05-01      3.00
#
#                   bank_name   payment_date_local  ... tipo_dispersion  \
# 0                 BANCOPPEL  2023-05-01 14:24:35  ...            TRAD
# 1  Banco Nacional de México  2023-05-01 14:19:32  ...            TRAD
# 2  Banco Nacional de México  2023-05-01 14:22:15  ...            TRAD
# 3             BBVA Bancomer  2023-05-01 14:23:54  ...            TRAD
# 4             BBVA Bancomer  2023-05-01 14:30:09  ...            TRAD
#
#       tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 0  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 1  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 3  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#   error_description esquema_query  status_cubeta
# 0               NaN           NaN            NaN
# 1               NaN           NaN            NaN
# 2               NaN           NaN            NaN
# 3               NaN           NaN            NaN
# 4               NaN           NaN            NaN
#
# [5 rows x 27 columns]

# %%
cruce_3.shape
# Out:
# (9315586, 27)
# (9315586, 27)

# %%
cruce_3_final = cruce_3[(cruce_3['month'] != 'Not found')]
cruce_3_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_3_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\2713612933.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_3_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_10852\2713612933.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_3_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
#           type                           merchant_id  \
# 5166119  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5264976  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5264991  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5264998  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5265002  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#                                merchant_token        merchant_name  \
# 5166119  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5264976  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5264991  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5264998  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5265002  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
#
#                                 user_email  report_id report_date_local  \
# 5166119  edithzoraidasalazarcruz@gmail.com  95JLP3FKP        2023-01-12
# 5264976  edithzoraidasalazarcruz@gmail.com  BQY58NVF4        2022-12-12
# 5264991  edithzoraidasalazarcruz@gmail.com  HR28PSBBR        2022-11-18
# 5264998  edithzoraidasalazarcruz@gmail.com  LGDLG24B9        2023-02-11
# 5265002  edithzoraidasalazarcruz@gmail.com  MRGNX9SF3        2022-11-21
#
#          amount_x bank_name   payment_date_local  ... tipo_dispersion  \
# 5166119  3,449.67   BANORTE  2023-06-21 19:12:59  ...            TRAD
# 5264976  3,269.74   BANORTE  2023-06-21 19:13:01  ...            TRAD
# 5264991      2.00   BANORTE  2023-06-21 19:13:01  ...            TRAD
# 5264998  2,587.25   BANORTE  2023-06-21 19:12:59  ...            TRAD
# 5265002  2,751.37   BANORTE  2023-06-21 19:12:59  ...            TRAD
#
#               tipo_pago amount_y ultimo_mov ultimo_mov_date_only month status  \
# 5166119  Reprogramación 3,449.67 2023-06-21           2023-06-21  6.00  ERROR
# 5264976  Reprogramación 3,269.74 2023-06-21           2023-06-21  6.00  ERROR
# 5264991  Reprogramación     2.00 2023-06-21           2023-06-21  6.00  ERROR
# 5264998  Reprogramación 2,587.25 2023-06-21           2023-06-21  6.00  ERROR
# 5265002  Reprogramación 2,751.37 2023-06-21           2023-06-21  6.00  ERROR
#
#                                          error_description esquema_query  \
# 5166119  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5264976  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5264991  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5264998  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5265002  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
#
#          status_cubeta
# 5166119            NEW
# 5264976            NEW
# 5264991            NEW
# 5264998            NEW
# 5265002            NEW
#
# [5 rows x 27 columns]
#           type                           merchant_id  \
# 5166119  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5264976  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5264991  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5264998  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
# 5265002  DAILY  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#                                merchant_token        merchant_name  \
# 5166119  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5264976  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5264991  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5264998  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
# 5265002  8001523d-d4ff-4678-aeab-d46e0dbb2c52  Viajes Zory Salazar
#
#                                 user_email  report_id report_date_local  \
# 5166119  edithzoraidasalazarcruz@gmail.com  95JLP3FKP        2023-01-12
# 5264976  edithzoraidasalazarcruz@gmail.com  BQY58NVF4        2022-12-12
# 5264991  edithzoraidasalazarcruz@gmail.com  HR28PSBBR        2022-11-18
# 5264998  edithzoraidasalazarcruz@gmail.com  LGDLG24B9        2023-02-11
# 5265002  edithzoraidasalazarcruz@gmail.com  MRGNX9SF3        2022-11-21
#
#          amount_x bank_name   payment_date_local  ... tipo_dispersion  \
# 5166119  3,449.67   BANORTE  2023-06-21 19:12:59  ...            TRAD
# 5264976  3,269.74   BANORTE  2023-06-21 19:13:01  ...            TRAD
# 5264991      2.00   BANORTE  2023-06-21 19:13:01  ...            TRAD
# 5264998  2,587.25   BANORTE  2023-06-21 19:12:59  ...            TRAD
# 5265002  2,751.37   BANORTE  2023-06-21 19:12:59  ...            TRAD
#
#               tipo_pago amount_y ultimo_mov ultimo_mov_date_only month status  \
# 5166119  Reprogramación 3,449.67 2023-06-21           2023-06-21  6.00  ERROR
# 5264976  Reprogramación 3,269.74 2023-06-21           2023-06-21  6.00  ERROR
# 5264991  Reprogramación     2.00 2023-06-21           2023-06-21  6.00  ERROR
# 5264998  Reprogramación 2,587.25 2023-06-21           2023-06-21  6.00  ERROR
# 5265002  Reprogramación 2,751.37 2023-06-21           2023-06-21  6.00  ERROR
#
#                                          error_description esquema_query  \
# 5166119  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5264976  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5264991  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5264998  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
# 5265002  DEVOLUCION(01): Cuenta inexistente        0728...   ERROR_USUAL
#
#          status_cubeta
# 5166119            NEW
# 5264976            NEW
# 5264991            NEW
# 5264998            NEW
# 5265002            NEW
#
# [5 rows x 27 columns]

# %%
cruce_3_final.shape
# Out:
# (8, 27)
# (8, 27)

# %%
duplicates_cruce_3_final = cruce_3_final[cruce_3_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_3_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_3_final.shape
# Out:
# (0, 27)
# (0, 27)

# %% [markdown]
# # CRUCE 4 - MES ANTERIOR

# %%
cruce_4 = query_new_last_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_4['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_4.head()
# Out:
#    Unnamed: 0                           merchant_id        merchant_name  \
# 0       96528  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 1      104580  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 2      103538  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 3      103309  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 4      101755  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#    report_id report_date_local   amount    status  \
# 0  SSL6DGTLG        2022-12-31     8.00  ERROR_TV
# 1  S92NNTKJ3        2023-03-07 1,724.83  ERROR_TV
# 2  DCWNBQZC5        2023-02-27     8.00  ERROR_TV
# 3  9X787BYD8        2023-02-25 3,449.66  ERROR_TV
# 4  WSM742YZC        2023-02-15     8.00  ERROR_TV
#
#                                    error_description ultimo_mov  month  year  \
# 0                     CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6  2023
# 1  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6  2023
# 2  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6  2023
# 3                     CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6  2023
# 4  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6  2023
#
#   status_cubeta esquema_query                     merchant_id_query  \
# 0           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 1           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 2           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 3           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 4           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#   ultimo_mov_date_only  day mes_cierre tipo_dispersion tipo_pago
# 0           2023-06-01    1        NaN       Not found       NaN
# 1           2023-06-01    1        NaN       Not found       NaN
# 2           2023-06-01    1        NaN       Not found       NaN
# 3           2023-06-01    1        NaN       Not found       NaN
# 4           2023-06-01    1        NaN       Not found       NaN
#    Unnamed: 0                           merchant_id        merchant_name  \
# 0       96528  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 1      104580  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 2      103538  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 3      103309  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 4      101755  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#    report_id report_date_local   amount    status  \
# 0  SSL6DGTLG        2022-12-31     8.00  ERROR_TV
# 1  S92NNTKJ3        2023-03-07 1,724.83  ERROR_TV
# 2  DCWNBQZC5        2023-02-27     8.00  ERROR_TV
# 3  9X787BYD8        2023-02-25 3,449.66  ERROR_TV
# 4  WSM742YZC        2023-02-15     8.00  ERROR_TV
#
#                                    error_description ultimo_mov  month  year  \
# 0                     CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6  2023
# 1  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6  2023
# 2  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6  2023
# 3                     CUENTA NO ACTIVA,    VERIFICAR 2023-06-01      6  2023
# 4  DEVOLUCION(03): Cuenta cancelada        072813... 2023-06-01      6  2023
#
#   status_cubeta esquema_query                     merchant_id_query  \
# 0           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 1           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 2           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 3           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 4           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#   ultimo_mov_date_only  day mes_cierre tipo_dispersion tipo_pago
# 0           2023-06-01    1        NaN       Not found       NaN
# 1           2023-06-01    1        NaN       Not found       NaN
# 2           2023-06-01    1        NaN       Not found       NaN
# 3           2023-06-01    1        NaN       Not found       NaN
# 4           2023-06-01    1        NaN       Not found       NaN

# %%
cruce_4.shape
# Out:
# (68, 19)
# (68, 19)

# %%
cruce_4_final = cruce_4[(cruce_4['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_4_final.head()
# Out:
#     Unnamed: 0                           merchant_id        merchant_name  \
# 12       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 13       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 14       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 15       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 16       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#     report_id report_date_local   amount status  \
# 12  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 13  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 14  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 15  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 16  BQY58NVF4        2022-12-12 3,269.74  ERROR
#
#                                     error_description ultimo_mov  month  year  \
# 12  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 13  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 14  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 15  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 16  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
#
#    status_cubeta esquema_query                     merchant_id_query  \
# 12           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 13           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 14           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 15           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 16           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#    ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 12           2023-06-21   21        NaN            TRAD  Reprogramación
# 13           2023-06-21   21        NaN            TRAD  Reprogramación
# 14           2023-06-21   21        NaN            TRAD  Reprogramación
# 15           2023-06-21   21        NaN            TRAD  Reprogramación
# 16           2023-06-21   21        NaN            TRAD  Reprogramación
#     Unnamed: 0                           merchant_id        merchant_name  \
# 12       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 13       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 14       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 15       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 16       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#     report_id report_date_local   amount status  \
# 12  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 13  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 14  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 15  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 16  BQY58NVF4        2022-12-12 3,269.74  ERROR
#
#                                     error_description ultimo_mov  month  year  \
# 12  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 13  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 14  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 15  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 16  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
#
#    status_cubeta esquema_query                     merchant_id_query  \
# 12           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 13           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 14           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 15           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 16           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#    ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 12           2023-06-21   21        NaN            TRAD  Reprogramación
# 13           2023-06-21   21        NaN            TRAD  Reprogramación
# 14           2023-06-21   21        NaN            TRAD  Reprogramación
# 15           2023-06-21   21        NaN            TRAD  Reprogramación
# 16           2023-06-21   21        NaN            TRAD  Reprogramación

# %%
cruce_4_final.shape
# Out:
# (56, 19)
# (56, 19)

# %%
duplicates_cruce_4_final = cruce_4_final[cruce_4_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_4_final.head()
# Out:
#     Unnamed: 0                           merchant_id        merchant_name  \
# 12       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 13       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 14       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 15       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 16       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#     report_id report_date_local   amount status  \
# 12  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 13  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 14  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 15  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 16  BQY58NVF4        2022-12-12 3,269.74  ERROR
#
#                                     error_description ultimo_mov  month  year  \
# 12  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 13  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 14  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 15  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 16  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
#
#    status_cubeta esquema_query                     merchant_id_query  \
# 12           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 13           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 14           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 15           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 16           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#    ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 12           2023-06-21   21        NaN            TRAD  Reprogramación
# 13           2023-06-21   21        NaN            TRAD  Reprogramación
# 14           2023-06-21   21        NaN            TRAD  Reprogramación
# 15           2023-06-21   21        NaN            TRAD  Reprogramación
# 16           2023-06-21   21        NaN            TRAD  Reprogramación
#     Unnamed: 0                           merchant_id        merchant_name  \
# 12       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 13       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 14       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 15       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
# 16       93543  41483b66-12f7-42e8-8484-26a20dd9a4de  Viajes Zory Salazar
#
#     report_id report_date_local   amount status  \
# 12  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 13  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 14  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 15  BQY58NVF4        2022-12-12 3,269.74  ERROR
# 16  BQY58NVF4        2022-12-12 3,269.74  ERROR
#
#                                     error_description ultimo_mov  month  year  \
# 12  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 13  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 14  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 15  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
# 16  DEVOLUCION(01): Cuenta inexistente        0728... 2023-06-21      6  2023
#
#    status_cubeta esquema_query                     merchant_id_query  \
# 12           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 13           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 14           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 15           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
# 16           NEW   ERROR_USUAL  41483b66-12f7-42e8-8484-26a20dd9a4de
#
#    ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 12           2023-06-21   21        NaN            TRAD  Reprogramación
# 13           2023-06-21   21        NaN            TRAD  Reprogramación
# 14           2023-06-21   21        NaN            TRAD  Reprogramación
# 15           2023-06-21   21        NaN            TRAD  Reprogramación
# 16           2023-06-21   21        NaN            TRAD  Reprogramación

# %%
duplicates_cruce_4_final.shape
# Out:
# (56, 19)
# (56, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ANTERIOR

# %%
group_tipo_pago_last_month = pd.pivot_table(cruce_3_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago_last_month.fillna(0,inplace=True)
group_tipo_pago_last_month.head()
# Out:
#                 ultimo_mov_date_only       amount_x
# esquema_query                           ERROR_USUAL       All
# status_cubeta                                   NEW
# tipo_dispersion                                TRAD
# tipo_pago                            Reprogramación
# 0                         2023-06-21      16,851.23 16,851.23
# 1                                All      16,851.23 16,851.23
#                 ultimo_mov_date_only       amount_x
# esquema_query                           ERROR_USUAL       All
# status_cubeta                                   NEW
# tipo_dispersion                                TRAD
# tipo_pago                            Reprogramación
# 0                         2023-06-21      16,851.23 16,851.23
# 1                                All      16,851.23 16,851.23

# %%
group_tipo_pago_last_month.shape
# Out:
# (2, 3)
# (2, 3)

# %%
group_esquema_last_month = pd.pivot_table(cruce_4_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema_last_month.fillna(0,inplace=True)
group_esquema_last_month.head()
# Out:
#               ultimo_mov_date_only         amount
# esquema_query                         ERROR_USUAL        All
# status_cubeta                                 NEW
# tipo_pago                          Reprogramación
# 0                       2023-06-21     117,958.61 117,958.61
# 1                              All     117,958.61 117,958.61
#               ultimo_mov_date_only         amount
# esquema_query                         ERROR_USUAL        All
# status_cubeta                                 NEW
# tipo_pago                          Reprogramación
# 0                       2023-06-21     117,958.61 117,958.61
# 1                              All     117,958.61 117,958.61

# %%
group_esquema_last_month.shape
# Out:
# (2, 3)
# (2, 3)

# %%
writer = pd.ExcelWriter('FASE V. DATA POLIZA ERROR-USUAL JULIO 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
group_tipo_pago.to_excel(writer, sheet_name='GRUPO TIPO PAGO')
group_esquema.to_excel(writer, sheet_name='GRUPO ESQUEMA')
group_tipo_pago_last_month.to_excel(writer, sheet_name='GRUPO TIPO PAGO-MESES ANT')
group_esquema_last_month.to_excel(writer, sheet_name='GRUPO ESQUEMA-MESES ANT')
cruce_1_final.to_excel(writer, sheet_name='DETALLE',index=False)
cruce_3_final.to_excel(writer, sheet_name='DETALLE-MESES ANTERIORES',index=False)
writer.close()
