# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %%
start_date = '2023-10-01'
final_date = '2023-10-31'
query_error_year = 2023
query_error_month = 10

# %% [markdown]
# # INFORMACION DE  CUBETA ERROR

# %%
query_error = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\POLIZAS\2023\10. OCTUBRE\DATA\ERROR OCTUBRE 2023.csv',
                          dtype={'report_id':object})
query_error.rename(columns ={'MAX(report_date_local)':'report_date_local'}, inplace=True)
query_error['report_date_local']= pd.to_datetime(query_error['report_date_local'])
query_error['ultimo_mov'] = pd.to_datetime(query_error['ultimo_mov'])
query_error['merchant_id_query'] = query_error['merchant_id']
query_error['ultimo_mov_date_only']= pd.to_datetime(query_error['ultimo_mov']).dt.date
query_error['day'] = query_error['ultimo_mov'].dt.day
query_error['month'] = query_error['ultimo_mov'].dt.month
query_error['year'] = query_error['ultimo_mov'].dt.year
# query_error.loc[((query_error['day'] == 30 )
#                 & (query_error['month'] == 7)
#                 & (query_error['year'] == 2022)), "mes_cierre"] = 'Actual'
# query_error.loc[(query_error['day'] == 31 )
#             & (query_error['month'] == 7 )
#             & (query_error['year'] == 2022), "mes_cierre"] = 'Actual'
query_error.loc[(query_error['month'] == query_error_month )
            & (query_error['year'] == query_error_year), "mes_cierre"] = 'Actual'
query_error.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1697737663.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   query_error = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\POLIZAS\2023\10. OCTUBRE\DATA\ERROR OCTUBRE 2023.csv',
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1697737663.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   query_error = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\POLIZAS\2023\10. OCTUBRE\DATA\ERROR OCTUBRE 2023.csv',
#    Unnamed: 0                           merchant_id  \
# 0           0  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 1           1  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 2           2  d1087b80-5383-4b90-8738-bf309a1ce297
# 3           3  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
# 4           4  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
#
#                        merchant_name  report_id report_date_local   amount  \
# 0              Mscelanea Dulce Maria  GTS92WH86        2015-11-05   734.34
# 1              Mscelanea Dulce Maria  8VQRDV39G        2015-11-06   597.26
# 2                      Grupo Solutec  82G5CYSR7        2015-12-21 9,160.77
# 3  Ediciones Malinalco S de RL de CV  XWRKLC2ZL        2016-02-08 1,216.98
# 4  Ediciones Malinalco S de RL de CV  D9468C7W4        2016-02-16 1,993.14
#
#   status    error_description ultimo_mov  month  year status_cubeta  \
# 0  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 1  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 2  ERROR          failed swap 2017-11-01     11  2017         ERROR
# 3  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
# 4  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
#
#   esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 0   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 1   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 2   ERROR_USUAL  d1087b80-5383-4b90-8738-bf309a1ce297           2017-11-01
# 3   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
# 4   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
#
#    day mes_cierre
# 0   15        NaN
# 1   15        NaN
# 2    1        NaN
# 3   12        NaN
# 4   12        NaN
#    Unnamed: 0                           merchant_id  \
# 0           0  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 1           1  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 2           2  d1087b80-5383-4b90-8738-bf309a1ce297
# 3           3  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
# 4           4  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
#
#                        merchant_name  report_id report_date_local   amount  \
# 0              Mscelanea Dulce Maria  GTS92WH86        2015-11-05   734.34
# 1              Mscelanea Dulce Maria  8VQRDV39G        2015-11-06   597.26
# 2                      Grupo Solutec  82G5CYSR7        2015-12-21 9,160.77
# 3  Ediciones Malinalco S de RL de CV  XWRKLC2ZL        2016-02-08 1,216.98
# 4  Ediciones Malinalco S de RL de CV  D9468C7W4        2016-02-16 1,993.14
#
#   status    error_description ultimo_mov  month  year status_cubeta  \
# 0  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 1  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 2  ERROR          failed swap 2017-11-01     11  2017         ERROR
# 3  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
# 4  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
#
#   esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 0   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 1   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 2   ERROR_USUAL  d1087b80-5383-4b90-8738-bf309a1ce297           2017-11-01
# 3   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
# 4   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
#
#    day mes_cierre
# 0   15        NaN
# 1   15        NaN
# 2    1        NaN
# 3   12        NaN
# 4   12        NaN

# %%
query_error.shape
# Out:
# (150498, 17)
# (150498, 17)

# %%
query_error.dtypes
# Out:
# Unnamed: 0                       int64
# merchant_id                     object
# merchant_name                   object
# report_id                       object
# report_date_local       datetime64[ns]
# amount                         float64
# status                          object
# error_description               object
# ultimo_mov              datetime64[ns]
# month                            int32
# year                             int32
# status_cubeta                   object
# esquema_query                   object
# merchant_id_query               object
# ultimo_mov_date_only            object
# day                              int32
# mes_cierre                      object
# dtype: object
# Unnamed: 0                       int64
# merchant_id                     object
# merchant_name                   object
# report_id                       object
# report_date_local       datetime64[ns]
# amount                         float64
# status                          object
# error_description               object
# ultimo_mov              datetime64[ns]
# month                            int32
# year                             int32
# status_cubeta                   object
# esquema_query                   object
# merchant_id_query               object
# ultimo_mov_date_only            object
# day                              int32
# mes_cierre                      object
# dtype: object

# %%
query_error['esquema_query'].unique()
# Out:
# array(['ERROR_USUAL', 'SIN_CLABE'], dtype=object)
# array(['ERROR_USUAL', 'SIN_CLABE'], dtype=object)

# %%
query_error['status_cubeta'].unique()
# Out:
# array(['ERROR', 'NEW'], dtype=object)
# array(['ERROR', 'NEW'], dtype=object)

# %% [markdown]
# # FILTRAR INFORMACION DE ACUERDO AL MES EN CURSO

# %%
query_error_current_month = query_error[(query_error['mes_cierre'] == 'Actual')]
query_error_current_month.sort_values(by=['day'],inplace=True)
query_error_current_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\3502651561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_error_current_month.sort_values(by=['day'],inplace=True)
#         Unnamed: 0                           merchant_id merchant_name  \
# 139442      139442  3718ec56-c655-4122-b559-bcf6f18ea5eb           NaN
# 139312      139312  259bc94a-ee94-4a2e-830e-f524ca57544f           NaN
# 139422      139422  6b4cf764-fdbf-4538-9695-a14de77c93d1           NaN
# 139448      139448  5000090d-1974-4b11-a3a9-afd6d722edf6           NaN
# 139423      139423  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4           NaN
#
#         report_id report_date_local  amount status  \
# 139442  AP4HK3FDY        2023-10-01  134.15  ERROR
# 139312  AR7C8922Y        2023-10-01    0.95  ERROR
# 139422  APR86ZNDT        2023-10-01   75.71  ERROR
# 139448  AXLD2T7C8        2023-10-01  397.67  ERROR
# 139423  AP72KHPLY        2023-10-01  284.62  ERROR
#
#                              error_description ultimo_mov  month  year  \
# 139442  Bank account information not available 2023-10-01     10  2023
# 139312  Bank account information not available 2023-10-01     10  2023
# 139422  Bank account information not available 2023-10-01     10  2023
# 139448  Bank account information not available 2023-10-01     10  2023
# 139423  Bank account information not available 2023-10-01     10  2023
#
#        status_cubeta esquema_query                     merchant_id_query  \
# 139442           NEW     SIN_CLABE  3718ec56-c655-4122-b559-bcf6f18ea5eb
# 139312           NEW     SIN_CLABE  259bc94a-ee94-4a2e-830e-f524ca57544f
# 139422           NEW     SIN_CLABE  6b4cf764-fdbf-4538-9695-a14de77c93d1
# 139448           NEW     SIN_CLABE  5000090d-1974-4b11-a3a9-afd6d722edf6
# 139423           NEW     SIN_CLABE  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4
#
#        ultimo_mov_date_only  day mes_cierre
# 139442           2023-10-01    1     Actual
# 139312           2023-10-01    1     Actual
# 139422           2023-10-01    1     Actual
# 139448           2023-10-01    1     Actual
# 139423           2023-10-01    1     Actual
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\3502651561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_error_current_month.sort_values(by=['day'],inplace=True)
#         Unnamed: 0                           merchant_id merchant_name  \
# 139442      139442  3718ec56-c655-4122-b559-bcf6f18ea5eb           NaN
# 139312      139312  259bc94a-ee94-4a2e-830e-f524ca57544f           NaN
# 139422      139422  6b4cf764-fdbf-4538-9695-a14de77c93d1           NaN
# 139448      139448  5000090d-1974-4b11-a3a9-afd6d722edf6           NaN
# 139423      139423  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4           NaN
#
#         report_id report_date_local  amount status  \
# 139442  AP4HK3FDY        2023-10-01  134.15  ERROR
# 139312  AR7C8922Y        2023-10-01    0.95  ERROR
# 139422  APR86ZNDT        2023-10-01   75.71  ERROR
# 139448  AXLD2T7C8        2023-10-01  397.67  ERROR
# 139423  AP72KHPLY        2023-10-01  284.62  ERROR
#
#                              error_description ultimo_mov  month  year  \
# 139442  Bank account information not available 2023-10-01     10  2023
# 139312  Bank account information not available 2023-10-01     10  2023
# 139422  Bank account information not available 2023-10-01     10  2023
# 139448  Bank account information not available 2023-10-01     10  2023
# 139423  Bank account information not available 2023-10-01     10  2023
#
#        status_cubeta esquema_query                     merchant_id_query  \
# 139442           NEW     SIN_CLABE  3718ec56-c655-4122-b559-bcf6f18ea5eb
# 139312           NEW     SIN_CLABE  259bc94a-ee94-4a2e-830e-f524ca57544f
# 139422           NEW     SIN_CLABE  6b4cf764-fdbf-4538-9695-a14de77c93d1
# 139448           NEW     SIN_CLABE  5000090d-1974-4b11-a3a9-afd6d722edf6
# 139423           NEW     SIN_CLABE  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4
#
#        ultimo_mov_date_only  day mes_cierre
# 139442           2023-10-01    1     Actual
# 139312           2023-10-01    1     Actual
# 139422           2023-10-01    1     Actual
# 139448           2023-10-01    1     Actual
# 139423           2023-10-01    1     Actual

# %%
query_error_current_month.shape
# Out:
# (12134, 17)
# (12134, 17)

# %%
query_error_current_month['month'].unique()
# Out:
# array([10])
# array([10])

# %%
query_error_current_month.columns
# Out:
# Index(['Unnamed: 0', 'merchant_id', 'merchant_name', 'report_id',
#        'report_date_local', 'amount', 'status', 'error_description',
#        'ultimo_mov', 'month', 'year', 'status_cubeta', 'esquema_query',
#        'merchant_id_query', 'ultimo_mov_date_only', 'day', 'mes_cierre'],
#       dtype='object')
# Index(['Unnamed: 0', 'merchant_id', 'merchant_name', 'report_id',
#        'report_date_local', 'amount', 'status', 'error_description',
#        'ultimo_mov', 'month', 'year', 'status_cubeta', 'esquema_query',
#        'merchant_id_query', 'ultimo_mov_date_only', 'day', 'mes_cierre'],
#       dtype='object')

# %%
duplicates_query_error = query_error_current_month[query_error_current_month.duplicated(['report_id'] , keep=False)]
duplicates_query_error.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []

# %%
duplicates_query_error.shape
# Out:
# (0, 17)
# (0, 17)

# %% [markdown]
# # PAGOS NEW DE MESES ANTERIORES

# %%
query_new_last_month = query_error[(query_error['mes_cierre'] != 'Actual') & (query_error['status_cubeta'] == 'NEW')]
query_new_last_month.sort_values(by=['day'],inplace=True)
query_new_last_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\3381233170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_new_last_month.sort_values(by=['day'],inplace=True)
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\3381233170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_new_last_month.sort_values(by=['day'],inplace=True)
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []

# %%
query_new_last_month.shape
# Out:
# (0, 17)
# (0, 17)

# %% [markdown]
# # INFORMACIÓN QUERIES - PAGOS

# %%
name_header = ['merchant_id','merchant_name','user_email','report_id','report_date_local','amount','status','bank_name'
               ,'payment_date_local','bank_account_owner_name','bank_account_number','swap']

# %% [markdown]
# ### NEXT MONTH

# %%
# TRADICIONAL
# trad_files_csv_2021_may = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\06. JUNE\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
# fp_files_csv_2021_may = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\06. JUNE\QUERIES\*.csv', recursive=False)

# %%
# disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_may])
# disp_files_csv_2021_may['date_query'] = disp_files_csv_2021_may["file_name"].str[-14:-4]
# disp_files_csv_2021_may['date_query']= pd.to_datetime(disp_files_csv_2021_may['date_query'])

# %%
# fp_disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_may])
# fp_disp_files_csv_2021_may['date_query'] = fp_disp_files_csv_2021_may["file_name"].str[-14:-4]
# fp_disp_files_csv_2021_may['date_query']= pd.to_datetime(fp_disp_files_csv_2021_may['date_query'])

# %% [markdown]
# ### CURRENT MONTH

# %%
# TRADICIONAL
trad_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\10. OCTOBER\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\10. OCTUBRE\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2022_current])
disp_files_csv_2022_current['date_query'] = disp_files_csv_2022_current["file_name"].str[-14:-4]
disp_files_csv_2022_current['date_query']= pd.to_datetime(disp_files_csv_2022_current['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2022_current])
fp_disp_files_csv_2022_current['date_query'] = fp_disp_files_csv_2022_current["file_name"].str[-14:-4]
fp_disp_files_csv_2022_current['date_query']= pd.to_datetime(fp_disp_files_csv_2022_current['date_query'])

# %% [markdown]
# ### LAST MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\09. SEPTEMBER\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\09. SEPTIEMBRE\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_last])
disp_files_csv_2021_last['date_query'] = disp_files_csv_2021_last["file_name"].str[-14:-4]
disp_files_csv_2021_last['date_query']= pd.to_datetime(disp_files_csv_2021_last['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_last])
fp_disp_files_csv_2021_last['date_query'] = fp_disp_files_csv_2021_last["file_name"].str[-14:-4]
fp_disp_files_csv_2021_last['date_query']= pd.to_datetime(fp_disp_files_csv_2021_last['date_query'])

# %% [markdown]
# ### SPECIAL MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\08. AUGUST\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\08. AGOSTO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_spec])
disp_files_csv_2021_spec['date_query'] = disp_files_csv_2021_spec["file_name"].str[-14:-4]
disp_files_csv_2021_spec['date_query']= pd.to_datetime(disp_files_csv_2021_spec['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_spec])
fp_disp_files_csv_2021_spec['date_query'] = fp_disp_files_csv_2021_spec["file_name"].str[-14:-4]
fp_disp_files_csv_2021_spec['date_query']= pd.to_datetime(fp_disp_files_csv_2021_spec['date_query'])

# %% [markdown]
# ## ALL FILES

# %%
allfiles = pd.concat([disp_files_csv_2022_current,fp_disp_files_csv_2022_current
                     ,disp_files_csv_2021_last,fp_disp_files_csv_2021_last,
                     disp_files_csv_2021_spec,fp_disp_files_csv_2021_spec])
allfiles.reset_index()
allfiles.fillna('BLANK',inplace=True)
allfiles['date_query']= pd.to_datetime(allfiles['date_query'])
allfiles['report_date_local']= pd.to_datetime(allfiles['report_date_local'])
allfiles.loc[(allfiles['file_name'].str.contains('FP'),'tipo_dispersion')] = 'FP'
allfiles.loc[(allfiles['file_name'].str.contains('SWAP'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('BNTE'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('SANT'),'tipo_dispersion')] = 'TRAD'
allfiles.sort_values(by=['date_query','report_id'],inplace=True)
allfiles.drop(['status'],axis=1,inplace=True)
allfiles.head()
# Out:
#           type                           merchant_id  \
# 4586   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 4537   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1603   INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 19715    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 980    INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                              merchant_token             merchant_name  \
# 4586   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 4537   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1603   a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 19715  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 980    e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                                user_email  report_id report_date_local  \
# 4586               gamboah100@hotmail.com  22CDBX79P        2022-07-24
# 4537               gamboah100@hotmail.com  22J9YCFMV        2021-10-19
# 1603             rogeliogibarra@gmail.com  25QK27WLN        2021-12-31
# 19715  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22
# 980                   tusitaoky@gmail.com  26QY75YTQ        2022-08-28
#
#         amount                                          bank_name  \
# 4586  2,319.90  Opciones Empresariales del Noreste, S.A. de C....
# 4537    258.72  Opciones Empresariales del Noreste, S.A. de C....
# 1603  1,433.53  Opciones Empresariales del Noreste, S.A. de C....
# 19715 1,744.00                                      BBVA BANCOMER
# 980     275.91  Opciones Empresariales del Noreste, S.A. de C....
#
#         payment_date_local   bank_account_owner_name  bank_account_number  \
# 4586   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 4537   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 1603   2023-08-02 06:40:22      Rogelio Gaona Ibarra  '659802020000193465
# 19715  2023-08-01 16:21:23  Jesús Ángel Rojas Garcia  '012180015517939538
# 980    2023-08-02 06:40:26        Sonia Reyes Flores  '659802020000128663
#
#         batch_created_date disbursement_method  \
# 4586   2023-08-01 12:56:29           SANTANDER
# 4537   2023-08-01 12:56:29           SANTANDER
# 1603   2023-08-01 15:00:44             BANORTE
# 19715  2023-08-01 10:08:43           SANTANDER
# 980    2023-08-01 15:00:40             BANORTE
#
#                                                     swap  \
# 4586   Jorge Luis Gamboa Huerta,,2319.90,659802020000...
# 4537   Jorge Luis Gamboa Huerta,,258.72,6598020200002...
# 1603   Rogelio Gaona Ibarra,,1433.53,6598020200001934...
# 19715  Jesús Ángel Rojas Garcia,,1744.00,012180015517...
# 980    Sonia Reyes Flores,,275.91,659802020000128663,...
#
#                    file_name date_query tipo_dispersion
# 4586   FP-ALL 2023-08-01.csv 2023-08-01              FP
# 4537   FP-ALL 2023-08-01.csv 2023-08-01              FP
# 1603   BNTE-3 2023-08-01.csv 2023-08-01            TRAD
# 19715  SANT-1 2023-08-01.csv 2023-08-01            TRAD
# 980    BNTE-3 2023-08-01.csv 2023-08-01            TRAD
#           type                           merchant_id  \
# 4586   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 4537   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1603   INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 19715    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 980    INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                              merchant_token             merchant_name  \
# 4586   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 4537   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1603   a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 19715  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 980    e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                                user_email  report_id report_date_local  \
# 4586               gamboah100@hotmail.com  22CDBX79P        2022-07-24
# 4537               gamboah100@hotmail.com  22J9YCFMV        2021-10-19
# 1603             rogeliogibarra@gmail.com  25QK27WLN        2021-12-31
# 19715  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22
# 980                   tusitaoky@gmail.com  26QY75YTQ        2022-08-28
#
#         amount                                          bank_name  \
# 4586  2,319.90  Opciones Empresariales del Noreste, S.A. de C....
# 4537    258.72  Opciones Empresariales del Noreste, S.A. de C....
# 1603  1,433.53  Opciones Empresariales del Noreste, S.A. de C....
# 19715 1,744.00                                      BBVA BANCOMER
# 980     275.91  Opciones Empresariales del Noreste, S.A. de C....
#
#         payment_date_local   bank_account_owner_name  bank_account_number  \
# 4586   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 4537   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 1603   2023-08-02 06:40:22      Rogelio Gaona Ibarra  '659802020000193465
# 19715  2023-08-01 16:21:23  Jesús Ángel Rojas Garcia  '012180015517939538
# 980    2023-08-02 06:40:26        Sonia Reyes Flores  '659802020000128663
#
#         batch_created_date disbursement_method  \
# 4586   2023-08-01 12:56:29           SANTANDER
# 4537   2023-08-01 12:56:29           SANTANDER
# 1603   2023-08-01 15:00:44             BANORTE
# 19715  2023-08-01 10:08:43           SANTANDER
# 980    2023-08-01 15:00:40             BANORTE
#
#                                                     swap  \
# 4586   Jorge Luis Gamboa Huerta,,2319.90,659802020000...
# 4537   Jorge Luis Gamboa Huerta,,258.72,6598020200002...
# 1603   Rogelio Gaona Ibarra,,1433.53,6598020200001934...
# 19715  Jesús Ángel Rojas Garcia,,1744.00,012180015517...
# 980    Sonia Reyes Flores,,275.91,659802020000128663,...
#
#                    file_name date_query tipo_dispersion
# 4586   FP-ALL 2023-08-01.csv 2023-08-01              FP
# 4537   FP-ALL 2023-08-01.csv 2023-08-01              FP
# 1603   BNTE-3 2023-08-01.csv 2023-08-01            TRAD
# 19715  SANT-1 2023-08-01.csv 2023-08-01            TRAD
# 980    BNTE-3 2023-08-01.csv 2023-08-01            TRAD

# %%
def tipo_pago(allfiles):
    if allfiles['date_query'] == allfiles['report_date_local']:
        return 'Pago del día'
    else:
        return 'Reprogramación'
allfiles['tipo_pago'] = allfiles.apply(tipo_pago, axis=1)

# %%
allfiles.head()
# Out:
#           type                           merchant_id  \
# 4586   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 4537   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1603   INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 19715    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 980    INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                              merchant_token             merchant_name  \
# 4586   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 4537   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1603   a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 19715  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 980    e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                                user_email  report_id report_date_local  \
# 4586               gamboah100@hotmail.com  22CDBX79P        2022-07-24
# 4537               gamboah100@hotmail.com  22J9YCFMV        2021-10-19
# 1603             rogeliogibarra@gmail.com  25QK27WLN        2021-12-31
# 19715  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22
# 980                   tusitaoky@gmail.com  26QY75YTQ        2022-08-28
#
#         amount                                          bank_name  \
# 4586  2,319.90  Opciones Empresariales del Noreste, S.A. de C....
# 4537    258.72  Opciones Empresariales del Noreste, S.A. de C....
# 1603  1,433.53  Opciones Empresariales del Noreste, S.A. de C....
# 19715 1,744.00                                      BBVA BANCOMER
# 980     275.91  Opciones Empresariales del Noreste, S.A. de C....
#
#         payment_date_local   bank_account_owner_name  bank_account_number  \
# 4586   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 4537   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 1603   2023-08-02 06:40:22      Rogelio Gaona Ibarra  '659802020000193465
# 19715  2023-08-01 16:21:23  Jesús Ángel Rojas Garcia  '012180015517939538
# 980    2023-08-02 06:40:26        Sonia Reyes Flores  '659802020000128663
#
#         batch_created_date disbursement_method  \
# 4586   2023-08-01 12:56:29           SANTANDER
# 4537   2023-08-01 12:56:29           SANTANDER
# 1603   2023-08-01 15:00:44             BANORTE
# 19715  2023-08-01 10:08:43           SANTANDER
# 980    2023-08-01 15:00:40             BANORTE
#
#                                                     swap  \
# 4586   Jorge Luis Gamboa Huerta,,2319.90,659802020000...
# 4537   Jorge Luis Gamboa Huerta,,258.72,6598020200002...
# 1603   Rogelio Gaona Ibarra,,1433.53,6598020200001934...
# 19715  Jesús Ángel Rojas Garcia,,1744.00,012180015517...
# 980    Sonia Reyes Flores,,275.91,659802020000128663,...
#
#                    file_name date_query tipo_dispersion       tipo_pago
# 4586   FP-ALL 2023-08-01.csv 2023-08-01              FP  Reprogramación
# 4537   FP-ALL 2023-08-01.csv 2023-08-01              FP  Reprogramación
# 1603   BNTE-3 2023-08-01.csv 2023-08-01            TRAD  Reprogramación
# 19715  SANT-1 2023-08-01.csv 2023-08-01            TRAD  Reprogramación
# 980    BNTE-3 2023-08-01.csv 2023-08-01            TRAD  Reprogramación
#           type                           merchant_id  \
# 4586   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 4537   INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1603   INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 19715    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 980    INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                              merchant_token             merchant_name  \
# 4586   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 4537   caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1603   a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 19715  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 980    e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                                user_email  report_id report_date_local  \
# 4586               gamboah100@hotmail.com  22CDBX79P        2022-07-24
# 4537               gamboah100@hotmail.com  22J9YCFMV        2021-10-19
# 1603             rogeliogibarra@gmail.com  25QK27WLN        2021-12-31
# 19715  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22
# 980                   tusitaoky@gmail.com  26QY75YTQ        2022-08-28
#
#         amount                                          bank_name  \
# 4586  2,319.90  Opciones Empresariales del Noreste, S.A. de C....
# 4537    258.72  Opciones Empresariales del Noreste, S.A. de C....
# 1603  1,433.53  Opciones Empresariales del Noreste, S.A. de C....
# 19715 1,744.00                                      BBVA BANCOMER
# 980     275.91  Opciones Empresariales del Noreste, S.A. de C....
#
#         payment_date_local   bank_account_owner_name  bank_account_number  \
# 4586   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 4537   2023-08-02 00:46:34  Jorge Luis Gamboa Huerta  '659802020000265911
# 1603   2023-08-02 06:40:22      Rogelio Gaona Ibarra  '659802020000193465
# 19715  2023-08-01 16:21:23  Jesús Ángel Rojas Garcia  '012180015517939538
# 980    2023-08-02 06:40:26        Sonia Reyes Flores  '659802020000128663
#
#         batch_created_date disbursement_method  \
# 4586   2023-08-01 12:56:29           SANTANDER
# 4537   2023-08-01 12:56:29           SANTANDER
# 1603   2023-08-01 15:00:44             BANORTE
# 19715  2023-08-01 10:08:43           SANTANDER
# 980    2023-08-01 15:00:40             BANORTE
#
#                                                     swap  \
# 4586   Jorge Luis Gamboa Huerta,,2319.90,659802020000...
# 4537   Jorge Luis Gamboa Huerta,,258.72,6598020200002...
# 1603   Rogelio Gaona Ibarra,,1433.53,6598020200001934...
# 19715  Jesús Ángel Rojas Garcia,,1744.00,012180015517...
# 980    Sonia Reyes Flores,,275.91,659802020000128663,...
#
#                    file_name date_query tipo_dispersion       tipo_pago
# 4586   FP-ALL 2023-08-01.csv 2023-08-01              FP  Reprogramación
# 4537   FP-ALL 2023-08-01.csv 2023-08-01              FP  Reprogramación
# 1603   BNTE-3 2023-08-01.csv 2023-08-01            TRAD  Reprogramación
# 19715  SANT-1 2023-08-01.csv 2023-08-01            TRAD  Reprogramación
# 980    BNTE-3 2023-08-01.csv 2023-08-01            TRAD  Reprogramación

# %%
allfiles.shape
# Out:
# (9471708, 19)
# (9471708, 19)

# %% [markdown]
# # CRUCE 1 - MES ACTUAL

# %%
cruce_1 = allfiles.merge(query_error_current_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status'
                                                   ,'error_description','esquema_query','status_cubeta']],on='report_id',how='left')
cruce_1['month'].fillna('Not found',inplace=True)
cruce_1.head()
# Out:
#       type                           merchant_id  \
# 0  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 2  INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 3    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 4  INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                          merchant_token             merchant_name  \
# 0  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 2  a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 3  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 4  e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                            user_email  report_id report_date_local  amount_x  \
# 0              gamboah100@hotmail.com  22CDBX79P        2022-07-24  2,319.90
# 1              gamboah100@hotmail.com  22J9YCFMV        2021-10-19    258.72
# 2            rogeliogibarra@gmail.com  25QK27WLN        2021-12-31  1,433.53
# 3  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22  1,744.00
# 4                 tusitaoky@gmail.com  26QY75YTQ        2022-08-28    275.91
#
#                                            bank_name   payment_date_local  \
# 0  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 1  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 2  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:22
# 3                                      BBVA BANCOMER  2023-08-01 16:21:23
# 4  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:26
#
#    ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 0  ...              FP  Reprogramación      NaN        NaT
# 1  ...              FP  Reprogramación      NaN        NaT
# 2  ...            TRAD  Reprogramación      NaN        NaT
# 3  ...            TRAD  Reprogramación      NaN        NaT
# 4  ...            TRAD  Reprogramación      NaN        NaT
#
#   ultimo_mov_date_only      month status error_description esquema_query  \
# 0                  NaN  Not found    NaN               NaN           NaN
# 1                  NaN  Not found    NaN               NaN           NaN
# 2                  NaN  Not found    NaN               NaN           NaN
# 3                  NaN  Not found    NaN               NaN           NaN
# 4                  NaN  Not found    NaN               NaN           NaN
#
#    status_cubeta
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 27 columns]
#       type                           merchant_id  \
# 0  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 2  INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 3    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 4  INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                          merchant_token             merchant_name  \
# 0  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 2  a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 3  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 4  e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                            user_email  report_id report_date_local  amount_x  \
# 0              gamboah100@hotmail.com  22CDBX79P        2022-07-24  2,319.90
# 1              gamboah100@hotmail.com  22J9YCFMV        2021-10-19    258.72
# 2            rogeliogibarra@gmail.com  25QK27WLN        2021-12-31  1,433.53
# 3  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22  1,744.00
# 4                 tusitaoky@gmail.com  26QY75YTQ        2022-08-28    275.91
#
#                                            bank_name   payment_date_local  \
# 0  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 1  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 2  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:22
# 3                                      BBVA BANCOMER  2023-08-01 16:21:23
# 4  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:26
#
#    ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 0  ...              FP  Reprogramación      NaN        NaT
# 1  ...              FP  Reprogramación      NaN        NaT
# 2  ...            TRAD  Reprogramación      NaN        NaT
# 3  ...            TRAD  Reprogramación      NaN        NaT
# 4  ...            TRAD  Reprogramación      NaN        NaT
#
#   ultimo_mov_date_only      month status error_description esquema_query  \
# 0                  NaN  Not found    NaN               NaN           NaN
# 1                  NaN  Not found    NaN               NaN           NaN
# 2                  NaN  Not found    NaN               NaN           NaN
# 3                  NaN  Not found    NaN               NaN           NaN
# 4                  NaN  Not found    NaN               NaN           NaN
#
#    status_cubeta
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 27 columns]

# %%
cruce_1.shape
# Out:
# (9471708, 27)
# (9471708, 27)

# %%
duplicates_cruce_1_previo = cruce_1[cruce_1.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_previo.head()
# Out:
#       type                           merchant_id  \
# 13   DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 65   DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 164  BLANK  8d36124a-41ce-48d0-847e-71f2d32211fc
# 199  BLANK  b9e50331-00d2-494e-94ad-06eec8756e16
# 200  BLANK  b9e50331-00d2-494e-94ad-06eec8756e16
#
#                            merchant_token    merchant_name  \
# 13   ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 65   ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 164                                 BLANK            BLANK
# 199                                 BLANK            BLANK
# 200                                 BLANK            BLANK
#
#                         user_email  report_id report_date_local  amount_x  \
# 13   lolita.marquez.alva@gmail.com  2DVT2L3HK        2023-03-06  1,028.14
# 65   lolita.marquez.alva@gmail.com  64VSYDHZR        2023-03-03  1,427.90
# 164                          BLANK  A229RFD5Z        2023-08-01  1,694.17
# 199                          BLANK  A22K3CWBR        2023-08-01  4,311.11
# 200                          BLANK  A22K3CWBR        2023-08-01  4,311.11
#
#                                              bank_name   payment_date_local  \
# 13                                             BANORTE  2023-08-02 02:01:01
# 65                                             BANORTE  2023-08-02 02:01:01
# 164  Opciones Empresariales del Noreste, S.A. de C....  2023-08-01 22:33:19
# 199  Caja Popular Mexicana, S.C. de A.P. de R.L. de...  2023-08-01 18:28:28
# 200  Caja Popular Mexicana, S.C. de A.P. de R.L. de...  2023-08-01 18:28:28
#
#      ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 13   ...            TRAD  Reprogramación      NaN        NaT
# 65   ...            TRAD  Reprogramación      NaN        NaT
# 164  ...              FP    Pago del día      NaN        NaT
# 199  ...            TRAD    Pago del día      NaN        NaT
# 200  ...            TRAD    Pago del día      NaN        NaT
#
#     ultimo_mov_date_only      month status error_description esquema_query  \
# 13                   NaN  Not found    NaN               NaN           NaN
# 65                   NaN  Not found    NaN               NaN           NaN
# 164                  NaN  Not found    NaN               NaN           NaN
# 199                  NaN  Not found    NaN               NaN           NaN
# 200                  NaN  Not found    NaN               NaN           NaN
#
#      status_cubeta
# 13             NaN
# 65             NaN
# 164            NaN
# 199            NaN
# 200            NaN
#
# [5 rows x 27 columns]
#       type                           merchant_id  \
# 13   DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 65   DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 164  BLANK  8d36124a-41ce-48d0-847e-71f2d32211fc
# 199  BLANK  b9e50331-00d2-494e-94ad-06eec8756e16
# 200  BLANK  b9e50331-00d2-494e-94ad-06eec8756e16
#
#                            merchant_token    merchant_name  \
# 13   ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 65   ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 164                                 BLANK            BLANK
# 199                                 BLANK            BLANK
# 200                                 BLANK            BLANK
#
#                         user_email  report_id report_date_local  amount_x  \
# 13   lolita.marquez.alva@gmail.com  2DVT2L3HK        2023-03-06  1,028.14
# 65   lolita.marquez.alva@gmail.com  64VSYDHZR        2023-03-03  1,427.90
# 164                          BLANK  A229RFD5Z        2023-08-01  1,694.17
# 199                          BLANK  A22K3CWBR        2023-08-01  4,311.11
# 200                          BLANK  A22K3CWBR        2023-08-01  4,311.11
#
#                                              bank_name   payment_date_local  \
# 13                                             BANORTE  2023-08-02 02:01:01
# 65                                             BANORTE  2023-08-02 02:01:01
# 164  Opciones Empresariales del Noreste, S.A. de C....  2023-08-01 22:33:19
# 199  Caja Popular Mexicana, S.C. de A.P. de R.L. de...  2023-08-01 18:28:28
# 200  Caja Popular Mexicana, S.C. de A.P. de R.L. de...  2023-08-01 18:28:28
#
#      ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 13   ...            TRAD  Reprogramación      NaN        NaT
# 65   ...            TRAD  Reprogramación      NaN        NaT
# 164  ...              FP    Pago del día      NaN        NaT
# 199  ...            TRAD    Pago del día      NaN        NaT
# 200  ...            TRAD    Pago del día      NaN        NaT
#
#     ultimo_mov_date_only      month status error_description esquema_query  \
# 13                   NaN  Not found    NaN               NaN           NaN
# 65                   NaN  Not found    NaN               NaN           NaN
# 164                  NaN  Not found    NaN               NaN           NaN
# 199                  NaN  Not found    NaN               NaN           NaN
# 200                  NaN  Not found    NaN               NaN           NaN
#
#      status_cubeta
# 13             NaN
# 65             NaN
# 164            NaN
# 199            NaN
# 200            NaN
#
# [5 rows x 27 columns]

# %%
duplicates_cruce_1_previo.shape
# Out:
# (131158, 27)
# (131158, 27)

# %%
cruce_1_final = cruce_1[(cruce_1['month'] != 'Not found')]
cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_1_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1938979547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
#           type                           merchant_id merchant_token  \
# 126812   BLANK  60b0b25c-672c-496f-823b-66a902b40784          BLANK
# 3647973  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 4238189  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 6109286  BLANK  f01c87dd-f0ac-47de-9f81-f951b5d37d96          BLANK
# 6109982  BLANK  cd636201-58f3-4b45-ac0f-d9e87b998c4b          BLANK
#
#         merchant_name user_email  report_id report_date_local  amount_x  \
# 126812          BLANK      BLANK  A8CDP4KWY        2023-04-29    407.25
# 3647973         BLANK      BLANK  ANLZSPRDT        2023-09-04     18.00
# 4238189         BLANK      BLANK  A8RB2N586        2023-09-11      4.80
# 6109286         BLANK      BLANK  A294BFZSX        2023-09-30     70.12
# 6109982         BLANK      BLANK  A2G5KR3Y9        2023-09-30  5,093.01
#
#                                                  bank_name  \
# 126812   Opciones Empresariales del Noreste, S.A. de C....
# 3647973  Opciones Empresariales del Noreste, S.A. de C....
# 4238189  Opciones Empresariales del Noreste, S.A. de C....
# 6109286  Opciones Empresariales del Noreste, S.A. de C....
# 6109982                                      BBVA Bancomer
#
#           payment_date_local  ... tipo_dispersion       tipo_pago amount_y  \
# 126812   2023-08-02 21:55:12  ...              FP  Reprogramación   407.25
# 3647973  2023-09-05 19:33:40  ...              FP  Reprogramación    18.00
# 4238189  2023-09-11 19:34:20  ...              FP    Pago del día     4.80
# 6109286  2023-10-01 06:38:17  ...              FP    Pago del día    70.12
# 6109982  2023-10-01 06:38:07  ...            TRAD    Pago del día 5,093.01
#
#         ultimo_mov ultimo_mov_date_only month    status  \
# 126812  2023-10-12           2023-10-12 10.00  ERROR_TV
# 3647973 2023-10-03           2023-10-03 10.00  ERROR_TV
# 4238189 2023-10-03           2023-10-03 10.00  ERROR_TV
# 6109286 2023-10-01           2023-10-01 10.00     ERROR
# 6109982 2023-10-01           2023-10-01 10.00     ERROR
#
#                                          error_description esquema_query  \
# 126812                                     sin_descripcion   ERROR_USUAL
# 3647973  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
# 4238189  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
# 6109286                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 6109982                     DEV.SPEICUENTA EN OTRA DIVISA    ERROR_USUAL
#
#          status_cubeta
# 126812           ERROR
# 3647973          ERROR
# 4238189          ERROR
# 6109286            NEW
# 6109982            NEW
#
# [5 rows x 27 columns]
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_23420\1938979547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
#           type                           merchant_id merchant_token  \
# 126812   BLANK  60b0b25c-672c-496f-823b-66a902b40784          BLANK
# 3647973  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 4238189  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 6109286  BLANK  f01c87dd-f0ac-47de-9f81-f951b5d37d96          BLANK
# 6109982  BLANK  cd636201-58f3-4b45-ac0f-d9e87b998c4b          BLANK
#
#         merchant_name user_email  report_id report_date_local  amount_x  \
# 126812          BLANK      BLANK  A8CDP4KWY        2023-04-29    407.25
# 3647973         BLANK      BLANK  ANLZSPRDT        2023-09-04     18.00
# 4238189         BLANK      BLANK  A8RB2N586        2023-09-11      4.80
# 6109286         BLANK      BLANK  A294BFZSX        2023-09-30     70.12
# 6109982         BLANK      BLANK  A2G5KR3Y9        2023-09-30  5,093.01
#
#                                                  bank_name  \
# 126812   Opciones Empresariales del Noreste, S.A. de C....
# 3647973  Opciones Empresariales del Noreste, S.A. de C....
# 4238189  Opciones Empresariales del Noreste, S.A. de C....
# 6109286  Opciones Empresariales del Noreste, S.A. de C....
# 6109982                                      BBVA Bancomer
#
#           payment_date_local  ... tipo_dispersion       tipo_pago amount_y  \
# 126812   2023-08-02 21:55:12  ...              FP  Reprogramación   407.25
# 3647973  2023-09-05 19:33:40  ...              FP  Reprogramación    18.00
# 4238189  2023-09-11 19:34:20  ...              FP    Pago del día     4.80
# 6109286  2023-10-01 06:38:17  ...              FP    Pago del día    70.12
# 6109982  2023-10-01 06:38:07  ...            TRAD    Pago del día 5,093.01
#
#         ultimo_mov ultimo_mov_date_only month    status  \
# 126812  2023-10-12           2023-10-12 10.00  ERROR_TV
# 3647973 2023-10-03           2023-10-03 10.00  ERROR_TV
# 4238189 2023-10-03           2023-10-03 10.00  ERROR_TV
# 6109286 2023-10-01           2023-10-01 10.00     ERROR
# 6109982 2023-10-01           2023-10-01 10.00     ERROR
#
#                                          error_description esquema_query  \
# 126812                                     sin_descripcion   ERROR_USUAL
# 3647973  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
# 4238189  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
# 6109286                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 6109982                     DEV.SPEICUENTA EN OTRA DIVISA    ERROR_USUAL
#
#          status_cubeta
# 126812           ERROR
# 3647973          ERROR
# 4238189          ERROR
# 6109286            NEW
# 6109982            NEW
#
# [5 rows x 27 columns]

# %%
cruce_1_final.shape
# Out:
# (6857, 27)
# (6857, 27)

# %%
duplicates_cruce_1_final = cruce_1_final[cruce_1_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_1_final.shape
# Out:
# (0, 27)
# (0, 27)

# %% [markdown]
# # CRUCE 2 MES ACTUAL

# %%
cruce_2 = query_error_current_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_2['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_2.head()
# Out:
#    Unnamed: 0                           merchant_id merchant_name  report_id  \
# 0      139442  3718ec56-c655-4122-b559-bcf6f18ea5eb           NaN  AP4HK3FDY
# 1      139312  259bc94a-ee94-4a2e-830e-f524ca57544f           NaN  AR7C8922Y
# 2      139422  6b4cf764-fdbf-4538-9695-a14de77c93d1           NaN  APR86ZNDT
# 3      139448  5000090d-1974-4b11-a3a9-afd6d722edf6           NaN  AXLD2T7C8
# 4      139423  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4           NaN  AP72KHPLY
#
#   report_date_local  amount status                       error_description  \
# 0        2023-10-01  134.15  ERROR  Bank account information not available
# 1        2023-10-01    0.95  ERROR  Bank account information not available
# 2        2023-10-01   75.71  ERROR  Bank account information not available
# 3        2023-10-01  397.67  ERROR  Bank account information not available
# 4        2023-10-01  284.62  ERROR  Bank account information not available
#
#   ultimo_mov  month  year status_cubeta esquema_query  \
# 0 2023-10-01     10  2023           NEW     SIN_CLABE
# 1 2023-10-01     10  2023           NEW     SIN_CLABE
# 2 2023-10-01     10  2023           NEW     SIN_CLABE
# 3 2023-10-01     10  2023           NEW     SIN_CLABE
# 4 2023-10-01     10  2023           NEW     SIN_CLABE
#
#                       merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 0  3718ec56-c655-4122-b559-bcf6f18ea5eb           2023-10-01    1     Actual
# 1  259bc94a-ee94-4a2e-830e-f524ca57544f           2023-10-01    1     Actual
# 2  6b4cf764-fdbf-4538-9695-a14de77c93d1           2023-10-01    1     Actual
# 3  5000090d-1974-4b11-a3a9-afd6d722edf6           2023-10-01    1     Actual
# 4  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4           2023-10-01    1     Actual
#
#   tipo_dispersion tipo_pago
# 0       Not found       NaN
# 1       Not found       NaN
# 2       Not found       NaN
# 3       Not found       NaN
# 4       Not found       NaN
#    Unnamed: 0                           merchant_id merchant_name  report_id  \
# 0      139442  3718ec56-c655-4122-b559-bcf6f18ea5eb           NaN  AP4HK3FDY
# 1      139312  259bc94a-ee94-4a2e-830e-f524ca57544f           NaN  AR7C8922Y
# 2      139422  6b4cf764-fdbf-4538-9695-a14de77c93d1           NaN  APR86ZNDT
# 3      139448  5000090d-1974-4b11-a3a9-afd6d722edf6           NaN  AXLD2T7C8
# 4      139423  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4           NaN  AP72KHPLY
#
#   report_date_local  amount status                       error_description  \
# 0        2023-10-01  134.15  ERROR  Bank account information not available
# 1        2023-10-01    0.95  ERROR  Bank account information not available
# 2        2023-10-01   75.71  ERROR  Bank account information not available
# 3        2023-10-01  397.67  ERROR  Bank account information not available
# 4        2023-10-01  284.62  ERROR  Bank account information not available
#
#   ultimo_mov  month  year status_cubeta esquema_query  \
# 0 2023-10-01     10  2023           NEW     SIN_CLABE
# 1 2023-10-01     10  2023           NEW     SIN_CLABE
# 2 2023-10-01     10  2023           NEW     SIN_CLABE
# 3 2023-10-01     10  2023           NEW     SIN_CLABE
# 4 2023-10-01     10  2023           NEW     SIN_CLABE
#
#                       merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 0  3718ec56-c655-4122-b559-bcf6f18ea5eb           2023-10-01    1     Actual
# 1  259bc94a-ee94-4a2e-830e-f524ca57544f           2023-10-01    1     Actual
# 2  6b4cf764-fdbf-4538-9695-a14de77c93d1           2023-10-01    1     Actual
# 3  5000090d-1974-4b11-a3a9-afd6d722edf6           2023-10-01    1     Actual
# 4  76ff7d54-d0eb-4a0f-ba3f-6ead842d55d4           2023-10-01    1     Actual
#
#   tipo_dispersion tipo_pago
# 0       Not found       NaN
# 1       Not found       NaN
# 2       Not found       NaN
# 3       Not found       NaN
# 4       Not found       NaN

# %%
cruce_2.shape
# Out:
# (14520, 19)
# (14520, 19)

# %%
cruce_2_final = cruce_2[(cruce_2['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_2_final.head()
# Out:
#     Unnamed: 0                           merchant_id merchant_name  report_id  \
# 12      139307  5019cfaf-94e6-47d3-b4bb-073d4ec09348           NaN  AHMC3GPGG
# 18      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 19      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 20      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 21      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
#
#    report_date_local  amount status                 error_description  \
# 12        2023-10-01   40.25  ERROR    CUENTA 0006994695    NO EXISTE
# 18        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 19        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 20        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 21        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
#
#    ultimo_mov  month  year status_cubeta esquema_query  \
# 12 2023-10-01     10  2023           NEW   ERROR_USUAL
# 18 2023-10-01     10  2023           NEW   ERROR_USUAL
# 19 2023-10-01     10  2023           NEW   ERROR_USUAL
# 20 2023-10-01     10  2023           NEW   ERROR_USUAL
# 21 2023-10-01     10  2023           NEW   ERROR_USUAL
#
#                        merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 12  5019cfaf-94e6-47d3-b4bb-073d4ec09348           2023-10-01    1     Actual
# 18  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 19  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 20  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 21  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
#
#    tipo_dispersion     tipo_pago
# 12            TRAD  Pago del día
# 18            TRAD  Pago del día
# 19              FP  Pago del día
# 20              FP  Pago del día
# 21              FP  Pago del día
#     Unnamed: 0                           merchant_id merchant_name  report_id  \
# 12      139307  5019cfaf-94e6-47d3-b4bb-073d4ec09348           NaN  AHMC3GPGG
# 18      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 19      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 20      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 21      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
#
#    report_date_local  amount status                 error_description  \
# 12        2023-10-01   40.25  ERROR    CUENTA 0006994695    NO EXISTE
# 18        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 19        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 20        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 21        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
#
#    ultimo_mov  month  year status_cubeta esquema_query  \
# 12 2023-10-01     10  2023           NEW   ERROR_USUAL
# 18 2023-10-01     10  2023           NEW   ERROR_USUAL
# 19 2023-10-01     10  2023           NEW   ERROR_USUAL
# 20 2023-10-01     10  2023           NEW   ERROR_USUAL
# 21 2023-10-01     10  2023           NEW   ERROR_USUAL
#
#                        merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 12  5019cfaf-94e6-47d3-b4bb-073d4ec09348           2023-10-01    1     Actual
# 18  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 19  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 20  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 21  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
#
#    tipo_dispersion     tipo_pago
# 12            TRAD  Pago del día
# 18            TRAD  Pago del día
# 19              FP  Pago del día
# 20              FP  Pago del día
# 21              FP  Pago del día

# %%
cruce_2_final.shape
# Out:
# (9243, 19)
# (9243, 19)

# %%
duplicates_cruce_2_final = cruce_2_final[cruce_2_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_2_final.head()
# Out:
#     Unnamed: 0                           merchant_id merchant_name  report_id  \
# 18      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 19      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 20      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 21      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 29      139321  827cca41-c0f7-4c76-b4b1-f0ca2f316152           NaN  AF4CF97C3
#
#    report_date_local  amount status                 error_description  \
# 18        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 19        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 20        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 21        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 29        2023-10-01   47.91  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
#
#    ultimo_mov  month  year status_cubeta esquema_query  \
# 18 2023-10-01     10  2023           NEW   ERROR_USUAL
# 19 2023-10-01     10  2023           NEW   ERROR_USUAL
# 20 2023-10-01     10  2023           NEW   ERROR_USUAL
# 21 2023-10-01     10  2023           NEW   ERROR_USUAL
# 29 2023-10-01     10  2023           NEW   ERROR_USUAL
#
#                        merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 18  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 19  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 20  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 21  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 29  827cca41-c0f7-4c76-b4b1-f0ca2f316152           2023-10-01    1     Actual
#
#    tipo_dispersion     tipo_pago
# 18            TRAD  Pago del día
# 19              FP  Pago del día
# 20              FP  Pago del día
# 21              FP  Pago del día
# 29            TRAD  Pago del día
#     Unnamed: 0                           merchant_id merchant_name  report_id  \
# 18      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 19      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 20      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 21      139302  0f8187da-2201-47a4-a080-c3fd0c295845           NaN  AFDPZKBW6
# 29      139321  827cca41-c0f7-4c76-b4b1-f0ca2f316152           NaN  AF4CF97C3
#
#    report_date_local  amount status                 error_description  \
# 18        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 19        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 20        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 21        2023-10-01    6.00  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
# 29        2023-10-01   47.91  ERROR  BANCO RECEPTOR ESTA DESCONECTADO
#
#    ultimo_mov  month  year status_cubeta esquema_query  \
# 18 2023-10-01     10  2023           NEW   ERROR_USUAL
# 19 2023-10-01     10  2023           NEW   ERROR_USUAL
# 20 2023-10-01     10  2023           NEW   ERROR_USUAL
# 21 2023-10-01     10  2023           NEW   ERROR_USUAL
# 29 2023-10-01     10  2023           NEW   ERROR_USUAL
#
#                        merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 18  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 19  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 20  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 21  0f8187da-2201-47a4-a080-c3fd0c295845           2023-10-01    1     Actual
# 29  827cca41-c0f7-4c76-b4b1-f0ca2f316152           2023-10-01    1     Actual
#
#    tipo_dispersion     tipo_pago
# 18            TRAD  Pago del día
# 19              FP  Pago del día
# 20              FP  Pago del día
# 21              FP  Pago del día
# 29            TRAD  Pago del día

# %%
duplicates_cruce_2_final.shape
# Out:
# (4014, 19)
# (4014, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ACTUAL

# %%
group_tipo_pago = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago.fillna(0,inplace=True)
group_tipo_pago.head()
# Out:
#                 ultimo_mov_date_only     amount_x                 \
# esquema_query                         ERROR_USUAL
# status_cubeta                               ERROR
# tipo_dispersion                                FP
# tipo_pago                            Pago del día Reprogramación
# 0                         2023-10-01         0.00           0.00
# 1                         2023-10-02         0.00       3,587.86
# 2                         2023-10-03         4.80      29,677.05
# 3                         2023-10-04         0.00      63,347.70
# 4                         2023-10-05         0.00           0.00
#
#                                                                          \
# esquema_query
# status_cubeta                           NEW
# tipo_dispersion           TRAD           FP                        TRAD
# tipo_pago       Reprogramación Pago del día Reprogramación Pago del día
# 0                         0.00   106,660.33           0.00   154,503.36
# 1                         0.00    33,831.48     115,846.99   142,392.87
# 2                     6,332.05     9,434.39       1,334.81    49,586.93
# 3                     6,943.39     3,596.75         403.44    70,756.11
# 4                     4,121.32    12,610.79           0.00    62,231.82
#
#
# esquema_query                         All
# status_cubeta
# tipo_dispersion
# tipo_pago       Reprogramación
# 0                         0.00 261,163.69
# 1                         0.01 295,659.21
# 2                         1.90  96,371.93
# 3                         0.00 145,047.39
# 4                       701.84  79,665.77
#                 ultimo_mov_date_only     amount_x                 \
# esquema_query                         ERROR_USUAL
# status_cubeta                               ERROR
# tipo_dispersion                                FP
# tipo_pago                            Pago del día Reprogramación
# 0                         2023-10-01         0.00           0.00
# 1                         2023-10-02         0.00       3,587.86
# 2                         2023-10-03         4.80      29,677.05
# 3                         2023-10-04         0.00      63,347.70
# 4                         2023-10-05         0.00           0.00
#
#                                                                          \
# esquema_query
# status_cubeta                           NEW
# tipo_dispersion           TRAD           FP                        TRAD
# tipo_pago       Reprogramación Pago del día Reprogramación Pago del día
# 0                         0.00   106,660.33           0.00   154,503.36
# 1                         0.00    33,831.48     115,846.99   142,392.87
# 2                     6,332.05     9,434.39       1,334.81    49,586.93
# 3                     6,943.39     3,596.75         403.44    70,756.11
# 4                     4,121.32    12,610.79           0.00    62,231.82
#
#
# esquema_query                         All
# status_cubeta
# tipo_dispersion
# tipo_pago       Reprogramación
# 0                         0.00 261,163.69
# 1                         0.01 295,659.21
# 2                         1.90  96,371.93
# 3                         0.00 145,047.39
# 4                       701.84  79,665.77

# %%
group_tipo_pago.shape
# Out:
# (32, 9)
# (32, 9)

# %%
group_esquema = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema.fillna(0,inplace=True)
group_esquema.head()
# Out:
#               ultimo_mov_date_only     amount_x                              \
# esquema_query                       ERROR_USUAL
# status_cubeta                             ERROR                         NEW
# tipo_pago                          Pago del día Reprogramación Pago del día
# 0                       2023-10-01         0.00           0.00   261,163.69
# 1                       2023-10-02         0.00       3,587.86   176,224.35
# 2                       2023-10-03         4.80      36,009.10    59,021.32
# 3                       2023-10-04         0.00      70,291.09    74,352.86
# 4                       2023-10-05         0.00       4,121.32    74,842.61
#
#
# esquema_query                       All
# status_cubeta
# tipo_pago     Reprogramación
# 0                       0.00 261,163.69
# 1                 115,847.00 295,659.21
# 2                   1,336.71  96,371.93
# 3                     403.44 145,047.39
# 4                     701.84  79,665.77
#               ultimo_mov_date_only     amount_x                              \
# esquema_query                       ERROR_USUAL
# status_cubeta                             ERROR                         NEW
# tipo_pago                          Pago del día Reprogramación Pago del día
# 0                       2023-10-01         0.00           0.00   261,163.69
# 1                       2023-10-02         0.00       3,587.86   176,224.35
# 2                       2023-10-03         4.80      36,009.10    59,021.32
# 3                       2023-10-04         0.00      70,291.09    74,352.86
# 4                       2023-10-05         0.00       4,121.32    74,842.61
#
#
# esquema_query                       All
# status_cubeta
# tipo_pago     Reprogramación
# 0                       0.00 261,163.69
# 1                 115,847.00 295,659.21
# 2                   1,336.71  96,371.93
# 3                     403.44 145,047.39
# 4                     701.84  79,665.77

# %%
group_esquema.shape
# Out:
# (32, 6)
# (32, 6)

# %% [markdown]
# # CRUCE 3 - MES ANTERIOR

# %%
cruce_3 = allfiles.merge(query_new_last_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status',
                                               'error_description','esquema_query','status_cubeta']],
                         on='report_id',how='left')
cruce_3['month'].fillna('Not found',inplace=True)
cruce_3.head()
# Out:
#       type                           merchant_id  \
# 0  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 2  INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 3    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 4  INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                          merchant_token             merchant_name  \
# 0  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 2  a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 3  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 4  e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                            user_email  report_id report_date_local  amount_x  \
# 0              gamboah100@hotmail.com  22CDBX79P        2022-07-24  2,319.90
# 1              gamboah100@hotmail.com  22J9YCFMV        2021-10-19    258.72
# 2            rogeliogibarra@gmail.com  25QK27WLN        2021-12-31  1,433.53
# 3  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22  1,744.00
# 4                 tusitaoky@gmail.com  26QY75YTQ        2022-08-28    275.91
#
#                                            bank_name   payment_date_local  \
# 0  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 1  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 2  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:22
# 3                                      BBVA BANCOMER  2023-08-01 16:21:23
# 4  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:26
#
#    ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 0  ...              FP  Reprogramación      NaN        NaT
# 1  ...              FP  Reprogramación      NaN        NaT
# 2  ...            TRAD  Reprogramación      NaN        NaT
# 3  ...            TRAD  Reprogramación      NaN        NaT
# 4  ...            TRAD  Reprogramación      NaN        NaT
#
#   ultimo_mov_date_only      month status error_description esquema_query  \
# 0                  NaN  Not found    NaN               NaN           NaN
# 1                  NaN  Not found    NaN               NaN           NaN
# 2                  NaN  Not found    NaN               NaN           NaN
# 3                  NaN  Not found    NaN               NaN           NaN
# 4                  NaN  Not found    NaN               NaN           NaN
#
#    status_cubeta
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 27 columns]
#       type                           merchant_id  \
# 0  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 1  INSTANT  fcb7ed60-1414-4e84-a763-265119ea32f2
# 2  INSTANT  e5e7483e-066d-4b56-b075-3358e7e1ddb3
# 3    DAILY  35892ae8-c3e4-40d3-83f8-0679258d1314
# 4  INSTANT  b41fab61-153d-4c57-a49b-9bcb2fa89e21
#
#                          merchant_token             merchant_name  \
# 0  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 1  caf21096-91eb-4c7d-bc79-f80019c121d3              La Terracita
# 2  a9e01641-6028-423a-8448-cd8d384e6fd6          Mini super zayra
# 3  b0f5676e-d1e4-4da4-b44b-2d3dd7fdecf4  Cerrajeria La Cachanilla
# 4  e59ebe27-4fe6-4de9-b31d-4f21abfcd56a   Frutas Y Verduras Marjo
#
#                            user_email  report_id report_date_local  amount_x  \
# 0              gamboah100@hotmail.com  22CDBX79P        2022-07-24  2,319.90
# 1              gamboah100@hotmail.com  22J9YCFMV        2021-10-19    258.72
# 2            rogeliogibarra@gmail.com  25QK27WLN        2021-12-31  1,433.53
# 3  cerrajerialacachanilla@hotmail.com  26CSLRNL9        2021-08-22  1,744.00
# 4                 tusitaoky@gmail.com  26QY75YTQ        2022-08-28    275.91
#
#                                            bank_name   payment_date_local  \
# 0  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 1  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 00:46:34
# 2  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:22
# 3                                      BBVA BANCOMER  2023-08-01 16:21:23
# 4  Opciones Empresariales del Noreste, S.A. de C....  2023-08-02 06:40:26
#
#    ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 0  ...              FP  Reprogramación      NaN        NaT
# 1  ...              FP  Reprogramación      NaN        NaT
# 2  ...            TRAD  Reprogramación      NaN        NaT
# 3  ...            TRAD  Reprogramación      NaN        NaT
# 4  ...            TRAD  Reprogramación      NaN        NaT
#
#   ultimo_mov_date_only      month status error_description esquema_query  \
# 0                  NaN  Not found    NaN               NaN           NaN
# 1                  NaN  Not found    NaN               NaN           NaN
# 2                  NaN  Not found    NaN               NaN           NaN
# 3                  NaN  Not found    NaN               NaN           NaN
# 4                  NaN  Not found    NaN               NaN           NaN
#
#    status_cubeta
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 27 columns]

# %%
cruce_3.shape
# Out:
# (9471708, 27)
# (9471708, 27)

# %%
cruce_3_final = cruce_3[(cruce_3['month'] != 'Not found')]
cruce_3_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_3_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
cruce_3_final.shape
# Out:
# (0, 27)
# (0, 27)

# %%
duplicates_cruce_3_final = cruce_3_final[cruce_3_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_3_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_3_final.shape
# Out:
# (0, 27)
# (0, 27)

# %% [markdown]
# # CRUCE 4 - MES ANTERIOR

# %%
cruce_4 = query_new_last_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_4['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_4.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []

# %%
cruce_4.shape
# Out:
# (0, 19)
# (0, 19)

# %%
cruce_4_final = cruce_4[(cruce_4['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_4_final.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []

# %%
cruce_4_final.shape
# Out:
# (0, 19)
# (0, 19)

# %%
duplicates_cruce_4_final = cruce_4_final[cruce_4_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_4_final.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []

# %%
duplicates_cruce_4_final.shape
# Out:
# (0, 19)
# (0, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ANTERIOR

# %%
group_tipo_pago_last_month = pd.pivot_table(cruce_3_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago_last_month.fillna(0,inplace=True)
group_tipo_pago_last_month.head()
# Out:
# Empty DataFrame
# Columns: [(ultimo_mov_date_only, , , , )]
# Index: []
# Empty DataFrame
# Columns: [(ultimo_mov_date_only, , , , )]
# Index: []

# %%
group_tipo_pago_last_month.shape
# Out:
# (0, 1)
# (0, 1)

# %%
group_esquema_last_month = pd.pivot_table(cruce_4_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema_last_month.fillna(0,inplace=True)
group_esquema_last_month.head()
# Out:
# Empty DataFrame
# Columns: [(ultimo_mov_date_only, , , )]
# Index: []
# Empty DataFrame
# Columns: [(ultimo_mov_date_only, , , )]
# Index: []

# %%
group_esquema_last_month.shape
# Out:
# (0, 1)
# (0, 1)

# %%
writer = pd.ExcelWriter('FASE V. DATA POLIZA ERROR-USUAL OCTUBRE 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
group_tipo_pago.to_excel(writer, sheet_name='GRUPO TIPO PAGO')
group_esquema.to_excel(writer, sheet_name='GRUPO ESQUEMA')
group_tipo_pago_last_month.to_excel(writer, sheet_name='GRUPO TIPO PAGO-MESES ANT')
group_esquema_last_month.to_excel(writer, sheet_name='GRUPO ESQUEMA-MESES ANT')
cruce_1_final.to_excel(writer, sheet_name='DETALLE',index=False)
cruce_3_final.to_excel(writer, sheet_name='DETALLE-MESES ANTERIORES',index=False)
writer.close()
