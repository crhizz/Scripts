# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %%
start_date = '2023-09-01'
final_date = '2023-09-30'
query_error_year = 2023
query_error_month = 9

# %% [markdown]
# # INFORMACION DE  CUBETA ERROR

# %%
query_error = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\POLIZAS\2023\09. SEPTIEMBRE\DATA\ERROR SEPTIEMBRE 2023.csv',
                          dtype={'report_id':object})
query_error.rename(columns ={'MAX(report_date_local)':'report_date_local'}, inplace=True)
query_error['report_date_local']= pd.to_datetime(query_error['report_date_local'])
query_error['ultimo_mov'] = pd.to_datetime(query_error['ultimo_mov'])
query_error['merchant_id_query'] = query_error['merchant_id']
query_error['ultimo_mov_date_only']= pd.to_datetime(query_error['ultimo_mov']).dt.date
query_error['day'] = query_error['ultimo_mov'].dt.day
query_error['month'] = query_error['ultimo_mov'].dt.month
query_error['year'] = query_error['ultimo_mov'].dt.year
# query_error.loc[((query_error['day'] == 30 )
#                 & (query_error['month'] == 7)
#                 & (query_error['year'] == 2022)), "mes_cierre"] = 'Actual'
# query_error.loc[(query_error['day'] == 31 )
#             & (query_error['month'] == 7 )
#             & (query_error['year'] == 2022), "mes_cierre"] = 'Actual'
query_error.loc[(query_error['month'] == query_error_month )
            & (query_error['year'] == query_error_year), "mes_cierre"] = 'Actual'
query_error.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\2983591189.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   query_error = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\POLIZAS\2023\09. SEPTIEMBRE\DATA\ERROR SEPTIEMBRE 2023.csv',
#    Unnamed: 0                           merchant_id  \
# 0           0  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 1           1  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 2           2  d1087b80-5383-4b90-8738-bf309a1ce297
# 3           3  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
# 4           4  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
#
#                        merchant_name  report_id report_date_local   amount  \
# 0              Mscelanea Dulce Maria  GTS92WH86        2015-11-05   734.34
# 1              Mscelanea Dulce Maria  8VQRDV39G        2015-11-06   597.26
# 2                      Grupo Solutec  82G5CYSR7        2015-12-21 9,160.77
# 3  Ediciones Malinalco S de RL de CV  XWRKLC2ZL        2016-02-08 1,216.98
# 4  Ediciones Malinalco S de RL de CV  D9468C7W4        2016-02-16 1,993.14
#
#   status    error_description ultimo_mov  month  year status_cubeta  \
# 0  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 1  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 2  ERROR          failed swap 2017-11-01     11  2017         ERROR
# 3  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
# 4  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
#
#   esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 0   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 1   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 2   ERROR_USUAL  d1087b80-5383-4b90-8738-bf309a1ce297           2017-11-01
# 3   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
# 4   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
#
#    day mes_cierre
# 0   15        NaN
# 1   15        NaN
# 2    1        NaN
# 3   12        NaN
# 4   12        NaN

# %%
query_error.shape
# Out:
# (146572, 17)

# %%
query_error.dtypes
# Out:
# Unnamed: 0                       int64
# merchant_id                     object
# merchant_name                   object
# report_id                       object
# report_date_local       datetime64[ns]
# amount                         float64
# status                          object
# error_description               object
# ultimo_mov              datetime64[ns]
# month                            int32
# year                             int32
# status_cubeta                   object
# esquema_query                   object
# merchant_id_query               object
# ultimo_mov_date_only            object
# day                              int32
# mes_cierre                      object
# dtype: object

# %%
query_error['esquema_query'].unique()
# Out:
# array(['ERROR_USUAL', 'SIN_CLABE'], dtype=object)

# %%
query_error['status_cubeta'].unique()
# Out:
# array(['ERROR', 'NEW'], dtype=object)

# %% [markdown]
# # FILTRAR INFORMACION DE ACUERDO AL MES EN CURSO

# %%
query_error_current_month = query_error[(query_error['mes_cierre'] == 'Actual')]
query_error_current_month.sort_values(by=['day'],inplace=True)
query_error_current_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\3502651561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_error_current_month.sort_values(by=['day'],inplace=True)
#         Unnamed: 0                           merchant_id   merchant_name  \
# 137158      137158  a58e4e8d-43ca-4208-b6c5-7472515870db             NaN
# 92261        92261  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
# 137492      137492  9d160f57-491d-412f-b9e8-12d014e58093             NaN
# 92368        92368  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
# 92491        92491  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
#
#         report_id report_date_local   amount status  \
# 137158  A2YN83MDN        2023-08-31   143.74  ERROR
# 92261   R52VTB4SF        2022-12-12 1,302.25  ERROR
# 137492  AMHK8RCGN        2023-09-01 8,389.26  ERROR
# 92368   8Z4RQJK2L        2022-12-13   939.06  ERROR
# 92491   6CLXR2573        2022-12-14 1,270.64  ERROR
#
#                                         error_description ultimo_mov  month  \
# 137158                     DEV.SPEIEXCEDE EL LNMITE DE AB 2023-09-01      9
# 92261   DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9
# 137492  DEVOLUCION(02): Cuenta bloqueada        127420... 2023-09-01      9
# 92368   DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9
# 92491   DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9
#
#         year status_cubeta esquema_query  \
# 137158  2023           NEW   ERROR_USUAL
# 92261   2023           NEW   ERROR_USUAL
# 137492  2023           NEW   ERROR_USUAL
# 92368   2023           NEW   ERROR_USUAL
# 92491   2023           NEW   ERROR_USUAL
#
#                            merchant_id_query ultimo_mov_date_only  day  \
# 137158  a58e4e8d-43ca-4208-b6c5-7472515870db           2023-09-01    1
# 92261   39488a20-a5f8-4397-8998-7fc4e75d594f           2023-09-01    1
# 137492  9d160f57-491d-412f-b9e8-12d014e58093           2023-09-01    1
# 92368   39488a20-a5f8-4397-8998-7fc4e75d594f           2023-09-01    1
# 92491   39488a20-a5f8-4397-8998-7fc4e75d594f           2023-09-01    1
#
#        mes_cierre
# 137158     Actual
# 92261      Actual
# 137492     Actual
# 92368      Actual
# 92491      Actual

# %%
query_error_current_month.shape
# Out:
# (9872, 17)

# %%
query_error_current_month['month'].unique()
# Out:
# array([9])

# %%
query_error_current_month.columns
# Out:
# Index(['Unnamed: 0', 'merchant_id', 'merchant_name', 'report_id',
#        'report_date_local', 'amount', 'status', 'error_description',
#        'ultimo_mov', 'month', 'year', 'status_cubeta', 'esquema_query',
#        'merchant_id_query', 'ultimo_mov_date_only', 'day', 'mes_cierre'],
#       dtype='object')

# %%
duplicates_query_error = query_error_current_month[query_error_current_month.duplicated(['report_id'] , keep=False)]
duplicates_query_error.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []

# %%
duplicates_query_error.shape
# Out:
# (0, 17)

# %% [markdown]
# # PAGOS NEW DE MESES ANTERIORES

# %%
query_new_last_month = query_error[(query_error['mes_cierre'] != 'Actual') & (query_error['status_cubeta'] == 'NEW')]
query_new_last_month.sort_values(by=['day'],inplace=True)
query_new_last_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\3381233170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_new_last_month.sort_values(by=['day'],inplace=True)
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []

# %%
query_new_last_month.shape
# Out:
# (0, 17)

# %% [markdown]
# # INFORMACIÓN QUERIES - PAGOS

# %%
name_header = ['merchant_id','merchant_name','user_email','report_id','report_date_local','amount','status','bank_name'
               ,'payment_date_local','bank_account_owner_name','bank_account_number','swap']

# %% [markdown]
# ### NEXT MONTH

# %%
# TRADICIONAL
# trad_files_csv_2021_may = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\06. JUNE\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
# fp_files_csv_2021_may = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\06. JUNE\QUERIES\*.csv', recursive=False)

# %%
# disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_may])
# disp_files_csv_2021_may['date_query'] = disp_files_csv_2021_may["file_name"].str[-14:-4]
# disp_files_csv_2021_may['date_query']= pd.to_datetime(disp_files_csv_2021_may['date_query'])

# %%
# fp_disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_may])
# fp_disp_files_csv_2021_may['date_query'] = fp_disp_files_csv_2021_may["file_name"].str[-14:-4]
# fp_disp_files_csv_2021_may['date_query']= pd.to_datetime(fp_disp_files_csv_2021_may['date_query'])

# %% [markdown]
# ### CURRENT MONTH

# %%
# TRADICIONAL
trad_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\09. SEPTEMBER\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\09. SEPTIEMBRE\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2022_current])
disp_files_csv_2022_current['date_query'] = disp_files_csv_2022_current["file_name"].str[-14:-4]
disp_files_csv_2022_current['date_query']= pd.to_datetime(disp_files_csv_2022_current['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1256843064.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2022_current])
fp_disp_files_csv_2022_current['date_query'] = fp_disp_files_csv_2022_current["file_name"].str[-14:-4]
fp_disp_files_csv_2022_current['date_query']= pd.to_datetime(fp_disp_files_csv_2022_current['date_query'])

# %% [markdown]
# ### LAST MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\08. AUGUST\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\08. AGOSTO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_last])
disp_files_csv_2021_last['date_query'] = disp_files_csv_2021_last["file_name"].str[-14:-4]
disp_files_csv_2021_last['date_query']= pd.to_datetime(disp_files_csv_2021_last['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1395025386.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_last])
fp_disp_files_csv_2021_last['date_query'] = fp_disp_files_csv_2021_last["file_name"].str[-14:-4]
fp_disp_files_csv_2021_last['date_query']= pd.to_datetime(fp_disp_files_csv_2021_last['date_query'])

# %% [markdown]
# ### SPECIAL MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\07. JULY\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\07. JULIO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_spec])
disp_files_csv_2021_spec['date_query'] = disp_files_csv_2021_spec["file_name"].str[-14:-4]
disp_files_csv_2021_spec['date_query']= pd.to_datetime(disp_files_csv_2021_spec['date_query'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\4195701225.py:1: DtypeWarning: Columns (0,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})

# %%
fp_disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_spec])
fp_disp_files_csv_2021_spec['date_query'] = fp_disp_files_csv_2021_spec["file_name"].str[-14:-4]
fp_disp_files_csv_2021_spec['date_query']= pd.to_datetime(fp_disp_files_csv_2021_spec['date_query'])

# %% [markdown]
# ## ALL FILES

# %%
allfiles = pd.concat([disp_files_csv_2022_current,fp_disp_files_csv_2022_current
                     ,disp_files_csv_2021_last,fp_disp_files_csv_2021_last,
                     disp_files_csv_2021_spec,fp_disp_files_csv_2021_spec])
allfiles.reset_index()
allfiles.fillna('BLANK',inplace=True)
allfiles['date_query']= pd.to_datetime(allfiles['date_query'])
allfiles['report_date_local']= pd.to_datetime(allfiles['report_date_local'])
allfiles.loc[(allfiles['file_name'].str.contains('FP'),'tipo_dispersion')] = 'FP'
allfiles.loc[(allfiles['file_name'].str.contains('SWAP'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('BNTE'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('SANT'),'tipo_dispersion')] = 'TRAD'
allfiles.sort_values(by=['date_query','report_id'],inplace=True)
allfiles.drop(['status'],axis=1,inplace=True)
allfiles.head()
# Out:
#           type                           merchant_id  \
# 3510   INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 2013     DAILY  dad30253-f762-4835-ac81-88da19027087
# 31965    DAILY  48758a3a-a1c4-4212-ac57-8abe91bb3c55
# 3513   INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 2695   INSTANT  86a715c9-0980-485f-9945-271fc0a68ac4
#
#                              merchant_token            merchant_name  \
# 3510   11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 2013   73b433c6-0dad-461d-a9b9-b4e2cd378cf6  Mariachi Conquistadores
# 31965  8c39023d-a23c-477d-a61d-faaad72cf940     Grupo banquetero Dgi
# 3513   11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 2695   de9a79ed-c29d-4c82-a8cc-52e34758dfa8                Techmovil
#
#                           user_email  report_id report_date_local  amount  \
# 3510          fernando@idemsport.com  2H4VP2QMH        2022-11-15  344.97
# 2013   conquistadores200@hotmail.com  2MNBS8GYF        2021-12-03    0.03
# 31965                anuaraf@msn.com  2RDJ9GXQR        2023-03-15  191.65
# 3513          fernando@idemsport.com  362FL37N3        2022-11-17   57.49
# 2695        vale_fresa06@hotmail.com  36ZVM6FZW        2022-07-03  281.73
#
#                                                bank_name   payment_date_local  \
# 3510                                     ASP INTEGRA OPC  2023-07-01 13:20:01
# 2013                                       BBVA Bancomer  2023-07-01 12:00:10
# 31965                                Scotiabank Inverlat  2023-07-01 12:51:34
# 3513                                     ASP INTEGRA OPC  2023-07-01 13:19:53
# 2695   Opciones Empresariales del Noreste, S.A. de C....  2023-07-01 15:29:50
#
#             bank_account_owner_name  bank_account_number   batch_created_date  \
# 3510       Fernando Margain Morales  '659802020000012892  2023-07-01 12:55:56
# 2013   Roxana Noemi Alcerreca Rueda  '012180015621366738  2023-07-01 10:35:00
# 31965            Anuar Flores Frias  '044180001038781250  2023-07-01 10:13:09
# 3513       Fernando Margain Morales  '659802020000012892  2023-07-01 12:55:56
# 2695        Valeria Estrada Rosales  '659802020000213507  2023-07-01 15:05:47
#
#       disbursement_method                                               swap  \
# 3510              BANORTE  Fernando Margain Morales,,344.97,6598020200000...
# 2013              BANORTE  Roxana Noemi Alcerreca Rueda,,0.03,01218001562...
# 31965             BANORTE  Anuar Flores Frias,,191.65,044180001038781250,...
# 3513              BANORTE  Fernando Margain Morales,,57.49,65980202000001...
# 2695              BANORTE  Valeria Estrada Rosales,,281.73,65980202000021...
#
#                    file_name date_query tipo_dispersion
# 3510   FP-ALL 2023-07-01.csv 2023-07-01              FP
# 2013   BNTE-2 2023-07-01.csv 2023-07-01            TRAD
# 31965  BNTE-1 2023-07-01.csv 2023-07-01            TRAD
# 3513   FP-ALL 2023-07-01.csv 2023-07-01              FP
# 2695   FP-ALL 2023-07-01.csv 2023-07-01              FP

# %%
def tipo_pago(allfiles):
    if allfiles['date_query'] == allfiles['report_date_local']:
        return 'Pago del día'
    else:
        return 'Reprogramación'
allfiles['tipo_pago'] = allfiles.apply(tipo_pago, axis=1)

# %%
allfiles.head()
# Out:
#           type                           merchant_id  \
# 3510   INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 2013     DAILY  dad30253-f762-4835-ac81-88da19027087
# 31965    DAILY  48758a3a-a1c4-4212-ac57-8abe91bb3c55
# 3513   INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 2695   INSTANT  86a715c9-0980-485f-9945-271fc0a68ac4
#
#                              merchant_token            merchant_name  \
# 3510   11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 2013   73b433c6-0dad-461d-a9b9-b4e2cd378cf6  Mariachi Conquistadores
# 31965  8c39023d-a23c-477d-a61d-faaad72cf940     Grupo banquetero Dgi
# 3513   11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 2695   de9a79ed-c29d-4c82-a8cc-52e34758dfa8                Techmovil
#
#                           user_email  report_id report_date_local  amount  \
# 3510          fernando@idemsport.com  2H4VP2QMH        2022-11-15  344.97
# 2013   conquistadores200@hotmail.com  2MNBS8GYF        2021-12-03    0.03
# 31965                anuaraf@msn.com  2RDJ9GXQR        2023-03-15  191.65
# 3513          fernando@idemsport.com  362FL37N3        2022-11-17   57.49
# 2695        vale_fresa06@hotmail.com  36ZVM6FZW        2022-07-03  281.73
#
#                                                bank_name   payment_date_local  \
# 3510                                     ASP INTEGRA OPC  2023-07-01 13:20:01
# 2013                                       BBVA Bancomer  2023-07-01 12:00:10
# 31965                                Scotiabank Inverlat  2023-07-01 12:51:34
# 3513                                     ASP INTEGRA OPC  2023-07-01 13:19:53
# 2695   Opciones Empresariales del Noreste, S.A. de C....  2023-07-01 15:29:50
#
#             bank_account_owner_name  bank_account_number   batch_created_date  \
# 3510       Fernando Margain Morales  '659802020000012892  2023-07-01 12:55:56
# 2013   Roxana Noemi Alcerreca Rueda  '012180015621366738  2023-07-01 10:35:00
# 31965            Anuar Flores Frias  '044180001038781250  2023-07-01 10:13:09
# 3513       Fernando Margain Morales  '659802020000012892  2023-07-01 12:55:56
# 2695        Valeria Estrada Rosales  '659802020000213507  2023-07-01 15:05:47
#
#       disbursement_method                                               swap  \
# 3510              BANORTE  Fernando Margain Morales,,344.97,6598020200000...
# 2013              BANORTE  Roxana Noemi Alcerreca Rueda,,0.03,01218001562...
# 31965             BANORTE  Anuar Flores Frias,,191.65,044180001038781250,...
# 3513              BANORTE  Fernando Margain Morales,,57.49,65980202000001...
# 2695              BANORTE  Valeria Estrada Rosales,,281.73,65980202000021...
#
#                    file_name date_query tipo_dispersion       tipo_pago
# 3510   FP-ALL 2023-07-01.csv 2023-07-01              FP  Reprogramación
# 2013   BNTE-2 2023-07-01.csv 2023-07-01            TRAD  Reprogramación
# 31965  BNTE-1 2023-07-01.csv 2023-07-01            TRAD  Reprogramación
# 3513   FP-ALL 2023-07-01.csv 2023-07-01              FP  Reprogramación
# 2695   FP-ALL 2023-07-01.csv 2023-07-01              FP  Reprogramación

# %%
allfiles.shape
# Out:
# (9376119, 19)

# %% [markdown]
# # CRUCE 1 - MES ACTUAL

# %%
cruce_1 = allfiles.merge(query_error_current_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status'
                                                   ,'error_description','esquema_query','status_cubeta']],on='report_id',how='left')
cruce_1['month'].fillna('Not found',inplace=True)
cruce_1.head()
# Out:
#       type                           merchant_id  \
# 0  INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 1    DAILY  dad30253-f762-4835-ac81-88da19027087
# 2    DAILY  48758a3a-a1c4-4212-ac57-8abe91bb3c55
# 3  INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 4  INSTANT  86a715c9-0980-485f-9945-271fc0a68ac4
#
#                          merchant_token            merchant_name  \
# 0  11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 1  73b433c6-0dad-461d-a9b9-b4e2cd378cf6  Mariachi Conquistadores
# 2  8c39023d-a23c-477d-a61d-faaad72cf940     Grupo banquetero Dgi
# 3  11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 4  de9a79ed-c29d-4c82-a8cc-52e34758dfa8                Techmovil
#
#                       user_email  report_id report_date_local  amount_x  \
# 0         fernando@idemsport.com  2H4VP2QMH        2022-11-15    344.97
# 1  conquistadores200@hotmail.com  2MNBS8GYF        2021-12-03      0.03
# 2                anuaraf@msn.com  2RDJ9GXQR        2023-03-15    191.65
# 3         fernando@idemsport.com  362FL37N3        2022-11-17     57.49
# 4       vale_fresa06@hotmail.com  36ZVM6FZW        2022-07-03    281.73
#
#                                            bank_name   payment_date_local  \
# 0                                    ASP INTEGRA OPC  2023-07-01 13:20:01
# 1                                      BBVA Bancomer  2023-07-01 12:00:10
# 2                                Scotiabank Inverlat  2023-07-01 12:51:34
# 3                                    ASP INTEGRA OPC  2023-07-01 13:19:53
# 4  Opciones Empresariales del Noreste, S.A. de C....  2023-07-01 15:29:50
#
#    ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 0  ...              FP  Reprogramación      NaN        NaT
# 1  ...            TRAD  Reprogramación      NaN        NaT
# 2  ...            TRAD  Reprogramación      NaN        NaT
# 3  ...              FP  Reprogramación      NaN        NaT
# 4  ...              FP  Reprogramación      NaN        NaT
#
#   ultimo_mov_date_only      month status error_description esquema_query  \
# 0                  NaN  Not found    NaN               NaN           NaN
# 1                  NaN  Not found    NaN               NaN           NaN
# 2                  NaN  Not found    NaN               NaN           NaN
# 3                  NaN  Not found    NaN               NaN           NaN
# 4                  NaN  Not found    NaN               NaN           NaN
#
#    status_cubeta
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 27 columns]

# %%
cruce_1.shape
# Out:
# (9376119, 27)

# %%
duplicates_cruce_1_previo = cruce_1[cruce_1.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_previo.head()
# Out:
#        type                           merchant_id merchant_token  \
# 800   BLANK  875bbd26-3e3e-4672-999b-000ad2b327d6          BLANK
# 1050  BLANK  4f5cf90f-5539-4cb9-a9d4-850a04e064b9          BLANK
# 1173  BLANK  d9834451-d7b4-4e04-9922-f2d902de9d63          BLANK
# 1214  BLANK  13d53ea5-28b1-48f3-902c-eee1683201d3          BLANK
# 2269  BLANK  4f5cf90f-5539-4cb9-a9d4-850a04e064b9          BLANK
#
#      merchant_name user_email  report_id report_date_local  amount_x  \
# 800          BLANK      BLANK  A27BSZ75J        2023-06-25  4,325.50
# 1050         BLANK      BLANK  A28X46SY7        2023-06-21    138.12
# 1173         BLANK      BLANK  A29NWFVZK        2023-07-01    306.64
# 1214         BLANK      BLANK  A2B34LSS2        2023-07-01  4,050.05
# 2269         BLANK      BLANK  A2KJXNLB3        2023-06-30    197.88
#
#                                               bank_name   payment_date_local  \
# 800                            Banco Nacional de México  2023-07-02 07:44:37
# 1050  Opciones Empresariales del Noreste, S.A. de C....  2023-07-02 07:44:39
# 1173                    Banco Mercantil del Norte, S.A.  2023-07-01 11:57:26
# 1214                              Banco Santander, S.A.  2023-07-02 07:44:35
# 2269  Opciones Empresariales del Noreste, S.A. de C....  2023-07-02 07:44:38
#
#       ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 800   ...              FP  Reprogramación      NaN        NaT
# 1050  ...              FP  Reprogramación      NaN        NaT
# 1173  ...            TRAD    Pago del día      NaN        NaT
# 1214  ...            TRAD    Pago del día      NaN        NaT
# 2269  ...              FP  Reprogramación      NaN        NaT
#
#      ultimo_mov_date_only      month status error_description esquema_query  \
# 800                   NaN  Not found    NaN               NaN           NaN
# 1050                  NaN  Not found    NaN               NaN           NaN
# 1173                  NaN  Not found    NaN               NaN           NaN
# 1214                  NaN  Not found    NaN               NaN           NaN
# 2269                  NaN  Not found    NaN               NaN           NaN
#
#       status_cubeta
# 800             NaN
# 1050            NaN
# 1173            NaN
# 1214            NaN
# 2269            NaN
#
# [5 rows x 27 columns]

# %%
duplicates_cruce_1_previo.shape
# Out:
# (66857, 27)

# %%
cruce_1_final = cruce_1[(cruce_1['month'] != 'Not found')]
cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_1_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_24996\1938979547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
#           type                           merchant_id merchant_token  \
# 3557412  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 3628262  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 3799292  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 3801065  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
# 3851924  BLANK  c360bab1-1acb-4c0a-9c05-fa82a1557a03          BLANK
#
#         merchant_name user_email  report_id report_date_local  amount_x  \
# 3557412         BLANK      BLANK  AXHB6XYWB        2023-08-04      6.00
# 3628262         BLANK      BLANK  AKV36HV7Q        2023-08-05      4.00
# 3799292         BLANK      BLANK  A5NH6QZ7V        2023-05-22      2.00
# 3801065         BLANK      BLANK  A6BWF3JMT        2023-05-08      6.00
# 3851924         BLANK      BLANK  AT6J8HZ49        2023-06-18     12.00
#
#                                                  bank_name  \
# 3557412  Opciones Empresariales del Noreste, S.A. de C....
# 3628262  Opciones Empresariales del Noreste, S.A. de C....
# 3799292  Opciones Empresariales del Noreste, S.A. de C....
# 3801065  Opciones Empresariales del Noreste, S.A. de C....
# 3851924  Opciones Empresariales del Noreste, S.A. de C....
#
#           payment_date_local  ... tipo_dispersion       tipo_pago amount_y  \
# 3557412  2023-08-04 21:56:05  ...              FP    Pago del día     6.00
# 3628262  2023-08-06 07:32:50  ...            TRAD    Pago del día     4.00
# 3799292  2023-08-08 07:55:12  ...              FP  Reprogramación     2.00
# 3801065  2023-08-08 07:55:12  ...              FP  Reprogramación     6.00
# 3851924  2023-08-08 07:55:12  ...              FP  Reprogramación    12.00
#
#         ultimo_mov ultimo_mov_date_only month    status  \
# 3557412 2023-09-01           2023-09-01  9.00  ERROR_TV
# 3628262 2023-09-01           2023-09-01  9.00  ERROR_TV
# 3799292 2023-09-01           2023-09-01  9.00  ERROR_TV
# 3801065 2023-09-01           2023-09-01  9.00  ERROR_TV
# 3851924 2023-09-01           2023-09-01  9.00  ERROR_TV
#
#                                          error_description esquema_query  \
# 3557412  /21/CB Return Exceeds the limit of credits all...   ERROR_USUAL
# 3628262                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 3799292                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 3801065                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
# 3851924                     DEV.SPEIEXCEDE EL LNMITE DE AB   ERROR_USUAL
#
#          status_cubeta
# 3557412            NEW
# 3628262            NEW
# 3799292            NEW
# 3801065            NEW
# 3851924            NEW
#
# [5 rows x 27 columns]

# %%
cruce_1_final.shape
# Out:
# (4494, 27)

# %%
duplicates_cruce_1_final = cruce_1_final[cruce_1_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_1_final.shape
# Out:
# (0, 27)

# %% [markdown]
# # CRUCE 2 MES ACTUAL

# %%
cruce_2 = query_error_current_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_2['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_2.head()
# Out:
#    Unnamed: 0                           merchant_id   merchant_name  \
# 0      137158  a58e4e8d-43ca-4208-b6c5-7472515870db             NaN
# 1       92261  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
# 2      137492  9d160f57-491d-412f-b9e8-12d014e58093             NaN
# 3       92368  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
# 4       92491  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
#
#    report_id report_date_local   amount status  \
# 0  A2YN83MDN        2023-08-31   143.74  ERROR
# 1  R52VTB4SF        2022-12-12 1,302.25  ERROR
# 2  AMHK8RCGN        2023-09-01 8,389.26  ERROR
# 3  8Z4RQJK2L        2022-12-13   939.06  ERROR
# 4  6CLXR2573        2022-12-14 1,270.64  ERROR
#
#                                    error_description ultimo_mov  month  year  \
# 0                     DEV.SPEIEXCEDE EL LNMITE DE AB 2023-09-01      9  2023
# 1  DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9  2023
# 2  DEVOLUCION(02): Cuenta bloqueada        127420... 2023-09-01      9  2023
# 3  DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9  2023
# 4  DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9  2023
#
#   status_cubeta esquema_query                     merchant_id_query  \
# 0           NEW   ERROR_USUAL  a58e4e8d-43ca-4208-b6c5-7472515870db
# 1           NEW   ERROR_USUAL  39488a20-a5f8-4397-8998-7fc4e75d594f
# 2           NEW   ERROR_USUAL  9d160f57-491d-412f-b9e8-12d014e58093
# 3           NEW   ERROR_USUAL  39488a20-a5f8-4397-8998-7fc4e75d594f
# 4           NEW   ERROR_USUAL  39488a20-a5f8-4397-8998-7fc4e75d594f
#
#   ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 0           2023-09-01    1     Actual            TRAD    Pago del día
# 1           2023-09-01    1     Actual            TRAD  Reprogramación
# 2           2023-09-01    1     Actual            TRAD    Pago del día
# 3           2023-09-01    1     Actual            TRAD  Reprogramación
# 4           2023-09-01    1     Actual            TRAD  Reprogramación

# %%
cruce_2.shape
# Out:
# (11722, 19)

# %%
cruce_2_final = cruce_2[(cruce_2['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_2_final.head()
# Out:
#    Unnamed: 0                           merchant_id   merchant_name  \
# 0      137158  a58e4e8d-43ca-4208-b6c5-7472515870db             NaN
# 1       92261  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
# 2      137492  9d160f57-491d-412f-b9e8-12d014e58093             NaN
# 3       92368  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
# 4       92491  39488a20-a5f8-4397-8998-7fc4e75d594f  Abarrotes vero
#
#    report_id report_date_local   amount status  \
# 0  A2YN83MDN        2023-08-31   143.74  ERROR
# 1  R52VTB4SF        2022-12-12 1,302.25  ERROR
# 2  AMHK8RCGN        2023-09-01 8,389.26  ERROR
# 3  8Z4RQJK2L        2022-12-13   939.06  ERROR
# 4  6CLXR2573        2022-12-14 1,270.64  ERROR
#
#                                    error_description ultimo_mov  month  year  \
# 0                     DEV.SPEIEXCEDE EL LNMITE DE AB 2023-09-01      9  2023
# 1  DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9  2023
# 2  DEVOLUCION(02): Cuenta bloqueada        127420... 2023-09-01      9  2023
# 3  DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9  2023
# 4  DEVOLUCION(20): Excede el limite de saldo auto... 2023-09-01      9  2023
#
#   status_cubeta esquema_query                     merchant_id_query  \
# 0           NEW   ERROR_USUAL  a58e4e8d-43ca-4208-b6c5-7472515870db
# 1           NEW   ERROR_USUAL  39488a20-a5f8-4397-8998-7fc4e75d594f
# 2           NEW   ERROR_USUAL  9d160f57-491d-412f-b9e8-12d014e58093
# 3           NEW   ERROR_USUAL  39488a20-a5f8-4397-8998-7fc4e75d594f
# 4           NEW   ERROR_USUAL  39488a20-a5f8-4397-8998-7fc4e75d594f
#
#   ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 0           2023-09-01    1     Actual            TRAD    Pago del día
# 1           2023-09-01    1     Actual            TRAD  Reprogramación
# 2           2023-09-01    1     Actual            TRAD    Pago del día
# 3           2023-09-01    1     Actual            TRAD  Reprogramación
# 4           2023-09-01    1     Actual            TRAD  Reprogramación

# %%
cruce_2_final.shape
# Out:
# (6344, 19)

# %%
duplicates_cruce_2_final = cruce_2_final[cruce_2_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_2_final.head()
# Out:
#     Unnamed: 0                           merchant_id merchant_name  report_id  \
# 20      131436  25ffe999-9c0b-4db1-8b35-2b710c0b0d1c           NaN  AQKWYC5J8
# 21      131436  25ffe999-9c0b-4db1-8b35-2b710c0b0d1c           NaN  AQKWYC5J8
# 23      137508  a6693044-88e6-430a-9501-09601e6406a4           NaN  A3JZGXWR5
# 24      137508  a6693044-88e6-430a-9501-09601e6406a4           NaN  A3JZGXWR5
# 71      137514  d02e4ffe-7313-4637-9a2c-d9a59918feac           NaN  ASGN5VZGY
#
#    report_date_local   amount status  \
# 20        2023-08-10   388.66  ERROR
# 21        2023-08-10   388.66  ERROR
# 23        2023-09-01 1,849.40  ERROR
# 24        2023-09-01 1,849.40  ERROR
# 71        2023-09-01   220.40  ERROR
#
#                                     error_description ultimo_mov  month  year  \
# 20  /21/CB Return m.BNMX_RET_98 (BNMX_RET_98) /SBS... 2023-09-01      9  2023
# 21  /21/CB Return m.BNMX_RET_98 (BNMX_RET_98) /SBS... 2023-09-01      9  2023
# 23  /21/CB Return Blocked account (BNMX_RET_2) /SB... 2023-09-01      9  2023
# 24  /21/CB Return Blocked account (BNMX_RET_2) /SB... 2023-09-01      9  2023
# 71  /21/CB Return Blocked account (BNMX_RET_2) /SB... 2023-09-01      9  2023
#
#    status_cubeta esquema_query                     merchant_id_query  \
# 20         ERROR   ERROR_USUAL  25ffe999-9c0b-4db1-8b35-2b710c0b0d1c
# 21         ERROR   ERROR_USUAL  25ffe999-9c0b-4db1-8b35-2b710c0b0d1c
# 23           NEW   ERROR_USUAL  a6693044-88e6-430a-9501-09601e6406a4
# 24           NEW   ERROR_USUAL  a6693044-88e6-430a-9501-09601e6406a4
# 71           NEW   ERROR_USUAL  d02e4ffe-7313-4637-9a2c-d9a59918feac
#
#    ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 20           2023-09-01    1     Actual            TRAD    Pago del día
# 21           2023-09-01    1     Actual              FP  Reprogramación
# 23           2023-09-01    1     Actual            TRAD    Pago del día
# 24           2023-09-01    1     Actual              FP    Pago del día
# 71           2023-09-01    1     Actual            TRAD    Pago del día

# %%
duplicates_cruce_2_final.shape
# Out:
# (3101, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ACTUAL

# %%
group_tipo_pago = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago.fillna(0,inplace=True)
group_tipo_pago.head()
# Out:
#                 ultimo_mov_date_only       amount_x                 \
# esquema_query                           ERROR_USUAL
# status_cubeta                                 ERROR
# tipo_dispersion                                  FP           TRAD
# tipo_pago                            Reprogramación Reprogramación
# 0                         2023-09-01       1,589.52           0.00
# 1                         2023-09-02           0.00           0.00
# 2                         2023-09-03           0.00           0.00
# 3                         2023-09-04         253.49           0.00
# 4                         2023-09-05      50,445.29      75,076.15
#
#                                                                          \
# esquema_query
# status_cubeta            NEW
# tipo_dispersion           FP                        TRAD
# tipo_pago       Pago del día Reprogramación Pago del día Reprogramación
# 0                  25,833.35       1,190.18    39,131.78      89,335.43
# 1                  73,424.02           0.00     3,414.46           0.00
# 2                  69,767.11           0.00    52,585.96           5.74
# 3                   4,201.88           0.00    67,756.57           0.00
# 4                  10,009.20      25,795.12    56,549.91           0.00
#
#
# esquema_query          All
# status_cubeta
# tipo_dispersion
# tipo_pago
# 0               157,080.26
# 1                76,838.48
# 2               122,358.81
# 3                72,211.94
# 4               217,875.67

# %%
group_tipo_pago.shape
# Out:
# (31, 8)

# %%
group_esquema = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema.fillna(0,inplace=True)
group_esquema.head()
# Out:
#               ultimo_mov_date_only       amount_x                              \
# esquema_query                         ERROR_USUAL
# status_cubeta                               ERROR          NEW
# tipo_pago                          Reprogramación Pago del día Reprogramación
# 0                       2023-09-01       1,589.52    64,965.13      90,525.61
# 1                       2023-09-02           0.00    76,838.48           0.00
# 2                       2023-09-03           0.00   122,353.07           5.74
# 3                       2023-09-04         253.49    71,958.45           0.00
# 4                       2023-09-05     125,521.44    66,559.11      25,795.12
#
#
# esquema_query        All
# status_cubeta
# tipo_pago
# 0             157,080.26
# 1              76,838.48
# 2             122,358.81
# 3              72,211.94
# 4             217,875.67

# %%
group_esquema.shape
# Out:
# (31, 5)

# %% [markdown]
# # CRUCE 3 - MES ANTERIOR

# %%
cruce_3 = allfiles.merge(query_new_last_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status',
                                               'error_description','esquema_query','status_cubeta']],
                         on='report_id',how='left')
cruce_3['month'].fillna('Not found',inplace=True)
cruce_3.head()
# Out:
#       type                           merchant_id  \
# 0  INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 1    DAILY  dad30253-f762-4835-ac81-88da19027087
# 2    DAILY  48758a3a-a1c4-4212-ac57-8abe91bb3c55
# 3  INSTANT  ab347b7d-7bc3-4aa2-bdef-9b8a54721169
# 4  INSTANT  86a715c9-0980-485f-9945-271fc0a68ac4
#
#                          merchant_token            merchant_name  \
# 0  11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 1  73b433c6-0dad-461d-a9b9-b4e2cd378cf6  Mariachi Conquistadores
# 2  8c39023d-a23c-477d-a61d-faaad72cf940     Grupo banquetero Dgi
# 3  11326391-880d-40d4-876b-79578ad53a57        LA NUBE ARTESANAL
# 4  de9a79ed-c29d-4c82-a8cc-52e34758dfa8                Techmovil
#
#                       user_email  report_id report_date_local  amount_x  \
# 0         fernando@idemsport.com  2H4VP2QMH        2022-11-15    344.97
# 1  conquistadores200@hotmail.com  2MNBS8GYF        2021-12-03      0.03
# 2                anuaraf@msn.com  2RDJ9GXQR        2023-03-15    191.65
# 3         fernando@idemsport.com  362FL37N3        2022-11-17     57.49
# 4       vale_fresa06@hotmail.com  36ZVM6FZW        2022-07-03    281.73
#
#                                            bank_name   payment_date_local  \
# 0                                    ASP INTEGRA OPC  2023-07-01 13:20:01
# 1                                      BBVA Bancomer  2023-07-01 12:00:10
# 2                                Scotiabank Inverlat  2023-07-01 12:51:34
# 3                                    ASP INTEGRA OPC  2023-07-01 13:19:53
# 4  Opciones Empresariales del Noreste, S.A. de C....  2023-07-01 15:29:50
#
#    ... tipo_dispersion       tipo_pago amount_y ultimo_mov  \
# 0  ...              FP  Reprogramación      NaN        NaT
# 1  ...            TRAD  Reprogramación      NaN        NaT
# 2  ...            TRAD  Reprogramación      NaN        NaT
# 3  ...              FP  Reprogramación      NaN        NaT
# 4  ...              FP  Reprogramación      NaN        NaT
#
#   ultimo_mov_date_only      month status error_description esquema_query  \
# 0                  NaN  Not found    NaN               NaN           NaN
# 1                  NaN  Not found    NaN               NaN           NaN
# 2                  NaN  Not found    NaN               NaN           NaN
# 3                  NaN  Not found    NaN               NaN           NaN
# 4                  NaN  Not found    NaN               NaN           NaN
#
#    status_cubeta
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 27 columns]

# %%
cruce_3.shape
# Out:
# (9376119, 27)

# %%
cruce_3_final = cruce_3[(cruce_3['month'] != 'Not found')]
cruce_3_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_3_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
cruce_3_final.shape
# Out:
# (0, 27)

# %%
duplicates_cruce_3_final = cruce_3_final[cruce_3_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_3_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_3_final.shape
# Out:
# (0, 27)

# %% [markdown]
# # CRUCE 4 - MES ANTERIOR

# %%
cruce_4 = query_new_last_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_4['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_4.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []

# %%
cruce_4.shape
# Out:
# (0, 19)

# %%
cruce_4_final = cruce_4[(cruce_4['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_4_final.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []

# %%
cruce_4_final.shape
# Out:
# (0, 19)

# %%
duplicates_cruce_4_final = cruce_4_final[cruce_4_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_4_final.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre, report_id, tipo_dispersion, tipo_pago]
# Index: []

# %%
duplicates_cruce_4_final.shape
# Out:
# (0, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ANTERIOR

# %%
group_tipo_pago_last_month = pd.pivot_table(cruce_3_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago_last_month.fillna(0,inplace=True)
group_tipo_pago_last_month.head()
# Out:
# Empty DataFrame
# Columns: [(ultimo_mov_date_only, , , , )]
# Index: []

# %%
group_tipo_pago_last_month.shape
# Out:
# (0, 1)

# %%
group_esquema_last_month = pd.pivot_table(cruce_4_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema_last_month.fillna(0,inplace=True)
group_esquema_last_month.head()
# Out:
# Empty DataFrame
# Columns: [(ultimo_mov_date_only, , , )]
# Index: []

# %%
group_esquema_last_month.shape
# Out:
# (0, 1)

# %%
writer = pd.ExcelWriter('FASE V. DATA POLIZA ERROR-USUAL SEPTIEMBRE 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
group_tipo_pago.to_excel(writer, sheet_name='GRUPO TIPO PAGO')
group_esquema.to_excel(writer, sheet_name='GRUPO ESQUEMA')
group_tipo_pago_last_month.to_excel(writer, sheet_name='GRUPO TIPO PAGO-MESES ANT')
group_esquema_last_month.to_excel(writer, sheet_name='GRUPO ESQUEMA-MESES ANT')
cruce_1_final.to_excel(writer, sheet_name='DETALLE',index=False)
cruce_3_final.to_excel(writer, sheet_name='DETALLE-MESES ANTERIORES',index=False)
writer.close()
