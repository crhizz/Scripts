#
#    applied_fees_benefits  applied_taxes_benefits  fee_direct_deposit  \
# 0                 363.27                   58.16           18,685.19
# 1                 405.39                   64.91           22,005.46
# 2                 374.55                   59.97           19,550.84
# 3                 482.31                   77.20           20,318.01
# 4                 330.73                   52.92           19,087.77
#
#    taxes_direct_deposit  total_adjustments  total_adjustment_fees_charged  \
# 0              2,992.61       1,166,061.47                          -0.00
# 1              3,524.54       1,351,215.88                      27,212.50
# 2              3,131.36       1,157,981.53                          -0.00
# 3              3,254.19       1,550,295.70                         576.00
# 4              3,057.23       1,769,609.08                          -0.00
#
#    total_adjustment_taxes   cobranza  total_released  total_retained  \
# 0                   -0.00  20,758.20    1,531,794.44    2,495,899.78
# 1                4,354.00  10,623.06    2,038,983.65      615,419.39
# 2                   -0.00   2,663.37    5,501,120.02    1,645,211.10
# 3                   92.16 196,019.02    1,263,352.39    1,752,149.41
# 4                   -0.00  25,978.96      357,194.01      432,484.81
#
#    cancelaciones  total_due_calculado      total_due  diferencias
# 0           0.00       180,723,575.26 180,723,575.26        -0.00
# 1      31,566.50       176,913,873.21 176,913,873.21        -0.00
# 2           0.00       184,765,883.02 184,765,883.02         0.00
# 3         668.16       207,731,904.57 207,731,904.57        -0.00
# 4           0.00       234,802,072.80 234,802,072.80        -0.00

# %%
conc_1.shape
# Out:
# (28, 18)

# %%
conc_3 = settled_current_month.groupby(['report_date_local','type']).agg({'total_transactions':sum,'total_fees_charged':sum
                                                                    ,'total_taxes':sum,'applied_fees_benefits':sum
                                                                    ,'applied_taxes_benefits':sum,'fee_direct_deposit':sum
                                                                    ,'taxes_direct_deposit':sum,'total_adjustments':sum     
                                                                    ,'total_adjustment_fees_charged':sum
                                                                    ,'total_adjustment_taxes':sum 
                                                                    ,'cobranza':sum,'total_released':sum
                                                                    ,'total_retained':sum,'cancelaciones':sum
                                                                    ,'total_due_calculado':sum,'total_due':sum
                                                                    ,'diferencias':sum}).reset_index()
conc_3['total_adjustments'] = conc_3['total_adjustments']*-1 
conc_3['total_adjustment_fees_charged'] = conc_3['total_adjustment_fees_charged']*-1
conc_3['total_adjustment_taxes'] = conc_3['total_adjustment_taxes']*-1 
conc_3.head()
# Out:
#   report_date_local     type  total_transactions  total_fees_charged  \
# 0        2023-02-01    DAILY      192,006,810.59        8,046,896.43
# 1        2023-02-01  INSTANT          187,846.10            6,762.43
# 2        2023-02-02    DAILY      185,316,692.44        7,454,576.26
# 3        2023-02-02  INSTANT          130,662.73            4,703.82
# 4        2023-02-03    DAILY      190,925,612.72        7,745,321.49
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 0 1,287,514.76                 363.27                   58.16
# 1     1,082.03                   0.00                    0.00
# 2 1,192,741.41                 405.39                   64.91
# 3       752.59                   0.00                    0.00
# 4 1,239,263.86                 374.55                   59.97
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 0           18,685.19              2,992.61       1,162,438.01
# 1                0.00                  0.00           3,623.46
# 2           22,005.46              3,524.54       1,346,730.37
# 3                0.00                  0.00           4,485.51
# 4           19,550.84              3,131.36       1,153,972.38
#
#    total_adjustment_fees_charged  total_adjustment_taxes  cobranza  \
# 0                          -0.00                   -0.00 20,758.20
# 1                          -0.00                   -0.00      0.00
# 2                      27,212.50                4,354.00 10,623.06
# 3                          -0.00                   -0.00      0.00
# 4                          -0.00                   -0.00  2,663.37
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 0    1,531,794.44    2,495,899.78           0.00       180,547,197.08
# 1            0.00            0.00           0.00           176,378.18
# 2    2,038,983.65      615,419.39      31,566.50       176,793,152.40
# 3            0.00            0.00           0.00           120,720.81
# 4    5,501,120.02    1,645,211.10           0.00       184,663,417.26
#
#        total_due  diferencias
# 0 180,547,197.08        -0.00
# 1     176,378.18         0.00
# 2 176,793,152.40        -0.00
# 3     120,720.81        -0.00
# 4 184,663,417.26         0.00

# %%
conc_3.shape
# Out:
# (56, 19)

# %%
conc_3['type'].unique()
# Out:
# array(['DAILY', 'INSTANT'], dtype=object)

# %%
data_daily = conc_3[(conc_3['type'] == 'DAILY')]
data_daily.head()
# Out:
#   report_date_local   type  total_transactions  total_fees_charged  \
# 0        2023-02-01  DAILY      192,006,810.59        8,046,896.43
# 2        2023-02-02  DAILY      185,316,692.44        7,454,576.26
# 4        2023-02-03  DAILY      190,925,612.72        7,745,321.49
# 6        2023-02-04  DAILY      219,985,740.58        8,770,644.29
# 8        2023-02-05  DAILY      247,914,436.98        9,823,362.35
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 0 1,287,514.76                 363.27                   58.16
# 2 1,192,741.41                 405.39                   64.91
# 4 1,239,263.86                 374.55                   59.97
# 6 1,403,316.28                 482.31                   77.20
# 8 1,571,746.92                 330.73                   52.92
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 0           18,685.19              2,992.61       1,162,438.01
# 2           22,005.46              3,524.54       1,346,730.37
# 4           19,550.84              3,131.36       1,153,972.38
# 6           20,318.01              3,254.19       1,546,244.79
# 8           19,087.77              3,057.23       1,766,293.25
#
#    total_adjustment_fees_charged  total_adjustment_taxes   cobranza  \
# 0                          -0.00                   -0.00  20,758.20
# 2                      27,212.50                4,354.00  10,623.06
# 4                          -0.00                   -0.00   2,663.37
# 6                         576.00                   92.16 196,019.02
# 8                          -0.00                   -0.00  25,978.96
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 0    1,531,794.44    2,495,899.78           0.00       180,547,197.08
# 2    2,038,983.65      615,419.39      31,566.50       176,793,152.40
# 4    5,501,120.02    1,645,211.10           0.00       184,663,417.26
# 6    1,263,352.39    1,752,149.41         668.16       207,605,519.05
# 8      357,194.01      432,484.81           0.00       234,674,293.35
#
#        total_due  diferencias
# 0 180,547,197.08        -0.00
# 2 176,793,152.40        -0.00
# 4 184,663,417.26         0.00
# 6 207,605,519.05        -0.00
# 8 234,674,293.35        -0.00

# %%
data_daily.shape
# Out:
# (28, 19)

# %%
data_instant = conc_3[(conc_3['type'] == 'INSTANT')]
data_instant.head()
# Out:
#   report_date_local     type  total_transactions  total_fees_charged  \
# 1        2023-02-01  INSTANT          187,846.10            6,762.43
# 3        2023-02-02  INSTANT          130,662.73            4,703.82
# 5        2023-02-03  INSTANT          114,286.04            6,733.73
# 7        2023-02-04  INSTANT          136,706.57            5,405.33
# 9        2023-02-05  INSTANT          139,832.63            7,532.14
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 1     1,082.03                   0.00                    0.00
# 3       752.59                   0.00                    0.00
# 5     1,077.40                   0.00                    0.00
# 7       864.81                   0.00                    0.00
# 9     1,205.21                   0.00                    0.00
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 1                0.00                  0.00           3,623.46
# 3                0.00                  0.00           4,485.51
# 5                0.00                  0.00           4,009.15
# 7                0.00                  0.00           4,050.91
# 9                0.00                  0.00           3,315.83
#
#    total_adjustment_fees_charged  total_adjustment_taxes  cobranza  \
# 1                          -0.00                   -0.00      0.00
# 3                          -0.00                   -0.00      0.00
# 5                          -0.00                   -0.00      0.00
# 7                          -0.00                   -0.00      0.00
# 9                          -0.00                   -0.00      0.00
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 1            0.00            0.00           0.00           176,378.18
# 3            0.00            0.00           0.00           120,720.81
# 5            0.00            0.00           0.00           102,465.76
# 7            0.00            0.00           0.00           126,385.52
# 9            0.00            0.00           0.00           127,779.45
#
#    total_due  diferencias
# 1 176,378.18         0.00
# 3 120,720.81        -0.00
# 5 102,465.76        -0.00
# 7 126,385.52         0.00
# 9 127,779.45         0.00

# %%
data_instant.shape
# Out:
# (28, 19)

# %% [markdown]
# ### RELEASED SIN CLABE

# %%
released_sinclabe = settled_current_month[(settled_current_month['tipopago'] == 'sin CLABE')]
released_sinclabe.head()
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, user_email, report_id, report_date_local, total_transactions, total_fees_charged, total_taxes, applied_fees_benefits, applied_taxes_benefits, fee_direct_deposit, taxes_direct_deposit, total_adjustments, total_adjustment_fees_charged, total_adjustment_taxes, cobranza, total_released, total_retained, tipopago, total_due, type, created_date, created_time, updated_date, updated_time, file_name, Date_file, canc_1, canc_2, cancelaciones, total_due_calculado, diferencias]
# Index: []
#
# [0 rows x 32 columns]

# %%
released_sinclabe.shape
# Out:
# (0, 32)

# %%
released_1 = released_sinclabe.groupby(['report_date_local']).agg({'total_released':sum}).reset_index()
released_1.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, total_released]
# Index: []

# %%
released_1.shape
# Out:
# (0, 2)

# %%
released_3 = released_sinclabe.groupby(['report_date_local','type']).agg({'total_released':sum}).reset_index()
released_3.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_3.shape
# Out:
# (0, 3)

# %%
released_3['type'].unique()
# Out:
# array([], dtype=object)

# %%
released_daily = released_3[(released_3['type'] == 'DAILY')]
released_daily.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_daily.shape
# Out:
# (0, 3)

# %%
released_instant = released_3[(released_3['type'] == 'INSTANT')]
released_instant.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_instant.shape
# Out:
# (0, 3)

# %% [markdown]
# # INFO CUPONES

# %%
allcupon_fact = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FACTURACION\2023\02. FEBRERO\Cupones*.csv', recursive=False)
allcupon_fact
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\FACTURACION\\2023\\02. FEBRERO\\Cupones_mm.csv']

# %%
cupon_current_month = pd.concat([pd.read_csv(f,dtype={'report_id':object})
                                 .assign(file_name=os.path.basename(f)) for f in allcupon_fact])
cupon_current_month.head()
# Out:
#                             merchant_id                        merchant_token  \
# 0  40dda9f3-518e-423f-8b04-1572ba44a0d7  fbafce7d-82d6-470f-b76a-151332042ddd
# 1  a2760683-129f-4de4-98e3-7e7a08d44e30  95e02cc8-864b-4249-83c6-6a41b7d39b0f
# 2  9f7384ad-a017-4e15-81f9-1a77eee62f5d  b4c82681-754a-4932-9d1e-11c116df2bb4
# 3  6856f295-75c8-4a35-8728-531630c3e0a2  5d5bff5a-e49a-4a09-95b0-0b6a19bfaf6f
# 4  738de109-77df-4182-9643-e436bb893a38  343c2a67-5c80-4779-8ede-c2e51ddd8436
#
#                           fee_refund_id  report_id  number_transactions  \
# 0  5ac1dd9f-221b-4943-bd46-ec4aa4ae749b  228LCKGVL                    2
# 1  f7acbad2-452a-4fca-a143-b790ca5df741  228TQD63W                    1
# 2  8ba3cd55-d8ac-46a8-939f-0fe124c2d08a  22BZKF2BX                    2
# 3  31a3d5f0-b8b1-417d-83eb-03715535ebf9  22G2FKHG7                    1
# 4  0714eca4-db00-42a5-8208-c383324b096d  22R67MKYL                    1
#
#    total_refunded  amount  pending   source           created_at  \
# 0           76.42  108.00    31.58  LOYALTY  2022-10-06 11:39:28
# 1            1.67  108.00   106.33  LOYALTY  2022-11-30 10:43:51
# 2          141.40  292.00   150.60  LOYALTY  2021-11-13 11:05:44
# 3          108.00  108.00     0.00  LOYALTY  2022-12-16 10:22:56
# 4          108.00  108.00     0.00  LOYALTY  2022-07-21 07:56:43
#
#         file_name
# 0  Cupones_mm.csv
# 1  Cupones_mm.csv
# 2  Cupones_mm.csv
# 3  Cupones_mm.csv
# 4  Cupones_mm.csv

# %%
cupon_current_month.shape
# Out:
# (2912, 11)

# %%
cupones_data = settled_current_month.merge(cupon_current_month[['report_id','total_refunded','pending','amount',
                                              'source']] ,on='report_id', how='left')
cupones_data['total_benefits'] = cupones_data['applied_fees_benefits'] + cupones_data['applied_taxes_benefits']
cupones_data.loc[(cupones_data['applied_fees_benefits'] != 0) & (cupones_data['source']!= 'LOYALTY'), 'source'] = 'TOP_UPS'
cupones_data.head()
# Out:
#                             merchant_id                     merchant_name  \
# 0  f2a4c65c-7b5b-45a1-ac0d-063f82222703                          HAPINESS
# 1  285e56bc-330e-427b-8a77-d12c09286e56   ABARROTES Y CARNICERA EL CHILIN
# 2  a38189fc-99b4-4320-a53d-37b18ca37e20                            STUDIO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                            MARESH
# 4  1b103437-7cd3-4774-817f-d68bfc6ebb05  FRUTAS Y VERDURAS DE LA ESQUINA
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0    nmiriam234@yahoo.com.mx  BLFCPR555        2023-02-01              392.00
# 1  arevalorocio987@gmail.com  H9QS6CVX5        2023-02-01              301.00
# 2         gabarr54@gmail.com  N48ZF2BQY        2023-02-01              492.34
# 3    Maresh20221@outlook.com  SDVNZCH5S        2023-02-01               92.56
# 4    juanluis1890@icloud.com  5GP9V5LPK        2023-02-01               65.65
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0               14.11         2.26                   0.00
# 1               10.84         1.73                   0.00
# 2               17.72         2.84                   0.00
# 3                3.33         0.53                   0.00
# 4                2.36         0.38                   0.00
#
#    applied_taxes_benefits  ...  canc_1  canc_2  cancelaciones  \
# 0                    0.00  ...    0.00    0.00          -0.00
# 1                    0.00  ...    0.00    0.00          -0.00
# 2                    0.00  ...    0.00    0.00          -0.00
# 3                    0.00  ...    0.00    0.00          -0.00
# 4                    0.00  ...    0.00    0.00          -0.00
#
#    total_due_calculado  diferencias  total_refunded  pending  amount source  \
# 0               379.63         0.00             NaN      NaN     NaN    NaN
# 1               288.43         0.00             NaN      NaN     NaN    NaN
# 2               471.78         0.00             NaN      NaN     NaN    NaN
# 3                88.70         0.00             NaN      NaN     NaN    NaN
# 4                62.91         0.00             NaN      NaN     NaN    NaN
#
#    total_benefits
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4            0.00
#
# [5 rows x 37 columns]

# %%
cupones_data['source'].unique()
# Out:
# array([nan, 'TOP_UPS', 'LOYALTY'], dtype=object)

# %%
cupones_data.shape
# Out:
# (2414063, 37)

# %% [markdown]
# ### TOPUPS

# %%
topups_benefits = cupones_data[(cupones_data['source'] == 'TOP_UPS')]
topups_benefits.head()
# Out:
#                                 merchant_id                merchant_name  \
# 1024   3bc03f7d-381f-4cc3-8900-e5eeea6ab2c9                   QAHWA CAFE
# 4785   e6137438-606e-4003-ab47-bc63b68aee80                 DULCE GUZMAN
# 8094   ee626dac-927c-4707-b432-f177161cb690  PAPELERÍA Y REGALOS  SNOOPY
# 9860   7787ddcc-b2af-426c-9ebd-5d570b81b85a                 FRANCISCO MS
# 10525  23be7539-0dd0-4643-bdaa-429b3a94edad            FARMACIAS PHARMAX
#
#                       user_email  report_id report_date_local  \
# 1024   quincymendoza@hotmail.com  QG5MD8FCK        2023-02-01
# 4785     mendez_1984@hotmail.com  GCCYPB4XV        2023-02-01
# 8094      rubencito101@gmail.com  7NWPP7PHF        2023-02-01
# 9860             fco_ms@live.com  PV2HP72BD        2023-02-01
# 10525     andresrl_1@hotmail.com  Y9CFBC63K        2023-02-01
#
#        total_transactions  total_fees_charged  total_taxes  \
# 1024               519.00               18.71         3.00
# 4785               240.00                8.64         1.39
# 8094                50.96                1.83         0.29
# 9860               240.00                8.64         1.38
# 10525               33.00                1.19         0.19
#
#        applied_fees_benefits  applied_taxes_benefits  ...  canc_1  canc_2  \
# 1024                    3.45                    0.55  ...    0.00    0.00
# 4785                    2.59                    0.41  ...    0.00    0.00
# 8094                    0.69                    0.11  ...    0.00    0.00
# 9860                    5.17                    0.83  ...    0.00    0.00
# 10525                   1.19                    0.19  ...    0.00    0.00
#
#        cancelaciones  total_due_calculado  diferencias  total_refunded  \
# 1024           -0.00               501.29         0.00             NaN
# 4785           -0.00               232.97         0.00             NaN
# 8094           -0.00                49.64         0.00             NaN
# 9860           -0.00               235.98         0.00             NaN
# 10525          -0.00                33.00        -0.00             NaN
#
#        pending  amount   source  total_benefits
# 1024       NaN     NaN  TOP_UPS            4.00
# 4785       NaN     NaN  TOP_UPS            3.00
# 8094       NaN     NaN  TOP_UPS            0.80
# 9860       NaN     NaN  TOP_UPS            6.00
# 10525      NaN     NaN  TOP_UPS            1.38
#
# [5 rows x 37 columns]

# %%
topups_benefits.shape
# Out:
# (1471, 37)

# %%
pivot_topups_benefits = pd.pivot_table(topups_benefits,index=['report_date_local'],values=['applied_fees_benefits',
                                                                                        'applied_taxes_benefits'],
                                       aggfunc=np.sum,margins=False).reset_index()
pivot_topups_benefits.rename(columns ={'applied_fees_benefits':'applied_fees_benefits_topups',
                                      'applied_taxes_benefits':'applied_taxes_benefits_topups'},inplace=True)
pivot_topups_benefits.head()
# Out:
#   report_date_local  applied_fees_benefits_topups  \
# 0        2023-02-01                        233.77
# 1        2023-02-02                        399.99
# 2        2023-02-03                        374.55
# 3        2023-02-04                        306.05
# 4        2023-02-05                        330.73
#
#    applied_taxes_benefits_topups
# 0                          37.44
# 1                          64.05
# 2                          59.97
# 3                          48.99
# 4                          52.92

# %%
pivot_topups_benefits.shape
# Out:
# (28, 3)

# %% [markdown]
# ### CUPONES

# %%
coupons_benefits = cupones_data[(cupones_data['source'] == 'LOYALTY')]
coupons_benefits.head()
# Out:
#                                  merchant_id        merchant_name  \
# 24691   ffc9fd20-4ea5-4bcc-9c67-0c8456c54ce4            MARTISHOP
# 151715  f28424e8-706c-4c74-8baa-e414b15ca5db  SERVICIOS DIGITALES
# 305177  014dd452-008b-407a-b87c-20182184c4fc       MENDIVIL CAKES
# 319588  5176b0fb-46bd-4983-9625-5bb64f4760a8   REFACCIONES TORRES
# 339019  10e71bb5-0ffb-4d1b-9967-624f1ccb0cc0       MULTISERVICIOS
#
#                            user_email  report_id report_date_local  \
# 24691   ernestodaniel2306@hotmail.com  LNW3WGDVT        2023-02-01
# 151715              og30663@gmail.com  697PKWFXT        2023-02-02
# 305177         g.s.m.952000@gmail.com  VPWSMDMXC        2023-02-04
# 319588   vrodriguezvergara6@gmail.com  SXK7HWL5K        2023-02-04
# 339019           tijmartini@gmail.com  L8PJML48L        2023-02-04
#
#         total_transactions  total_fees_charged  total_taxes  \
# 24691               500.00              129.50        20.72
# 151715              150.00                5.40         0.86
# 305177               60.00                2.16         0.35
# 319588            1,000.00               81.00        12.96
# 339019            3,000.00              243.00        38.88
#
#         applied_fees_benefits  applied_taxes_benefits  ...  canc_1  canc_2  \
# 24691                  129.50                   20.72  ...    0.00    0.00
# 151715                   5.40                    0.86  ...    0.00    0.00
# 305177                   2.16                    0.35  ...    0.00    0.00
# 319588                  81.00                   12.96  ...    0.00    0.00
# 339019                  93.10                   14.90  ...    0.00    0.00
#
#         cancelaciones  total_due_calculado  diferencias  total_refunded  \
# 24691           -0.00               500.00         0.00          150.22
# 151715          -0.00               151.20         0.00            6.26
# 305177          -0.00                60.00         0.00            2.51
# 319588          -0.00             1,000.00         0.00           93.96
# 339019          -0.00             2,826.12         0.00          108.00
#
#         pending  amount   source  total_benefits
# 24691    549.78  700.00  LOYALTY          150.22
# 151715   101.74  108.00  LOYALTY            6.26
# 305177   105.49  108.00  LOYALTY            2.51
# 319588    14.04  108.00  LOYALTY           93.96
# 339019     0.00  108.00  LOYALTY          108.00
#
# [5 rows x 37 columns]

# %%
coupons_benefits.shape
# Out:
# (23, 37)

# %%
pivot_coupons_benefits = pd.pivot_table(coupons_benefits,index=['report_date_local'],values=['applied_fees_benefits',
                                                                                        'applied_taxes_benefits'],
                                       aggfunc=np.sum,margins=False).reset_index()
pivot_coupons_benefits.rename(columns ={'applied_fees_benefits':'applied_fees_benefits_coupons',
                                      'applied_taxes_benefits':'applied_taxes_benefits_coupons'},inplace=True)
pivot_coupons_benefits.head()
# Out:
#   report_date_local  applied_fees_benefits_coupons  \
# 0        2023-02-01                         129.50
# 1        2023-02-02                           5.40
# 2        2023-02-04                         176.26
# 3        2023-02-06                          16.20
# 4        2023-02-07                         106.90
#
#    applied_taxes_benefits_coupons
# 0                           20.72
# 1                            0.86
# 2                           28.21
# 3                            2.59
# 4                           17.10

# %%
pivot_coupons_benefits.shape
# Out:
# (17, 3)

# %% [markdown]
# # EXCEL FINAL

# %%
writer = pd.ExcelWriter('FASE I. DATA POLIZA FEBRERO 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
conc_1.to_excel(writer, sheet_name='MONTOS REPORT_DATE',index=False)
data_daily.to_excel(writer, sheet_name='MONTOS_DAILY',index=False)
data_instant.to_excel(writer, sheet_name='MONTOS_INSTANT',index=False)
pivot_topups_benefits.to_excel(writer, sheet_name='TOPUPS',index=False)
pivot_coupons_benefits.to_excel(writer, sheet_name='COUPONS',index=False)
released_1.to_excel(writer, sheet_name='RELEASED REPORT_DATE',index=False)
released_daily.to_excel(writer, sheet_name='RELEASED_DAILY',index=False)
released_instant.to_excel(writer, sheet_name='RELEASED_INSTANT',index=False)
writer.close()
