# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
from functools import reduce
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# #### ACUMULADO

# %%
cumfiles = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2022\11. NOVIEMBRE\QUERIES\*.csv', recursive=False)
cumfiles
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-01.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-02.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-03.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-04.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-05.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-06.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-07.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-08.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-09.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-10.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-11.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-12.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-13.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-14.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-15.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-16.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-17.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-18.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-19.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-20.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-21.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-22.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-23.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-24.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-25.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-26.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-27.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-28.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-29.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-30.csv']

# %%
cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
cum_1.columns = cum_1.columns.str.strip().str.lower() 
cum_1['report_date_local']= pd.to_datetime(cum_1['report_date_local']) 
cum_1.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2603350484.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...  total_retained  tipopago  total_due   type  \
# 0                    0.00  ...            0.00       NaN      78.57  DAILY
# 1                    0.00  ...            0.00       NaN     368.92  DAILY
# 2                    0.00  ...            0.00       NaN     258.72  DAILY
# 3                    0.00  ...            0.00       NaN      27.90  DAILY
# 4                    0.00  ...            0.00       NaN     642.02  DAILY
#
#    created_date  created_time  updated_date  updated_time  \
# 0    2022-11-01      02:00:29    2022-11-01      02:00:29
# 1    2022-11-01      02:00:30    2022-11-01      02:00:30
# 2    2022-11-01      02:00:30    2022-11-01      02:00:30
# 3    2022-11-01      02:00:30    2022-11-01      02:00:30
# 4    2022-11-01      02:00:30    2022-11-01      02:00:30
#
#                    file_name  tipopago
# 0  SETTLEMENT 2022-11-01.csv       NaN
# 1  SETTLEMENT 2022-11-01.csv       NaN
# 2  SETTLEMENT 2022-11-01.csv       NaN
# 3  SETTLEMENT 2022-11-01.csv       NaN
# 4  SETTLEMENT 2022-11-01.csv       NaN
#
# [5 rows x 27 columns]

# %%
cum_1.shape
# Out:
# (2849038, 27)

# %%
cum_distinct_0 = cum_1[(cum_1['total_due'] != 0)]
cum_distinct_0.head()
# Out:
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...  total_retained  tipopago  total_due   type  \
# 0                    0.00  ...            0.00       NaN      78.57  DAILY
# 1                    0.00  ...            0.00       NaN     368.92  DAILY
# 2                    0.00  ...            0.00       NaN     258.72  DAILY
# 3                    0.00  ...            0.00       NaN      27.90  DAILY
# 4                    0.00  ...            0.00       NaN     642.02  DAILY
#
#    created_date  created_time  updated_date  updated_time  \
# 0    2022-11-01      02:00:29    2022-11-01      02:00:29
# 1    2022-11-01      02:00:30    2022-11-01      02:00:30
# 2    2022-11-01      02:00:30    2022-11-01      02:00:30
# 3    2022-11-01      02:00:30    2022-11-01      02:00:30
# 4    2022-11-01      02:00:30    2022-11-01      02:00:30
#
#                    file_name  tipopago
# 0  SETTLEMENT 2022-11-01.csv       NaN
# 1  SETTLEMENT 2022-11-01.csv       NaN
# 2  SETTLEMENT 2022-11-01.csv       NaN
# 3  SETTLEMENT 2022-11-01.csv       NaN
# 4  SETTLEMENT 2022-11-01.csv       NaN
#
# [5 rows x 27 columns]

# %%
cum_distinct_0.shape
# Out:
# (2847886, 27)

# %% [markdown]
# #### PAGOS DE DISPERSIONES

# %%
pagos_dia_files_1 = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2022\11. NOVIEMBRE\ARCHIVO DISPERSIONES\Dispersión*.xlsx', recursive=False)
pagos_dia_files_1
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221101.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221102.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221103.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221104.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221105.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221106.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221107.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221108.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221109.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221110.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221111.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221112.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221113.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221114.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221115.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221116.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221117.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221118.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221119.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221120.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221121.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221122.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221123.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221124.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221125.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221126.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221127.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221128.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221129.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES\\Dispersión-20221130.xlsx']

# %%
pagos_1 = pd.concat([pd.read_excel(f,sheet_name='Swap del día').assign(file_name=os.path.basename(f)) for f in pagos_dia_files_1])
pagos_1['date_file'] = pagos_1["file_name"].str[-13:-5]
pagos_1['date_file']= pd.to_datetime(pagos_1['date_file'], format='%Y%m%d').dt.date
pagos_1['date_file']= pd.to_datetime(pagos_1['date_file'])
pagos_1.sort_values(by=['date_file'],ascending=True,inplace=True)
pagos_1['report_date_local']= pd.to_datetime(pagos_1['report_date_local']) 
pagos_1.head()
# Out:
#         type                           merchant_id          merchant_name  \
# 0      DAILY  00582624-a7b2-4865-80d2-dfab60f15ff0           super jazmin
# 60752  DAILY  aa8835e9-d0e9-4034-a20d-f0f3b08a9793   Farmacia Guadalupana
# 60751  DAILY  aa877403-d775-4b57-8e35-c516196d5d3e                 Gandhu
# 60750  DAILY  aa86764b-b3c9-4702-bac1-df1ae7eca0a6  GREEN CAFETERIA  URN
# 60749  DAILY  aa846165-2179-4648-a0c8-ff56d0700f8f               ShowTime
#
#                             user_email  report_id report_date_local  \
# 0            efrariver140616@gmail.com  JTMGC8BS8        2022-08-17
# 60752       fguadalupana4c@hotmail.com  SQH5TPGJH        2022-11-01
# 60751         jardingandhi@hotmail.com  QBQZ6PZBJ        2022-11-01
# 60750        abdiel.beltranp@gmail.com  DGRTGNZR6        2022-11-01
# 60749  montana_musiccity50@hotmail.com  QL9TXKBQB        2022-11-01
#
#        total_due            tipo           bank  \
# 0      38,921.80  Reprogramación    BANORTE/IXE
# 60752     373.90    Pago del día      SANTANDER
# 60751   3,449.67    Pago del día        BANAMEX
# 60750   1,993.07    Pago del día  BBVA BANCOMER
# 60749   3,602.80    Pago del día        BANAMEX
#
#                   bank_account_owner_name              CLABE status  \
# 0                     Yolanda Valdez Rosa  72238011898630992  ERROR
# 60752         MONICA LIZETH SANTOS CASTRO  14075605539982963   PAID
# 60751  Maria Guadalupe Olivares Fernandez   2180700787522524   PAID
# 60750        Abdiel Armando Beltrán Pérez  12150001087846399   PAID
# 60749     Jose Antonio Villanueva Sanchez   2180701685464301   PAID
#
#                                                LINEA CEP       Batch_time  \
# 0                                                    NaN  01. First_batch
# 60752                  COMPROBANTE MISMO BANCO SANTANDER  01. First_batch
# 60751  2022-11-01,2022110140014HDH0001414006050,40014...  01. First_batch
# 60750  2022-11-01,2022110140014HDH0001414006060,40014...  01. First_batch
# 60749  2022-11-01,2022110140014HDH0001414006020,40014...  01. First_batch
#
#       Banco_emisor                 file_name  date_file
# 0        SANTANDER  Dispersión-20221101.xlsx 2022-11-01
# 60752    SANTANDER  Dispersión-20221101.xlsx 2022-11-01
# 60751    SANTANDER  Dispersión-20221101.xlsx 2022-11-01
# 60750    SANTANDER  Dispersión-20221101.xlsx 2022-11-01
# 60749    SANTANDER  Dispersión-20221101.xlsx 2022-11-01

# %%
pagos_1.shape
# Out:
# (2732549, 17)

# %%
pagos_1['report_date_local'].unique()
# Out:
# array(['2022-08-17T00:00:00.000000000', '2022-11-01T00:00:00.000000000',
#        '2022-10-23T00:00:00.000000000', '2022-10-22T00:00:00.000000000',
#        '2022-10-21T00:00:00.000000000', '2022-10-20T00:00:00.000000000',
#        '2022-10-19T00:00:00.000000000', '2022-10-29T00:00:00.000000000',
#        '2022-10-26T00:00:00.000000000', '2022-10-30T00:00:00.000000000',
#        '2022-10-27T00:00:00.000000000', '2022-10-31T00:00:00.000000000',
#        '2022-10-28T00:00:00.000000000', '2022-06-28T00:00:00.000000000',
#        '2022-07-17T00:00:00.000000000', '2022-09-30T00:00:00.000000000',
#        '2022-09-29T00:00:00.000000000', '2022-09-28T00:00:00.000000000',
#        '2022-09-26T00:00:00.000000000', '2022-09-25T00:00:00.000000000',
#        '2022-09-24T00:00:00.000000000', '2022-09-23T00:00:00.000000000',
#        '2022-09-22T00:00:00.000000000', '2022-09-21T00:00:00.000000000',
#        '2022-01-25T00:00:00.000000000', '2022-01-18T00:00:00.000000000',
#        '2021-12-21T00:00:00.000000000', '2017-10-17T00:00:00.000000000',
#        '2017-11-29T00:00:00.000000000', '2017-11-28T00:00:00.000000000',
#        '2017-11-27T00:00:00.000000000', '2017-12-01T00:00:00.000000000',
#        '2017-12-04T00:00:00.000000000', '2017-12-13T00:00:00.000000000',
#        '2017-12-15T00:00:00.000000000', '2017-12-08T00:00:00.000000000',
#        '2022-11-24T00:00:00.000000000', '2020-03-13T00:00:00.000000000',
#        '2022-11-25T00:00:00.000000000', '2022-11-26T00:00:00.000000000',
#        '2022-11-27T00:00:00.000000000', '2020-11-23T00:00:00.000000000',
#        '2020-11-21T00:00:00.000000000', '2020-11-20T00:00:00.000000000',
#        '2020-11-19T00:00:00.000000000', '2020-11-15T00:00:00.000000000',
#        '2021-10-31T00:00:00.000000000', '2022-01-03T00:00:00.000000000',
#        '2022-01-02T00:00:00.000000000', '2022-03-07T00:00:00.000000000',
#        '2022-02-20T00:00:00.000000000', '2022-11-28T00:00:00.000000000',
#        '2021-04-11T00:00:00.000000000', '2022-11-29T00:00:00.000000000',
#        '2019-05-24T00:00:00.000000000', '2019-04-03T00:00:00.000000000',
#        '2021-10-02T00:00:00.000000000', '2021-12-11T00:00:00.000000000',
#        '2022-11-30T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# #### PAGOS DUPLICADOS TRADICIONAL

# %%
duplicates_trad = pagos_1[pagos_1.duplicated(['report_id','date_file'] , keep=False)]
duplicates_trad['INDEX'] = duplicates_trad['report_id'] + '_' + duplicates_trad['date_file'].astype('str')
duplicates_trad.sort_values(by=['date_file','report_id'],inplace=True)
duplicates_trad.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\1112391532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_trad['INDEX'] = duplicates_trad['report_id'] + '_' + duplicates_trad['date_file'].astype('str')
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\1112391532.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_trad.sort_values(by=['date_file','report_id'],inplace=True)
#         type                           merchant_id         merchant_name  \
# 90691  DAILY  0bb27338-a5ec-4aca-88bc-620629137c2f  MERCADO SOBRE RUEDAS
# 4701   DAILY  0bb27338-a5ec-4aca-88bc-620629137c2f  MERCADO SOBRE RUEDAS
# 90694  DAILY  3da66052-e6c4-483d-aac6-f6a2dc85fd0a                   VAA
# 22379  DAILY  3da66052-e6c4-483d-aac6-f6a2dc85fd0a                   VAA
# 81392  DAILY  e536af72-1ace-477b-88c0-796047e0e16b   Dlara distribuidora
#
#                              user_email  report_id report_date_local  \
# 90691                 my.etpv@gmail.com  56FDWPL3L        2022-11-01
# 4701                  my.etpv@gmail.com  56FDWPL3L        2022-11-01
# 90694        alanpaninovillar@gmail.com  5BLDW3RJQ        2022-11-01
# 22379        alanpaninovillar@gmail.com  5BLDW3RJQ        2022-11-01
# 81392  elcuarteldevillabarber@gmail.com  5YTYR9ZCL        2022-11-01
#
#        total_due          tipo           bank       bank_account_owner_name  \
# 90691   1,068.43  Pago del día    COMPARTAMOS          JAIME HERRERA TORRES
# 4701    1,068.43  Pago del día    COMPARTAMOS          JAIME HERRERA TORRES
# 90694       4.00  Pago del día        BANAMEX     Eduardo Angeles Olivares
# 22379       4.00  Pago del día        BANAMEX     Eduardo Angeles Olivares
# 81392     114.60  Pago del día  BBVA BANCOMER  Diana Elizabeth Aldrete Lara
#
#                     CLABE status  \
# 90691  130180001685885028   PAID
# 4701   130180001685885028   PAID
# 90694    2073560176378526   PAID
# 22379    2073560176378526   PAID
# 81392   12164004721508591   PAID
#
#                                                LINEA CEP        Batch_time  \
# 90691  2022-11-01,42644264202211011967689891,40072,40...  02. Second_batch
# 4701   2022-11-01,2022110140014HDH0001414071590,40014...   01. First_batch
# 90694  2022-11-01,42644264202211011967689888,40072,40...  02. Second_batch
# 22379  2022-11-01,2022110140014HDH0001414333690,40014...   01. First_batch
# 81392  2022-11-01,2022110140014HDH0001412928240,40014...   01. First_batch
#
#       Banco_emisor                 file_name  date_file                 INDEX
# 90691      BANORTE  Dispersión-20221101.xlsx 2022-11-01  56FDWPL3L_2022-11-01
# 4701     SANTANDER  Dispersión-20221101.xlsx 2022-11-01  56FDWPL3L_2022-11-01
# 90694      BANORTE  Dispersión-20221101.xlsx 2022-11-01  5BLDW3RJQ_2022-11-01
# 22379    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  5BLDW3RJQ_2022-11-01
# 81392    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  5YTYR9ZCL_2022-11-01

# %%
duplicates_trad.shape
# Out:
# (688, 18)

# %%
duplicates_trad['status'].unique()
# Out:
# array(['PAID', 'ERROR'], dtype=object)

# %%
duplicates_trad.drop_duplicates(subset="INDEX", keep='last', inplace=True)
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\494774456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_trad.drop_duplicates(subset="INDEX", keep='last', inplace=True)

# %%
duplicates_trad.head()
# Out:
#         type                           merchant_id         merchant_name  \
# 4701   DAILY  0bb27338-a5ec-4aca-88bc-620629137c2f  MERCADO SOBRE RUEDAS
# 22379  DAILY  3da66052-e6c4-483d-aac6-f6a2dc85fd0a                   VAA
# 90926  DAILY  e536af72-1ace-477b-88c0-796047e0e16b   Dlara distribuidora
# 4682   DAILY  0bb27338-a5ec-4aca-88bc-620629137c2f  MERCADO SOBRE RUEDAS
# 73987  DAILY  cff920c7-4d00-4d15-aebb-f8e0cd0150a9          Arbol De Oro
#
#                              user_email  report_id report_date_local  \
# 4701                  my.etpv@gmail.com  56FDWPL3L        2022-11-01
# 22379        alanpaninovillar@gmail.com  5BLDW3RJQ        2022-11-01
# 90926  elcuarteldevillabarber@gmail.com  5YTYR9ZCL        2022-11-01
# 4682                  my.etpv@gmail.com  67BPDBV8F        2022-10-10
# 73987        priscilomtz_26@hotmail.com  6924VZ46R        2022-11-01
#
#        total_due            tipo           bank       bank_account_owner_name  \
# 4701    1,068.43    Pago del día    COMPARTAMOS          JAIME HERRERA TORRES
# 22379       4.00    Pago del día        BANAMEX     Eduardo Angeles Olivares
# 90926     114.60    Pago del día  BBVA BANCOMER  Diana Elizabeth Aldrete Lara
# 4682      359.34  Reprogramación    COMPARTAMOS          JAIME HERRERA TORRES
# 73987   1,126.97    Pago del día        BANAMEX   Alma Priscila Lpez Martinez
#
#                     CLABE status  \
# 4701   130180001685885028   PAID
# 22379    2073560176378526   PAID
# 90926   12164004721508591   PAID
# 4682   130180001685885028   PAID
# 73987    2073560188038524   PAID
#
#                                                LINEA CEP        Batch_time  \
# 4701   2022-11-01,2022110140014HDH0001414071590,40014...   01. First_batch
# 22379  2022-11-01,2022110140014HDH0001414333690,40014...   01. First_batch
# 90926  2022-11-01,42644264202211011967689277,40072,40...  02. Second_batch
# 4682   2022-11-01,2022110140014HDH0001414071130,40014...   01. First_batch
# 73987  2022-11-01,2022110140014HDH0001414330640,40014...   01. First_batch
#
#       Banco_emisor                 file_name  date_file                 INDEX
# 4701     SANTANDER  Dispersión-20221101.xlsx 2022-11-01  56FDWPL3L_2022-11-01
# 22379    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  5BLDW3RJQ_2022-11-01
# 90926      BANORTE  Dispersión-20221101.xlsx 2022-11-01  5YTYR9ZCL_2022-11-01
# 4682     SANTANDER  Dispersión-20221101.xlsx 2022-11-01  67BPDBV8F_2022-11-01
# 73987    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  6924VZ46R_2022-11-01

# %%
duplicates_trad.shape
# Out:
# (344, 18)

# %%
pivot_duplicates_trad = pd.pivot_table(duplicates_trad,index=['tipo','date_file'],
                                  values=['total_due']
                                  ,aggfunc = ['sum', len],margins=True)
pivot_duplicates_trad.reset_index(drop=False, inplace=True)
pivot_duplicates_trad.head(10)
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\739626261.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_duplicates_trad = pd.pivot_table(duplicates_trad,index=['tipo','date_file'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\739626261.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_duplicates_trad = pd.pivot_table(duplicates_trad,index=['tipo','date_file'],
#            tipo  date_file        sum       len
#                             total_due total_due
# 0  Pago del día 2022-11-01  19,645.68        19
# 1  Pago del día 2022-11-02   1,582.05         3
# 2  Pago del día 2022-11-03   1,541.79         1
# 3  Pago del día 2022-11-04  16,294.70        17
# 4  Pago del día 2022-11-08  46,942.21        18
# 5  Pago del día 2022-11-09  19,097.44        20
# 6  Pago del día 2022-11-10  53,420.49        18
# 7  Pago del día 2022-11-11 128,532.24        13
# 8  Pago del día 2022-11-15     114.59         2
# 9  Pago del día 2022-11-16  85,608.22        22

# %%
pivot_duplicates_trad.shape
# Out:
# (30, 4)

# %% [markdown]
# #### FAST PAYMENTS

# %%
fp_files_1 = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2022\11. NOVIEMBRE\ARCHIVO DISPERSIONES FP\Dispersión-FP*.xlsx', recursive=False)
fp_files_1
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-01.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-02.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-03.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-04.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-05.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-06.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-07.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-08.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-09.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-10.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-11.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-12.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-13.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-14.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-15.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-16.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-17.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-18.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-19.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-20.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-21.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-22.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-23.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-24.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-25.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-26.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-27.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-28.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-29.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2022\\11. NOVIEMBRE\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2022-11-30.xlsx']

# %%
pagos_2 = pd.concat([pd.read_excel(f,sheet_name='FAST PAYMENTS').assign(file_name=os.path.basename(f)) for f in fp_files_1])
pagos_2['date_file'] = pagos_2["file_name"].str[-15:-4]
pagos_2['date_file']= pd.to_datetime(pagos_2['date_file']) 
pagos_2.sort_values(by=['date_file'],ascending=True,inplace=True)
pagos_2['report_date_local']= pd.to_datetime(pagos_2['report_date_local']) 
pagos_2.head()
# Out:
#          type                           merchant_id  \
# 0     INSTANT  f03bef74-3df8-41de-9c00-2a4a5e89888a
# 3173  INSTANT  3a71a0d7-45af-4462-beb9-eca7a3998483
# 3172  INSTANT  39b6d23e-9bb6-4954-b56c-3455be7544ad
# 3171  INSTANT  397e3523-75ae-45e7-99d9-820dc83f3933
# 3170  INSTANT  395f869a-4146-46b6-8481-713e5373dfdd
#
#                           merchant_name                    user_email  \
# 0                      DULCERIA TREVINO            goyob018@gmail.com
# 3173                      Naturalaceite   naturalmente-88@hotmail.com
# 3172      Quinta San Agustn Restaurante         9671504341f@gmail.com
# 3171  Chiles Secos Y Semillas Del Campo         davidha1808@gmail.com
# 3170                      Podologo Guel  anakarenzapatacruz@gmail.com
#
#       report_id report_date_local  total_due            tipo             bank  \
# 0     4GZJQTQCF        2022-10-27     160.98  Reprogramación    BBVA BANCOMER
# 3173  WJSDBNHCT        2022-11-01     210.81    Pago del día  ASP INTEGRA OPC
# 3172  NBHXTHSTG        2022-11-01   1,013.34    Pago del día  ASP INTEGRA OPC
# 3171  7X4PLVQ5S        2022-11-01     203.30    Pago del día  ASP INTEGRA OPC
# 3170  4QLZ4RLSW        2022-11-01     301.85    Pago del día  ASP INTEGRA OPC
#
#                            swap               CLABE status  \
# 0            012580004828704872   12580004828704872  ERROR
# 3173      Rodrigo Aceves Barron  659802020000149040   PAID
# 3172  Dayana Idali Santiz Gomez  659802020000013684   PAID
# 3171      David Hernandez Arias  659802020000138682   PAID
# 3170       Jhovany Guel Martnez  659802020000189521   PAID
#
#                                               LINEA CEP       Batch_time  \
# 0                                                   NaN  01. First_batch
# 3173  2022-11-01,18435C224FF7EF2D,40002,90659,659802...  05. Fifth_batch
# 3172  2022-11-01,18435C1A60B8F263,40002,90659,659802...  05. Fifth_batch
# 3171  2022-11-01,18435C1641C746D6,40002,90659,659802...  05. Fifth_batch
# 3170  2022-11-01,18435C184C90D75E,40002,90659,659802...  05. Fifth_batch
#
#      Banco_emisor                      file_name  date_file
# 0       SANTANDER  Dispersión-FP 2022-11-01.xlsx 2022-11-01
# 3173      BANAMEX  Dispersión-FP 2022-11-01.xlsx 2022-11-01
# 3172      BANAMEX  Dispersión-FP 2022-11-01.xlsx 2022-11-01
# 3171      BANAMEX  Dispersión-FP 2022-11-01.xlsx 2022-11-01
# 3170      BANAMEX  Dispersión-FP 2022-11-01.xlsx 2022-11-01

# %%
pagos_2.shape
# Out:
# (126333, 17)

# %% [markdown]
# #### PAGOS REPETIDOS FAST PAYMENTS

# %%
duplicates_fp = pagos_2[pagos_2.duplicated(['report_id','date_file'] , keep=False)]
duplicates_fp['INDEX'] = duplicates_fp['report_id'] + '_' + duplicates_fp['date_file'].astype('str')
duplicates_fp.sort_values(by=['date_file','report_id','Batch_time'],inplace=True)
duplicates_fp.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\3928666323.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_fp['INDEX'] = duplicates_fp['report_id'] + '_' + duplicates_fp['date_file'].astype('str')
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\3928666323.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_fp.sort_values(by=['date_file','report_id','Batch_time'],inplace=True)
#          type                           merchant_id merchant_name  \
# 1874  INSTANT  decc19df-985e-4ea9-8c48-ef4444cb28ea          CLIP
# 3332  INSTANT  decc19df-985e-4ea9-8c48-ef4444cb28ea          CLIP
# 1562  INSTANT  8638066e-fb8c-414e-80c0-d6793ba2ff3a  Laundry Room
# 2461  INSTANT  8638066e-fb8c-414e-80c0-d6793ba2ff3a  Laundry Room
# 1734  INSTANT  de602102-cd32-4ed8-9f74-e1a2a0e62426       Acuario
#
#                     user_email  report_id report_date_local  total_due  \
# 1874         vmorg07@gmail.com  8CG7BQT2G        2022-11-10  19,164.80
# 3332         vmorg07@gmail.com  8CG7BQT2G        2022-11-10  19,164.80
# 1562    josuerulfo@hotmail.com  22C7Q3DKD        2022-11-12     114.99
# 2461    josuerulfo@hotmail.com  22C7Q3DKD        2022-11-12     114.99
# 1734  jimenezsofia48@gmail.com  2357HGK95        2022-11-12   1,800.54
#
#               tipo             bank                      swap  \
# 1874  Pago del día  ASP INTEGRA OPC   Leonardo Fuentes Garcia
# 3332  Pago del día         BANREGIO   Veronica Morales Garcia
# 1562  Pago del día  ASP INTEGRA OPC  Josue Perez Rulfo Ibarra
# 2461  Pago del día  ASP INTEGRA OPC  Josue Perez Rulfo Ibarra
# 1734  Pago del día  ASP INTEGRA OPC     Sofia Jimenez Munguia
#
#                    CLABE status  \
# 1874  659802020000018511   PAID
# 3332   58597000016364761   PAID
# 1562  659802020000133315   PAID
# 2461  659802020000133315   PAID
# 1734  659802020000310099   PAID
#
#                                               LINEA CEP        Batch_time  \
# 1874  2022-11-10,18464199BDB59857,40014,90659,659802...   03. Third_batch
# 3332  2022-11-10,18464199BDB59857,40002,40058,058597...   05. Fifth_batch
# 1562                                                NaN  02. Second_batch
# 2461  2022-11-12,42644264202211121984514145,40072,90...   03. Third_batch
# 1734                                                NaN  02. Second_batch
#
#      Banco_emisor                      file_name  date_file  \
# 1874    SANTANDER  Dispersión-FP 2022-11-10.xlsx 2022-11-10
# 3332      BANAMEX  Dispersión-FP 2022-11-10.xlsx 2022-11-10
# 1562      BANORTE  Dispersión-FP 2022-11-12.xlsx 2022-11-12
# 2461      BANORTE  Dispersión-FP 2022-11-12.xlsx 2022-11-12
# 1734      BANORTE  Dispersión-FP 2022-11-12.xlsx 2022-11-12
#
#                      INDEX
# 1874  8CG7BQT2G_2022-11-10
# 3332  8CG7BQT2G_2022-11-10
# 1562  22C7Q3DKD_2022-11-12
# 2461  22C7Q3DKD_2022-11-12
# 1734  2357HGK95_2022-11-12

# %%
duplicates_fp.shape
# Out:
# (1028, 18)

# %%
duplicates_fp.drop_duplicates(subset="INDEX", keep='last', inplace=True)
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2218390481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_fp.drop_duplicates(subset="INDEX", keep='last', inplace=True)

# %%
duplicates_fp.head()
# Out:
#          type                           merchant_id    merchant_name  \
# 3332  INSTANT  decc19df-985e-4ea9-8c48-ef4444cb28ea             CLIP
# 2461  INSTANT  8638066e-fb8c-414e-80c0-d6793ba2ff3a     Laundry Room
# 2889  INSTANT  de602102-cd32-4ed8-9f74-e1a2a0e62426          Acuario
# 2997  INSTANT  face56d0-51aa-459e-b62a-f41c1fbfbebd        LA LUPITA
# 2577  INSTANT  9ea42026-078e-4570-98a0-2e0126a50a84  Abarrotes Fanny
#
#                           user_email  report_id report_date_local  total_due  \
# 3332               vmorg07@gmail.com  8CG7BQT2G        2022-11-10  19,164.80
# 2461          josuerulfo@hotmail.com  22C7Q3DKD        2022-11-12     114.99
# 2889        jimenezsofia48@gmail.com  2357HGK95        2022-11-12   1,800.54
# 2997  garciagallegosselene@gmail.com  25B8C5KZH        2022-11-12      93.91
# 2577         fanny01lobato@gmail.com  27GF4J45W        2022-11-12      49.51
#
#               tipo             bank                              swap  \
# 3332  Pago del día         BANREGIO           Veronica Morales Garcia
# 2461  Pago del día  ASP INTEGRA OPC          Josue Perez Rulfo Ibarra
# 2889  Pago del día  ASP INTEGRA OPC             Sofia Jimenez Munguia
# 2997  Pago del día  ASP INTEGRA OPC  Selene del rocio Garcia Gallegos
# 2577  Pago del día  ASP INTEGRA OPC          Juanita Lobato Gutierrez
#
#                    CLABE status  \
# 3332   58597000016364761   PAID
# 2461  659802020000133315   PAID
# 2889  659802020000310099   PAID
# 2997  659802020000030243   PAID
# 2577  659802020000355517   PAID
#
#                                               LINEA CEP       Batch_time  \
# 3332  2022-11-10,18464199BDB59857,40002,40058,058597...  05. Fifth_batch
# 2461  2022-11-12,42644264202211121984514145,40072,90...  03. Third_batch
# 2889  2022-11-12,42644264202211121984514166,40072,90...  03. Third_batch
# 2997  2022-11-12,42644264202211121984514240,40072,90...  03. Third_batch
# 2577  2022-11-12,42644264202211121984514805,40072,90...  03. Third_batch
#
#      Banco_emisor                      file_name  date_file  \
# 3332      BANAMEX  Dispersión-FP 2022-11-10.xlsx 2022-11-10
# 2461      BANORTE  Dispersión-FP 2022-11-12.xlsx 2022-11-12
# 2889      BANORTE  Dispersión-FP 2022-11-12.xlsx 2022-11-12
# 2997      BANORTE  Dispersión-FP 2022-11-12.xlsx 2022-11-12
# 2577      BANORTE  Dispersión-FP 2022-11-12.xlsx 2022-11-12
#
#                      INDEX
# 3332  8CG7BQT2G_2022-11-10
# 2461  22C7Q3DKD_2022-11-12
# 2889  2357HGK95_2022-11-12
# 2997  25B8C5KZH_2022-11-12
# 2577  27GF4J45W_2022-11-12

# %%
duplicates_fp.shape
# Out:
# (514, 18)

# %%
pivot_duplicates_fp = pd.pivot_table(duplicates_fp,index=['tipo','date_file'],
                                  values=['total_due']
                                  ,aggfunc = ['sum', len],margins=True)
pivot_duplicates_fp.reset_index(drop=False, inplace=True)
pivot_duplicates_fp.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\3187082303.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_duplicates_fp = pd.pivot_table(duplicates_fp,index=['tipo','date_file'],
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\3187082303.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_duplicates_fp = pd.pivot_table(duplicates_fp,index=['tipo','date_file'],
#            tipo  date_file        sum       len
#                             total_due total_due
# 0  Pago del día 2022-11-10  19,164.80         1
# 1  Pago del día 2022-11-12 316,629.49       506
# 2  Pago del día 2022-11-16  49,703.37         3
# 3  Pago del día 2022-11-29   1,495.80         2
# 4  Pago del día 2022-11-30     225.19         1

# %%
pivot_duplicates_fp.shape
# Out:
# (7, 4)

# %%
# pivot_duplicates_fp.to_excel('DUPLICADOS FP JUNIO 2021.xlsx',index=True)

# %% [markdown]
# #### ALL PAGOS

# %%
allpagos = pd.concat([pagos_1,pagos_2])
allpagos.head()
# Out:
#         type                           merchant_id          merchant_name  \
# 0      DAILY  00582624-a7b2-4865-80d2-dfab60f15ff0           super jazmin
# 60752  DAILY  aa8835e9-d0e9-4034-a20d-f0f3b08a9793   Farmacia Guadalupana
# 60751  DAILY  aa877403-d775-4b57-8e35-c516196d5d3e                 Gandhu
# 60750  DAILY  aa86764b-b3c9-4702-bac1-df1ae7eca0a6  GREEN CAFETERIA  URN
# 60749  DAILY  aa846165-2179-4648-a0c8-ff56d0700f8f               ShowTime
#
#                             user_email  report_id report_date_local  \
# 0            efrariver140616@gmail.com  JTMGC8BS8        2022-08-17
# 60752       fguadalupana4c@hotmail.com  SQH5TPGJH        2022-11-01
# 60751         jardingandhi@hotmail.com  QBQZ6PZBJ        2022-11-01
# 60750        abdiel.beltranp@gmail.com  DGRTGNZR6        2022-11-01
# 60749  montana_musiccity50@hotmail.com  QL9TXKBQB        2022-11-01
#
#        total_due            tipo           bank  \
# 0      38,921.80  Reprogramación    BANORTE/IXE
# 60752     373.90    Pago del día      SANTANDER
# 60751   3,449.67    Pago del día        BANAMEX
# 60750   1,993.07    Pago del día  BBVA BANCOMER
# 60749   3,602.80    Pago del día        BANAMEX
#
#                   bank_account_owner_name              CLABE status  \
# 0                     Yolanda Valdez Rosa  72238011898630992  ERROR
# 60752         MONICA LIZETH SANTOS CASTRO  14075605539982963   PAID
# 60751  Maria Guadalupe Olivares Fernandez   2180700787522524   PAID
# 60750        Abdiel Armando Beltrán Pérez  12150001087846399   PAID
# 60749     Jose Antonio Villanueva Sanchez   2180701685464301   PAID
#
#                                                LINEA CEP       Batch_time  \
# 0                                                    NaN  01. First_batch
# 60752                  COMPROBANTE MISMO BANCO SANTANDER  01. First_batch
# 60751  2022-11-01,2022110140014HDH0001414006050,40014...  01. First_batch
# 60750  2022-11-01,2022110140014HDH0001414006060,40014...  01. First_batch
# 60749  2022-11-01,2022110140014HDH0001414006020,40014...  01. First_batch
#
#       Banco_emisor                 file_name  date_file swap
# 0        SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60752    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60751    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60750    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60749    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN

# %%
allpagos.shape
# Out:
# (2858882, 18)

# %%
allpagos['tipo'].unique()
# Out:
# array(['Reprogramación', 'Pago del día'], dtype=object)

# %%
group_allpagos = allpagos.groupby(['date_file']).agg({'total_due':sum,'report_id':'count'}).reset_index()
group_allpagos.head()
# Out:
#    date_file      total_due  report_id
# 0 2022-11-01 187,006,184.37      95875
# 1 2022-11-02 186,808,356.15      95291
# 2 2022-11-03 160,763,393.49      80998
# 3 2022-11-04 187,639,197.27      98998
# 4 2022-11-05 217,876,040.77     105300

# %%
group_allpagos.shape
# Out:
# (30, 3)

# %% [markdown]
# #### PAGOS DEL DIA

# %%
pagosdia = allpagos[(allpagos['tipo'].isin(['Pago del día']))]
pagosdia.head()
# Out:
#         type                           merchant_id          merchant_name  \
# 60752  DAILY  aa8835e9-d0e9-4034-a20d-f0f3b08a9793   Farmacia Guadalupana
# 60751  DAILY  aa877403-d775-4b57-8e35-c516196d5d3e                 Gandhu
# 60750  DAILY  aa86764b-b3c9-4702-bac1-df1ae7eca0a6  GREEN CAFETERIA  URN
# 60749  DAILY  aa846165-2179-4648-a0c8-ff56d0700f8f               ShowTime
# 60748  DAILY  aa82f0d9-b59c-4a7b-9d86-70ab5d8634b7                Acuario
#
#                             user_email  report_id report_date_local  \
# 60752       fguadalupana4c@hotmail.com  SQH5TPGJH        2022-11-01
# 60751         jardingandhi@hotmail.com  QBQZ6PZBJ        2022-11-01
# 60750        abdiel.beltranp@gmail.com  DGRTGNZR6        2022-11-01
# 60749  montana_musiccity50@hotmail.com  QL9TXKBQB        2022-11-01
# 60748       abmt.suc.acuario@gmail.com  9KWY8K7B6        2022-11-01
#
#        total_due          tipo           bank  \
# 60752     373.90  Pago del día      SANTANDER
# 60751   3,449.67  Pago del día        BANAMEX
# 60750   1,993.07  Pago del día  BBVA BANCOMER
# 60749   3,602.80  Pago del día        BANAMEX
# 60748     334.55  Pago del día  BBVA BANCOMER
#
#                   bank_account_owner_name              CLABE status  \
# 60752         MONICA LIZETH SANTOS CASTRO  14075605539982963   PAID
# 60751  Maria Guadalupe Olivares Fernandez   2180700787522524   PAID
# 60750        Abdiel Armando Beltrán Pérez  12150001087846399   PAID
# 60749     Jose Antonio Villanueva Sanchez   2180701685464301   PAID
# 60748             Esmeralda Copete Torres  12905028891011360   PAID
#
#                                                LINEA CEP       Batch_time  \
# 60752                  COMPROBANTE MISMO BANCO SANTANDER  01. First_batch
# 60751  2022-11-01,2022110140014HDH0001414006050,40014...  01. First_batch
# 60750  2022-11-01,2022110140014HDH0001414006060,40014...  01. First_batch
# 60749  2022-11-01,2022110140014HDH0001414006020,40014...  01. First_batch
# 60748  2022-11-01,2022110140014HDH0001414006000,40014...  01. First_batch
#
#       Banco_emisor                 file_name  date_file swap
# 60752    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60751    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60750    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60749    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60748    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN

# %%
pagosdia.shape
# Out:
# (2840478, 18)

# %%
group_dia = pagosdia.groupby(['date_file']).agg({'total_due':sum,'report_id':'count'}).reset_index()
group_dia.head()
# Out:
#    date_file      total_due  report_id
# 0 2022-11-01 184,284,606.86      93835
# 1 2022-11-02 182,426,010.34      92579
# 2 2022-11-03 159,926,075.69      80331
# 3 2022-11-04 185,839,449.08      98239
# 4 2022-11-05 217,101,355.35     104667

# %%
group_dia.shape
# Out:
# (30, 3)

# %% [markdown]
# # PRIMER MATCH (SETTLED VS PAGOS DEL DIA)

# %%
check_1 = cum_1.merge(pagosdia[['report_id','total_due','tipo','file_name']] ,on='report_id', how='left')
check_1['total_due_y'].fillna('NO ENCONTRADO')
check_1['tipo'].fillna('NO ENCONTRADO',inplace=True)
check_1['file_name_y'].fillna('NO ENCONTRADO',inplace=True)
# check_1.fillna({'total_due_y':'NO ENCONTRADO', 'tipo':'NO ENCONTRADO', 'file_name_y':'NO ENCONTRADO'}, inplace=True)
check_1.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2369092600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_1['tipo'].fillna('NO ENCONTRADO',inplace=True)
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_5028\2369092600.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_1['file_name_y'].fillna('NO ENCONTRADO',inplace=True)
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...   type  created_date  created_time  \
# 0                    0.00  ...  DAILY    2022-11-01      02:00:29
# 1                    0.00  ...  DAILY    2022-11-01      02:00:30
# 2                    0.00  ...  DAILY    2022-11-01      02:00:30
# 3                    0.00  ...  DAILY    2022-11-01      02:00:30
# 4                    0.00  ...  DAILY    2022-11-01      02:00:30
#
#    updated_date  updated_time                file_name_x  tipopago  \
# 0    2022-11-01      02:00:29  SETTLEMENT 2022-11-01.csv       NaN
# 1    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv       NaN
# 2    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv       NaN
# 3    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv       NaN
# 4    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv       NaN
#
#    total_due_y          tipo               file_name_y
# 0        78.57  Pago del día  Dispersión-20221101.xlsx
# 1       368.92  Pago del día  Dispersión-20221101.xlsx
# 2       258.72  Pago del día  Dispersión-20221101.xlsx
# 3        27.90  Pago del día  Dispersión-20221101.xlsx
# 4       642.02  Pago del día  Dispersión-20221101.xlsx
#
# [5 rows x 30 columns]

# %%
check_1['file_name_y'].unique()
# Out:
# array(['Dispersión-20221101.xlsx', nan, 'Dispersión-FP 2022-11-01.xlsx',
#        'Dispersión-20221102.xlsx', 'Dispersión-FP 2022-11-02.xlsx',
#        'Dispersión-20221103.xlsx', 'Dispersión-FP 2022-11-03.xlsx',
#        'Dispersión-20221104.xlsx', 'Dispersión-FP 2022-11-04.xlsx',
#        'Dispersión-20221105.xlsx', 'Dispersión-FP 2022-11-05.xlsx',
#        'Dispersión-20221106.xlsx', 'Dispersión-FP 2022-11-06.xlsx',
#        'Dispersión-20221107.xlsx', 'Dispersión-FP 2022-11-07.xlsx',
#        'Dispersión-20221108.xlsx', 'Dispersión-FP 2022-11-08.xlsx',
#        'Dispersión-20221109.xlsx', 'Dispersión-FP 2022-11-09.xlsx',
#        'Dispersión-20221110.xlsx', 'Dispersión-FP 2022-11-10.xlsx',
#        'Dispersión-20221111.xlsx', 'Dispersión-FP 2022-11-11.xlsx',
#        'Dispersión-20221112.xlsx', 'Dispersión-FP 2022-11-12.xlsx',
#        'Dispersión-20221113.xlsx', 'Dispersión-FP 2022-11-13.xlsx',
#        'Dispersión-20221114.xlsx', 'Dispersión-FP 2022-11-14.xlsx',
#        'Dispersión-20221115.xlsx', 'Dispersión-FP 2022-11-15.xlsx',
#        'Dispersión-20221116.xlsx', 'Dispersión-FP 2022-11-16.xlsx',
#        'Dispersión-20221117.xlsx', 'Dispersión-FP 2022-11-17.xlsx',
#        'Dispersión-20221118.xlsx', 'Dispersión-FP 2022-11-18.xlsx',
#        'Dispersión-20221119.xlsx', 'Dispersión-FP 2022-11-19.xlsx',
#        'Dispersión-20221120.xlsx', 'Dispersión-FP 2022-11-20.xlsx',
#        'Dispersión-20221121.xlsx', 'Dispersión-FP 2022-11-21.xlsx',
#        'Dispersión-20221122.xlsx', 'Dispersión-FP 2022-11-22.xlsx',
#        'Dispersión-20221123.xlsx', 'Dispersión-FP 2022-11-23.xlsx',
#        'Dispersión-20221124.xlsx', 'Dispersión-FP 2022-11-24.xlsx',
#        'Dispersión-20221125.xlsx', 'Dispersión-FP 2022-11-25.xlsx',
#        'Dispersión-20221126.xlsx', 'Dispersión-FP 2022-11-26.xlsx',
#        'Dispersión-20221127.xlsx', 'Dispersión-FP 2022-11-27.xlsx',
#        'Dispersión-20221128.xlsx', 'Dispersión-FP 2022-11-28.xlsx',
#        'Dispersión-20221129.xlsx', 'Dispersión-FP 2022-11-29.xlsx',
#        'Dispersión-20221130.xlsx', 'Dispersión-FP 2022-11-30.xlsx'],
#       dtype=object)

# %%
not_found_1 = check_1[((check_1['file_name_y'].isnull()) | (check_1['file_name_y'].isin(['NO ENCONTRADO'])))
                        & (check_1['total_due_x'] != 0)]
not_found_1.head()
# Out:
#                               merchant_id  \
# 446  e203d263-fba7-432b-9bcf-2cbd2c328d84
# 517  ff3ffa18-480e-4b9e-a580-6aee211451de
# 868  1e645282-be64-4b61-ba3e-d89ae7c96e83
# 958  5fb7e99b-f3da-4f9e-bcbc-48f6a83b62b1
# 980  ab3816d8-a05a-46cd-8d0d-87a2642dd120
#
#                            merchant_name                     user_email  \
# 446                         LUCIO ORTIZ          link_naruto@hotmail.es
# 517                                PATTY        patyyosorio78@gmail.com
# 868  TACOS Y MARISCOS EL CANGREJITO FELI  elcangrejitofeliz@outlook.com
# 958                TRUST DISTRITO ARMIDA    syamileth.navarro@gmail.com
# 980                            LA BOTICA   laboticavalquirico@gmail.com
#
#      report_id report_date_local  total_transactions  total_fees_charged  \
# 446  VQ69BRTJK        2022-11-01                1.00                0.04
# 517  62XSF8RNZ        2022-11-01              550.00               19.80
# 868  JGNQCF3RB        2022-11-01               20.00                0.72
# 958  RSQHDSXKQ        2022-11-01            1,927.75               69.40
# 980  VVNDZ5HW4        2022-11-01               33.00                1.19
#
#      total_taxes  applied_fees_benefits  applied_taxes_benefits  ...   type  \
# 446         0.01                   0.00                    0.00  ...  DAILY
# 517         3.17                   0.00                    0.00  ...  DAILY
# 868         0.12                   0.00                    0.00  ...  DAILY
# 958        11.10                   0.00                    0.00  ...  DAILY
# 980         0.19                   0.00                    0.00  ...  DAILY
#
#      created_date  created_time  updated_date  updated_time  \
# 446    2022-11-01      02:01:56    2022-11-01      02:01:56
# 517    2022-11-01      02:02:11    2022-11-01      02:02:11
# 868    2022-11-01      02:03:30    2022-11-01      02:03:30
# 958    2022-11-01      02:03:46    2022-11-01      02:03:46
# 980    2022-11-01      02:03:52    2022-11-01      02:03:52
#
#                    file_name_x  tipopago  total_due_y tipo  file_name_y
# 446  SETTLEMENT 2022-11-01.csv       NaN          NaN  NaN          NaN
# 517  SETTLEMENT 2022-11-01.csv       NaN          NaN  NaN          NaN
# 868  SETTLEMENT 2022-11-01.csv       NaN          NaN  NaN          NaN
# 958  SETTLEMENT 2022-11-01.csv       NaN          NaN  NaN          NaN
# 980  SETTLEMENT 2022-11-01.csv       NaN          NaN  NaN          NaN
#
# [5 rows x 30 columns]

# %%
not_found_1.shape
# Out:
# (8129, 30)

# %%
group_notfound = not_found_1.groupby(['report_date_local']).agg({'total_due_x':sum,'report_id':'count'}).reset_index()
group_notfound.rename(columns={'report_date_local':'date_file'},inplace=True)
group_notfound.head()
# Out:
#    date_file  total_due_x  report_id
# 0 2022-11-01   328,245.82        260
# 1 2022-11-02   175,977.01        246
# 2 2022-11-03   145,741.11        214
# 3 2022-11-04   311,302.93        256
# 4 2022-11-05   151,602.57        261

# %%
group_notfound.shape
# Out:
# (30, 3)

# %% [markdown]
# #### REPROGRAMACIONES

# %%
repro = allpagos[(allpagos['tipo'].isin(['Reprogramación']))]
repro.head()
# Out:
#         type                           merchant_id          merchant_name  \
# 0      DAILY  00582624-a7b2-4865-80d2-dfab60f15ff0           super jazmin
# 60696  DAILY  aa622ced-ec67-49ee-8811-f96b471d0f52  Hamburguesas La Media
# 60695  DAILY  aa622ced-ec67-49ee-8811-f96b471d0f52  Hamburguesas La Media
# 60694  DAILY  aa622ced-ec67-49ee-8811-f96b471d0f52  Hamburguesas La Media
# 60693  DAILY  aa622ced-ec67-49ee-8811-f96b471d0f52  Hamburguesas La Media
#
#                             user_email  report_id report_date_local  \
# 0            efrariver140616@gmail.com  JTMGC8BS8        2022-08-17
# 60696  margaritachavez200381@gmail.com  TQJF2CR62        2022-10-23
# 60695  margaritachavez200381@gmail.com  7QLNHDJ3R        2022-10-22
# 60694  margaritachavez200381@gmail.com  8CSVP3NWR        2022-10-21
# 60693  margaritachavez200381@gmail.com  P6ZPLKQDZ        2022-10-20
#
#        total_due            tipo           bank   bank_account_owner_name  \
# 0      38,921.80  Reprogramación    BANORTE/IXE       Yolanda Valdez Rosa
# 60696     185.89  Reprogramación  BBVA BANCOMER  Margarita Chavez Aguilar
# 60695     609.43  Reprogramación  BBVA BANCOMER  Margarita Chavez Aguilar
# 60694     462.34  Reprogramación  BBVA BANCOMER  Margarita Chavez Aguilar
# 60693     341.13  Reprogramación  BBVA BANCOMER  Margarita Chavez Aguilar
#
#                    CLABE status  \
# 0      72238011898630992  ERROR
# 60696  12180015674325454   PAID
# 60695  12180015674325454   PAID
# 60694  12180015674325454   PAID
# 60693  12180015674325454   PAID
#
#                                                LINEA CEP       Batch_time  \
# 0                                                    NaN  01. First_batch
# 60696  2022-11-01,2022110140014HDH0001414005050,40014...  01. First_batch
# 60695  2022-11-01,2022110140014HDH0001414004900,40014...  01. First_batch
# 60694  2022-11-01,2022110140014HDH0001414004870,40014...  01. First_batch
# 60693  2022-11-01,2022110140014HDH0001414004850,40014...  01. First_batch
#
#       Banco_emisor                 file_name  date_file swap
# 0        SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60696    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60695    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60694    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN
# 60693    SANTANDER  Dispersión-20221101.xlsx 2022-11-01  NaN

# %%
repro.shape
# Out:
# (18404, 18)

# %%
group_repro = repro.groupby(['date_file']).agg({'total_due':sum,'report_id':'count'}).reset_index()
group_repro.head()
# Out:
#    date_file    total_due  report_id
# 0 2022-11-01 2,721,577.51       2040
# 1 2022-11-02 4,382,345.81       2712
# 2 2022-11-03   837,317.80        667
# 3 2022-11-04 1,799,748.19        759
# 4 2022-11-05   774,685.42        633

# %%
group_repro.shape
# Out:
# (30, 3)

# %% [markdown]
# # SEGUNDO MATCH (IDENTIFICACION DE REPROGRAMACIONES)

# %%
check_2 = not_found_1.merge(repro[['report_id','total_due','tipo','file_name']] ,on='report_id', how='left')
check_2.head()
# Out:
#                             merchant_id                        merchant_name  \
# 0  e203d263-fba7-432b-9bcf-2cbd2c328d84                         LUCIO ORTIZ
# 1  ff3ffa18-480e-4b9e-a580-6aee211451de                                PATTY
# 2  1e645282-be64-4b61-ba3e-d89ae7c96e83  TACOS Y MARISCOS EL CANGREJITO FELI
# 3  5fb7e99b-f3da-4f9e-bcbc-48f6a83b62b1                TRUST DISTRITO ARMIDA
# 4  ab3816d8-a05a-46cd-8d0d-87a2642dd120                            LA BOTICA
#
#                       user_email  report_id report_date_local  \
# 0         link_naruto@hotmail.es  VQ69BRTJK        2022-11-01
# 1        patyyosorio78@gmail.com  62XSF8RNZ        2022-11-01
# 2  elcangrejitofeliz@outlook.com  JGNQCF3RB        2022-11-01
# 3    syamileth.navarro@gmail.com  RSQHDSXKQ        2022-11-01
# 4   laboticavalquirico@gmail.com  VVNDZ5HW4        2022-11-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                1.00                0.04         0.01                   0.00
# 1              550.00               19.80         3.17                   0.00
# 2               20.00                0.72         0.12                   0.00
# 3            1,927.75               69.40        11.10                   0.00
# 4               33.00                1.19         0.19                   0.00
#
#    applied_taxes_benefits  ...  updated_date  updated_time  \
# 0                    0.00  ...    2022-11-01      02:01:56
# 1                    0.00  ...    2022-11-01      02:02:11
# 2                    0.00  ...    2022-11-01      02:03:30
# 3                    0.00  ...    2022-11-01      02:03:46
# 4                    0.00  ...    2022-11-01      02:03:52
#
#                  file_name_x  tipopago  total_due_y  tipo_x  file_name_y  \
# 0  SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 1  SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 2  SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 3  SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 4  SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
#
#    total_due          tipo_y                 file_name
# 0       0.95  Reprogramación  Dispersión-20221104.xlsx
# 1        NaN             NaN                       NaN
# 2      19.16  Reprogramación  Dispersión-20221111.xlsx
# 3   1,847.25  Reprogramación  Dispersión-20221117.xlsx
# 4        NaN             NaN                       NaN
#
# [5 rows x 33 columns]

# %%
check_2.shape
# Out:
# (8155, 33)

# %%
# writer = pd.ExcelWriter('REPROGRAMACIONES JUNIO 2021.xlsx', engine='xlsxwriter', options={'encoding':'utf-8'})
# check_2.to_excel(writer, sheet_name='DETAIL REPROGRAMACIONES',index=False)
# writer.save()
# writer.close()

# %% [markdown]
# # FECHA DE PAGOS (SETTLED VS PAGOS DEL DIA)

# %%
fecha_pago = not_found_1.merge(repro[['report_id','date_file','tipo','status','file_name']] ,on='report_id', how='left')
fecha_pago.sort_values(by=['date_file'],ascending=True,inplace=True)
fecha_pago.head()
# Out:
#                               merchant_id             merchant_name  \
# 106  2dc87969-2cae-4309-bb60-6d0cd9540f09          CHURROS DON FEDE
# 73   8e1d71b4-67a5-4dfd-ab93-3284e9999591               CONSULTORIO
# 76   533a47f9-8dbd-45c0-ba69-c4b1df298b59                DEVELOPERS
# 86   65592f92-67fc-492e-b9bf-28b0f14da5ce  HOTEL FINCA ORTIZ LUXURY
# 92   ef5d6e40-cfd7-4939-930d-3ef7081dc956                    CHENKO
#
#                             user_email  report_id report_date_local  \
# 106                  niktl@hotmail.com  YPJ7CFRKW        2022-11-01
# 73             arantxaheadly@gmail.com  WBSGMKMTC        2022-11-01
# 76             rodrigozamc@hotmail.com  GY97QXQYF        2022-11-01
# 86   hotelfincaortizluxury@outlook.com  YVHHMB75Q        2022-11-01
# 92            sweet_girl11@live.com.mx  4KYZBFT8L        2022-11-01
#
#      total_transactions  total_fees_charged  total_taxes  \
# 106               64.00                2.30         0.37
# 73                 1.00                0.04         0.01
# 76                 1.00                0.04         0.01
# 86                 5.00                0.18         0.03
# 92               426.00               15.34         2.46
#
#      applied_fees_benefits  applied_taxes_benefits  ...  updated_time  \
# 106                   0.00                    0.00  ...      03:53:45
# 73                    0.00                    0.00  ...      03:22:08
# 76                    0.00                    0.00  ...      03:26:51
# 86                    0.00                    0.00  ...      03:36:33
# 92                    0.00                    0.00  ...      03:43:00
#
#                    file_name_x  tipopago  total_due_y  tipo_x  file_name_y  \
# 106  SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 73   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 76   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 86   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 92   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
#
#      date_file          tipo_y status                 file_name
# 106 2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 73  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 76  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 86  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 92  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
#
# [5 rows x 34 columns]

# %%
fecha_pago.shape
# Out:
# (8155, 34)

# %%
fecha_pago.drop_duplicates(subset ='report_id',keep='first',inplace=True)

# %%
fecha_pago.head()
# Out:
#                               merchant_id             merchant_name  \
# 106  2dc87969-2cae-4309-bb60-6d0cd9540f09          CHURROS DON FEDE
# 73   8e1d71b4-67a5-4dfd-ab93-3284e9999591               CONSULTORIO
# 76   533a47f9-8dbd-45c0-ba69-c4b1df298b59                DEVELOPERS
# 86   65592f92-67fc-492e-b9bf-28b0f14da5ce  HOTEL FINCA ORTIZ LUXURY
# 92   ef5d6e40-cfd7-4939-930d-3ef7081dc956                    CHENKO
#
#                             user_email  report_id report_date_local  \
# 106                  niktl@hotmail.com  YPJ7CFRKW        2022-11-01
# 73             arantxaheadly@gmail.com  WBSGMKMTC        2022-11-01
# 76             rodrigozamc@hotmail.com  GY97QXQYF        2022-11-01
# 86   hotelfincaortizluxury@outlook.com  YVHHMB75Q        2022-11-01
# 92            sweet_girl11@live.com.mx  4KYZBFT8L        2022-11-01
#
#      total_transactions  total_fees_charged  total_taxes  \
# 106               64.00                2.30         0.37
# 73                 1.00                0.04         0.01
# 76                 1.00                0.04         0.01
# 86                 5.00                0.18         0.03
# 92               426.00               15.34         2.46
#
#      applied_fees_benefits  applied_taxes_benefits  ...  updated_time  \
# 106                   0.00                    0.00  ...      03:53:45
# 73                    0.00                    0.00  ...      03:22:08
# 76                    0.00                    0.00  ...      03:26:51
# 86                    0.00                    0.00  ...      03:36:33
# 92                    0.00                    0.00  ...      03:43:00
#
#                    file_name_x  tipopago  total_due_y  tipo_x  file_name_y  \
# 106  SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 73   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 76   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 86   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
# 92   SETTLEMENT 2022-11-01.csv       NaN          NaN     NaN          NaN
#
#      date_file          tipo_y status                 file_name
# 106 2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 73  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 76  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 86  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
# 92  2022-11-02  Reprogramación   PAID  Dispersión-20221102.xlsx
#
# [5 rows x 34 columns]

# %%
fecha_pago.shape
# Out:
# (8129, 34)

# %% [markdown]
# ### AGRUPADO POR DÍA

# %%
pivot_fecha_pago = pd.pivot_table(fecha_pago,index=['report_date_local'],
                                  values=['total_due_x'],aggfunc = ['sum', len],margins=True)
pivot_fecha_pago.head()
# Out:
#                             sum         len
#                     total_due_x total_due_x
# report_date_local
# 2022-11-01 00:00:00  328,245.82         260
# 2022-11-02 00:00:00  175,977.01         246
# 2022-11-03 00:00:00  145,741.11         214
# 2022-11-04 00:00:00  311,302.93         256
# 2022-11-05 00:00:00  151,602.57         261

# %%
pivot_fecha_pago.shape
# Out:
# (31, 2)

# %% [markdown]
# # PAGOS MANUALES

# %%
file_manual = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2022\11. NOVEMBER\MANUALES\*.xlsx', recursive=False)
file_manual
# Out:
# ['G:\\.shortcut-targets-by-id\\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\\3.-Settlement\\5.-HISTORICO FILES PAGOS\\01. TRADICIONAL\\2022\\11. NOVEMBER\\MANUALES\\Manuales 2022.11.01 - 2022.11.28.xlsx',
#  'G:\\.shortcut-targets-by-id\\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\\3.-Settlement\\5.-HISTORICO FILES PAGOS\\01. TRADICIONAL\\2022\\11. NOVEMBER\\MANUALES\\Manuales 2022.11.29 - 2022.11.30.xlsx']

# %%
manuales_all = pd.concat([pd.read_excel(f,sheet_name='Formato Pago Manual',skiprows=1
                                      ,converters={'Cta. CLABE de depósito':str,'report_id':str})
                          .assign(file_name=os.path.basename(f)) for f in file_manual])
manuales_all['Date']= pd.to_datetime(manuales_all['Date'])  
manuales_all['Tipo'] = 'MANUAL'

# %%
manuales_final = manuales_all[['Date','ME ID','ME NAME',' (mxn)','Banco','Justificación para el pago','Tipo','Report ID']]
manuales_final.head()
# Out:
#         Date                                  ME ID                   ME NAME  \
# 0 2022-11-03                                    NaN                 not_found
# 1 2022-11-03   6f73029b-48f0-4894-b2b6-9acec9391ddf            ELEMENTS TULUM
# 2 2022-11-03   d36a7a85-a69d-4a41-a95c-7536a08c52d5                MILMED TEC
# 3 2022-11-03   49e4e137-7802-432c-b6a6-87b92bf537ae          LAS ALAS DEL PUG
# 4 2022-11-03   826bcd3d-2805-4f93-8103-014f04365600  ACCESORIOS PARA CELULAR
#
#       (mxn)                           Banco  \
# 0  1,500.00                      SCOTIABANK
# 1 15,710.83       Scotiabank Inverlat, S.A.
# 2  1,999.00                 Banco del Bajio
# 3     70.00  Banco Nacional de Mexico, S.A.
# 4  3,570.48              Banco Azteca, S.A.
#
#                           Justificación para el pago    Tipo Report ID
# 0                    Re: PMR-612 || Reembolsos a MEs  MANUAL       NaN
# 1                          elementstulum16@gmail.com  MANUAL       NaN
# 2                        Pago manual a ME MILMED TEC  MANUAL       NaN
# 3  Re: PMR-722 || Transactions Post-outage 28 de ...  MANUAL  SOP-9946
# 4  Re: PMR-722 || Transactions Post-outage 28 de ...  MANUAL  SOP-9949

# %%
manuales_final.shape
# Out:
# (48, 8)

# %%
manuales_final.columns
# Out:
# Index(['Date', 'ME ID', 'ME NAME', ' (mxn)', 'Banco',
#        'Justificación para el pago', 'Tipo', 'Report ID'],
#       dtype='object')

# %%
group_manual = manuales_final.groupby(['Date']).agg({' (mxn)':sum,'Report ID':'count'}).reset_index()
group_manual.rename(columns={'Date':'date_file','Report ID':'report_id'},inplace=True)
group_manual.head()
# Out:
#    date_file      (mxn)  report_id
# 0 2022-11-03  33,714.87         12
# 1 2022-11-09 227,696.66          8
# 2 2022-11-10  30,637.48          4
# 3 2022-11-17   7,160.96          2
# 4 2022-11-22   1,658.97          0

# %%
group_manual.shape
# Out:
# (7, 3)

# %% [markdown]
# # ACUMULADOS SETTLEMENT

# %%
conc_disp = cum_distinct_0.groupby(['report_date_local']).agg({'total_due':sum,'report_id':'count'}).reset_index()
conc_disp.rename(columns={'report_date_local':'date_file'}, inplace=True)
conc_disp.head()
# Out:
#    date_file      total_due  report_id
# 0 2022-11-01 184,593,207.00      94076
# 1 2022-11-02 182,600,405.30      92822
# 2 2022-11-03 160,070,275.01      80544
# 3 2022-11-04 186,134,457.31      98478
# 4 2022-11-05 217,252,957.92     104928

# %%
conc_disp.shape
# Out:
# (30, 3)

# %% [markdown]
# # MERGING ALL DATA FRAMES

# %%
total_1 = conc_disp.merge(group_repro[['date_file','total_due','report_id']],on='date_file',how='left') \
.merge(group_manual,on='date_file',how='left')
total_1[' (mxn)'].fillna(0,inplace=True)
total_1['report_id'].fillna(0,inplace=True)
total_1.head()
# Out:
#    date_file    total_due_x  report_id_x  total_due_y  report_id_y     (mxn)  \
# 0 2022-11-01 184,593,207.00        94076 2,721,577.51         2040      0.00
# 1 2022-11-02 182,600,405.30        92822 4,382,345.81         2712      0.00
# 2 2022-11-03 160,070,275.01        80544   837,317.80          667 33,714.87
# 3 2022-11-04 186,134,457.31        98478 1,799,748.19          759      0.00
# 4 2022-11-05 217,252,957.92       104928   774,685.42          633      0.00
#
#    report_id
# 0       0.00
# 1       0.00
# 2      12.00
# 3       0.00
# 4       0.00

# %%
total_1['count_total_pago_dia'] = total_1['report_id_x'] + total_1['report_id_y'] + total_1['report_id']
total_1['sum_total_pago_dia'] = total_1['total_due_x'] + total_1['total_due_y'] + total_1[' (mxn)']

# %%
total_1
# Out:
#     date_file    total_due_x  report_id_x  total_due_y  report_id_y  \
# 0  2022-11-01 184,593,207.00        94076 2,721,577.51         2040
# 1  2022-11-02 182,600,405.30        92822 4,382,345.81         2712
# 2  2022-11-03 160,070,275.01        80544   837,317.80          667
# 3  2022-11-04 186,134,457.31        98478 1,799,748.19          759
# 4  2022-11-05 217,252,957.92       104928   774,685.42          633
# 5  2022-11-06 241,495,265.19       105756   542,827.28          467
# 6  2022-11-07 166,392,958.32        74776   586,251.23          463
# 7  2022-11-08 170,083,565.92        90941 1,182,169.14          786
# 8  2022-11-09 167,249,094.26        91658   589,196.08          494
# 9  2022-11-10 178,438,339.15        94306   534,554.81          453
# 10 2022-11-11 196,879,899.33        99090   743,680.83          506
# 11 2022-11-12 223,442,812.21       106030   583,575.46          523
# 12 2022-11-13 248,536,330.35       106046   679,675.95          596
# 13 2022-11-14 168,135,536.49        74783   495,393.13          359
# 14 2022-11-15 178,637,342.21        93667 1,097,432.72          401
# 15 2022-11-16 197,979,156.32        98870   814,279.90          434
# 16 2022-11-17 200,558,033.45        99383   945,738.00          433
# 17 2022-11-18 208,608,483.54       102217   619,487.94          368
# 18 2022-11-19 257,556,300.84       108849   884,014.80          531
# 19 2022-11-20 283,702,633.94       107015   949,560.46          287
# 20 2022-11-21 194,171,315.30        74283   711,971.40          211
# 21 2022-11-22 207,358,949.57        79369 1,291,484.38          320
# 22 2022-11-23 181,902,835.63        92696 1,925,315.59          621
# 23 2022-11-24 189,807,955.21        96352   639,294.06          397
# 24 2022-11-25 200,653,973.97       100428   799,420.12          268
# 25 2022-11-26 237,863,153.11       108136 2,927,138.63          542
# 26 2022-11-27 238,630,254.57       103951 1,927,234.05          656
# 27 2022-11-28 175,828,255.91        76030 1,331,241.24          439
# 28 2022-11-29 180,613,780.59        93408 1,565,772.45          523
# 29 2022-11-30 194,160,350.86        98998   800,806.83          515
#
#         (mxn)  report_id  count_total_pago_dia  sum_total_pago_dia
# 0        0.00       0.00             96,116.00      187,314,784.51
# 1        0.00       0.00             95,534.00      186,982,751.11
# 2   33,714.87      12.00             81,223.00      160,941,307.68
# 3        0.00       0.00             99,237.00      187,934,205.50
# 4        0.00       0.00            105,561.00      218,027,643.34
# 5        0.00       0.00            106,223.00      242,038,092.47
# 6        0.00       0.00             75,239.00      166,979,209.55
# 7        0.00       0.00             91,727.00      171,265,735.06
# 8  227,696.66       8.00             92,160.00      168,065,987.00
# 9   30,637.48       4.00             94,763.00      179,003,531.44
# 10       0.00       0.00             99,596.00      197,623,580.16
# 11       0.00       0.00            106,553.00      224,026,387.67
# 12       0.00       0.00            106,642.00      249,216,006.30
# 13       0.00       0.00             75,142.00      168,630,929.62
# 14       0.00       0.00             94,068.00      179,734,774.93
# 15       0.00       0.00             99,304.00      198,793,436.22
# 16   7,160.96       2.00             99,818.00      201,510,932.41
# 17       0.00       0.00            102,585.00      209,227,971.48
# 18       0.00       0.00            109,380.00      258,440,315.64
# 19       0.00       0.00            107,302.00      284,652,194.40
# 20       0.00       0.00             74,494.00      194,883,286.70
# 21   1,658.97       0.00             79,689.00      208,652,092.92
# 22       0.00       0.00             93,317.00      183,828,151.22
# 23       0.00       0.00             96,749.00      190,447,249.27
# 24   3,061.25       1.00            100,697.00      201,456,455.34
# 25       0.00       0.00            108,678.00      240,790,291.74
# 26       0.00       0.00            104,607.00      240,557,488.62
# 27       0.00       0.00             76,469.00      177,159,497.15
# 28       0.00       0.00             93,931.00      182,179,553.04
# 29   2,203.57       2.00             99,515.00      194,963,361.26

# %% [markdown]
# # ACUMULADOS PAGO DEL DIA

# %%
total_2 = group_allpagos.merge(group_notfound[['date_file','total_due_x','report_id']],on='date_file',how='left')\
.merge(group_manual,on='date_file',how='left')
total_2[' (mxn)'].fillna(0,inplace=True)
total_2['report_id'].fillna(0,inplace=True)
total_2['total_due_x'].fillna(0,inplace=True)
total_2['report_id_y'].fillna(0,inplace=True)
total_2.head()
# Out:
#    date_file      total_due  report_id_x  total_due_x  report_id_y     (mxn)  \
# 0 2022-11-01 187,006,184.37        95875   328,245.82          260      0.00
# 1 2022-11-02 186,808,356.15        95291   175,977.01          246      0.00
# 2 2022-11-03 160,763,393.49        80998   145,741.11          214 33,714.87
# 3 2022-11-04 187,639,197.27        98998   311,302.93          256      0.00
# 4 2022-11-05 217,876,040.77       105300   151,602.57          261      0.00
#
#    report_id
# 0       0.00
# 1       0.00
# 2      12.00
# 3       0.00
# 4       0.00

# %%
total_2['count_swap_dia'] = total_2['report_id_x'] + total_2['report_id_y'] + total_2['report_id']
total_2['sum_swap_dia'] = total_2['total_due'] + total_2['total_due_x'] + total_2[' (mxn)']

# %%
total_2.head()
# Out:
#    date_file      total_due  report_id_x  total_due_x  report_id_y     (mxn)  \
# 0 2022-11-01 187,006,184.37        95875   328,245.82          260      0.00
# 1 2022-11-02 186,808,356.15        95291   175,977.01          246      0.00
# 2 2022-11-03 160,763,393.49        80998   145,741.11          214 33,714.87
# 3 2022-11-04 187,639,197.27        98998   311,302.93          256      0.00
# 4 2022-11-05 217,876,040.77       105300   151,602.57          261      0.00
#
#    report_id  count_swap_dia   sum_swap_dia
# 0       0.00       96,135.00 187,334,430.19
# 1       0.00       95,537.00 186,984,333.16
# 2      12.00       81,224.00 160,942,849.47
# 3       0.00       99,254.00 187,950,500.20
# 4       0.00      105,561.00 218,027,643.34

# %%
total_2.shape
# Out:
# (30, 9)

# %% [markdown]
# # COMPARACION FINAL

# %%
final_comparacion = total_1[['date_file','count_total_pago_dia','sum_total_pago_dia']] \
.merge(total_2[['date_file','count_swap_dia','sum_swap_dia']],on='date_file',how='left')
final_comparacion.head()
# Out:
#    date_file  count_total_pago_dia  sum_total_pago_dia  count_swap_dia  \
# 0 2022-11-01             96,116.00      187,314,784.51       96,135.00
# 1 2022-11-02             95,534.00      186,982,751.11       95,537.00
# 2 2022-11-03             81,223.00      160,941,307.68       81,224.00
# 3 2022-11-04             99,237.00      187,934,205.50       99,254.00
# 4 2022-11-05            105,561.00      218,027,643.34      105,561.00
#
#     sum_swap_dia
# 0 187,334,430.19
# 1 186,984,333.16
# 2 160,942,849.47
# 3 187,950,500.20
# 4 218,027,643.34

# %%
final_comparacion['diff_count'] = final_comparacion['count_total_pago_dia'] - final_comparacion['count_swap_dia']
final_comparacion['diff_sum'] = final_comparacion['sum_total_pago_dia'] - final_comparacion['sum_swap_dia']

# %%
final_comparacion
# Out:
#     date_file  count_total_pago_dia  sum_total_pago_dia  count_swap_dia  \
# 0  2022-11-01             96,116.00      187,314,784.51       96,135.00
# 1  2022-11-02             95,534.00      186,982,751.11       95,537.00
# 2  2022-11-03             81,223.00      160,941,307.68       81,224.00
# 3  2022-11-04             99,237.00      187,934,205.50       99,254.00
# 4  2022-11-05            105,561.00      218,027,643.34      105,561.00
# 5  2022-11-06            106,223.00      242,038,092.47      106,223.00
# 6  2022-11-07             75,239.00      166,979,209.55       75,239.00
# 7  2022-11-08             91,727.00      171,265,735.06       91,745.00
# 8  2022-11-09             92,160.00      168,065,987.00       92,180.00
# 9  2022-11-10             94,763.00      179,003,531.44       94,782.00
# 10 2022-11-11             99,596.00      197,623,580.16       99,609.00
# 11 2022-11-12            106,553.00      224,026,387.67      107,059.00
# 12 2022-11-13            106,642.00      249,216,006.30      106,642.00
# 13 2022-11-14             75,142.00      168,630,929.62       75,142.00
# 14 2022-11-15             94,068.00      179,734,774.93       94,070.00
# 15 2022-11-16             99,304.00      198,793,436.22       99,329.00
# 16 2022-11-17             99,818.00      201,510,932.41       99,841.00
# 17 2022-11-18            102,585.00      209,227,971.48      102,605.00
# 18 2022-11-19            109,380.00      258,440,315.64      109,380.00
# 19 2022-11-20            107,302.00      284,652,194.40      107,302.00
# 20 2022-11-21             74,494.00      194,883,286.70       74,496.00
# 21 2022-11-22             79,689.00      208,652,092.92       79,689.00
# 22 2022-11-23             93,317.00      183,828,151.22       93,319.00
# 23 2022-11-24             96,749.00      190,447,249.27       96,775.00
# 24 2022-11-25            100,697.00      201,456,455.34      100,697.00
# 25 2022-11-26            108,678.00      240,790,291.74      108,678.00
# 26 2022-11-27            104,607.00      240,557,488.62      104,607.00
# 27 2022-11-28             76,469.00      177,159,497.15       76,469.00
# 28 2022-11-29             93,931.00      182,179,553.04       93,934.00
# 29 2022-11-30             99,515.00      194,963,361.26       99,517.00
#
#      sum_swap_dia  diff_count    diff_sum
# 0  187,334,430.19      -19.00  -19,645.68
# 1  186,984,333.16       -3.00   -1,582.05
# 2  160,942,849.47       -1.00   -1,541.79
# 3  187,950,500.20      -17.00  -16,294.70
# 4  218,027,643.34        0.00       -0.00
# 5  242,038,092.47        0.00        0.00
# 6  166,979,209.55        0.00       -0.00
# 7  171,312,677.27      -18.00  -46,942.21
# 8  168,085,084.44      -20.00  -19,097.44
# 9  179,076,116.73      -19.00  -72,585.29
# 10 197,752,112.40      -13.00 -128,532.24
# 11 224,343,017.16     -506.00 -316,629.49
# 12 249,216,006.30        0.00        0.00
# 13 168,630,929.62        0.00        0.00
# 14 179,734,889.52       -2.00     -114.59
# 15 198,928,747.81      -25.00 -135,311.59
# 16 201,537,764.20      -23.00  -26,831.79
# 17 209,255,698.74      -20.00  -27,727.26
# 18 258,440,315.64        0.00        0.00
# 19 284,652,194.40        0.00       -0.00
# 20 194,884,812.69       -2.00   -1,525.99
# 21 208,652,092.92        0.00       -0.00
# 22 183,831,260.71       -2.00   -3,109.49
# 23 190,518,713.70      -26.00  -71,464.43
# 24 201,456,455.34        0.00        0.00
# 25 240,790,291.74        0.00        0.00
# 26 240,557,488.62        0.00        0.00
# 27 177,159,497.15        0.00        0.00
# 28 182,183,396.53       -3.00   -3,843.49
# 29 194,964,125.94       -2.00     -764.68

# %%
writer = pd.ExcelWriter('FASE III. SETTLED VS PAGO DIA NOVIEMBRE 2022.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
pivot_fecha_pago.to_excel(writer, sheet_name='ENVIADOS POSTERIOR')
fecha_pago.to_excel(writer, sheet_name='DETAIL NO ENCONTRADO',index=False)
pivot_duplicates_trad.to_excel(writer, sheet_name='PAGOS DUPLICADOS')
pivot_duplicates_fp.to_excel(writer, sheet_name='FP PAGOS DUPLICADOS')
group_manual.to_excel(writer, sheet_name='PAGOS MANUALES')
writer.close()
