# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook
import glob
import os
import datetime
pd.options.display.float_format = '{:,.2f}'.format
datetime.timedelta(days=1)
datetime.timedelta(1)
# Out:
# datetime.timedelta(days=1)

# %% [markdown]
# # SETTLEMENT

# %%
start_date = '2022-11-01'
final_date = '2022-11-30'

# %%
allfiles_settled = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2022\11. NOVIEMBRE\QUERIES\*.csv', recursive=False)
allfiles_settled
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-01.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-02.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-03.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-04.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-05.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-06.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-07.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-08.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-09.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-10.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-11.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-12.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-13.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-14.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-15.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-16.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-17.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-18.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-19.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-20.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-21.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-22.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-23.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-24.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-25.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-26.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-27.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-28.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-29.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2022\\11. NOVIEMBRE\\QUERIES\\SETTLEMENT 2022-11-30.csv']

# %%
settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
settled['Date_file'] = settled["file_name"].str[-14:-4]
settled['Date_file']= pd.to_datetime(settled['Date_file'])
settled['report_date_local']= pd.to_datetime(settled['report_date_local'])
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17976\1803293925.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])

# %%
settled.reset_index(inplace=True)
settled.drop(['index'],axis=1,inplace=True)
settled.head()
# Out:
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...  tipopago  total_due   type  created_date  \
# 0                    0.00  ...       NaN      78.57  DAILY    2022-11-01
# 1                    0.00  ...       NaN     368.92  DAILY    2022-11-01
# 2                    0.00  ...       NaN     258.72  DAILY    2022-11-01
# 3                    0.00  ...       NaN      27.90  DAILY    2022-11-01
# 4                    0.00  ...       NaN     642.02  DAILY    2022-11-01
#
#    created_time  updated_date  updated_time                  file_name  \
# 0      02:00:29    2022-11-01      02:00:29  SETTLEMENT 2022-11-01.csv
# 1      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
# 2      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
# 3      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
# 4      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
#
#   tipoPago  Date_file
# 0      NaN 2022-11-01
# 1      NaN 2022-11-01
# 2      NaN 2022-11-01
# 3      NaN 2022-11-01
# 4      NaN 2022-11-01
#
# [5 rows x 28 columns]

# %%
settled.shape
# Out:
# (2849038, 28)

# %% [markdown]
# ### CURRENT MONTH

# %%
settled_current_month = settled[(settled['report_date_local'] >= start_date) & (settled['report_date_local'] <= final_date)]
settled_current_month.head()
# Out:
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...  tipopago  total_due   type  created_date  \
# 0                    0.00  ...       NaN      78.57  DAILY    2022-11-01
# 1                    0.00  ...       NaN     368.92  DAILY    2022-11-01
# 2                    0.00  ...       NaN     258.72  DAILY    2022-11-01
# 3                    0.00  ...       NaN      27.90  DAILY    2022-11-01
# 4                    0.00  ...       NaN     642.02  DAILY    2022-11-01
#
#    created_time  updated_date  updated_time                  file_name  \
# 0      02:00:29    2022-11-01      02:00:29  SETTLEMENT 2022-11-01.csv
# 1      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
# 2      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
# 3      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
# 4      02:00:30    2022-11-01      02:00:30  SETTLEMENT 2022-11-01.csv
#
#   tipoPago  Date_file
# 0      NaN 2022-11-01
# 1      NaN 2022-11-01
# 2      NaN 2022-11-01
# 3      NaN 2022-11-01
# 4      NaN 2022-11-01
#
# [5 rows x 28 columns]

# %%
settled_current_month.shape
# Out:
# (2849038, 28)

# %%
settled_current_month.dtypes
# Out:
# merchant_id                              object
# merchant_name                            object
# user_email                               object
# report_id                                object
# report_date_local                datetime64[ns]
# total_transactions                      float64
# total_fees_charged                      float64
# total_taxes                             float64
# applied_fees_benefits                   float64
# applied_taxes_benefits                  float64
# fee_direct_deposit                      float64
# taxes_direct_deposit                    float64
# total_adjustments                       float64
# total_adjustment_fees_charged           float64
# total_adjustment_taxes                  float64
# cobranza                                float64
# total_released                          float64
# total_retained                          float64
# tipopago                                 object
# total_due                               float64
# type                                     object
# created_date                             object
# created_time                             object
# updated_date                             object
# updated_time                             object
# file_name                                object
# tipoPago                                 object
# Date_file                        datetime64[ns]
# dtype: object

# %%
# def next_date(settled_current_month):
#     if settled_current_month['updated_time'] >= '20:00:00':
#         return settled_current_month['report_date_local'] + datetime.timedelta(days=1)
#     else:
#         return settled_current_month['report_date_local']
    
# settled_current_month['poliza_date'] = settled_current_month.apply(next_date, axis=1)

# %%
# settled_current_month.head()

# %%
# settled_current_month.shape

# %%
# settled_current_month['poliza_date'].unique()

# %% [markdown]
# ### CANCELACIONES

# %%
settled_current_month.loc[(settled_current_month['total_released'] > 0)
                          & (settled_current_month['total_adjustments'] < 0),'canc_1'] = settled_current_month['total_adjustments']
settled_current_month['canc_1'].fillna(0,inplace=True)

# %%
settled_current_month.loc[(settled_current_month['total_released'] > 0)
                          & (settled_current_month['total_adjustments'] < 0),'canc_2'] = settled_current_month['total_released']
settled_current_month['canc_2'].fillna(0,inplace=True)

# %%
settled_current_month['cancelaciones'] = (-settled_current_month['canc_1']) - (settled_current_month['canc_2'])
settled_current_month.head()
# Out:
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...  created_date  created_time  updated_date  \
# 0                    0.00  ...    2022-11-01      02:00:29    2022-11-01
# 1                    0.00  ...    2022-11-01      02:00:30    2022-11-01
# 2                    0.00  ...    2022-11-01      02:00:30    2022-11-01
# 3                    0.00  ...    2022-11-01      02:00:30    2022-11-01
# 4                    0.00  ...    2022-11-01      02:00:30    2022-11-01
#
#    updated_time                  file_name  tipoPago  Date_file  canc_1  \
# 0      02:00:29  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00
# 1      02:00:30  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00
# 2      02:00:30  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00
# 3      02:00:30  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00
# 4      02:00:30  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00
#
#   canc_2  cancelaciones
# 0   0.00          -0.00
# 1   0.00          -0.00
# 2   0.00          -0.00
# 3   0.00          -0.00
# 4   0.00          -0.00
#
# [5 rows x 31 columns]

# %%
settled_current_month.shape
# Out:
# (2849038, 31)

# %% [markdown]
# ### TOTAL DUE CALCULADO

# %%
settled_current_month['total_due_calculado'] = (settled_current_month['total_transactions']
                                                - settled_current_month['total_fees_charged']
                                                - settled_current_month['total_taxes']
                                                + settled_current_month['applied_fees_benefits']
                                                + settled_current_month['applied_taxes_benefits']
                                                + settled_current_month['fee_direct_deposit']
                                                + settled_current_month['taxes_direct_deposit']
                                                - (-settled_current_month['total_adjustments'])
                                                + (-settled_current_month['total_adjustment_fees_charged'])
                                                + (-settled_current_month['total_adjustment_taxes'])
                                                - settled_current_month['cobranza']
                                                + settled_current_month['total_released']
                                                - settled_current_month['total_retained'])
settled_current_month['diferencias'] = settled_current_month['total_due_calculado'] - settled_current_month['total_due']
settled_current_month.head()
# Out:
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...  updated_date  updated_time  \
# 0                    0.00  ...    2022-11-01      02:00:29
# 1                    0.00  ...    2022-11-01      02:00:30
# 2                    0.00  ...    2022-11-01      02:00:30
# 3                    0.00  ...    2022-11-01      02:00:30
# 4                    0.00  ...    2022-11-01      02:00:30
#
#                    file_name  tipoPago  Date_file  canc_1  canc_2  \
# 0  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00    0.00
# 1  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00    0.00
# 2  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00    0.00
# 3  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00    0.00
# 4  SETTLEMENT 2022-11-01.csv       NaN 2022-11-01    0.00    0.00
#
#    cancelaciones total_due_calculado  diferencias
# 0          -0.00               78.57         0.00
# 1          -0.00              368.92        -0.00
# 2          -0.00              258.72        -0.00
# 3          -0.00               27.90         0.00
# 4          -0.00              642.02         0.00
#
# [5 rows x 33 columns]

# %%
settled_current_month.shape
# Out:
# (2849038, 33)

# %% [markdown]
# ### CONCILIACION TPV

# %%
conc_1 = settled_current_month.groupby(['report_date_local']).agg({'total_transactions':sum,'total_fees_charged':sum
                                                                    ,'total_taxes':sum,'applied_fees_benefits':sum
                                                                    ,'applied_taxes_benefits':sum,'fee_direct_deposit':sum
                                                                    ,'taxes_direct_deposit':sum,'total_adjustments':sum
                                                                    ,'total_adjustment_fees_charged':sum
                                                                    ,'total_adjustment_taxes':sum 
                                                                    ,'cobranza':sum,'total_released':sum
                                                                    ,'total_retained':sum,'cancelaciones':sum
                                                                    ,'total_due_calculado':sum,'total_due':sum
                                                                    ,'diferencias':sum}).reset_index()
conc_1['total_adjustments'] = conc_1['total_adjustments']*-1 
conc_1['total_adjustment_fees_charged'] = conc_1['total_adjustment_fees_charged']*-1
conc_1['total_adjustment_taxes'] = conc_1['total_adjustment_taxes']*-1 
conc_1.head()
# Out:
#   report_date_local  total_transactions  total_fees_charged  total_taxes  \
# 0        2022-11-01      195,322,939.19        8,033,746.36 1,285,412.04
# 1        2022-11-02      192,552,378.35        7,612,761.57 1,218,056.40
# 2        2022-11-03      170,751,746.39        6,780,345.07 1,084,868.66
# 3        2022-11-04      196,812,420.97        7,858,113.59 1,257,313.97
# 4        2022-11-05      229,447,308.04        9,120,015.40 1,459,221.75
#
#    applied_fees_benefits  applied_taxes_benefits  fee_direct_deposit  \
# 0               1,015.82                  162.60           25,359.10
# 1               1,016.66                  162.73           21,706.06
# 2                 755.29                  120.87           16,565.90
# 3               1,546.84                  247.51           24,420.94
# 4               1,394.75                  223.19           22,731.80
#
#    taxes_direct_deposit  total_adjustments  total_adjustment_fees_charged  \
# 0              4,060.30       1,399,145.28                          -0.00
# 1              3,476.14       1,563,570.53                          -0.00
# 2              2,653.10       1,444,443.34                          -0.00
# 3              3,911.26       1,489,555.84                         288.00
# 4              3,641.20       1,902,471.22                          -0.00
#
#    total_adjustment_taxes   cobranza  total_released  total_retained  \
# 0                   -0.00  39,384.80      199,088.88      201,730.41
# 1                   -0.00   1,456.53      549,243.25      131,732.86
# 2                   -0.00  52,657.82       99,930.56    1,439,182.21
# 3                   46.07  29,522.25      421,429.80      495,348.43
# 4                   -0.00 198,970.71    2,026,468.02    1,568,130.00
#
#    cancelaciones  total_due_calculado      total_due  diferencias
# 0           0.00       184,593,207.00 184,593,207.00        -0.00
# 1           0.00       182,600,405.30 182,600,405.30        -0.00
# 2           0.00       160,070,275.01 160,070,275.01        -0.00
# 3     -26,463.70       186,134,457.31 186,134,457.31         0.00
# 4     -69,450.36       217,252,957.92 217,252,957.92         0.00

# %%
conc_1.shape
# Out:
# (30, 18)

# %%
conc_3 = settled_current_month.groupby(['report_date_local','type']).agg({'total_transactions':sum,'total_fees_charged':sum
                                                                    ,'total_taxes':sum,'applied_fees_benefits':sum
                                                                    ,'applied_taxes_benefits':sum,'fee_direct_deposit':sum
                                                                    ,'taxes_direct_deposit':sum,'total_adjustments':sum     
                                                                    ,'total_adjustment_fees_charged':sum
                                                                    ,'total_adjustment_taxes':sum 
                                                                    ,'cobranza':sum,'total_released':sum
                                                                    ,'total_retained':sum,'cancelaciones':sum
                                                                    ,'total_due_calculado':sum,'total_due':sum
                                                                    ,'diferencias':sum}).reset_index()
conc_3['total_adjustments'] = conc_3['total_adjustments']*-1 
conc_3['total_adjustment_fees_charged'] = conc_3['total_adjustment_fees_charged']*-1
conc_3['total_adjustment_taxes'] = conc_3['total_adjustment_taxes']*-1 
conc_3.head()
# Out:
#   report_date_local     type  total_transactions  total_fees_charged  \
# 0        2022-11-01    DAILY      192,787,249.91        7,932,804.63
# 1        2022-11-01  INSTANT        2,535,689.28          100,941.73
# 2        2022-11-02    DAILY      190,112,947.55        7,509,571.66
# 3        2022-11-02  INSTANT        2,439,430.80          103,189.91
# 4        2022-11-03    DAILY      168,376,367.89        6,687,047.56
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 0 1,269,260.84               1,015.82                  162.60
# 1    16,151.20                   0.00                    0.00
# 2 1,201,545.59               1,016.66                  162.73
# 3    16,510.81                   0.00                    0.00
# 4 1,069,940.55                 755.29                  120.87
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 0           25,359.10              4,060.30       1,315,441.29
# 1                0.00                  0.00          83,703.99
# 2           21,706.06              3,476.14       1,483,530.03
# 3                0.00                  0.00          80,040.50
# 4           16,565.90              2,653.10       1,363,959.85
#
#    total_adjustment_fees_charged  total_adjustment_taxes  cobranza  \
# 0                          -0.00                   -0.00 39,384.80
# 1                          -0.00                   -0.00      0.00
# 2                          -0.00                   -0.00  1,456.53
# 3                          -0.00                   -0.00      0.00
# 4                          -0.00                   -0.00 52,657.82
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 0      199,088.88      201,711.43           0.00       182,258,333.62
# 1            0.00           18.98           0.00         2,334,873.38
# 2      549,243.25      131,663.30           0.00       180,360,785.28
# 3            0.00           69.56           0.00         2,239,620.02
# 4       98,627.36    1,438,059.64           0.00       157,883,424.99
#
#        total_due  diferencias
# 0 182,258,333.62        -0.00
# 1   2,334,873.38         0.00
# 2 180,360,785.28        -0.00
# 3   2,239,620.02        -0.00
# 4 157,883,424.99        -0.00

# %%
conc_3.shape
# Out:
# (60, 19)

# %%
conc_3['type'].unique()
# Out:
# array(['DAILY', 'INSTANT'], dtype=object)

# %%
data_daily = conc_3[(conc_3['type'] == 'DAILY')]
data_daily.head()
# Out:
#   report_date_local   type  total_transactions  total_fees_charged  \
# 0        2022-11-01  DAILY      192,787,249.91        7,932,804.63
# 2        2022-11-02  DAILY      190,112,947.55        7,509,571.66
# 4        2022-11-03  DAILY      168,376,367.89        6,687,047.56
# 6        2022-11-04  DAILY      194,448,508.38        7,764,292.51
# 8        2022-11-05  DAILY      226,375,606.80        8,995,934.20
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 0 1,269,260.84               1,015.82                  162.60
# 2 1,201,545.59               1,016.66                  162.73
# 4 1,069,940.55                 755.29                  120.87
# 6 1,242,302.08               1,546.84                  247.51
# 8 1,439,368.34               1,394.75                  223.19
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 0           25,359.10              4,060.30       1,315,441.29
# 2           21,706.06              3,476.14       1,483,530.03
# 4           16,565.90              2,653.10       1,363,959.85
# 6           24,420.94              3,911.26       1,410,140.78
# 8           22,731.80              3,641.20       1,790,439.89
#
#    total_adjustment_fees_charged  total_adjustment_taxes   cobranza  \
# 0                          -0.00                   -0.00  39,384.80
# 2                          -0.00                   -0.00   1,456.53
# 4                          -0.00                   -0.00  52,657.82
# 6                         288.00                   46.07  29,522.25
# 8                          -0.00                   -0.00 198,970.71
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 0      199,088.88      201,711.43           0.00       182,258,333.62
# 2      549,243.25      131,663.30           0.00       180,360,785.28
# 4       98,627.36    1,438,059.64           0.00       157,883,424.99
# 6      421,429.80      495,232.49     -26,463.70       183,958,908.69
# 8    2,026,468.02    1,567,883.35     -69,450.36       214,437,469.27
#
#        total_due  diferencias
# 0 182,258,333.62        -0.00
# 2 180,360,785.28        -0.00
# 4 157,883,424.99        -0.00
# 6 183,958,908.69         0.00
# 8 214,437,469.27         0.00

# %%
data_daily.shape
# Out:
# (30, 19)

# %%
data_instant = conc_3[(conc_3['type'] == 'INSTANT')]
data_instant.head()
# Out:
#   report_date_local     type  total_transactions  total_fees_charged  \
# 1        2022-11-01  INSTANT        2,535,689.28          100,941.73
# 3        2022-11-02  INSTANT        2,439,430.80          103,189.91
# 5        2022-11-03  INSTANT        2,375,378.50           93,297.51
# 7        2022-11-04  INSTANT        2,363,912.59           93,821.08
# 9        2022-11-05  INSTANT        3,071,701.24          124,081.20
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 1    16,151.20                   0.00                    0.00
# 3    16,510.81                   0.00                    0.00
# 5    14,928.11                   0.00                    0.00
# 7    15,011.89                   0.00                    0.00
# 9    19,853.41                   0.00                    0.00
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 1                0.00                  0.00          83,703.99
# 3                0.00                  0.00          80,040.50
# 5                0.00                  0.00          80,483.49
# 7                0.00                  0.00          79,415.06
# 9                0.00                  0.00         112,031.33
#
#    total_adjustment_fees_charged  total_adjustment_taxes  cobranza  \
# 1                          -0.00                   -0.00      0.00
# 3                          -0.00                   -0.00      0.00
# 5                          -0.00                   -0.00      0.00
# 7                          -0.00                   -0.00      0.00
# 9                          -0.00                   -0.00      0.00
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 1            0.00           18.98           0.00         2,334,873.38
# 3            0.00           69.56           0.00         2,239,620.02
# 5        1,303.20        1,122.57           0.00         2,186,850.02
# 7            0.00          115.94           0.00         2,175,548.62
# 9            0.00          246.65           0.00         2,815,488.65
#
#      total_due  diferencias
# 1 2,334,873.38         0.00
# 3 2,239,620.02        -0.00
# 5 2,186,850.02        -0.00
# 7 2,175,548.62        -0.00
# 9 2,815,488.65        -0.00

# %%
data_instant.shape
# Out:
# (30, 19)

# %% [markdown]
# ### RELEASED SIN CLABE

# %%
released_sinclabe = settled_current_month[(settled_current_month['tipopago'] == 'sin CLABE')]
released_sinclabe.head()
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, user_email, report_id, report_date_local, total_transactions, total_fees_charged, total_taxes, applied_fees_benefits, applied_taxes_benefits, fee_direct_deposit, taxes_direct_deposit, total_adjustments, total_adjustment_fees_charged, total_adjustment_taxes, cobranza, total_released, total_retained, tipopago, total_due, type, created_date, created_time, updated_date, updated_time, file_name, tipoPago, Date_file, canc_1, canc_2, cancelaciones, total_due_calculado, diferencias]
# Index: []
#
# [0 rows x 33 columns]

# %%
released_sinclabe.shape
# Out:
# (0, 33)

# %%
released_1 = released_sinclabe.groupby(['report_date_local']).agg({'total_released':sum}).reset_index()
released_1.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, total_released]
# Index: []

# %%
released_1.shape
# Out:
# (0, 2)

# %%
released_3 = released_sinclabe.groupby(['report_date_local','type']).agg({'total_released':sum}).reset_index()
released_3.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_3.shape
# Out:
# (0, 3)

# %%
released_3['type'].unique()
# Out:
# array([], dtype=object)

# %%
released_daily = released_3[(released_3['type'] == 'DAILY')]
released_daily.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_daily.shape
# Out:
# (0, 3)

# %%
released_instant = released_3[(released_3['type'] == 'INSTANT')]
released_instant.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_instant.shape
# Out:
# (0, 3)

# %% [markdown]
# # INFO CUPONES

# %%
allcupon_fact = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FACTURACION\2022\11. NOVIEMBRE\Cupones*.csv', recursive=False)
allcupon_fact
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\FACTURACION\\2022\\11. NOVIEMBRE\\Cupones_mm.csv']

# %%
cupon_current_month = pd.concat([pd.read_csv(f,dtype={'report_id':object})
                                 .assign(file_name=os.path.basename(f)) for f in allcupon_fact])
cupon_current_month.head()
# Out:
#                             merchant_id                        merchant_token  \
# 0  40dda9f3-518e-423f-8b04-1572ba44a0d7  fbafce7d-82d6-470f-b76a-151332042ddd
# 1  a2760683-129f-4de4-98e3-7e7a08d44e30  95e02cc8-864b-4249-83c6-6a41b7d39b0f
# 2  9f7384ad-a017-4e15-81f9-1a77eee62f5d  b4c82681-754a-4932-9d1e-11c116df2bb4
# 3  738de109-77df-4182-9643-e436bb893a38  343c2a67-5c80-4779-8ede-c2e51ddd8436
# 4  e162832e-84bf-46b8-8153-89fedf5653d0  5faa9f83-9136-4554-97a5-86b17110f616
#
#                           fee_refund_id  report_id  number_transactions  \
# 0  5ac1dd9f-221b-4943-bd46-ec4aa4ae749b  228LCKGVL                    2
# 1  f7acbad2-452a-4fca-a143-b790ca5df741  228TQD63W                    1
# 2  8ba3cd55-d8ac-46a8-939f-0fe124c2d08a  22BZKF2BX                    2
# 3  0714eca4-db00-42a5-8208-c383324b096d  22R67MKYL                    1
# 4  a54d32c4-8997-4080-9af2-2af1015f4626  2393Q8WCL                    1
#
#    total_refunded  amount  pending   source           created_at  \
# 0           76.42  108.00    31.58  LOYALTY  2022-10-06 11:39:28
# 1            1.67  108.00   106.33  LOYALTY  2022-11-30 10:43:51
# 2          141.40  292.00   150.60  LOYALTY  2021-11-13 11:05:44
# 3          108.00  108.00     0.00  LOYALTY  2022-07-21 07:56:43
# 4          108.00  108.00     0.00  LOYALTY  2022-07-28 08:35:08
#
#         file_name
# 0  Cupones_mm.csv
# 1  Cupones_mm.csv
# 2  Cupones_mm.csv
# 3  Cupones_mm.csv
# 4  Cupones_mm.csv

# %%
cupon_current_month.shape
# Out:
# (2815, 11)

# %%
cupones_data = settled_current_month.merge(cupon_current_month[['report_id','total_refunded','pending','amount',
                                              'source']] ,on='report_id', how='left')
cupones_data['total_benefits'] = cupones_data['applied_fees_benefits'] + cupones_data['applied_taxes_benefits']
cupones_data.loc[(cupones_data['applied_fees_benefits'] != 0) & (cupones_data['source']!= 'LOYALTY'), 'source'] = 'TOP_UPS'
cupones_data.head()
# Out:
#                             merchant_id                    merchant_name  \
# 0  285e56bc-330e-427b-8a77-d12c09286e56  ABARROTES Y CARNICERA EL CHILIN
# 1  56dfd220-a7a0-4777-b81f-c2457f51d1b6                      DOCTORSTORE
# 2  dea6de9c-7d7b-4611-8db8-b71a17b79a6c                         TIO PACO
# 3  0dfd920b-c2b3-43dd-9108-ec285db21f1e                           MARESH
# 4  567b732f-6165-4cbd-b402-4ef5d7b00aed                TLAPALERIA RAQUEL
#
#                   user_email  report_id report_date_local  total_transactions  \
# 0  arevalorocio987@gmail.com  D2VB7CD6H        2022-11-01               82.00
# 1  hector.vieyrasc@gmail.com  78HSQC2DD        2022-11-01              385.00
# 2          paoyxim@gmail.com  D6DJQ65VL        2022-11-01              270.00
# 3    Maresh20221@outlook.com  KF4S45WLC        2022-11-01               29.12
# 4      taviralugor@gmail.com  KFMPLRB3S        2022-11-01              670.00
#
#    total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                2.95         0.48                   0.00
# 1               13.86         2.22                   0.00
# 2                9.72         1.56                   0.00
# 3                1.05         0.17                   0.00
# 4               24.12         3.86                   0.00
#
#    applied_taxes_benefits  ...  canc_1  canc_2  cancelaciones  \
# 0                    0.00  ...    0.00    0.00          -0.00
# 1                    0.00  ...    0.00    0.00          -0.00
# 2                    0.00  ...    0.00    0.00          -0.00
# 3                    0.00  ...    0.00    0.00          -0.00
# 4                    0.00  ...    0.00    0.00          -0.00
#
#    total_due_calculado  diferencias  total_refunded  pending  amount source  \
# 0                78.57         0.00             NaN      NaN     NaN    NaN
# 1               368.92        -0.00             NaN      NaN     NaN    NaN
# 2               258.72        -0.00             NaN      NaN     NaN    NaN
# 3                27.90         0.00             NaN      NaN     NaN    NaN
# 4               642.02         0.00             NaN      NaN     NaN    NaN
#
#    total_benefits
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4            0.00
#
# [5 rows x 38 columns]

# %%
cupones_data['source'].unique()
# Out:
# array([nan, 'TOP_UPS', 'LOYALTY'], dtype=object)

# %%
cupones_data.shape
# Out:
# (2849038, 38)

# %% [markdown]
# ### TOPUPS

# %%
topups_benefits = cupones_data[(cupones_data['source'] == 'TOP_UPS')]
topups_benefits.head()
# Out:
#                                merchant_id          merchant_name  \
# 455   cc7dd62a-3397-4540-b315-a22b0593d322           DAVID CHERIT
# 1050  c7f6746b-aec6-409d-ba3c-e7c5cf7e1908    INTERNET Y ALGO MAS
# 2158  18358a04-39af-4b65-9b7d-f93ab58161a6  CARLITOS CLOTING SHOP
# 2537  34e3c755-bb24-4c13-95bc-0fe7e49bc959  REACCIONARIA LA OTRA
# 2763  0db363ff-e04a-4070-a37a-67ea3735170a               LA NUEVA
#
#                        user_email  report_id report_date_local  \
# 455            cherit70@gmail.com  BGLVJXDBS        2022-11-01
# 1050    ziibertolukaa@hotmail.com  LSNYYWJPC        2022-11-01
# 2158   juanitocarvajal5@gmail.com  3VVNWG8ZG        2022-11-01
# 2537     gerardodiaz669@gmail.com  7WKCXFYTQ        2022-11-01
# 2763  teregaytanlanueva@gmail.com  TYR6W3K6L        2022-11-01
#
#       total_transactions  total_fees_charged  total_taxes  \
# 455               200.00                7.20         1.15
# 1050               17.00                0.61         0.10
# 2158              279.00               10.04         1.61
# 2537            2,170.42               78.13        12.51
# 2763              294.00               10.58         1.70
#
#       applied_fees_benefits  applied_taxes_benefits  ...  canc_1  canc_2  \
# 455                    7.20                    1.15  ...    0.00    0.00
# 1050                   0.61                    0.10  ...    0.00    0.00
# 2158                  10.04                    1.61  ...    0.00    0.00
# 2537                   1.72                    0.28  ...    0.00    0.00
# 2763                   3.45                    0.55  ...    0.00    0.00
#
#       cancelaciones  total_due_calculado  diferencias  total_refunded  \
# 455           -0.00               200.00         0.00             NaN
# 1050          -0.00                17.00         0.00             NaN
# 2158          -0.00               279.00         0.00             NaN
# 2537          -0.00             2,081.78        -0.00             NaN
# 2763          -0.00               285.72         0.00             NaN
#
#       pending  amount   source  total_benefits
# 455       NaN     NaN  TOP_UPS            8.35
# 1050      NaN     NaN  TOP_UPS            0.71
# 2158      NaN     NaN  TOP_UPS           11.65
# 2537      NaN     NaN  TOP_UPS            2.00
# 2763      NaN     NaN  TOP_UPS            4.00
#
# [5 rows x 38 columns]

# %%
topups_benefits.shape
# Out:
# (2370, 38)

# %%
pivot_topups_benefits = pd.pivot_table(topups_benefits,index=['report_date_local'],values=['applied_fees_benefits',
                                                                                        'applied_taxes_benefits'],
                                       aggfunc=np.sum,margins=False).reset_index()
pivot_topups_benefits.rename(columns ={'applied_fees_benefits':'applied_fees_benefits_topups',
                                      'applied_taxes_benefits':'applied_taxes_benefits_topups'},inplace=True)
pivot_topups_benefits.head()
# Out:
#   report_date_local  applied_fees_benefits_topups  \
# 0        2022-11-01                        861.52
# 1        2022-11-02                        775.60
# 2        2022-11-03                        738.37
# 3        2022-11-04                        939.60
# 4        2022-11-05                      1,102.13
#
#    applied_taxes_benefits_topups
# 0                         137.91
# 1                         124.15
# 2                         118.16
# 3                         150.35
# 4                         176.36

# %%
pivot_topups_benefits.shape
# Out:
# (30, 3)

# %% [markdown]
# ### CUPONES

# %%
coupons_benefits = cupones_data[(cupones_data['source'] == 'LOYALTY')]
coupons_benefits.head()
# Out:
#                                  merchant_id               merchant_name  \
# 24797   e7063a1a-ebca-4dd7-8b79-525d990d2270          ABARROTES GONZALEZ
# 61532   5bd7e88f-67f7-4059-b1be-c411fcf84d4f                       KARLY
# 108838  f08c73e3-5202-41e7-bdb2-d64340e1846c         MARISCOS LOS PRIMOS
# 116324  2937322f-b61c-4348-a320-60d238222e2c  SUPER FARMACIAS DEL PUEBLO
# 137074  1a19b2f7-97ae-43bf-8239-fd54db84a3c9     TRAVELLING SOUNDS MUSIC
#
#                           user_email  report_id report_date_local  \
# 24797   luiguigonzalez1987@gmail.com  34VGKQVHV        2022-11-01
# 61532     Karla.rubalacava@gmail.com  645VDXBBL        2022-11-01
# 108838            enano366@gmail.com  79YMHKJVF        2022-11-02
# 116324           steliosgc@gmail.com  XTWJZKRFV        2022-11-02
# 137074  albertobarceinas@hotmail.com  YYGJ4DHWY        2022-11-02
#
#         total_transactions  total_fees_charged  total_taxes  \
# 24797             1,700.00               61.20         9.79
# 61532            21,000.00              756.00       120.96
# 108838               50.00                1.80         0.29
# 116324              330.00               11.88         1.90
# 137074            7,800.00              280.80        44.93
#
#         applied_fees_benefits  applied_taxes_benefits  ...  canc_1  canc_2  \
# 24797                   61.20                    9.79  ...    0.00    0.00
# 61532                   93.10                   14.90  ...    0.00    0.00
# 108838                   1.80                    0.29  ...    0.00    0.00
# 116324                  11.88                    1.90  ...    0.00    0.00
# 137074                  93.10                   14.90  ...    0.00    0.00
#
#         cancelaciones  total_due_calculado  diferencias  total_refunded  \
# 24797           -0.00             1,700.00         0.00           70.99
# 61532           -0.00            20,231.04         0.00          108.00
# 108838          -0.00                50.00         0.00            2.09
# 116324          -0.00               330.00         0.00           13.78
# 137074          -0.00             7,582.27        -0.00          108.00
#
#         pending  amount   source  total_benefits
# 24797     37.01  108.00  LOYALTY           70.99
# 61532      0.00  108.00  LOYALTY          108.00
# 108838   105.91  108.00  LOYALTY            2.09
# 116324    94.22  108.00  LOYALTY           13.78
# 137074     0.00  108.00  LOYALTY          108.00
#
# [5 rows x 38 columns]

# %%
coupons_benefits.shape
# Out:
# (87, 38)

# %%
pivot_coupons_benefits = pd.pivot_table(coupons_benefits,index=['report_date_local'],values=['applied_fees_benefits',
                                                                                        'applied_taxes_benefits'],
                                       aggfunc=np.sum,margins=False).reset_index()
pivot_coupons_benefits.rename(columns ={'applied_fees_benefits':'applied_fees_benefits_coupons',
                                      'applied_taxes_benefits':'applied_taxes_benefits_coupons'},inplace=True)
pivot_coupons_benefits.head()
# Out:
#   report_date_local  applied_fees_benefits_coupons  \
# 0        2022-11-01                         154.30
# 1        2022-11-02                         241.06
# 2        2022-11-03                          16.92
# 3        2022-11-04                         607.24
# 4        2022-11-05                         292.62
#
#    applied_taxes_benefits_coupons
# 0                           24.69
# 1                           38.58
# 2                            2.71
# 3                           97.16
# 4                           46.83

# %%
pivot_coupons_benefits.shape
# Out:
# (28, 3)

# %% [markdown]
# # EXCEL FINAL

# %%
writer = pd.ExcelWriter('FASE I. DATA POLIZA NOVIEMBRE 2022.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
conc_1.to_excel(writer, sheet_name='MONTOS REPORT_DATE',index=False)
data_daily.to_excel(writer, sheet_name='MONTOS_DAILY',index=False)
data_instant.to_excel(writer, sheet_name='MONTOS_INSTANT',index=False)
pivot_topups_benefits.to_excel(writer, sheet_name='TOPUPS',index=False)
pivot_coupons_benefits.to_excel(writer, sheet_name='COUPONS',index=False)
released_1.to_excel(writer, sheet_name='RELEASED REPORT_DATE',index=False)
released_daily.to_excel(writer, sheet_name='RELEASED_DAILY',index=False)
released_instant.to_excel(writer, sheet_name='RELEASED_INSTANT',index=False)
writer.close()
