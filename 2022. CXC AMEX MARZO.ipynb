# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # FECHA PERIODO CONTABLE

# %%
start_date = '2022-03-01'
finish_date = '2022-03-31'

# %% [markdown]
# # READING FILES

# %% [markdown]
# ### EPA

# %%
mov_ban_epa = glob.glob(r'G:\My Drive\3.-Settlement\PROVISIONES\2022\03. MARZO\MOVIMIENTOS BANCARIOS AMEX\EPA*.csv',
                            recursive=False)
mov_ban_epa
# Out:
# ['G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\EPA-Resultados_de_la_búsqueda_de_transacciones04042022_111911.csv']

# %% [markdown]
# ### GRRCN

# %%
mov_ban_grrcn = glob.glob(r'G:\My Drive\3.-Settlement\PROVISIONES\2022\03. MARZO\MOVIMIENTOS BANCARIOS AMEX\GRRCN*.csv',
                            recursive=False)
mov_ban_grrcn
# Out:
# ['G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (5).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (6).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (7).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (8).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (9).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (10).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (11).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (1).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (2).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (3).csv',
#  'G:\\My Drive\\3.-Settlement\\PROVISIONES\\2022\\03. MARZO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones04042022_110815 (4).csv']

# %% [markdown]
# # CUENTA POR COBRAR AGREGADOR

# %%
cxc_agg = pd.concat([pd.read_csv(f,skiprows=9,parse_dates=['Fecha de la transacción','Fecha de pago'],dayfirst=True)
                         .assign(file_name=os.path.basename(f)) for f in mov_ban_epa])
cxc_agg['Fecha de la transacción']= pd.to_datetime(cxc_agg['Fecha de la transacción'])
cxc_agg['Fecha de pago']= pd.to_datetime(cxc_agg['Fecha de pago'])
cxc_agg.sort_values(by=['Fecha de la transacción'],inplace=True)
cxc_agg.head()
# Out:
#    Fecha de la transacción Fecha de pago  Número de afiliación del que envía  \
# 0               2022-03-20    2022-03-23                          9351789434
# 27              2022-03-20    2022-03-23                          9351789434
# 26              2022-03-20    2022-03-23                          9351789434
# 25              2022-03-20    2022-03-23                          9351789434
# 24              2022-03-20    2022-03-23                          9351789434
#
#    Monto del cargo  Número de sucursal que envía Número de tarjetahabiente  \
# 0         5,500.00                           NaN           370782XXXXX4096
# 27           40.00                           NaN           376662XXXXX2072
# 26        5,000.00                           NaN           370730XXXXX1036
# 25          329.00                           NaN           376662XXXXX2072
# 24          634.70                           NaN           376668XXXXX1008
#
#     Tipo de ajuste Número de referencia del cargo Tipo de autorización  \
# 0              NaN                   5U7KLVNGND9H                    Y
# 27             NaN                   JIWGEMVRXEZI                    Y
# 26             NaN                   FITTDMOQKTPN                    Y
# 25             NaN                   DDPD3ACXMF6P                    Y
# 24             NaN                   DO8IV1EGLYDM                    Y
#
#     Código de aprobación  Tipo  Número de terminal  \
# 0                    NaN  Sale                 NaN
# 27                   NaN  Sale                 NaN
# 26                   NaN  Sale                 NaN
# 25                   NaN  Sale                 NaN
# 24                   NaN  Sale                 NaN
#
#                                             file_name
# 0   EPA-Resultados_de_la_búsqueda_de_transacciones...
# 27  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 26  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 25  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 24  EPA-Resultados_de_la_búsqueda_de_transacciones...

# %%
cxc_agg.shape
# Out:
# (367, 13)

# %%
cxc_agg_final = cxc_agg[((cxc_agg['Fecha de pago'] > finish_date) & (cxc_agg['Fecha de la transacción'] <= finish_date))]
cxc_agg_final.head()
# Out:
#     Fecha de la transacción Fecha de pago  Número de afiliación del que envía  \
# 236              2022-03-29    2022-04-01                          9351789434
# 237              2022-03-29    2022-04-01                          9351789434
# 238              2022-03-29    2022-04-01                          9351789434
# 239              2022-03-29    2022-04-01                          9351789434
# 235              2022-03-29    2022-04-01                          9351789434
#
#     Monto del cargo  Número de sucursal que envía Número de tarjetahabiente  \
# 236        3,780.00                           NaN           379780XXXXX1014
# 237          405.00                           NaN           376671XXXXX6000
# 238          156.00                           NaN           376669XXXXX1014
# 239          130.00                           NaN           376702XXXXX3007
# 235           16.00                           NaN           376664XXXXX1034
#
#      Tipo de ajuste Número de referencia del cargo Tipo de autorización  \
# 236             NaN                   FX8A9JYTMLC6                    Y
# 237             NaN                   IBAOHWV2F68F                    Y
# 238             NaN                   HA4TNGJW6NMY                    Y
# 239             NaN                   OU6R0BPMYLLM                    Y
# 235             NaN                   XP7DA4EMYY7L                    Y
#
#      Código de aprobación  Tipo  Número de terminal  \
# 236                   NaN  Sale                 NaN
# 237                   NaN  Sale                 NaN
# 238                   NaN  Sale                 NaN
# 239                   NaN  Sale                 NaN
# 235                   NaN  Sale                 NaN
#
#                                              file_name
# 236  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 237  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 238  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 239  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 235  EPA-Resultados_de_la_búsqueda_de_transacciones...

# %%
cxc_agg_final.shape
# Out:
# (65, 13)

# %% [markdown]
# # CUENTA POR COBRAR OPTBLUE

# %%
cxc_opt = pd.concat([pd.read_csv(f,skiprows=9,parse_dates=['Fecha de la transacción','Fecha de pago'],dayfirst=True)
                         .assign(file_name=os.path.basename(f)) for f in mov_ban_grrcn])
cxc_opt['Fecha de la transacción']= pd.to_datetime(cxc_opt['Fecha de la transacción'])
cxc_opt['Fecha de pago']= pd.to_datetime(cxc_opt['Fecha de pago'])
cxc_opt.sort_values(by=['Fecha de la transacción'],inplace=True)
cxc_opt.head()
# Out:
#      Fecha de la transacción Fecha de pago  \
# 8657              2022-03-20    2022-03-22
# 8249              2022-03-20    2022-03-22
# 8250              2022-03-20    2022-03-22
# 8251              2022-03-20    2022-03-22
# 8252              2022-03-20    2022-03-22
#
#       Número de afiliación del que envía Monto del cargo  \
# 8657                          8138464136          780.00
# 8249                          8138464227        6,400.00
# 8250                          8138464227          242.00
# 8251                          8138464227        5,687.00
# 8252                          8138464227          440.00
#
#       Número de sucursal que envía Número de tarjetahabiente  Tipo de ajuste  \
# 8657                           NaN           376723XXXXX5009             NaN
# 8249                           NaN           379755XXXXX8004             NaN
# 8250                           NaN           372697XXXXX2026             NaN
# 8251                           NaN           376722XXXXX5008             NaN
# 8252                           NaN           377754XXXXX7325             NaN
#
#      Número de referencia del cargo Tipo de autorización  \
# 8657                   JZ7859G6OPC6                    Y
# 8249                   RXBPBANSTTJZ                    Y
# 8250                   ZC5X9D4CUDQN                    Y
# 8251                   MDZYFFZVPY2D                    Y
# 8252                   8HXO0M14TFVC                    Y
#
#       Código de aprobación  Tipo  Número de terminal  \
# 8657                   NaN  Sale                 NaN
# 8249                   NaN  Sale                 NaN
# 8250                   NaN  Sale                 NaN
# 8251                   NaN  Sale                 NaN
# 8252                   NaN  Sale                 NaN
#
#                                               file_name
# 8657  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 8249  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 8250  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 8251  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 8252  GRRCN-Resultados_de_la_búsqueda_de_transaccion...

# %%
cxc_opt.shape
# Out:
# (103902, 13)

# %%
cxc_opt_final = cxc_opt[((cxc_opt['Fecha de pago'] > finish_date) & (cxc_opt['Fecha de la transacción'] <= finish_date))]
cxc_opt_final.head()
# Out:
#      Fecha de la transacción Fecha de pago  \
# 4568              2022-03-31    2022-04-01
# 4573              2022-03-31    2022-04-01
# 4569              2022-03-31    2022-04-01
# 4571              2022-03-31    2022-04-01
# 4572              2022-03-31    2022-04-01
#
#       Número de afiliación del que envía Monto del cargo  \
# 4568                          8138464441          590.00
# 4573                          8138464441        2,435.00
# 4569                          8138464441        2,520.00
# 4571                          8138464441          599.00
# 4572                          8138464441       23,458.24
#
#       Número de sucursal que envía Número de tarjetahabiente  Tipo de ajuste  \
# 4568                           NaN           376669XXXXX4017             NaN
# 4573                           NaN           376666XXXXX2031             NaN
# 4569                           NaN           379232XXXXX3003             NaN
# 4571                           NaN           373910XXXXX1008             NaN
# 4572                           NaN           370785XXXXX6000             NaN
#
#      Número de referencia del cargo Tipo de autorización  \
# 4568                   ZC32SSDRFQJ3                    Y
# 4573                   OV3CTXBWBOV5                    Y
# 4569                   2GNQFEEQVE3S                    Y
# 4571                   L59OXBSAOBZK                    Y
# 4572                   5JKSHX7CQ2WL                    Y
#
#       Código de aprobación  Tipo  Número de terminal  \
# 4568                   NaN  Sale                 NaN
# 4573                   NaN  Sale                 NaN
# 4569                   NaN  Sale                 NaN
# 4571                   NaN  Sale                 NaN
# 4572                   NaN  Sale                 NaN
#
#                                               file_name
# 4568  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 4573  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 4569  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 4571  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 4572  GRRCN-Resultados_de_la_búsqueda_de_transaccion...

# %%
cxc_opt_final.shape
# Out:
# (5626, 13)

# %% [markdown]
# # EXCEL FINAL

# %%
writer = pd.ExcelWriter('CXC AMEX MARZO 2022.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})   
cxc_agg_final.to_excel(writer, sheet_name='AGREGADOR',index=False)
cxc_opt_final.to_excel(writer, sheet_name='OPTBLUE',index=False)
writer.close()
