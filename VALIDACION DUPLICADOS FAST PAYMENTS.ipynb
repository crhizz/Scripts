# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook
import glob
import os
pd.options.display.float_format = '{:,.2f}'.format

# %%
query_1 = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\01. ENERO\FP*.csv', recursive=False)
query_1
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2021\\01. ENERO\\FP 2021-01-10.csv']

# %%
query = pd.concat([pd.read_csv(f,sep=',',dtype={'bank_account_number':object,'report_id':object})
                   .assign(file_name=os.path.basename(f)) for f in query_1])
query.head()
# Out:
#                             merchant_id merchant_name  \
# 0  b835fb96-098d-4bce-b75e-69d82c4bb0d2   consultorio
# 1  f6f57422-2002-4a7a-9809-7c8f5e83df90        Merlin
# 2  ea0369bb-df6c-4f51-a1a6-85cb3c539249      CHACABAR
# 3  ea0369bb-df6c-4f51-a1a6-85cb3c539249      CHACABAR
# 4  ea0369bb-df6c-4f51-a1a6-85cb3c539249      CHACABAR
#
#                       user_email  report_id    report_date_local    amount  \
# 0     leo_marycarmen@hotmail.com  CYBYR2F9S  2020-07-28 00:00:00    433.50
# 1          rubensgar@hotmail.com  LXBM66MCD  2020-11-20 00:00:00    797.26
# 2  sandy.fernandez.s@hotmail.com  6R42XZSFR  2020-11-27 00:00:00    870.08
# 3  sandy.fernandez.s@hotmail.com  58TJ53FSL  2020-12-05 00:00:00  4,949.30
# 4  sandy.fernandez.s@hotmail.com  FZC495JLP  2020-12-16 00:00:00 19,275.98
#
#   status                  bank_name   payment_date_local  \
# 0   PAID              BBVA BANCOMER  2021-01-11 00:00:00
# 1  ERROR        Banco Inbursa, S.A.  2021-01-11 00:00:00
# ...

# %%
ae = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\01. ENERO\Respuesta-FP 2021-01-10.csv')
#ae['report_id'] = ae['report_id'].str[5:].replace(' ', '',regex=True)
#ae['report_id'] = ae['report_id'].replace(' ', '',regex=True)
ae.head()
# Out:
#    report_id status report_date_local payment_date_local    amount  \
# 0  G228WW9ZC   PAID        2021-01-09         2021-01-10     85.29
# 1  V74XW24RR   PAID        2021-01-09         2021-01-10    400.54
# 2  35CTN8ZSJ   PAID        2021-01-09         2021-01-10 17,982.85
# 3  YS5XM6998   PAID        2021-01-09         2021-01-10     95.82
# 4  3RP3BDV6G  ERROR        2021-01-09         2021-01-10  2,206.82
#
#                   error_description                 disbursement_batch_id  \
# 0  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 1  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 2  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 3  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 4    RETORNO SPEI     1174018164     1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
#
#    dsp_reference_id  entry_number                       disbursement_id  ...  \
# ...

# %%
query.shape
# Out:
# (14934, 13)

# %%
ae.shape
# Out:
# (15131, 22)

# %% [markdown]
# # VALIDACION REGISTROS

# %%
duplicates_query = query[query.duplicated(['report_id'],keep=False)]
duplicates_query.head()
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, user_email, report_id, report_date_local, amount, status, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, swap, file_name]
# Index: []

# %%
duplicates_query.shape
# Out:
# (0, 13)

# %%
duplicates_file_sent = ae[ae.duplicated(['report_id'],keep=False)]
duplicates_file_sent.head()
# Out:
#    report_id status report_date_local payment_date_local    amount  \
# 0  G228WW9ZC   PAID        2021-01-09         2021-01-10     85.29
# 1  V74XW24RR   PAID        2021-01-09         2021-01-10    400.54
# 2  35CTN8ZSJ   PAID        2021-01-09         2021-01-10 17,982.85
# 3  YS5XM6998   PAID        2021-01-09         2021-01-10     95.82
# 4  3RP3BDV6G  ERROR        2021-01-09         2021-01-10  2,206.82
#
#                   error_description                 disbursement_batch_id  \
# 0  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 1  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 2  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 3  DISPONIBLE INSUFICIENTE     AUT.  1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
# 4    RETORNO SPEI     1174018164     1f2155aa-e5a5-4edb-b1e2-d56cdf58a8d0
#
#    dsp_reference_id  entry_number                       disbursement_id  ...  \
# ...

# %%
duplicates_file_sent.shape
# Out:
# (394, 22)
