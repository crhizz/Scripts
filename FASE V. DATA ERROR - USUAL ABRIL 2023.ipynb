# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %%
start_date = '2023-04-01'
final_date = '2023-04-30'
query_error_year = 2023
query_error_month = 4

# %% [markdown]
# # INFORMACION DE  CUBETA ERROR

# %%
query_error = pd.read_csv(r'C:\Users\Cristian.Aparicio\Documents\POLIZAS\2023\04. ABRIL\DATA\ERROR ABRIL 2023.csv',
                          dtype={'report_id':object})
query_error.rename(columns ={'MAX(report_date_local)':'report_date_local'}, inplace=True)
query_error['report_date_local']= pd.to_datetime(query_error['report_date_local'])
query_error['ultimo_mov'] = pd.to_datetime(query_error['ultimo_mov'])
query_error['merchant_id_query'] = query_error['merchant_id']
query_error['ultimo_mov_date_only']= pd.to_datetime(query_error['ultimo_mov']).dt.date
query_error['day'] = query_error['ultimo_mov'].dt.day
query_error['month'] = query_error['ultimo_mov'].dt.month
query_error['year'] = query_error['ultimo_mov'].dt.year
# query_error.loc[((query_error['day'] == 30 )
#                 & (query_error['month'] == 7)
#                 & (query_error['year'] == 2022)), "mes_cierre"] = 'Actual'
# query_error.loc[(query_error['day'] == 31 )
#             & (query_error['month'] == 7 )
#             & (query_error['year'] == 2022), "mes_cierre"] = 'Actual'
query_error.loc[(query_error['month'] == query_error_month )
            & (query_error['year'] == query_error_year), "mes_cierre"] = 'Actual'
query_error.head()
# Out:
#    Unnamed: 0                           merchant_id  \
# 0           0  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 1           1  b088c4b4-29dd-42c8-bd29-1eda61f73973
# 2           2  d1087b80-5383-4b90-8738-bf309a1ce297
# 3           3  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
# 4           4  8f666f7d-5eb8-4367-9c52-5564d6aca0c5
#
#                        merchant_name  report_id report_date_local   amount  \
# 0              Mscelanea Dulce Maria  GTS92WH86        2015-11-05   734.34
# 1              Mscelanea Dulce Maria  8VQRDV39G        2015-11-06   597.26
# 2                      Grupo Solutec  82G5CYSR7        2015-12-21 9,160.77
# 3  Ediciones Malinalco S de RL de CV  XWRKLC2ZL        2016-02-08 1,216.98
# 4  Ediciones Malinalco S de RL de CV  D9468C7W4        2016-02-16 1,993.14
#
#   status    error_description ultimo_mov  month  year status_cubeta  \
# 0  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 1  ERROR        swap devuelto 2017-08-15      8  2017         ERROR
# 2  ERROR          failed swap 2017-11-01     11  2017         ERROR
# 3  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
# 4  ERROR  confirmar la cuenta 2017-05-12      5  2017         ERROR
#
#   esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 0   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 1   ERROR_USUAL  b088c4b4-29dd-42c8-bd29-1eda61f73973           2017-08-15
# 2   ERROR_USUAL  d1087b80-5383-4b90-8738-bf309a1ce297           2017-11-01
# 3   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
# 4   ERROR_USUAL  8f666f7d-5eb8-4367-9c52-5564d6aca0c5           2017-05-12
#
#    day mes_cierre
# 0   15        NaN
# 1   15        NaN
# 2    1        NaN
# 3   12        NaN
# 4   12        NaN

# %%
query_error.shape
# Out:
# (125240, 17)

# %%
query_error.dtypes
# Out:
# Unnamed: 0                       int64
# merchant_id                     object
# merchant_name                   object
# report_id                       object
# report_date_local       datetime64[ns]
# amount                         float64
# status                          object
# error_description               object
# ultimo_mov              datetime64[ns]
# month                            int64
# year                             int64
# status_cubeta                   object
# esquema_query                   object
# merchant_id_query               object
# ultimo_mov_date_only            object
# day                              int64
# mes_cierre                      object
# dtype: object

# %%
query_error['esquema_query'].unique()
# Out:
# array(['ERROR_USUAL', 'SIN_CLABE'], dtype=object)

# %%
query_error['status_cubeta'].unique()
# Out:
# array(['ERROR', 'NEW'], dtype=object)

# %% [markdown]
# # FILTRAR INFORMACION DE ACUERDO AL MES EN CURSO

# %%
query_error_current_month = query_error[(query_error['mes_cierre'] == 'Actual')]
query_error_current_month.sort_values(by=['day'],inplace=True)
query_error_current_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17500\3502651561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_error_current_month.sort_values(by=['day'],inplace=True)
#         Unnamed: 0                           merchant_id merchant_name  \
# 114510      114510  86f663aa-8670-4195-bb17-f9b739a30cb3           NaN
# 114468      114468  6fb8bc6b-93d5-40f5-b374-f22d84493e5b           NaN
# 114467      114467  fddb3db6-64da-4539-95e7-5c8a31a82855           NaN
# 114466      114466  a27d5fc0-7749-498a-9933-7cee627b5555           NaN
# 114465      114465  ed642c2c-5451-418c-abd8-c7994267cf56           NaN
#
#         report_id report_date_local  amount status  \
# 114510  AM564SFM5        2023-04-01  431.21  ERROR
# 114468  A5ZG35KPW        2023-04-01  239.56  ERROR
# 114467  AWPT56CYY        2023-04-01    0.02  ERROR
# 114466  A2WDNBPQ8        2023-04-01    0.02  ERROR
# 114465  A7LVFXLWM        2023-04-01    0.95  ERROR
#
#                              error_description ultimo_mov  month  year  \
# 114510  Bank account information not available 2023-04-01      4  2023
# 114468  Bank account information not available 2023-04-01      4  2023
# 114467  Bank account information not available 2023-04-01      4  2023
# 114466  Bank account information not available 2023-04-01      4  2023
# 114465  Bank account information not available 2023-04-01      4  2023
#
#        status_cubeta esquema_query                     merchant_id_query  \
# 114510           NEW     SIN_CLABE  86f663aa-8670-4195-bb17-f9b739a30cb3
# 114468           NEW     SIN_CLABE  6fb8bc6b-93d5-40f5-b374-f22d84493e5b
# 114467           NEW     SIN_CLABE  fddb3db6-64da-4539-95e7-5c8a31a82855
# 114466           NEW     SIN_CLABE  a27d5fc0-7749-498a-9933-7cee627b5555
# 114465           NEW     SIN_CLABE  ed642c2c-5451-418c-abd8-c7994267cf56
#
#        ultimo_mov_date_only  day mes_cierre
# 114510           2023-04-01    1     Actual
# 114468           2023-04-01    1     Actual
# 114467           2023-04-01    1     Actual
# 114466           2023-04-01    1     Actual
# 114465           2023-04-01    1     Actual

# %%
query_error_current_month.shape
# Out:
# (10972, 17)

# %%
query_error_current_month['month'].unique()
# Out:
# array([4], dtype=int64)

# %%
query_error_current_month.columns
# Out:
# Index(['Unnamed: 0', 'merchant_id', 'merchant_name', 'report_id',
#        'report_date_local', 'amount', 'status', 'error_description',
#        'ultimo_mov', 'month', 'year', 'status_cubeta', 'esquema_query',
#        'merchant_id_query', 'ultimo_mov_date_only', 'day', 'mes_cierre'],
#       dtype='object')

# %%
duplicates_query_error = query_error_current_month[query_error_current_month.duplicated(['report_id'] , keep=False)]
duplicates_query_error.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, merchant_id, merchant_name, report_id, report_date_local, amount, status, error_description, ultimo_mov, month, year, status_cubeta, esquema_query, merchant_id_query, ultimo_mov_date_only, day, mes_cierre]
# Index: []

# %%
duplicates_query_error.shape
# Out:
# (0, 17)

# %% [markdown]
# # PAGOS NEW DE MESES ANTERIORES

# %%
query_new_last_month = query_error[(query_error['mes_cierre'] != 'Actual') & (query_error['status_cubeta'] == 'NEW')]
query_new_last_month.sort_values(by=['day'],inplace=True)
query_new_last_month.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17500\3381233170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_new_last_month.sort_values(by=['day'],inplace=True)
#         Unnamed: 0                           merchant_id    merchant_name  \
# 77290        77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 103448      103448  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 103302      103302  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 102197      102197  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 102028      102028  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
#
#         report_id report_date_local   amount status  \
# 77290   NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 103448  BL525Y57N        2023-01-25   960.65  ERROR
# 103302  DWS7DMGZ3        2023-01-24 1,260.67  ERROR
# 102197  FV4W4DNQJ        2023-01-15   371.50  ERROR
# 102028  JKHD3JNH2        2023-01-14 1,030.85  ERROR
#
#                                         error_description ultimo_mov  month  \
# 77290   DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3
# 103448  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3
# 103302  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3
# 102197  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3
# 102028  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3
#
#         year status_cubeta esquema_query  \
# 77290   2023           NEW   ERROR_USUAL
# 103448  2023           NEW   ERROR_USUAL
# 103302  2023           NEW   ERROR_USUAL
# 102197  2023           NEW   ERROR_USUAL
# 102028  2023           NEW   ERROR_USUAL
#
#                            merchant_id_query ultimo_mov_date_only  day  \
# 77290   d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60           2023-03-07    7
# 103448  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60           2023-03-07    7
# 103302  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60           2023-03-07    7
# 102197  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60           2023-03-07    7
# 102028  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60           2023-03-07    7
#
#        mes_cierre
# 77290         NaN
# 103448        NaN
# 103302        NaN
# 102197        NaN
# 102028        NaN

# %%
query_new_last_month.shape
# Out:
# (20, 17)

# %% [markdown]
# # INFORMACIÓN QUERIES - PAGOS

# %%
name_header = ['merchant_id','merchant_name','user_email','report_id','report_date_local','amount','status','bank_name'
               ,'payment_date_local','bank_account_owner_name','bank_account_number','swap']

# %% [markdown]
# ### NEXT MONTH

# %%
# TRADICIONAL
# trad_files_csv_2021_may = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\06. JUNE\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
# fp_files_csv_2021_may = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\06. JUNE\QUERIES\*.csv', recursive=False)

# %%
# disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_may])
# disp_files_csv_2021_may['date_query'] = disp_files_csv_2021_may["file_name"].str[-14:-4]
# disp_files_csv_2021_may['date_query']= pd.to_datetime(disp_files_csv_2021_may['date_query'])

# %%
# fp_disp_files_csv_2021_may = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
#                             .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_may])
# fp_disp_files_csv_2021_may['date_query'] = fp_disp_files_csv_2021_may["file_name"].str[-14:-4]
# fp_disp_files_csv_2021_may['date_query']= pd.to_datetime(fp_disp_files_csv_2021_may['date_query'])

# %% [markdown]
# ### CURRENT MONTH

# %%
# TRADICIONAL
trad_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\04. APRIL\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2022_current = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\04. ABRIL\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2022_current])
disp_files_csv_2022_current['date_query'] = disp_files_csv_2022_current["file_name"].str[-14:-4]
disp_files_csv_2022_current['date_query']= pd.to_datetime(disp_files_csv_2022_current['date_query'])

# %%
fp_disp_files_csv_2022_current = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2022_current])
fp_disp_files_csv_2022_current['date_query'] = fp_disp_files_csv_2022_current["file_name"].str[-14:-4]
fp_disp_files_csv_2022_current['date_query']= pd.to_datetime(fp_disp_files_csv_2022_current['date_query'])

# %% [markdown]
# ### LAST MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\03. MARCH\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_last = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\03. MARZO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_last])
disp_files_csv_2021_last['date_query'] = disp_files_csv_2021_last["file_name"].str[-14:-4]
disp_files_csv_2021_last['date_query']= pd.to_datetime(disp_files_csv_2021_last['date_query'])

# %%
fp_disp_files_csv_2021_last = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_last])
fp_disp_files_csv_2021_last['date_query'] = fp_disp_files_csv_2021_last["file_name"].str[-14:-4]
fp_disp_files_csv_2021_last['date_query']= pd.to_datetime(fp_disp_files_csv_2021_last['date_query'])

# %% [markdown]
# ### SPECIAL MONTH

# %%
# TRADICIONAL
trad_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\02. FEBRUARY\QUERIES\*.csv', recursive=False)
# trad_files_txt_2021_apr = glob.glob(r'G:\My Drive\Settlement\5.-HISTORICO FILES PAGOS\2021\04. APRIL\QUERIES\*.txt', recursive=False)
# FAST PAYMENTS
fp_files_csv_2021_spec = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\02. FAST PAYMENTS\2023\02. FEBRERO\QUERIES\*.csv', recursive=False)

# %%
disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in trad_files_csv_2021_spec])
disp_files_csv_2021_spec['date_query'] = disp_files_csv_2021_spec["file_name"].str[-14:-4]
disp_files_csv_2021_spec['date_query']= pd.to_datetime(disp_files_csv_2021_spec['date_query'])

# %%
fp_disp_files_csv_2021_spec = pd.concat([pd.read_csv(f,dtype={'bank_account_number':object,'report_id':object})
                            .assign(file_name=os.path.basename(f)) for f in fp_files_csv_2021_spec])
fp_disp_files_csv_2021_spec['date_query'] = fp_disp_files_csv_2021_spec["file_name"].str[-14:-4]
fp_disp_files_csv_2021_spec['date_query']= pd.to_datetime(fp_disp_files_csv_2021_spec['date_query'])

# %% [markdown]
# ## ALL FILES

# %%
allfiles = pd.concat([disp_files_csv_2022_current,fp_disp_files_csv_2022_current
                     ,disp_files_csv_2021_last,fp_disp_files_csv_2021_last,
                     disp_files_csv_2021_spec,fp_disp_files_csv_2021_spec])
allfiles.reset_index()
allfiles.fillna('BLANK',inplace=True)
allfiles['date_query']= pd.to_datetime(allfiles['date_query'])
allfiles['report_date_local']= pd.to_datetime(allfiles['report_date_local'])
allfiles.loc[(allfiles['file_name'].str.contains('FP'),'tipo_dispersion')] = 'FP'
allfiles.loc[(allfiles['file_name'].str.contains('SWAP'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('BNTE'),'tipo_dispersion')] = 'TRAD'
allfiles.loc[(allfiles['file_name'].str.contains('SANT'),'tipo_dispersion')] = 'TRAD'
allfiles.sort_values(by=['date_query','report_id'],inplace=True)
allfiles.drop(['status'],axis=1,inplace=True)
allfiles.head()
# Out:
#         type                           merchant_id  \
# 62133  DAILY  a71d5f76-e11a-423e-a94a-80eb97652e1d
# 80813  DAILY  d9bf4b05-9b13-4948-8c77-0603e5364268
# 86417  DAILY  e9131d1d-ada9-4454-887d-02a8eaa038c5
# 3808   DAILY  0a3ccf41-db5f-4d2f-bed2-6e37844a4f62
# 65464  DAILY  affee992-9efd-4e47-a259-350acc1a5488
#
#                              merchant_token   merchant_name  \
# 62133  b43bf099-70af-4c41-a4cf-d881c4b1214d   Minisuper Pau
# 80813  a0a02deb-f458-4a86-a09d-f887e1f1c98d  Varios Maribel
# 86417  40345622-b902-41c7-b945-9eaca92c16d7          Abonos
# 3808   24ad9187-577f-4b9e-a441-659c708101f6     San juditas
# 65464  5067c056-cc51-49c3-b52e-978afad742e3       Los titis
#
#                              user_email  report_id report_date_local   amount  \
# 62133         rodrigoolivas98@gmail.com  222VP3CB4        2023-02-01   334.91
# 80813   miguel.macedo29091984@gmail.com  223SYT9B2        2023-02-01   910.33
# 86417  erika.izc.comunicacion@gmail.com  22472Y8N9        2023-02-01 1,086.65
# 3808    josemariarodriguez211@gmail.com  2248ZQ452        2023-02-01    81.45
# 65464         ale.gonxaxa2525@gmail.com  224ZM4YRX        2023-02-01   149.74
#
#                             bank_name   payment_date_local  \
# 62133  Banco Nacional de México, S.A.  2023-02-01 11:42:36
# 80813             BBVA Bancomer, S.A.  2023-02-01 11:19:05
# 86417                         BANORTE  2023-02-01 11:21:18
# 3808              BBVA Bancomer, S.A.  2023-02-01 11:56:04
# 65464             BBVA Bancomer, S.A.  2023-02-01 11:43:55
#
#                bank_account_owner_name  bank_account_number  \
# 62133          Rodrigo Olivas Gonzales  '002150462200793098
# 80813               Juan Miguel Macedo  '012650015415238751
# 86417                    Erika Lechuga  '072930006204851021
# 3808     Jose Maria Rodriguez Martinez  '012180015170982058
# 65464  Sandra Alejandra Lopez Gonzalez  '012180011748221611
#
#         batch_created_date disbursement_method  \
# 62133  2023-02-01 10:10:08           SANTANDER
# 80813  2023-02-01 10:12:19           SANTANDER
# 86417  2023-02-01 10:12:56           SANTANDER
# 3808   2023-02-01 10:03:20           SANTANDER
# 65464  2023-02-01 10:10:31           SANTANDER
#
#                                                     swap  \
# 62133  Rodrigo Olivas Gonzales,,334.91,00215046220079...
# 80813  Juan Miguel Macedo,,910.33,012650015415238751,...
# 86417  Erika Lechuga,,1086.65,072930006204851021,CLIP...
# 3808   Jose Maria Rodriguez Martinez,,81.45,012180015...
# 65464  Sandra Alejandra Lopez Gonzalez,,149.74,012180...
#
#                    file_name date_query tipo_dispersion
# 62133  SANT-1 2023-02-01.csv 2023-02-01            TRAD
# 80813  SANT-1 2023-02-01.csv 2023-02-01            TRAD
# 86417  SANT-1 2023-02-01.csv 2023-02-01            TRAD
# 3808   SANT-1 2023-02-01.csv 2023-02-01            TRAD
# 65464  SANT-1 2023-02-01.csv 2023-02-01            TRAD

# %%
def tipo_pago(allfiles):
    if allfiles['date_query'] == allfiles['report_date_local']:
        return 'Pago del día'
    else:
        return 'Reprogramación'
allfiles['tipo_pago'] = allfiles.apply(tipo_pago, axis=1)

# %%
allfiles.head()
# Out:
#         type                           merchant_id  \
# 62133  DAILY  a71d5f76-e11a-423e-a94a-80eb97652e1d
# 80813  DAILY  d9bf4b05-9b13-4948-8c77-0603e5364268
# 86417  DAILY  e9131d1d-ada9-4454-887d-02a8eaa038c5
# 3808   DAILY  0a3ccf41-db5f-4d2f-bed2-6e37844a4f62
# 65464  DAILY  affee992-9efd-4e47-a259-350acc1a5488
#
#                              merchant_token   merchant_name  \
# 62133  b43bf099-70af-4c41-a4cf-d881c4b1214d   Minisuper Pau
# 80813  a0a02deb-f458-4a86-a09d-f887e1f1c98d  Varios Maribel
# 86417  40345622-b902-41c7-b945-9eaca92c16d7          Abonos
# 3808   24ad9187-577f-4b9e-a441-659c708101f6     San juditas
# 65464  5067c056-cc51-49c3-b52e-978afad742e3       Los titis
#
#                              user_email  report_id report_date_local   amount  \
# 62133         rodrigoolivas98@gmail.com  222VP3CB4        2023-02-01   334.91
# 80813   miguel.macedo29091984@gmail.com  223SYT9B2        2023-02-01   910.33
# 86417  erika.izc.comunicacion@gmail.com  22472Y8N9        2023-02-01 1,086.65
# 3808    josemariarodriguez211@gmail.com  2248ZQ452        2023-02-01    81.45
# 65464         ale.gonxaxa2525@gmail.com  224ZM4YRX        2023-02-01   149.74
#
#                             bank_name   payment_date_local  \
# 62133  Banco Nacional de México, S.A.  2023-02-01 11:42:36
# 80813             BBVA Bancomer, S.A.  2023-02-01 11:19:05
# 86417                         BANORTE  2023-02-01 11:21:18
# 3808              BBVA Bancomer, S.A.  2023-02-01 11:56:04
# 65464             BBVA Bancomer, S.A.  2023-02-01 11:43:55
#
#                bank_account_owner_name  bank_account_number  \
# 62133          Rodrigo Olivas Gonzales  '002150462200793098
# 80813               Juan Miguel Macedo  '012650015415238751
# 86417                    Erika Lechuga  '072930006204851021
# 3808     Jose Maria Rodriguez Martinez  '012180015170982058
# 65464  Sandra Alejandra Lopez Gonzalez  '012180011748221611
#
#         batch_created_date disbursement_method  \
# 62133  2023-02-01 10:10:08           SANTANDER
# 80813  2023-02-01 10:12:19           SANTANDER
# 86417  2023-02-01 10:12:56           SANTANDER
# 3808   2023-02-01 10:03:20           SANTANDER
# 65464  2023-02-01 10:10:31           SANTANDER
#
#                                                     swap  \
# 62133  Rodrigo Olivas Gonzales,,334.91,00215046220079...
# 80813  Juan Miguel Macedo,,910.33,012650015415238751,...
# 86417  Erika Lechuga,,1086.65,072930006204851021,CLIP...
# 3808   Jose Maria Rodriguez Martinez,,81.45,012180015...
# 65464  Sandra Alejandra Lopez Gonzalez,,149.74,012180...
#
#                    file_name date_query tipo_dispersion     tipo_pago
# 62133  SANT-1 2023-02-01.csv 2023-02-01            TRAD  Pago del día
# 80813  SANT-1 2023-02-01.csv 2023-02-01            TRAD  Pago del día
# 86417  SANT-1 2023-02-01.csv 2023-02-01            TRAD  Pago del día
# 3808   SANT-1 2023-02-01.csv 2023-02-01            TRAD  Pago del día
# 65464  SANT-1 2023-02-01.csv 2023-02-01            TRAD  Pago del día

# %%
allfiles.shape
# Out:
# (9004630, 19)

# %% [markdown]
# # CRUCE 1 - MES ACTUAL

# %%
cruce_1 = allfiles.merge(query_error_current_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status'
                                                   ,'error_description','esquema_query','status_cubeta']],on='report_id',how='left')
cruce_1['month'].fillna('Not found',inplace=True)
cruce_1.head()
# Out:
#     type                           merchant_id  \
# 0  DAILY  a71d5f76-e11a-423e-a94a-80eb97652e1d
# 1  DAILY  d9bf4b05-9b13-4948-8c77-0603e5364268
# 2  DAILY  e9131d1d-ada9-4454-887d-02a8eaa038c5
# 3  DAILY  0a3ccf41-db5f-4d2f-bed2-6e37844a4f62
# 4  DAILY  affee992-9efd-4e47-a259-350acc1a5488
#
#                          merchant_token   merchant_name  \
# 0  b43bf099-70af-4c41-a4cf-d881c4b1214d   Minisuper Pau
# 1  a0a02deb-f458-4a86-a09d-f887e1f1c98d  Varios Maribel
# 2  40345622-b902-41c7-b945-9eaca92c16d7          Abonos
# 3  24ad9187-577f-4b9e-a441-659c708101f6     San juditas
# 4  5067c056-cc51-49c3-b52e-978afad742e3       Los titis
#
#                          user_email  report_id report_date_local  amount_x  \
# 0         rodrigoolivas98@gmail.com  222VP3CB4        2023-02-01    334.91
# 1   miguel.macedo29091984@gmail.com  223SYT9B2        2023-02-01    910.33
# 2  erika.izc.comunicacion@gmail.com  22472Y8N9        2023-02-01  1,086.65
# 3   josemariarodriguez211@gmail.com  2248ZQ452        2023-02-01     81.45
# 4         ale.gonxaxa2525@gmail.com  224ZM4YRX        2023-02-01    149.74
#
#                         bank_name   payment_date_local  ... tipo_dispersion  \
# 0  Banco Nacional de México, S.A.  2023-02-01 11:42:36  ...            TRAD
# 1             BBVA Bancomer, S.A.  2023-02-01 11:19:05  ...            TRAD
# 2                         BANORTE  2023-02-01 11:21:18  ...            TRAD
# 3             BBVA Bancomer, S.A.  2023-02-01 11:56:04  ...            TRAD
# 4             BBVA Bancomer, S.A.  2023-02-01 11:43:55  ...            TRAD
#
#       tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 0  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 1  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 3  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#   error_description esquema_query  status_cubeta
# 0               NaN           NaN            NaN
# 1               NaN           NaN            NaN
# 2               NaN           NaN            NaN
# 3               NaN           NaN            NaN
# 4               NaN           NaN            NaN
#
# [5 rows x 27 columns]

# %%
cruce_1.shape
# Out:
# (9004630, 27)

# %%
duplicates_cruce_1_previo = cruce_1[cruce_1.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_previo.head()
# Out:
#        type                           merchant_id  \
# 1747  DAILY  1a5d9343-d8e5-41d5-bbad-1e00dbaa4b41
# 2323  DAILY  a67de575-bce8-4f5b-b74e-2c6820fb8821
# 3231  DAILY  7d36e72f-746b-43ba-b216-8d7525abda81
# 4012  DAILY  3a2e6983-f0a1-4bf8-9bb3-66f83465b4c5
# 4509  DAILY  0e8a96d3-0f67-4db0-9b0f-cbebda482676
#
#                             merchant_token         merchant_name  \
# 1747  f41ade9a-b31e-4d51-8348-1134c9137644               Lefranm
# 2323  41792d36-7c17-48cd-a3a0-b4bd0a49d1ef     We Cycling Cancun
# 3231  27bb3518-73b9-454d-bccf-41c53a3e5bdb           Gym Mictlan
# 4012  83b261d4-14a9-41a1-8b17-14b032cd57f1  Veterinaria La Palma
# 4509  0bfe30ad-c10f-4b61-8195-274664971c33                  Alex
#
#                           user_email  report_id report_date_local  amount_x  \
# 1747             wjuan_9@hotmail.com  2NCGNDKDM        2023-02-01 14,421.51
# 2323        weactivecancun@gmail.com  2V4MMVPF7        2023-02-01 11,829.47
# 3231        satiraelfina@hotmail.com  36LQS8YMF        2023-02-01  1,109.63
# 4012  veterinarialapalma13@gmail.com  3GM7S3TXS        2023-02-01    225.95
# 4509          alendrohdz07@gmail.com  3M7PM5DK8        2023-02-01    275.97
#
#               bank_name   payment_date_local  ... tipo_dispersion  \
# 1747               HSBC  2023-02-01 11:58:28  ...            TRAD
# 2323      BBVA Bancomer  2023-02-01 11:42:30  ...            TRAD
# 3231             AZTECA  2023-02-01 11:57:12  ...            TRAD
# 4012            BANAMEX  2023-02-01 11:42:30  ...            TRAD
# 4509  Banco Compartamos  2023-02-01 11:56:40  ...            TRAD
#
#          tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 1747  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2323  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 3231  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4012  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4509  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#      error_description esquema_query  status_cubeta
# 1747               NaN           NaN            NaN
# 2323               NaN           NaN            NaN
# 3231               NaN           NaN            NaN
# 4012               NaN           NaN            NaN
# 4509               NaN           NaN            NaN
#
# [5 rows x 27 columns]

# %%
duplicates_cruce_1_previo.shape
# Out:
# (30580, 27)

# %%
cruce_1_final = cruce_1[(cruce_1['month'] != 'Not found')]
cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_1_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17500\1938979547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_1_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
#           type                           merchant_id merchant_token  \
# 1716389  BLANK  6e1af873-92af-4ff0-addf-2177c9a4fff2          BLANK
# 1822835  BLANK  6e1af873-92af-4ff0-addf-2177c9a4fff2          BLANK
# 2407458  BLANK  6e1af873-92af-4ff0-addf-2177c9a4fff2          BLANK
# 2522985  BLANK  6e1af873-92af-4ff0-addf-2177c9a4fff2          BLANK
# 4870692  BLANK  a44756d9-266e-4f39-9649-02deb7e582d3          BLANK
#
#         merchant_name user_email  report_id report_date_local  amount_x  \
# 1716389         BLANK      BLANK  AJTTDKQ7N        2023-02-18    761.80
# 1822835         BLANK      BLANK  A93JX8RHZ        2023-02-19    191.65
# 2407458         BLANK      BLANK  ADFXHLV25        2023-02-25    321.01
# 2522985         BLANK      BLANK  AVZXK8WGT        2023-02-26    124.57
# 4870692         BLANK      BLANK  AFPNZSMVQ        2023-03-21    293.22
#
#                                                  bank_name  \
# 1716389                              Banco Santander, S.A.
# 1822835                              Banco Santander, S.A.
# 2407458                              Banco Santander, S.A.
# 2522985                              Banco Santander, S.A.
# 4870692  Opciones Empresariales del Noreste, S.A. de C....
#
#           payment_date_local  ... tipo_dispersion     tipo_pago amount_y  \
# 1716389  2023-02-18 12:50:30  ...            TRAD  Pago del día   761.80
# 1822835  2023-02-19 12:43:01  ...            TRAD  Pago del día   191.65
# 2407458  2023-02-25 12:40:04  ...            TRAD  Pago del día   321.01
# 2522985  2023-02-26 12:51:27  ...            TRAD  Pago del día   124.57
# 4870692  2023-03-21 11:41:35  ...            TRAD  Pago del día   293.22
#
#         ultimo_mov ultimo_mov_date_only month status  \
# 1716389 2023-04-17           2023-04-17  4.00  ERROR
# 1822835 2023-04-17           2023-04-17  4.00  ERROR
# 2407458 2023-04-17           2023-04-17  4.00  ERROR
# 2522985 2023-04-17           2023-04-17  4.00  ERROR
# 4870692 2023-04-12           2023-04-12  4.00  ERROR
#
#                    error_description esquema_query  status_cubeta
# 1716389  Error request by Backoffice   ERROR_USUAL            NEW
# 1822835  Error request by Backoffice   ERROR_USUAL            NEW
# 2407458  Error request by Backoffice   ERROR_USUAL            NEW
# 2522985  Error request by Backoffice   ERROR_USUAL            NEW
# 4870692  Error request by Backoffice   ERROR_USUAL            NEW
#
# [5 rows x 27 columns]

# %%
cruce_1_final.shape
# Out:
# (5433, 27)

# %%
duplicates_cruce_1_final = cruce_1_final[cruce_1_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_1_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_1_final.shape
# Out:
# (0, 27)

# %% [markdown]
# # CRUCE 2 MES ACTUAL

# %%
cruce_2 = query_error_current_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_2['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_2.head()
# Out:
#    Unnamed: 0                           merchant_id merchant_name  report_id  \
# 0      114510  86f663aa-8670-4195-bb17-f9b739a30cb3           NaN  AM564SFM5
# 1      114468  6fb8bc6b-93d5-40f5-b374-f22d84493e5b           NaN  A5ZG35KPW
# 2      114467  fddb3db6-64da-4539-95e7-5c8a31a82855           NaN  AWPT56CYY
# 3      114466  a27d5fc0-7749-498a-9933-7cee627b5555           NaN  A2WDNBPQ8
# 4      114465  ed642c2c-5451-418c-abd8-c7994267cf56           NaN  A7LVFXLWM
#
#   report_date_local  amount status                       error_description  \
# 0        2023-04-01  431.21  ERROR  Bank account information not available
# 1        2023-04-01  239.56  ERROR  Bank account information not available
# 2        2023-04-01    0.02  ERROR  Bank account information not available
# 3        2023-04-01    0.02  ERROR  Bank account information not available
# 4        2023-04-01    0.95  ERROR  Bank account information not available
#
#   ultimo_mov  month  year status_cubeta esquema_query  \
# 0 2023-04-01      4  2023           NEW     SIN_CLABE
# 1 2023-04-01      4  2023           NEW     SIN_CLABE
# 2 2023-04-01      4  2023           NEW     SIN_CLABE
# 3 2023-04-01      4  2023           NEW     SIN_CLABE
# 4 2023-04-01      4  2023           NEW     SIN_CLABE
#
#                       merchant_id_query ultimo_mov_date_only  day mes_cierre  \
# 0  86f663aa-8670-4195-bb17-f9b739a30cb3           2023-04-01    1     Actual
# 1  6fb8bc6b-93d5-40f5-b374-f22d84493e5b           2023-04-01    1     Actual
# 2  fddb3db6-64da-4539-95e7-5c8a31a82855           2023-04-01    1     Actual
# 3  a27d5fc0-7749-498a-9933-7cee627b5555           2023-04-01    1     Actual
# 4  ed642c2c-5451-418c-abd8-c7994267cf56           2023-04-01    1     Actual
#
#   tipo_dispersion tipo_pago
# 0       Not found       NaN
# 1       Not found       NaN
# 2       Not found       NaN
# 3       Not found       NaN
# 4       Not found       NaN

# %%
cruce_2.shape
# Out:
# (11358, 19)

# %%
cruce_2_final = cruce_2[(cruce_2['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_2_final.head()
# Out:
#      Unnamed: 0                           merchant_id merchant_name  \
# 162      113660  03539972-0dd0-4cf9-bce2-18834941f3d7    Tessa Shop
# 163      113660  03539972-0dd0-4cf9-bce2-18834941f3d7    Tessa Shop
# 164      113660  03539972-0dd0-4cf9-bce2-18834941f3d7    Tessa Shop
# 165      113660  03539972-0dd0-4cf9-bce2-18834941f3d7    Tessa Shop
# 340      111278  ee34319f-7f9c-4ba7-a2c9-fd226953f486   Marquesitas
#
#      report_id report_date_local   amount status  \
# 162  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 163  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 164  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 165  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 340  4CMNCLLQK        2023-03-13   268.30  ERROR
#
#                   error_description ultimo_mov  month  year status_cubeta  \
# 162  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 163  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 164  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 165  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 340  DEV.SPEICUENTA BLOQUEADA       2023-04-02      4  2023           NEW
#
#     esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 162   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 163   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 164   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 165   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 340   ERROR_USUAL  ee34319f-7f9c-4ba7-a2c9-fd226953f486           2023-04-02
#
#      day mes_cierre tipo_dispersion       tipo_pago
# 162    1     Actual            TRAD    Pago del día
# 163    1     Actual            TRAD  Reprogramación
# 164    1     Actual            TRAD  Reprogramación
# 165    1     Actual            TRAD  Reprogramación
# 340    2     Actual            TRAD  Reprogramación

# %%
cruce_2_final.shape
# Out:
# (5819, 19)

# %%
duplicates_cruce_2_final = cruce_2_final[cruce_2_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_2_final.head()
# Out:
#      Unnamed: 0                           merchant_id        merchant_name  \
# 162      113660  03539972-0dd0-4cf9-bce2-18834941f3d7           Tessa Shop
# 163      113660  03539972-0dd0-4cf9-bce2-18834941f3d7           Tessa Shop
# 164      113660  03539972-0dd0-4cf9-bce2-18834941f3d7           Tessa Shop
# 165      113660  03539972-0dd0-4cf9-bce2-18834941f3d7           Tessa Shop
# 347      114211  f7565b81-df68-4ad9-a5a3-42edc249315b  Miscelanea don Juan
#
#      report_id report_date_local   amount status  \
# 162  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 163  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 164  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 165  MT3Q8D4QM        2023-03-27 9,580.50  ERROR
# 347  MB7JKH4ZG        2023-03-31     3.00  ERROR
#
#                   error_description ultimo_mov  month  year status_cubeta  \
# 162  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 163  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 164  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 165  DEV.SPEIEXCEDE EL LNMITE DE AB 2023-04-01      4  2023           NEW
# 347  DEV.SPEICUENTA NO PERTE A BCO  2023-04-02      4  2023           NEW
#
#     esquema_query                     merchant_id_query ultimo_mov_date_only  \
# 162   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 163   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 164   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 165   ERROR_USUAL  03539972-0dd0-4cf9-bce2-18834941f3d7           2023-04-01
# 347   ERROR_USUAL  f7565b81-df68-4ad9-a5a3-42edc249315b           2023-04-02
#
#      day mes_cierre tipo_dispersion       tipo_pago
# 162    1     Actual            TRAD    Pago del día
# 163    1     Actual            TRAD  Reprogramación
# 164    1     Actual            TRAD  Reprogramación
# 165    1     Actual            TRAD  Reprogramación
# 347    2     Actual            TRAD    Pago del día

# %%
duplicates_cruce_2_final.shape
# Out:
# (682, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ACTUAL

# %%
group_tipo_pago = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago.fillna(0,inplace=True)
group_tipo_pago.head()
# Out:
#                 ultimo_mov_date_only       amount_x                 \
# esquema_query                           ERROR_USUAL
# status_cubeta                                 ERROR
# tipo_dispersion                                  FP           TRAD
# tipo_pago                            Reprogramación Reprogramación
# 0                         2023-04-01           0.00           0.00
# 1                         2023-04-02           0.00           0.00
# 2                         2023-04-03         275.49       2,712.78
# 3                         2023-04-04           0.00           0.00
# 4                         2023-04-05           0.00      15,626.48
#
#                                                                          \
# esquema_query
# status_cubeta            NEW
# tipo_dispersion           FP                        TRAD
# tipo_pago       Pago del día Reprogramación Pago del día Reprogramación
# 0                       0.00           0.00         0.00       9,580.50
# 1                       0.00           0.00        33.20       1,176.83
# 2                       0.00           0.00        44.20      19,085.75
# 3                 205,629.88           0.00   832,413.72           0.00
# 4                      90.56           0.00   836,311.88           0.00
#
#
# esquema_query            All
# status_cubeta
# tipo_dispersion
# tipo_pago
# 0                   9,580.50
# 1                   1,210.03
# 2                  22,118.22
# 3               1,038,043.60
# 4                 852,028.92

# %%
group_tipo_pago.shape
# Out:
# (31, 8)

# %%
group_esquema = pd.pivot_table(cruce_1_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema.fillna(0,inplace=True)
group_esquema.head()
# Out:
#               ultimo_mov_date_only       amount_x                              \
# esquema_query                         ERROR_USUAL
# status_cubeta                               ERROR          NEW
# tipo_pago                          Reprogramación Pago del día Reprogramación
# 0                       2023-04-01           0.00         0.00       9,580.50
# 1                       2023-04-02           0.00        33.20       1,176.83
# 2                       2023-04-03       2,988.27        44.20      19,085.75
# 3                       2023-04-04           0.00 1,038,043.60           0.00
# 4                       2023-04-05      15,626.48   836,402.44           0.00
#
#
# esquema_query          All
# status_cubeta
# tipo_pago
# 0                 9,580.50
# 1                 1,210.03
# 2                22,118.22
# 3             1,038,043.60
# 4               852,028.92

# %%
group_esquema.shape
# Out:
# (31, 5)

# %% [markdown]
# # CRUCE 3 - MES ANTERIOR

# %%
cruce_3 = allfiles.merge(query_new_last_month[['report_id','amount','ultimo_mov','ultimo_mov_date_only','month','status',
                                               'error_description','esquema_query','status_cubeta']],
                         on='report_id',how='left')
cruce_3['month'].fillna('Not found',inplace=True)
cruce_3.head()
# Out:
#     type                           merchant_id  \
# 0  DAILY  a71d5f76-e11a-423e-a94a-80eb97652e1d
# 1  DAILY  d9bf4b05-9b13-4948-8c77-0603e5364268
# 2  DAILY  e9131d1d-ada9-4454-887d-02a8eaa038c5
# 3  DAILY  0a3ccf41-db5f-4d2f-bed2-6e37844a4f62
# 4  DAILY  affee992-9efd-4e47-a259-350acc1a5488
#
#                          merchant_token   merchant_name  \
# 0  b43bf099-70af-4c41-a4cf-d881c4b1214d   Minisuper Pau
# 1  a0a02deb-f458-4a86-a09d-f887e1f1c98d  Varios Maribel
# 2  40345622-b902-41c7-b945-9eaca92c16d7          Abonos
# 3  24ad9187-577f-4b9e-a441-659c708101f6     San juditas
# 4  5067c056-cc51-49c3-b52e-978afad742e3       Los titis
#
#                          user_email  report_id report_date_local  amount_x  \
# 0         rodrigoolivas98@gmail.com  222VP3CB4        2023-02-01    334.91
# 1   miguel.macedo29091984@gmail.com  223SYT9B2        2023-02-01    910.33
# 2  erika.izc.comunicacion@gmail.com  22472Y8N9        2023-02-01  1,086.65
# 3   josemariarodriguez211@gmail.com  2248ZQ452        2023-02-01     81.45
# 4         ale.gonxaxa2525@gmail.com  224ZM4YRX        2023-02-01    149.74
#
#                         bank_name   payment_date_local  ... tipo_dispersion  \
# 0  Banco Nacional de México, S.A.  2023-02-01 11:42:36  ...            TRAD
# 1             BBVA Bancomer, S.A.  2023-02-01 11:19:05  ...            TRAD
# 2                         BANORTE  2023-02-01 11:21:18  ...            TRAD
# 3             BBVA Bancomer, S.A.  2023-02-01 11:56:04  ...            TRAD
# 4             BBVA Bancomer, S.A.  2023-02-01 11:43:55  ...            TRAD
#
#       tipo_pago amount_y ultimo_mov ultimo_mov_date_only      month status  \
# 0  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 1  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 2  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 3  Pago del día      NaN        NaT                  NaN  Not found    NaN
# 4  Pago del día      NaN        NaT                  NaN  Not found    NaN
#
#   error_description esquema_query  status_cubeta
# 0               NaN           NaN            NaN
# 1               NaN           NaN            NaN
# 2               NaN           NaN            NaN
# 3               NaN           NaN            NaN
# 4               NaN           NaN            NaN
#
# [5 rows x 27 columns]

# %%
cruce_3.shape
# Out:
# (9004630, 27)

# %%
cruce_3_final = cruce_3[(cruce_3['month'] != 'Not found')]
cruce_3_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_3_final.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_17500\2713612933.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cruce_3_final.drop_duplicates(subset='report_id',keep='last', inplace=True)
#           type                           merchant_id  \
# 3402173  DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 3404214  DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 3407293  DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 3414145  DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 3415632  DAILY  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
#
#                                merchant_token    merchant_name  \
# 3402173  ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 3404214  ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 3407293  ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 3414145  ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
# 3415632  ff72b8de-7445-45ea-bafc-5d0770f607cc  Tiendita Lolita
#
#                             user_email  report_id report_date_local  amount_x  \
# 3402173  lolita.marquez.alva@gmail.com  2ZMRWFT67        2023-01-12    823.56
# 3404214  lolita.marquez.alva@gmail.com  3Q6ZK78CM        2022-12-20  1,574.63
# 3407293  lolita.marquez.alva@gmail.com  4RGDKTGRN        2022-12-26  1,435.82
# 3414145  lolita.marquez.alva@gmail.com  74KFMDWDF        2023-01-13  1,355.52
# 3415632  lolita.marquez.alva@gmail.com  7LP27268H        2022-12-15    715.97
#
#         bank_name   payment_date_local  ... tipo_dispersion       tipo_pago  \
# 3402173   BANORTE  2023-03-07 10:13:57  ...            TRAD  Reprogramación
# 3404214   BANORTE  2023-03-07 10:13:57  ...            TRAD  Reprogramación
# 3407293   BANORTE  2023-03-07 10:13:57  ...            TRAD  Reprogramación
# 3414145   BANORTE  2023-03-07 10:13:57  ...            TRAD  Reprogramación
# 3415632   BANORTE  2023-03-07 10:13:57  ...            TRAD  Reprogramación
#
#         amount_y ultimo_mov ultimo_mov_date_only month status  \
# 3402173   823.56 2023-03-07           2023-03-07  3.00  ERROR
# 3404214 1,574.63 2023-03-07           2023-03-07  3.00  ERROR
# 3407293 1,435.82 2023-03-07           2023-03-07  3.00  ERROR
# 3414145 1,355.52 2023-03-07           2023-03-07  3.00  ERROR
# 3415632   715.97 2023-03-07           2023-03-07  3.00  ERROR
#
#                                          error_description esquema_query  \
# 3402173  DEVOLUCION(21): Excede el limite de abonos per...   ERROR_USUAL
# 3404214  DEVOLUCION(21): Excede el limite de abonos per...   ERROR_USUAL
# 3407293  DEVOLUCION(21): Excede el limite de abonos per...   ERROR_USUAL
# 3414145  DEVOLUCION(21): Excede el limite de abonos per...   ERROR_USUAL
# 3415632  DEVOLUCION(21): Excede el limite de abonos per...   ERROR_USUAL
#
#          status_cubeta
# 3402173            NEW
# 3404214            NEW
# 3407293            NEW
# 3414145            NEW
# 3415632            NEW
#
# [5 rows x 27 columns]

# %%
cruce_3_final.shape
# Out:
# (20, 27)

# %%
duplicates_cruce_3_final = cruce_3_final[cruce_3_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_3_final.head()
# Out:
# Empty DataFrame
# Columns: [type, merchant_id, merchant_token, merchant_name, user_email, report_id, report_date_local, amount_x, bank_name, payment_date_local, bank_account_owner_name, bank_account_number, batch_created_date, disbursement_method, swap, file_name, date_query, tipo_dispersion, tipo_pago, amount_y, ultimo_mov, ultimo_mov_date_only, month, status, error_description, esquema_query, status_cubeta]
# Index: []
#
# [0 rows x 27 columns]

# %%
duplicates_cruce_3_final.shape
# Out:
# (0, 27)

# %% [markdown]
# # CRUCE 4 - MES ANTERIOR

# %%
cruce_4 = query_new_last_month.merge(allfiles[['report_id','tipo_dispersion','tipo_pago']],on='report_id',how='left')
cruce_4['tipo_dispersion'].fillna('Not found',inplace=True)
cruce_4.head()
# Out:
#    Unnamed: 0                           merchant_id    merchant_name  \
# 0       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 1       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 2       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 3       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 4      103448  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
#
#    report_id report_date_local   amount status  \
# 0  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 1  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 2  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 3  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 4  BL525Y57N        2023-01-25   960.65  ERROR
#
#                                    error_description ultimo_mov  month  year  \
# 0  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 1  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 2  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 3  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 4  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
#
#   status_cubeta esquema_query                     merchant_id_query  \
# 0           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 1           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 2           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 3           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 4           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
#
#   ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 0           2023-03-07    7        NaN            TRAD  Reprogramación
# 1           2023-03-07    7        NaN            TRAD  Reprogramación
# 2           2023-03-07    7        NaN            TRAD  Reprogramación
# 3           2023-03-07    7        NaN            TRAD  Reprogramación
# 4           2023-03-07    7        NaN            TRAD  Reprogramación

# %%
cruce_4.shape
# Out:
# (80, 19)

# %%
cruce_4_final = cruce_4[(cruce_4['tipo_dispersion'] != 'Not found')]
#cruce_2_final.drop_duplicates(subset='report_id',keep='last', inplace=True) 
cruce_4_final.head()
# Out:
#    Unnamed: 0                           merchant_id    merchant_name  \
# 0       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 1       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 2       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 3       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 4      103448  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
#
#    report_id report_date_local   amount status  \
# 0  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 1  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 2  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 3  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 4  BL525Y57N        2023-01-25   960.65  ERROR
#
#                                    error_description ultimo_mov  month  year  \
# 0  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 1  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 2  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 3  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 4  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
#
#   status_cubeta esquema_query                     merchant_id_query  \
# 0           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 1           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 2           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 3           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 4           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
#
#   ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 0           2023-03-07    7        NaN            TRAD  Reprogramación
# 1           2023-03-07    7        NaN            TRAD  Reprogramación
# 2           2023-03-07    7        NaN            TRAD  Reprogramación
# 3           2023-03-07    7        NaN            TRAD  Reprogramación
# 4           2023-03-07    7        NaN            TRAD  Reprogramación

# %%
cruce_4_final.shape
# Out:
# (80, 19)

# %%
duplicates_cruce_4_final = cruce_4_final[cruce_4_final.duplicated(['report_id'] , keep=False)]
duplicates_cruce_4_final.head()
# Out:
#    Unnamed: 0                           merchant_id    merchant_name  \
# 0       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 1       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 2       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 3       77290  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
# 4      103448  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60  Tiendita Lolita
#
#    report_id report_date_local   amount status  \
# 0  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 1  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 2  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 3  NZQMYLTTG        2022-08-15 1,181.62  ERROR
# 4  BL525Y57N        2023-01-25   960.65  ERROR
#
#                                    error_description ultimo_mov  month  year  \
# 0  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 1  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 2  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 3  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
# 4  DEVOLUCION(21): Excede el limite de abonos per... 2023-03-07      3  2023
#
#   status_cubeta esquema_query                     merchant_id_query  \
# 0           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 1           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 2           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 3           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
# 4           NEW   ERROR_USUAL  d2d62c7d-4bdb-4a83-ab2a-98d5a03c7d60
#
#   ultimo_mov_date_only  day mes_cierre tipo_dispersion       tipo_pago
# 0           2023-03-07    7        NaN            TRAD  Reprogramación
# 1           2023-03-07    7        NaN            TRAD  Reprogramación
# 2           2023-03-07    7        NaN            TRAD  Reprogramación
# 3           2023-03-07    7        NaN            TRAD  Reprogramación
# 4           2023-03-07    7        NaN            TRAD  Reprogramación

# %%
duplicates_cruce_4_final.shape
# Out:
# (80, 19)

# %% [markdown]
# # AGRUPADO POR TIPO DE PAGO - MES ANTERIOR

# %%
group_tipo_pago_last_month = pd.pivot_table(cruce_3_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_dispersion',
                                                        'tipo_pago'],values=['amount_x']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_tipo_pago_last_month.fillna(0,inplace=True)
group_tipo_pago_last_month.head()
# Out:
#                 ultimo_mov_date_only       amount_x
# esquema_query                           ERROR_USUAL       All
# status_cubeta                                   NEW
# tipo_dispersion                                TRAD
# tipo_pago                            Reprogramación
# 0                         2023-03-07      24,016.78 24,016.78
# 1                                All      24,016.78 24,016.78

# %%
group_tipo_pago_last_month.shape
# Out:
# (2, 3)

# %%
group_esquema_last_month = pd.pivot_table(cruce_4_final,index=['ultimo_mov_date_only']
                                              ,columns=['esquema_query','status_cubeta','tipo_pago'],values=['amount']
                                              ,aggfunc=np.sum,margins=True).reset_index()
group_esquema_last_month.fillna(0,inplace=True)
group_esquema_last_month.head()
# Out:
#               ultimo_mov_date_only         amount
# esquema_query                         ERROR_USUAL       All
# status_cubeta                                 NEW
# tipo_pago                          Reprogramación
# 0                       2023-03-07      96,067.12 96,067.12
# 1                              All      96,067.12 96,067.12

# %%
group_esquema_last_month.shape
# Out:
# (2, 3)

# %%
writer = pd.ExcelWriter('FASE V. DATA POLIZA ERROR-USUAL ABRIL 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
group_tipo_pago.to_excel(writer, sheet_name='GRUPO TIPO PAGO')
group_esquema.to_excel(writer, sheet_name='GRUPO ESQUEMA')
group_tipo_pago_last_month.to_excel(writer, sheet_name='GRUPO TIPO PAGO-MESES ANT')
group_esquema_last_month.to_excel(writer, sheet_name='GRUPO ESQUEMA-MESES ANT')
cruce_1_final.to_excel(writer, sheet_name='DETALLE',index=False)
cruce_3_final.to_excel(writer, sheet_name='DETALLE-MESES ANTERIORES',index=False)
writer.close()
