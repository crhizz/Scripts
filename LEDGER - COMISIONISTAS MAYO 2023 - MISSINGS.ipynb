# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # RUTAS

# %% [markdown]
# ### SETTLEMENT MASTER LOG

# %%
sml_files = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\COMISIONISTAS\2023\05. MAYO\LEDGER - DB\MISSINGS\SML*.csv', recursive=False)
sml_files
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\COMISIONISTAS\\2023\\05. MAYO\\LEDGER - DB\\MISSINGS\\SML_COMISIONISTAS - MISSINGS MAYO 2023.csv']

# %% [markdown]
# ### AP JOURNAL

# %%
ap_files = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\COMISIONISTAS\2023\05. MAYO\LEDGER - DB\MISSINGS\AP*.csv', recursive=False)
ap_files
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\COMISIONISTAS\\2023\\05. MAYO\\LEDGER - DB\\MISSINGS\\AP_JOURNAL_COMISIONISTAS - MISSINGS MAYO 2023.csv']

# %% [markdown]
# # DATA SETTLEMENT MASTER LOG

# %%
sml = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in sml_files])
sml.columns = sml.columns.str.strip().str.lower()
sml.replace('""','', regex=True, inplace=True)
sml['created_at'] = pd.to_datetime(sml['created_at']).dt.tz_localize(None)
sml['created_at_date'] =  pd.to_datetime(sml['created_at']).dt.date
sml['created_at_date'] =  pd.to_datetime(sml['created_at_date'])
sml['eff_dt'] = pd.to_datetime(sml['eff_dt']).dt.tz_localize(None)
sml['eff_dt_date'] =  pd.to_datetime(sml['eff_dt']).dt.date
sml['eff_dt_date'] =  pd.to_datetime(sml['eff_dt_date'])
sml.rename(columns={'ref_id':'transaction_id'},inplace=True)
#sml['PK'] = sml['PK'].replace('M#','',inplace=True)
sml.head()
# Out:
#                             record_uuid                           merchant_id  \
# 0  0b0f51c4-c7b6-5212-a733-92936fcbdddc  3ee0c85f-4617-4736-90a1-927a41e0deec
# 1  cc2adc7c-1bda-5879-983d-187a1d409055  3ee0c85f-4617-4736-90a1-927a41e0deec
# 2  57abeb9a-e99a-5f45-8c7e-0f29d4e47aad  3ee0c85f-4617-4736-90a1-927a41e0deec
# 3  fcff7359-19ce-58d6-b49c-1c30d5628957  3ee0c85f-4617-4736-90a1-927a41e0deec
# 4  167c24cd-6fbd-5376-b3b0-866bbd97efff  3ee0c85f-4617-4736-90a1-927a41e0deec
#
#             merchant_name                        transaction_id  \
# 0  PAY CLIP S DE RL DE CV  80125c7d-9900-492a-8e60-39220244304e
# 1  PAY CLIP S DE RL DE CV  e1b20367-135d-4473-8b78-b33687a77ad9
# 2  PAY CLIP S DE RL DE CV  85abf7cb-42d9-4539-aa13-45e1427e22d3
# 3  PAY CLIP S DE RL DE CV  71e757e9-e54a-46ac-b917-b2b8a2a43a8f
# 4  PAY CLIP S DE RL DE CV  2554f200-9b58-4241-83df-3f5a8af02432
#
#                                 mvnt_id   mvnt_type         pymt_prg  \
# 0  80125c7d-9900-492a-8e60-39220244304e  STL_PCS_RQ  REGULAR_PAYMENT
# 1  e1b20367-135d-4473-8b78-b33687a77ad9  STL_PCS_RQ  REGULAR_PAYMENT
# 2  85abf7cb-42d9-4539-aa13-45e1427e22d3  STL_PCS_RQ  REGULAR_PAYMENT
# 3  71e757e9-e54a-46ac-b917-b2b8a2a43a8f  STL_PCS_RQ  REGULAR_PAYMENT
# 4  2554f200-9b58-4241-83df-3f5a8af02432  STL_PCS_RQ  REGULAR_PAYMENT
#
#            created_at              eff_dt  psp_amount  ...  mdr  msi  \
# 0 2023-06-09 10:29:46 2023-06-10 02:30:00    1,490.00  ... 0.00 0.04
# 1 2023-05-31 11:57:32 2023-06-01 02:30:00    1,049.00  ... 0.00 0.00
# 2 2023-05-28 15:44:23 2023-05-29 03:30:00    1,049.00  ... 0.00 0.00
# 3 2023-05-27 15:10:47 2023-05-28 03:30:00    1,200.00  ... 0.00 0.00
# 4 2023-05-02 11:08:59 2023-05-03 02:30:00    7,390.00  ... 0.00 0.00
#
#    number_msi  status_code  status_msg  receipt_no     type  \
# 0        3.00            1        Paid     ZMwoj9f  PAYMENT
# 1        0.00            1        Paid     X2qTjaX  PAYMENT
# 2        0.00            1        Paid     ziW6mcR  PAYMENT
# 3        0.00            1        Paid     d3fcS18  PAYMENT
# 4        0.00            1        Paid     YRYzjqx  PAYMENT
#
#                                     file_name created_at_date eff_dt_date
# 0  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-06-09  2023-06-10
# 1  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-31  2023-06-01
# 2  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-28  2023-05-29
# 3  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-27  2023-05-28
# 4  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-02  2023-05-03
#
# [5 rows x 24 columns]

# %%
sml.shape
# Out:
# (294, 24)

# %%
sml.dtypes
# Out:
# record_uuid                object
# merchant_id                object
# merchant_name              object
# transaction_id             object
# mvnt_id                    object
# mvnt_type                  object
# pymt_prg                   object
# created_at         datetime64[ns]
# eff_dt             datetime64[ns]
# psp_amount                float64
# gross_amount              float64
# fees                      float64
# taxes                     float64
# net_amount                float64
# mdr                       float64
# msi                       float64
# number_msi                float64
# status_code                 int64
# status_msg                 object
# receipt_no                 object
# type                       object
# file_name                  object
# created_at_date    datetime64[ns]
# eff_dt_date        datetime64[ns]
# dtype: object

# %%
sml_final = sml[(sml['mvnt_type'] == 'STL_PCS_RQ')]
sml_final.head()
# Out:
#                             record_uuid                           merchant_id  \
# 0  0b0f51c4-c7b6-5212-a733-92936fcbdddc  3ee0c85f-4617-4736-90a1-927a41e0deec
# 1  cc2adc7c-1bda-5879-983d-187a1d409055  3ee0c85f-4617-4736-90a1-927a41e0deec
# 2  57abeb9a-e99a-5f45-8c7e-0f29d4e47aad  3ee0c85f-4617-4736-90a1-927a41e0deec
# 3  fcff7359-19ce-58d6-b49c-1c30d5628957  3ee0c85f-4617-4736-90a1-927a41e0deec
# 4  167c24cd-6fbd-5376-b3b0-866bbd97efff  3ee0c85f-4617-4736-90a1-927a41e0deec
#
#             merchant_name                        transaction_id  \
# 0  PAY CLIP S DE RL DE CV  80125c7d-9900-492a-8e60-39220244304e
# 1  PAY CLIP S DE RL DE CV  e1b20367-135d-4473-8b78-b33687a77ad9
# 2  PAY CLIP S DE RL DE CV  85abf7cb-42d9-4539-aa13-45e1427e22d3
# 3  PAY CLIP S DE RL DE CV  71e757e9-e54a-46ac-b917-b2b8a2a43a8f
# 4  PAY CLIP S DE RL DE CV  2554f200-9b58-4241-83df-3f5a8af02432
#
#                                 mvnt_id   mvnt_type         pymt_prg  \
# 0  80125c7d-9900-492a-8e60-39220244304e  STL_PCS_RQ  REGULAR_PAYMENT
# 1  e1b20367-135d-4473-8b78-b33687a77ad9  STL_PCS_RQ  REGULAR_PAYMENT
# 2  85abf7cb-42d9-4539-aa13-45e1427e22d3  STL_PCS_RQ  REGULAR_PAYMENT
# 3  71e757e9-e54a-46ac-b917-b2b8a2a43a8f  STL_PCS_RQ  REGULAR_PAYMENT
# 4  2554f200-9b58-4241-83df-3f5a8af02432  STL_PCS_RQ  REGULAR_PAYMENT
#
#            created_at              eff_dt  psp_amount  ...  mdr  msi  \
# 0 2023-06-09 10:29:46 2023-06-10 02:30:00    1,490.00  ... 0.00 0.04
# 1 2023-05-31 11:57:32 2023-06-01 02:30:00    1,049.00  ... 0.00 0.00
# 2 2023-05-28 15:44:23 2023-05-29 03:30:00    1,049.00  ... 0.00 0.00
# 3 2023-05-27 15:10:47 2023-05-28 03:30:00    1,200.00  ... 0.00 0.00
# 4 2023-05-02 11:08:59 2023-05-03 02:30:00    7,390.00  ... 0.00 0.00
#
#    number_msi  status_code  status_msg  receipt_no     type  \
# 0        3.00            1        Paid     ZMwoj9f  PAYMENT
# 1        0.00            1        Paid     X2qTjaX  PAYMENT
# 2        0.00            1        Paid     ziW6mcR  PAYMENT
# 3        0.00            1        Paid     d3fcS18  PAYMENT
# 4        0.00            1        Paid     YRYzjqx  PAYMENT
#
#                                     file_name created_at_date eff_dt_date
# 0  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-06-09  2023-06-10
# 1  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-31  2023-06-01
# 2  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-28  2023-05-29
# 3  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-27  2023-05-28
# 4  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv      2023-05-02  2023-05-03
#
# [5 rows x 24 columns]

# %%
sml_final.shape
# Out:
# (294, 24)

# %% [markdown]
# # DATA AP JOURNAL

# %%
ap = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in ap_files])
ap.columns = ap.columns.str.strip().str.lower()
ap.replace('""','', regex=True, inplace=True)
ap['eff_dt'] =  pd.to_datetime(ap['eff_dt']).dt.tz_localize(None)
ap['eff_dt_date'] =  pd.to_datetime(ap['eff_dt']).dt.date
ap['eff_dt_date'] =  pd.to_datetime(ap['eff_dt_date'])
ap['eff_dt_time'] =  pd.to_datetime(ap['eff_dt']).dt.time
ap['movement_day'] = pd.to_datetime(ap['movement_day']).dt.tz_localize(None)
ap['created_at'] = pd.to_datetime(ap['created_at']).dt.tz_localize(None)
ap['created_at_date'] =  pd.to_datetime(ap['created_at']).dt.date
ap['created_at_date'] =  pd.to_datetime(ap['created_at_date'])
ap['request_effective_date'] = pd.to_datetime(ap['request_effective_date']).dt.tz_localize(None)
ap['slot_date'] = pd.to_datetime(ap['slot_date']).dt.tz_localize(None)
ap['identifier'] = ap['source_type'].str[:1].astype(str)
ap['INDEX'] = (ap['eff_dt_date'].astype(str).replace(' ', '',regex=True)+'-'+
               ap['identifier'].astype(str).replace(' ', '',regex=True)+'-'+
               ap['eff_dt_time'].astype(str).replace(' ', '',regex=True))
ap.sort_values(by=(['merchant_id','eff_dt']), ascending=[True,False], inplace=True)

# %%
ap.loc[ap['source_type'] == 'DISB', 'report_id'] = ap['type_request']
ap['report_id'] = ap['report_id'].groupby(ap['merchant_id']).fillna(method='ffill')
ap.head()
# Out:
#                               merchant_id           merchant_name    amount  \
# 324  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV  1,490.00
# 325  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV 29,800.00
# 326  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV  4,470.00
# 327  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV  5,153.18
# 319  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV  1,490.00
#
#     currency                                  type_request  \
# 324      MXN  settlement processor regular payment request
# 325      MXN  settlement processor regular payment request
# 326      MXN  settlement processor regular payment request
# 327      MXN  settlement processor regular payment request
# 319      MXN  settlement processor regular payment request
#
#                                   mvnt_id    movement_type source_type  \
# 324  4343752b-d0a9-4fe9-9bf4-d30e193247cf  REGULAR_PYMT_RQ        SETT
# 325  d5e5cbf0-157c-45b8-bfa8-04513dcab92c  REGULAR_PYMT_RQ        SETT
# 326  746bb8b0-3c12-4aa9-9dcb-3474221cf7a3  REGULAR_PYMT_RQ        SETT
# 327  c5fd934f-5c89-4d30-8ddc-1d1788369c03  REGULAR_PYMT_RQ        SETT
# 319  75c1ad5e-10e3-42c1-8f4a-555af95c615b  REGULAR_PYMT_RQ        SETT
#
#              created_at              eff_dt        movement_day  \
# 324 2023-06-12 12:06:20 2023-06-13 03:30:00 2023-06-12 12:06:20
# 325 2023-06-12 12:11:09 2023-06-13 03:30:00 2023-06-12 12:11:09
# 326 2023-06-12 12:12:57 2023-06-13 03:30:00 2023-06-12 12:12:57
# 327 2023-06-12 12:16:59 2023-06-13 03:30:00 2023-06-12 12:16:59
# 319 2023-06-12 10:16:47 2023-06-13 03:00:00 2023-06-12 10:16:47
#
#     request_effective_date           slot_date  \
# 324    2023-06-13 03:00:00 2023-06-13 03:30:00
# 325    2023-06-13 03:00:00 2023-06-13 03:30:00
# 326    2023-06-13 03:00:00 2023-06-13 03:30:00
# 327    2023-06-13 03:00:00 2023-06-13 03:30:00
# 319    2023-06-13 02:30:00 2023-06-13 03:00:00
#
#                                              file_name eff_dt_date  \
# 324  AP_JOURNAL_COMISIONISTAS - MISSINGS MAYO 2023.csv  2023-06-13
# 325  AP_JOURNAL_COMISIONISTAS - MISSINGS MAYO 2023.csv  2023-06-13
# 326  AP_JOURNAL_COMISIONISTAS - MISSINGS MAYO 2023.csv  2023-06-13
# 327  AP_JOURNAL_COMISIONISTAS - MISSINGS MAYO 2023.csv  2023-06-13
# 319  AP_JOURNAL_COMISIONISTAS - MISSINGS MAYO 2023.csv  2023-06-13
#
#     eff_dt_time created_at_date identifier                  INDEX report_id
# 324    03:30:00      2023-06-12          S  2023-06-13-S-03:30:00       NaN
# 325    03:30:00      2023-06-12          S  2023-06-13-S-03:30:00       NaN
# 326    03:30:00      2023-06-12          S  2023-06-13-S-03:30:00       NaN
# 327    03:30:00      2023-06-12          S  2023-06-13-S-03:30:00       NaN
# 319    03:00:00      2023-06-12          S  2023-06-13-S-03:00:00       NaN

# %%
ap.shape
# Out:
# (364, 20)

# %%
ap.dtypes
# Out:
# merchant_id                       object
# merchant_name                     object
# amount                           float64
# currency                          object
# type_request                      object
# mvnt_id                           object
# movement_type                     object
# source_type                       object
# created_at                datetime64[ns]
# eff_dt                    datetime64[ns]
# movement_day              datetime64[ns]
# request_effective_date    datetime64[ns]
# slot_date                 datetime64[ns]
# file_name                         object
# eff_dt_date               datetime64[ns]
# eff_dt_time                       object
# created_at_date           datetime64[ns]
# identifier                        object
# INDEX                             object
# report_id                         object
# dtype: object

# %%
ap['source_type'].unique()
# Out:
# array(['SETT', 'DISB', 'TOPUPS', 'PYMT'], dtype=object)

# %%
ap['report_id'].unique()
# Out:
# array([nan, 'AH32PJFD3', 'A2VJGTZHC', 'A3SXVXP25', 'A7SXX3SGT',
#        'A6WZ9NQCM', 'A7T58LJ3P', 'AJWHJR6N6', 'A6JQKGTWD', 'A4PC45HGR',
#        'AL4YY7FVQ', 'AKXVFFSSQ', 'AV7MHYFBV', 'ACSNGTGRV', 'ASNV5D584',
#        'ABDQNQSN6', 'AJD2XCYV8', 'A9VHDD2PC', 'A3YT3WRZL', 'AMWW95HTY',
#        'A2SGF8NMF', 'ANJJCM7YQ', 'AY3HSM5W3', 'A7C9H4YW7', 'AXPZ5R9SZ',
#        'AMBN2W6PS', 'AST5R9FK6', 'AQW2CPZTB', 'ABSH9FJDH', 'A9ZQ3QV7M',
#        'AQQZV8M9Q', 'AKHRWDLCM', 'A5GT5C3CF', 'A6BK77BM9', 'AQT7TMGGM',
#        'ALPVGJ3WL', 'A7VF8P88T', 'ADRZ7L5GY', 'ABY7RMYMM', 'ANN9QJSKH',
#        'AWQDMM27T', 'AZNL5BQ2M', 'AWLNML65Z', 'A98XMNGX6', 'ATK75NB33',
#        'AQRNR9NQC', 'AF6DRNQ4Q', 'AGJ8WYSQ5', 'A7LRV2TT4', 'A35VMSN2S',
#        'ABJKPWG89', 'AFLDNMR5D', 'AGQBWT7SR', 'A4WKLNGB8', 'A245D7DXJ',
#        'ABKWK9TDT'], dtype=object)

# %%
ap_sett = ap[(ap['source_type'] == 'SETT')]
ap_topups = ap[(ap['source_type'] == 'TOPUPS')]
ap_disb = ap[(ap['source_type'] == 'DISB')]
ap_loan = ap[(ap['source_type'] == 'LOAN')]
ap_pymt = ap[(ap['source_type'] == 'PYMT')]
ap_risk = ap[(ap['source_type'] == 'RISK')]

# %% [markdown]
# # CRUCE: IDENTIFICACION DE REPORT_ID

# %%
cruce_1 = sml_final.merge(ap[['mvnt_id','report_id','movement_type']],on='mvnt_id',how='left')
cruce_1.head()
# Out:
#                             record_uuid                           merchant_id  \
# 0  0b0f51c4-c7b6-5212-a733-92936fcbdddc  3ee0c85f-4617-4736-90a1-927a41e0deec
# 1  cc2adc7c-1bda-5879-983d-187a1d409055  3ee0c85f-4617-4736-90a1-927a41e0deec
# 2  57abeb9a-e99a-5f45-8c7e-0f29d4e47aad  3ee0c85f-4617-4736-90a1-927a41e0deec
# 3  fcff7359-19ce-58d6-b49c-1c30d5628957  3ee0c85f-4617-4736-90a1-927a41e0deec
# 4  167c24cd-6fbd-5376-b3b0-866bbd97efff  3ee0c85f-4617-4736-90a1-927a41e0deec
#
#             merchant_name                        transaction_id  \
# 0  PAY CLIP S DE RL DE CV  80125c7d-9900-492a-8e60-39220244304e
# 1  PAY CLIP S DE RL DE CV  e1b20367-135d-4473-8b78-b33687a77ad9
# 2  PAY CLIP S DE RL DE CV  85abf7cb-42d9-4539-aa13-45e1427e22d3
# 3  PAY CLIP S DE RL DE CV  71e757e9-e54a-46ac-b917-b2b8a2a43a8f
# 4  PAY CLIP S DE RL DE CV  2554f200-9b58-4241-83df-3f5a8af02432
#
#                                 mvnt_id   mvnt_type         pymt_prg  \
# 0  80125c7d-9900-492a-8e60-39220244304e  STL_PCS_RQ  REGULAR_PAYMENT
# 1  e1b20367-135d-4473-8b78-b33687a77ad9  STL_PCS_RQ  REGULAR_PAYMENT
# 2  85abf7cb-42d9-4539-aa13-45e1427e22d3  STL_PCS_RQ  REGULAR_PAYMENT
# 3  71e757e9-e54a-46ac-b917-b2b8a2a43a8f  STL_PCS_RQ  REGULAR_PAYMENT
# 4  2554f200-9b58-4241-83df-3f5a8af02432  STL_PCS_RQ  REGULAR_PAYMENT
#
#            created_at              eff_dt  psp_amount  ...  number_msi  \
# 0 2023-06-09 10:29:46 2023-06-10 02:30:00    1,490.00  ...        3.00
# 1 2023-05-31 11:57:32 2023-06-01 02:30:00    1,049.00  ...        0.00
# 2 2023-05-28 15:44:23 2023-05-29 03:30:00    1,049.00  ...        0.00
# 3 2023-05-27 15:10:47 2023-05-28 03:30:00    1,200.00  ...        0.00
# 4 2023-05-02 11:08:59 2023-05-03 02:30:00    7,390.00  ...        0.00
#
#    status_code  status_msg  receipt_no     type  \
# 0            1        Paid     ZMwoj9f  PAYMENT
# 1            1        Paid     X2qTjaX  PAYMENT
# 2            1        Paid     ziW6mcR  PAYMENT
# 3            1        Paid     d3fcS18  PAYMENT
# 4            1        Paid     YRYzjqx  PAYMENT
#
#                                     file_name  created_at_date  eff_dt_date  \
# 0  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-06-09   2023-06-10
# 1  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-31   2023-06-01
# 2  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-28   2023-05-29
# 3  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-27   2023-05-28
# 4  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-02   2023-05-03
#
#    report_id    movement_type
# 0  A3SXVXP25  REGULAR_PYMT_RQ
# 1  AV7MHYFBV  REGULAR_PYMT_RQ
# 2  ABDQNQSN6  REGULAR_PYMT_RQ
# 3  AJD2XCYV8  REGULAR_PYMT_RQ
# 4  ANN9QJSKH  REGULAR_PYMT_RQ
#
# [5 rows x 26 columns]

# %%
cruce_1.shape
# Out:
# (296, 26)

# %%
cruce_1_not_found = cruce_1[(cruce_1['movement_type'].isnull())]
cruce_1_not_found.head()
# Out:
#                               record_uuid  \
# 20   9741fd0c-4a81-53c3-96b9-4fc1f36794ce
# 21   5eecbca0-3a2b-57dc-9481-59799f6f64fe
# 102  2aca743f-88c0-5a05-b82f-8d72632ce34d
# 117  9d4ecdaf-3331-52ed-9aa2-5daab2df9df1
#
#                               merchant_id           merchant_name  \
# 20   3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 21   3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 102  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 117  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
#
#                            transaction_id  \
# 20   a333c4e2-b6c9-4d32-8ade-640bdae94069
# 21   ed5839b3-239b-4a2f-af33-a6df667cbfda
# 102  6c648876-3027-4df6-8d28-208fd67acdeb
# 117  12636aec-13e1-4e24-adb8-42875e2eb341
#
#                                   mvnt_id   mvnt_type         pymt_prg  \
# 20   a333c4e2-b6c9-4d32-8ade-640bdae94069  STL_PCS_RQ  REGULAR_PAYMENT
# 21   ed5839b3-239b-4a2f-af33-a6df667cbfda  STL_PCS_RQ  REGULAR_PAYMENT
# 102  6c648876-3027-4df6-8d28-208fd67acdeb  STL_PCS_RQ  REGULAR_PAYMENT
# 117  12636aec-13e1-4e24-adb8-42875e2eb341  STL_PCS_RQ  REGULAR_PAYMENT
#
#              created_at              eff_dt  psp_amount  ...  number_msi  \
# 20  2023-06-12 12:32:15 2023-06-13 03:00:00    2,235.00  ...        0.00
# 21  2023-06-12 12:25:47 2023-06-13 03:00:00    5,885.00  ...        3.00
# 102 2023-06-12 12:59:10 2023-06-13 03:00:00   25,390.00  ...        0.00
# 117 2023-06-12 12:35:28 2023-06-13 03:00:00      745.00  ...        0.00
#
#      status_code  status_msg  receipt_no     type  \
# 20             1        Paid     mmsUETU  PAYMENT
# 21             1        Paid     WG4EaUa  PAYMENT
# 102            1        Paid     Xq1Dzk3  PAYMENT
# 117            1        Paid     uMbq9GD  PAYMENT
#
#                                       file_name  created_at_date  eff_dt_date  \
# 20   SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-06-12   2023-06-13
# 21   SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-06-12   2023-06-13
# 102  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-06-12   2023-06-13
# 117  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-06-12   2023-06-13
#
#     report_id movement_type
# 20        NaN           NaN
# 21        NaN           NaN
# 102       NaN           NaN
# 117       NaN           NaN
#
# [4 rows x 26 columns]

# %%
cruce_1_not_found.shape
# Out:
# (4, 26)

# %%
cruce_1_final = cruce_1[['merchant_id','merchant_name','transaction_id','report_id','receipt_no','gross_amount','fees','taxes',
                        'net_amount','eff_dt_date','created_at','created_at_date','status_code','status_msg']]
cruce_1_final.head()
# Out:
#                             merchant_id           merchant_name  \
# 0  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 1  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 2  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 3  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 4  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
#
#                          transaction_id  report_id receipt_no  gross_amount  \
# 0  80125c7d-9900-492a-8e60-39220244304e  A3SXVXP25    ZMwoj9f      1,490.00
# 1  e1b20367-135d-4473-8b78-b33687a77ad9  AV7MHYFBV    X2qTjaX      1,049.00
# 2  85abf7cb-42d9-4539-aa13-45e1427e22d3  ABDQNQSN6    ziW6mcR      1,049.00
# 3  71e757e9-e54a-46ac-b917-b2b8a2a43a8f  AJD2XCYV8    d3fcS18      1,200.00
# 4  2554f200-9b58-4241-83df-3f5a8af02432  ANN9QJSKH    YRYzjqx      7,390.00
#
#    fees  taxes  net_amount eff_dt_date          created_at created_at_date  \
# 0 67.05  10.73    1,412.22  2023-06-10 2023-06-09 10:29:46      2023-06-09
# 1  0.00   0.00    1,049.00  2023-06-01 2023-05-31 11:57:32      2023-05-31
# 2  0.00   0.00    1,049.00  2023-05-29 2023-05-28 15:44:23      2023-05-28
# 3  0.00   0.00    1,200.00  2023-05-28 2023-05-27 15:10:47      2023-05-27
# 4  0.00   0.00    7,390.00  2023-05-03 2023-05-02 11:08:59      2023-05-02
#
#    status_code status_msg
# 0            1       Paid
# 1            1       Paid
# 2            1       Paid
# 3            1       Paid
# 4            1       Paid

# %%
cruce_1_final.shape
# Out:
# (296, 14)

# %%
cruce_1_dup = cruce_1[cruce_1.duplicated(['mvnt_id'] , keep=False)]
cruce_1_dup.head()
# Out:
#                               record_uuid  \
# 70   5a3dd132-a349-5ef2-bcc8-9e6b681b34ab
# 71   5a3dd132-a349-5ef2-bcc8-9e6b681b34ab
# 149  6f493d38-9690-5429-9208-a0c743e89c97
# 150  6f493d38-9690-5429-9208-a0c743e89c97
#
#                               merchant_id           merchant_name  \
# 70   3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 71   3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 149  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 150  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
#
#                            transaction_id  \
# 70   be6b2ed9-224b-4ded-995d-4e6e714136cc
# 71   be6b2ed9-224b-4ded-995d-4e6e714136cc
# 149  882cac6f-931d-42ab-9f93-642559741c39
# 150  882cac6f-931d-42ab-9f93-642559741c39
#
#                                   mvnt_id   mvnt_type         pymt_prg  \
# 70   be6b2ed9-224b-4ded-995d-4e6e714136cc  STL_PCS_RQ  REGULAR_PAYMENT
# 71   be6b2ed9-224b-4ded-995d-4e6e714136cc  STL_PCS_RQ  REGULAR_PAYMENT
# 149  882cac6f-931d-42ab-9f93-642559741c39  STL_PCS_RQ  REGULAR_PAYMENT
# 150  882cac6f-931d-42ab-9f93-642559741c39  STL_PCS_RQ  REGULAR_PAYMENT
#
#              created_at              eff_dt  psp_amount  ...  number_msi  \
# 70  2023-05-27 12:26:32 2023-05-28 03:00:00    5,960.00  ...        0.00
# 71  2023-05-27 12:26:32 2023-05-28 03:00:00    5,960.00  ...        0.00
# 149 2023-05-29 13:46:04 2023-05-30 03:00:00    1,990.00  ...        0.00
# 150 2023-05-29 13:46:04 2023-05-30 03:00:00    1,990.00  ...        0.00
#
#      status_code                      status_msg  receipt_no     type  \
# 70             3  Cancelled. Merchant initiated.     lQ7DUoZ  PAYMENT
# 71             3  Cancelled. Merchant initiated.     lQ7DUoZ  PAYMENT
# 149            3  Cancelled. Merchant initiated.     4HDEAUM  PAYMENT
# 150            3  Cancelled. Merchant initiated.     4HDEAUM  PAYMENT
#
#                                       file_name  created_at_date  eff_dt_date  \
# 70   SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-27   2023-05-28
# 71   SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-27   2023-05-28
# 149  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-29   2023-05-30
# 150  SML_COMISIONISTAS - MISSINGS MAYO 2023.csv       2023-05-29   2023-05-30
#
#      report_id    movement_type
# 70   AJD2XCYV8  REGULAR_PYMT_RQ
# 71   AJD2XCYV8        CANCEL_RQ
# 149  ASNV5D584  REGULAR_PYMT_RQ
# 150  ASNV5D584        CANCEL_RQ
#
# [4 rows x 26 columns]

# %%
cruce_1_dup.shape
# Out:
# (4, 26)

# %%
check_data_puntual = cruce_1_final[(cruce_1_final['receipt_no'].isin([
'7ZBMiGL',
'VhmHhhm',
'4HDEAUM',
'cL1hVyp',
'WXYkjSf',
'X2qTjaX',
]))]
check_data_puntual.head()
# Out:
#                               merchant_id           merchant_name  \
# 1    3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 127  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 130  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 132  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
# 140  3ee0c85f-4617-4736-90a1-927a41e0deec  PAY CLIP S DE RL DE CV
#
#                            transaction_id  report_id receipt_no  gross_amount  \
# 1    e1b20367-135d-4473-8b78-b33687a77ad9  AV7MHYFBV    X2qTjaX      1,049.00
# 127  a0fb7a18-eb97-437f-be76-1a05cbf7205e  AV7MHYFBV    cL1hVyp      4,470.00
# 130  368db60b-c562-4ce3-b145-6907d8078e7f  AV7MHYFBV    VhmHhhm      1,849.00
# 132  cc037cdd-7d96-4e59-abde-2b9301bfdbb4  AV7MHYFBV    WXYkjSf      1,849.00
# 140  27e6609c-1c43-48c8-9dff-b4dc8c01dc58  AV7MHYFBV    7ZBMiGL      2,898.00
#
#       fees  taxes  net_amount eff_dt_date          created_at created_at_date  \
# 1     0.00   0.00    1,049.00  2023-06-01 2023-05-31 11:57:32      2023-05-31
# 127 201.15  32.18    4,236.67  2023-06-01 2023-05-31 11:17:24      2023-05-31
# 130   0.00   0.00    1,849.00  2023-06-01 2023-05-31 12:32:17      2023-05-31
# 132  83.21  13.31    1,752.48  2023-06-01 2023-05-31 11:20:32      2023-05-31
# 140   0.00   0.00    2,898.00  2023-06-01 2023-05-31 12:04:26      2023-05-31
#
#      status_code status_msg
# 1              1       Paid
# 127            1       Paid
# 130            1       Paid
# 132            1       Paid
# 140            1       Paid

# %%
check_data_puntual.shape
# Out:
# (7, 14)

# %%
check_data_puntual.to_excel('0. DATA COMISIONISTAS MAYO - MISSINGS 2023.xlsx',index=False)
