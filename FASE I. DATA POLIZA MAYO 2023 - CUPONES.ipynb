# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook
import glob
import os
import datetime
pd.options.display.float_format = '{:,.2f}'.format
datetime.timedelta(days=1)
datetime.timedelta(1)
# Out:
# datetime.timedelta(days=1)

# %% [markdown]
# # SETTLEMENT

# %%
start_date = '2023-05-01'
final_date = '2023-05-31'

# %%
allfiles_settled = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2023\05. MAYO\QUERIES\*.csv', recursive=False)
allfiles_settled
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-01.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-02.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-03.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-04.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-05.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-06.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-07.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-08.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-09.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-10.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-11.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-12.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-13.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-14.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-15.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-16.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-17.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-18.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-19.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-20.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-21.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-22.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-23.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-24.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-25.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-26.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-27.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-28.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-29.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-30.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\05. MAYO\\QUERIES\\SETTLEMENT 2023-05-31.csv']

# %%
settled = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in allfiles_settled])
settled['Date_file'] = settled["file_name"].str[-14:-4]
settled['Date_file']= pd.to_datetime(settled['Date_file'])
settled['report_date_local']= pd.to_datetime(settled['report_date_local'])

# %%
settled.reset_index(inplace=True)
settled.drop(['index'],axis=1,inplace=True)
settled.head()
# Out:
#                             merchant_id        merchant_name  \
# 0  86891848-99c4-41b3-8c64-2cd863b1d075             RHR Y CC
# 1  073c8eeb-0b0d-4455-ab60-f1fc26eee7e1   CARNITAS MICHOACAN
# 2  35bab555-82b1-481a-a9b1-950f146410f6            CAFETERIA
# 3  4a799aeb-1ba9-4809-8bc5-02fe66a71d2f  INDEPENDIENTE MDICO
# 4  1ead08d3-67b1-4625-9a7c-65fd0b65107c     ABARROTES LUPITA
#
#                            user_email  report_id report_date_local  \
# 0               phisabel1@hotmail.com  JSSPVVNQ8        2023-05-01
# 1            fabiola12749@outlook.com  PGSS3JKPW        2023-05-01
# 2             alex_fish25@hotmail.com  3V84FFW3T        2023-05-01
# 3              karengpepo@hotmail.com  MXW2MWWJ2        2023-05-01
# 4  felipemoralesbarrera2605@gmail.com  RKGHW8YTX        2023-05-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  total_retained  tipopago  total_due   type  \
# 0                    0.00  ...            0.00       NaN       1.20  DAILY
# 1                    0.00  ...            0.00       NaN      13.00  DAILY
# 2                    0.00  ...            0.00       NaN       4.00  DAILY
# 3                    0.00  ...            0.00       NaN       2.00  DAILY
# 4                    0.00  ...            0.00       NaN      11.60  DAILY
#
#    created_date  created_time  updated_date  updated_time  \
# 0    2023-05-01      03:00:41    2023-05-01      03:00:41
# 1    2023-05-01      03:00:41    2023-05-01      03:00:41
# 2    2023-05-01      03:00:47    2023-05-01      03:00:47
# 3    2023-05-01      03:00:51    2023-05-01      03:00:51
# 4    2023-05-01      03:00:55    2023-05-01      03:00:55
#
#                    file_name  Date_file
# 0  SETTLEMENT 2023-05-01.csv 2023-05-01
# 1  SETTLEMENT 2023-05-01.csv 2023-05-01
# 2  SETTLEMENT 2023-05-01.csv 2023-05-01
# 3  SETTLEMENT 2023-05-01.csv 2023-05-01
# 4  SETTLEMENT 2023-05-01.csv 2023-05-01
#
# [5 rows x 27 columns]

# %%
settled.shape
# Out:
# (11755, 27)

# %% [markdown]
# ### CURRENT MONTH

# %%
settled_current_month = settled[(settled['report_date_local'] >= start_date) & (settled['report_date_local'] <= final_date)]
settled_current_month.head()
# Out:
#                             merchant_id        merchant_name  \
# 0  86891848-99c4-41b3-8c64-2cd863b1d075             RHR Y CC
# 1  073c8eeb-0b0d-4455-ab60-f1fc26eee7e1   CARNITAS MICHOACAN
# 2  35bab555-82b1-481a-a9b1-950f146410f6            CAFETERIA
# 3  4a799aeb-1ba9-4809-8bc5-02fe66a71d2f  INDEPENDIENTE MDICO
# 4  1ead08d3-67b1-4625-9a7c-65fd0b65107c     ABARROTES LUPITA
#
#                            user_email  report_id report_date_local  \
# 0               phisabel1@hotmail.com  JSSPVVNQ8        2023-05-01
# 1            fabiola12749@outlook.com  PGSS3JKPW        2023-05-01
# 2             alex_fish25@hotmail.com  3V84FFW3T        2023-05-01
# 3              karengpepo@hotmail.com  MXW2MWWJ2        2023-05-01
# 4  felipemoralesbarrera2605@gmail.com  RKGHW8YTX        2023-05-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  total_retained  tipopago  total_due   type  \
# 0                    0.00  ...            0.00       NaN       1.20  DAILY
# 1                    0.00  ...            0.00       NaN      13.00  DAILY
# 2                    0.00  ...            0.00       NaN       4.00  DAILY
# 3                    0.00  ...            0.00       NaN       2.00  DAILY
# 4                    0.00  ...            0.00       NaN      11.60  DAILY
#
#    created_date  created_time  updated_date  updated_time  \
# 0    2023-05-01      03:00:41    2023-05-01      03:00:41
# 1    2023-05-01      03:00:41    2023-05-01      03:00:41
# 2    2023-05-01      03:00:47    2023-05-01      03:00:47
# 3    2023-05-01      03:00:51    2023-05-01      03:00:51
# 4    2023-05-01      03:00:55    2023-05-01      03:00:55
#
#                    file_name  Date_file
# 0  SETTLEMENT 2023-05-01.csv 2023-05-01
# 1  SETTLEMENT 2023-05-01.csv 2023-05-01
# 2  SETTLEMENT 2023-05-01.csv 2023-05-01
# 3  SETTLEMENT 2023-05-01.csv 2023-05-01
# 4  SETTLEMENT 2023-05-01.csv 2023-05-01
#
# [5 rows x 27 columns]

# %%
settled_current_month.shape
# Out:
# (11755, 27)

# %%
settled_current_month.dtypes
# Out:
# merchant_id                              object
# merchant_name                            object
# user_email                               object
# report_id                                object
# report_date_local                datetime64[ns]
# total_transactions                      float64
# total_fees_charged                      float64
# total_taxes                             float64
# applied_fees_benefits                   float64
# applied_taxes_benefits                  float64
# fee_direct_deposit                      float64
# taxes_direct_deposit                    float64
# total_adjustments                       float64
# total_adjustment_fees_charged           float64
# total_adjustment_taxes                  float64
# cobranza                                float64
# total_released                          float64
# total_retained                          float64
# tipopago                                float64
# total_due                               float64
# type                                     object
# created_date                             object
# created_time                             object
# updated_date                             object
# updated_time                             object
# file_name                                object
# Date_file                        datetime64[ns]
# dtype: object

# %%
# def next_date(settled_current_month):
#     if settled_current_month['updated_time'] >= '20:00:00':
#         return settled_current_month['report_date_local'] + datetime.timedelta(days=1)
#     else:
#         return settled_current_month['report_date_local']
    
# settled_current_month['poliza_date'] = settled_current_month.apply(next_date, axis=1)

# %%
# settled_current_month.head()

# %%
# settled_current_month.shape

# %%
# settled_current_month['poliza_date'].unique()

# %% [markdown]
# ### CANCELACIONES

# %%
settled_current_month.loc[(settled_current_month['total_released'] > 0)
                          & (settled_current_month['total_adjustments'] < 0),'canc_1'] = settled_current_month['total_adjustments']
settled_current_month['canc_1'].fillna(0,inplace=True)

# %%
settled_current_month.loc[(settled_current_month['total_released'] > 0)
                          & (settled_current_month['total_adjustments'] < 0),'canc_2'] = settled_current_month['total_released']
settled_current_month['canc_2'].fillna(0,inplace=True)

# %%
settled_current_month['cancelaciones'] = (-settled_current_month['canc_1']) - (settled_current_month['canc_2'])
settled_current_month.head()
# Out:
#                             merchant_id        merchant_name  \
# 0  86891848-99c4-41b3-8c64-2cd863b1d075             RHR Y CC
# 1  073c8eeb-0b0d-4455-ab60-f1fc26eee7e1   CARNITAS MICHOACAN
# 2  35bab555-82b1-481a-a9b1-950f146410f6            CAFETERIA
# 3  4a799aeb-1ba9-4809-8bc5-02fe66a71d2f  INDEPENDIENTE MDICO
# 4  1ead08d3-67b1-4625-9a7c-65fd0b65107c     ABARROTES LUPITA
#
#                            user_email  report_id report_date_local  \
# 0               phisabel1@hotmail.com  JSSPVVNQ8        2023-05-01
# 1            fabiola12749@outlook.com  PGSS3JKPW        2023-05-01
# 2             alex_fish25@hotmail.com  3V84FFW3T        2023-05-01
# 3              karengpepo@hotmail.com  MXW2MWWJ2        2023-05-01
# 4  felipemoralesbarrera2605@gmail.com  RKGHW8YTX        2023-05-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...   type  created_date  created_time  \
# 0                    0.00  ...  DAILY    2023-05-01      03:00:41
# 1                    0.00  ...  DAILY    2023-05-01      03:00:41
# 2                    0.00  ...  DAILY    2023-05-01      03:00:47
# 3                    0.00  ...  DAILY    2023-05-01      03:00:51
# 4                    0.00  ...  DAILY    2023-05-01      03:00:55
#
#    updated_date  updated_time                  file_name  Date_file  canc_1  \
# 0    2023-05-01      03:00:41  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 1    2023-05-01      03:00:41  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 2    2023-05-01      03:00:47  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 3    2023-05-01      03:00:51  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 4    2023-05-01      03:00:55  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
#
#    canc_2  cancelaciones
# 0    0.00          -0.00
# 1    0.00          -0.00
# 2    0.00          -0.00
# 3    0.00          -0.00
# 4    0.00          -0.00
#
# [5 rows x 30 columns]

# %%
settled_current_month.shape
# Out:
# (11755, 30)

# %%
settled_current_month_final = settled_current_month
settled_current_month_final.head()
# Out:
#                             merchant_id        merchant_name  \
# 0  86891848-99c4-41b3-8c64-2cd863b1d075             RHR Y CC
# 1  073c8eeb-0b0d-4455-ab60-f1fc26eee7e1   CARNITAS MICHOACAN
# 2  35bab555-82b1-481a-a9b1-950f146410f6            CAFETERIA
# 3  4a799aeb-1ba9-4809-8bc5-02fe66a71d2f  INDEPENDIENTE MDICO
# 4  1ead08d3-67b1-4625-9a7c-65fd0b65107c     ABARROTES LUPITA
#
#                            user_email  report_id report_date_local  \
# 0               phisabel1@hotmail.com  JSSPVVNQ8        2023-05-01
# 1            fabiola12749@outlook.com  PGSS3JKPW        2023-05-01
# 2             alex_fish25@hotmail.com  3V84FFW3T        2023-05-01
# 3              karengpepo@hotmail.com  MXW2MWWJ2        2023-05-01
# 4  felipemoralesbarrera2605@gmail.com  RKGHW8YTX        2023-05-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...   type  created_date  created_time  \
# 0                    0.00  ...  DAILY    2023-05-01      03:00:41
# 1                    0.00  ...  DAILY    2023-05-01      03:00:41
# 2                    0.00  ...  DAILY    2023-05-01      03:00:47
# 3                    0.00  ...  DAILY    2023-05-01      03:00:51
# 4                    0.00  ...  DAILY    2023-05-01      03:00:55
#
#    updated_date  updated_time                  file_name  Date_file  canc_1  \
# 0    2023-05-01      03:00:41  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 1    2023-05-01      03:00:41  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 2    2023-05-01      03:00:47  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 3    2023-05-01      03:00:51  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
# 4    2023-05-01      03:00:55  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00
#
#    canc_2  cancelaciones
# 0    0.00          -0.00
# 1    0.00          -0.00
# 2    0.00          -0.00
# 3    0.00          -0.00
# 4    0.00          -0.00
#
# [5 rows x 30 columns]

# %%
settled_current_month_final.shape
# Out:
# (11755, 30)

# %% [markdown]
# ### TOTAL DUE CALCULADO

# %%
settled_current_month_final['total_due_calculado'] = (settled_current_month_final['total_transactions']
                                                - settled_current_month_final['total_fees_charged']
                                                - settled_current_month_final['total_taxes']
                                                + settled_current_month_final['applied_fees_benefits']
                                                + settled_current_month_final['applied_taxes_benefits']
                                                + settled_current_month_final['fee_direct_deposit']
                                                + settled_current_month_final['taxes_direct_deposit']
                                                - (-settled_current_month_final['total_adjustments'])
                                                + (-settled_current_month_final['total_adjustment_fees_charged'])
                                                + (-settled_current_month_final['total_adjustment_taxes'])
                                                - settled_current_month_final['cobranza']
                                                + settled_current_month_final['total_released']
                                                - settled_current_month_final['total_retained'])
settled_current_month_final['diferencias'] = settled_current_month_final['total_due_calculado'] - settled_current_month_final['total_due']
settled_current_month_final.head()
# Out:
#                             merchant_id        merchant_name  \
# 0  86891848-99c4-41b3-8c64-2cd863b1d075             RHR Y CC
# 1  073c8eeb-0b0d-4455-ab60-f1fc26eee7e1   CARNITAS MICHOACAN
# 2  35bab555-82b1-481a-a9b1-950f146410f6            CAFETERIA
# 3  4a799aeb-1ba9-4809-8bc5-02fe66a71d2f  INDEPENDIENTE MDICO
# 4  1ead08d3-67b1-4625-9a7c-65fd0b65107c     ABARROTES LUPITA
#
#                            user_email  report_id report_date_local  \
# 0               phisabel1@hotmail.com  JSSPVVNQ8        2023-05-01
# 1            fabiola12749@outlook.com  PGSS3JKPW        2023-05-01
# 2             alex_fish25@hotmail.com  3V84FFW3T        2023-05-01
# 3              karengpepo@hotmail.com  MXW2MWWJ2        2023-05-01
# 4  felipemoralesbarrera2605@gmail.com  RKGHW8YTX        2023-05-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  created_time  updated_date  updated_time  \
# 0                    0.00  ...      03:00:41    2023-05-01      03:00:41
# 1                    0.00  ...      03:00:41    2023-05-01      03:00:41
# 2                    0.00  ...      03:00:47    2023-05-01      03:00:47
# 3                    0.00  ...      03:00:51    2023-05-01      03:00:51
# 4                    0.00  ...      03:00:55    2023-05-01      03:00:55
#
#                    file_name  Date_file  canc_1  canc_2  cancelaciones  \
# 0  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00    0.00          -0.00
# 1  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00    0.00          -0.00
# 2  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00    0.00          -0.00
# 3  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00    0.00          -0.00
# 4  SETTLEMENT 2023-05-01.csv 2023-05-01    0.00    0.00          -0.00
#
#    total_due_calculado  diferencias
# 0                 1.20         0.00
# 1                13.00         0.00
# 2                 4.00         0.00
# 3                 2.00         0.00
# 4                11.60         0.00
#
# [5 rows x 32 columns]

# %%
settled_current_month_final.shape
# Out:
# (11755, 32)

# %% [markdown]
# ### CONCILIACION TPV

# %%
conc_1 = settled_current_month_final.groupby(['report_date_local']).agg({'total_transactions':sum,
                                                                         'total_fees_charged':sum,'total_taxes':sum,
                                                                         'applied_fees_benefits':sum,
                                                                         'applied_taxes_benefits':sum,'fee_direct_deposit':sum,
                                                                         'taxes_direct_deposit':sum,'total_adjustments':sum,
                                                                         'total_adjustment_fees_charged':sum,
                                                                         'total_adjustment_taxes':sum ,
                                                                         'cobranza':sum,'total_released':sum,
                                                                         'total_retained':sum,'cancelaciones':sum,
                                                                         'total_due_calculado':sum,'total_due':sum,
                                                                         'diferencias':sum}).reset_index()
conc_1['total_adjustments'] = conc_1['total_adjustments']*-1 
conc_1['total_adjustment_fees_charged'] = conc_1['total_adjustment_fees_charged']*-1
conc_1['total_adjustment_taxes'] = conc_1['total_adjustment_taxes']*-1 
conc_1.head()
# Out:
#   report_date_local  total_transactions  total_fees_charged  total_taxes  \
# 0        2023-05-01                0.00                0.00         0.00
# 1        2023-05-02                0.00                0.00         0.00
# 2        2023-05-03                0.00                0.00         0.00
# 3        2023-05-04                0.00                0.00         0.00
# 4        2023-05-05                0.00                0.00         0.00
#
#    applied_fees_benefits  applied_taxes_benefits  fee_direct_deposit  \
# 0                   0.00                    0.00            4,128.43
# 1                   0.00                    0.00            4,391.72
# 2                   0.00                    0.00            6,224.49
# 3                   0.00                    0.00            5,257.05
# 4                   0.00                    0.00            4,903.18
#
#    taxes_direct_deposit  total_adjustments  total_adjustment_fees_charged  \
# 0                661.17              35.98                          -0.00
# 1                703.48              26.88                          -0.00
# 2                996.91              53.13                          -0.00
# 3                842.15              34.96                          -0.00
# 4                785.62              41.44                          -0.00
#
#    total_adjustment_taxes  cobranza  total_released  total_retained  \
# 0                   -0.00 23,956.00       79,427.57            0.00
# 1                   -0.00      0.00       69,081.44            0.00
# 2                   -0.00      0.00       74,009.69            0.00
# 3                   -0.00    843.25       84,832.99            0.00
# 4                   -0.00    760.06      194,109.54            0.00
#
#    cancelaciones  total_due_calculado  total_due  diferencias
# 0           0.00            60,225.19  60,225.19        -0.00
# 1           0.00            74,149.76  74,149.76        -0.00
# 2           0.00            81,177.96  81,177.96        -0.00
# 3           0.00            90,053.98  90,053.98         0.00
# 4           0.00           198,996.84 198,996.84         0.00

# %%
conc_1.shape
# Out:
# (31, 18)

# %%
conc_3 = settled_current_month_final.groupby(['report_date_local','type']).agg({'total_transactions':sum,
                                                                                'total_fees_charged':sum,'total_taxes':sum,
                                                                                'applied_fees_benefits':sum,
                                                                                'applied_taxes_benefits':sum,
                                                                                'fee_direct_deposit':sum,
                                                                                'taxes_direct_deposit':sum,
                                                                                'total_adjustments':sum,
                                                                                'total_adjustment_fees_charged':sum,
                                                                                'total_adjustment_taxes':sum ,
                                                                                'cobranza':sum,'total_released':sum,
                                                                                'total_retained':sum,'cancelaciones':sum,
                                                                                'total_due_calculado':sum,'total_due':sum,
                                                                                'diferencias':sum}).reset_index()
conc_3['total_adjustments'] = conc_3['total_adjustments']*-1 
conc_3['total_adjustment_fees_charged'] = conc_3['total_adjustment_fees_charged']*-1
conc_3['total_adjustment_taxes'] = conc_3['total_adjustment_taxes']*-1 
conc_3.head()
# Out:
#   report_date_local   type  total_transactions  total_fees_charged  \
# 0        2023-05-01  DAILY                0.00                0.00
# 1        2023-05-02  DAILY                0.00                0.00
# 2        2023-05-03  DAILY                0.00                0.00
# 3        2023-05-04  DAILY                0.00                0.00
# 4        2023-05-05  DAILY                0.00                0.00
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 0         0.00                   0.00                    0.00
# 1         0.00                   0.00                    0.00
# 2         0.00                   0.00                    0.00
# 3         0.00                   0.00                    0.00
# 4         0.00                   0.00                    0.00
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 0            4,128.43                661.17              35.98
# 1            4,391.72                703.48              26.88
# 2            6,224.49                996.91              53.13
# 3            5,257.05                842.15              34.96
# 4            4,903.18                785.62              41.44
#
#    total_adjustment_fees_charged  total_adjustment_taxes  cobranza  \
# 0                          -0.00                   -0.00 23,956.00
# 1                          -0.00                   -0.00      0.00
# 2                          -0.00                   -0.00      0.00
# 3                          -0.00                   -0.00    843.25
# 4                          -0.00                   -0.00    760.06
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 0       79,427.57            0.00           0.00            60,225.19
# 1       69,081.44            0.00           0.00            74,149.76
# 2       74,009.69            0.00           0.00            81,177.96
# 3       84,832.99            0.00           0.00            90,053.98
# 4      194,109.54            0.00           0.00           198,996.84
#
#    total_due  diferencias
# 0  60,225.19        -0.00
# 1  74,149.76        -0.00
# 2  81,177.96        -0.00
# 3  90,053.98         0.00
# 4 198,996.84         0.00

# %%
conc_3.shape
# Out:
# (31, 19)

# %%
conc_3['type'].unique()
# Out:
# array(['DAILY'], dtype=object)

# %%
data_daily = conc_3[(conc_3['type'] == 'DAILY')]
data_daily.head()
# Out:
#   report_date_local   type  total_transactions  total_fees_charged  \
# 0        2023-05-01  DAILY                0.00                0.00
# 1        2023-05-02  DAILY                0.00                0.00
# 2        2023-05-03  DAILY                0.00                0.00
# 3        2023-05-04  DAILY                0.00                0.00
# 4        2023-05-05  DAILY                0.00                0.00
#
#    total_taxes  applied_fees_benefits  applied_taxes_benefits  \
# 0         0.00                   0.00                    0.00
# 1         0.00                   0.00                    0.00
# 2         0.00                   0.00                    0.00
# 3         0.00                   0.00                    0.00
# 4         0.00                   0.00                    0.00
#
#    fee_direct_deposit  taxes_direct_deposit  total_adjustments  \
# 0            4,128.43                661.17              35.98
# 1            4,391.72                703.48              26.88
# 2            6,224.49                996.91              53.13
# 3            5,257.05                842.15              34.96
# 4            4,903.18                785.62              41.44
#
#    total_adjustment_fees_charged  total_adjustment_taxes  cobranza  \
# 0                          -0.00                   -0.00 23,956.00
# 1                          -0.00                   -0.00      0.00
# 2                          -0.00                   -0.00      0.00
# 3                          -0.00                   -0.00    843.25
# 4                          -0.00                   -0.00    760.06
#
#    total_released  total_retained  cancelaciones  total_due_calculado  \
# 0       79,427.57            0.00           0.00            60,225.19
# 1       69,081.44            0.00           0.00            74,149.76
# 2       74,009.69            0.00           0.00            81,177.96
# 3       84,832.99            0.00           0.00            90,053.98
# 4      194,109.54            0.00           0.00           198,996.84
#
#    total_due  diferencias
# 0  60,225.19        -0.00
# 1  74,149.76        -0.00
# 2  81,177.96        -0.00
# 3  90,053.98         0.00
# 4 198,996.84         0.00

# %%
data_daily.shape
# Out:
# (31, 19)

# %%
data_instant = conc_3[(conc_3['type'] == 'INSTANT')]
data_instant.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_transactions, total_fees_charged, total_taxes, applied_fees_benefits, applied_taxes_benefits, fee_direct_deposit, taxes_direct_deposit, total_adjustments, total_adjustment_fees_charged, total_adjustment_taxes, cobranza, total_released, total_retained, cancelaciones, total_due_calculado, total_due, diferencias]
# Index: []

# %%
data_instant.shape
# Out:
# (0, 19)

# %% [markdown]
# ### RELEASED SIN CLABE

# %%
released_sinclabe = settled_current_month[(settled_current_month['tipopago'] == 'sin CLABE')]
released_sinclabe.head()
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, user_email, report_id, report_date_local, total_transactions, total_fees_charged, total_taxes, applied_fees_benefits, applied_taxes_benefits, fee_direct_deposit, taxes_direct_deposit, total_adjustments, total_adjustment_fees_charged, total_adjustment_taxes, cobranza, total_released, total_retained, tipopago, total_due, type, created_date, created_time, updated_date, updated_time, file_name, Date_file, canc_1, canc_2, cancelaciones, total_due_calculado, diferencias]
# Index: []
#
# [0 rows x 32 columns]

# %%
released_sinclabe.shape
# Out:
# (0, 32)

# %%
released_1 = released_sinclabe.groupby(['report_date_local']).agg({'total_released':sum}).reset_index()
released_1.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, total_released]
# Index: []

# %%
released_1.shape
# Out:
# (0, 2)

# %%
released_3 = released_sinclabe.groupby(['report_date_local','type']).agg({'total_released':sum}).reset_index()
released_3.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_3.shape
# Out:
# (0, 3)

# %%
released_3['type'].unique()
# Out:
# array([], dtype=object)

# %%
released_daily = released_3[(released_3['type'] == 'DAILY')]
released_daily.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_daily.shape
# Out:
# (0, 3)

# %%
released_instant = released_3[(released_3['type'] == 'INSTANT')]
released_instant.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local, type, total_released]
# Index: []

# %%
released_instant.shape
# Out:
# (0, 3)

# %% [markdown]
# # INFO CUPONES

# %%
allcupon_fact = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FACTURACION\2023\05. MAYO\Cupones*.csv', recursive=False)
allcupon_fact
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\FACTURACION\\2023\\05. MAYO\\Cupones_mm.csv']

# %%
cupon_current_month = pd.concat([pd.read_csv(f,dtype={'report_id':object})
                                 .assign(file_name=os.path.basename(f)) for f in allcupon_fact])
cupon_current_month.head()
# Out:
#                             merchant_id                        merchant_token  \
# 0  40dda9f3-518e-423f-8b04-1572ba44a0d7  fbafce7d-82d6-470f-b76a-151332042ddd
# 1  a2760683-129f-4de4-98e3-7e7a08d44e30  95e02cc8-864b-4249-83c6-6a41b7d39b0f
# 2  9f7384ad-a017-4e15-81f9-1a77eee62f5d  b4c82681-754a-4932-9d1e-11c116df2bb4
# 3  6856f295-75c8-4a35-8728-531630c3e0a2  5d5bff5a-e49a-4a09-95b0-0b6a19bfaf6f
# 4  738de109-77df-4182-9643-e436bb893a38  343c2a67-5c80-4779-8ede-c2e51ddd8436
#
#                           fee_refund_id  report_id  number_transactions  \
# 0  5ac1dd9f-221b-4943-bd46-ec4aa4ae749b  228LCKGVL                    2
# 1  f7acbad2-452a-4fca-a143-b790ca5df741  228TQD63W                    1
# 2  8ba3cd55-d8ac-46a8-939f-0fe124c2d08a  22BZKF2BX                    2
# 3  31a3d5f0-b8b1-417d-83eb-03715535ebf9  22G2FKHG7                    1
# 4  0714eca4-db00-42a5-8208-c383324b096d  22R67MKYL                    1
#
#    total_refunded  amount  pending   source           created_at  \
# 0           76.42  108.00    31.58  LOYALTY  2022-10-06 11:39:28
# 1            1.67  108.00   106.33  LOYALTY  2022-11-30 10:43:51
# 2          141.40  292.00   150.60  LOYALTY  2021-11-13 11:05:44
# 3          108.00  108.00     0.00  LOYALTY  2022-12-16 10:22:56
# 4          108.00  108.00     0.00  LOYALTY  2022-07-21 07:56:43
#
#         file_name
# 0  Cupones_mm.csv
# 1  Cupones_mm.csv
# 2  Cupones_mm.csv
# 3  Cupones_mm.csv
# 4  Cupones_mm.csv

# %%
cupon_current_month.shape
# Out:
# (2924, 11)

# %%
cupones_data = settled_current_month.merge(cupon_current_month[['report_id','total_refunded','pending','amount',
                                              'source']] ,on='report_id', how='left')
cupones_data['total_benefits'] = cupones_data['applied_fees_benefits'] + cupones_data['applied_taxes_benefits']
cupones_data.loc[(cupones_data['applied_fees_benefits'] != 0) & (cupones_data['source']!= 'LOYALTY'), 'source'] = 'TOP_UPS'
cupones_data.head()
# Out:
#                             merchant_id        merchant_name  \
# 0  86891848-99c4-41b3-8c64-2cd863b1d075             RHR Y CC
# 1  073c8eeb-0b0d-4455-ab60-f1fc26eee7e1   CARNITAS MICHOACAN
# 2  35bab555-82b1-481a-a9b1-950f146410f6            CAFETERIA
# 3  4a799aeb-1ba9-4809-8bc5-02fe66a71d2f  INDEPENDIENTE MDICO
# 4  1ead08d3-67b1-4625-9a7c-65fd0b65107c     ABARROTES LUPITA
#
#                            user_email  report_id report_date_local  \
# 0               phisabel1@hotmail.com  JSSPVVNQ8        2023-05-01
# 1            fabiola12749@outlook.com  PGSS3JKPW        2023-05-01
# 2             alex_fish25@hotmail.com  3V84FFW3T        2023-05-01
# 3              karengpepo@hotmail.com  MXW2MWWJ2        2023-05-01
# 4  felipemoralesbarrera2605@gmail.com  RKGHW8YTX        2023-05-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  canc_1  canc_2  cancelaciones  \
# 0                    0.00  ...    0.00    0.00          -0.00
# 1                    0.00  ...    0.00    0.00          -0.00
# 2                    0.00  ...    0.00    0.00          -0.00
# 3                    0.00  ...    0.00    0.00          -0.00
# 4                    0.00  ...    0.00    0.00          -0.00
#
#    total_due_calculado  diferencias  total_refunded  pending  amount  source  \
# 0                 1.20         0.00             NaN      NaN     NaN     NaN
# 1                13.00         0.00             NaN      NaN     NaN     NaN
# 2                 4.00         0.00             NaN      NaN     NaN     NaN
# 3                 2.00         0.00             NaN      NaN     NaN     NaN
# 4                11.60         0.00             NaN      NaN     NaN     NaN
#
#    total_benefits
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4            0.00
#
# [5 rows x 37 columns]

# %%
cupones_data['source'].unique()
# Out:
# array([nan], dtype=object)

# %%
cupones_data.shape
# Out:
# (11755, 37)

# %% [markdown]
# ### TOPUPS

# %%
topups_benefits = cupones_data[(cupones_data['source'] == 'TOP_UPS')]
topups_benefits.head()
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, user_email, report_id, report_date_local, total_transactions, total_fees_charged, total_taxes, applied_fees_benefits, applied_taxes_benefits, fee_direct_deposit, taxes_direct_deposit, total_adjustments, total_adjustment_fees_charged, total_adjustment_taxes, cobranza, total_released, total_retained, tipopago, total_due, type, created_date, created_time, updated_date, updated_time, file_name, Date_file, canc_1, canc_2, cancelaciones, total_due_calculado, diferencias, total_refunded, pending, amount, source, total_benefits]
# Index: []
#
# [0 rows x 37 columns]

# %%
topups_benefits.shape
# Out:
# (0, 37)

# %%
pivot_topups_benefits = pd.pivot_table(topups_benefits,index=['report_date_local'],values=['applied_fees_benefits',
                                                                                        'applied_taxes_benefits'],
                                       aggfunc=np.sum,margins=False).reset_index()
pivot_topups_benefits.rename(columns ={'applied_fees_benefits':'applied_fees_benefits_topups',
                                      'applied_taxes_benefits':'applied_taxes_benefits_topups'},inplace=True)
pivot_topups_benefits.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local]
# Index: []

# %%
pivot_topups_benefits.shape
# Out:
# (0, 1)

# %% [markdown]
# ### CUPONES

# %%
coupons_benefits = cupones_data[(cupones_data['source'] == 'LOYALTY')]
coupons_benefits.head()
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, user_email, report_id, report_date_local, total_transactions, total_fees_charged, total_taxes, applied_fees_benefits, applied_taxes_benefits, fee_direct_deposit, taxes_direct_deposit, total_adjustments, total_adjustment_fees_charged, total_adjustment_taxes, cobranza, total_released, total_retained, tipopago, total_due, type, created_date, created_time, updated_date, updated_time, file_name, Date_file, canc_1, canc_2, cancelaciones, total_due_calculado, diferencias, total_refunded, pending, amount, source, total_benefits]
# Index: []
#
# [0 rows x 37 columns]

# %%
coupons_benefits.shape
# Out:
# (0, 37)

# %%
pivot_coupons_benefits = pd.pivot_table(coupons_benefits,index=['report_date_local'],values=['applied_fees_benefits',
                                                                                        'applied_taxes_benefits'],
                                       aggfunc=np.sum,margins=False).reset_index()
pivot_coupons_benefits.rename(columns ={'applied_fees_benefits':'applied_fees_benefits_coupons',
                                      'applied_taxes_benefits':'applied_taxes_benefits_coupons'},inplace=True)
pivot_coupons_benefits.head()
# Out:
# Empty DataFrame
# Columns: [report_date_local]
# Index: []

# %%
pivot_coupons_benefits.shape
# Out:
# (0, 1)

# %% [markdown]
# # EXCEL FINAL

# %%
writer = pd.ExcelWriter('FASE I. DATA POLIZA MAYO 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
conc_1.to_excel(writer, sheet_name='MONTOS REPORT_DATE',index=False)
data_daily.to_excel(writer, sheet_name='MONTOS_DAILY',index=False)
data_instant.to_excel(writer, sheet_name='MONTOS_INSTANT',index=False)
pivot_topups_benefits.to_excel(writer, sheet_name='TOPUPS',index=False)
pivot_coupons_benefits.to_excel(writer, sheet_name='COUPONS',index=False)
released_1.to_excel(writer, sheet_name='RELEASED REPORT_DATE',index=False)
released_daily.to_excel(writer, sheet_name='RELEASED_DAILY',index=False)
released_instant.to_excel(writer, sheet_name='RELEASED_INSTANT',index=False)
writer.close()
