# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # FECHA PERIODO CONTABLE

# %%
start_date = '2022-01-01'
finish_date = '2022-01-31'

# %% [markdown]
# # READING FILES

# %% [markdown]
# ### EPA

# %%
mov_ban_epa = glob.glob(r'G:\My Drive\Settlement\PROVISIONES\2022\01. ENERO\MOVIMIENTOS BANCARIOS AMEX\EPA*.csv',
                            recursive=False)
mov_ban_epa
# Out:
# ['G:\\My Drive\\Settlement\\PROVISIONES\\2022\\01. ENERO\\MOVIMIENTOS BANCARIOS AMEX\\EPA-Resultados_de_la_búsqueda_de_transacciones02022022_101334.csv']

# %% [markdown]
# ### GRRCN

# %%
mov_ban_grrcn = glob.glob(r'G:\My Drive\Settlement\PROVISIONES\2022\01. ENERO\MOVIMIENTOS BANCARIOS AMEX\GRRCN*.csv',
                            recursive=False)
mov_ban_grrcn
# Out:
# ['G:\\My Drive\\Settlement\\PROVISIONES\\2022\\01. ENERO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones02022022_100953.csv',
#  'G:\\My Drive\\Settlement\\PROVISIONES\\2022\\01. ENERO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones02022022_100930.csv',
#  'G:\\My Drive\\Settlement\\PROVISIONES\\2022\\01. ENERO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones02022022_100826.csv',
#  'G:\\My Drive\\Settlement\\PROVISIONES\\2022\\01. ENERO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones02022022_100736.csv',
#  'G:\\My Drive\\Settlement\\PROVISIONES\\2022\\01. ENERO\\MOVIMIENTOS BANCARIOS AMEX\\GRRCN-Resultados_de_la_búsqueda_de_transacciones02022022_100646.csv']

# %% [markdown]
# # CUENTA POR COBRAR AGREGADOR

# %%
cxc_agg = pd.concat([pd.read_csv(f,skiprows=9,parse_dates=['Fecha de la transacción','Fecha de pago'],dayfirst=True)
                         .assign(file_name=os.path.basename(f)) for f in mov_ban_epa])
cxc_agg['Fecha de la transacción']= pd.to_datetime(cxc_agg['Fecha de la transacción'])
cxc_agg['Fecha de pago']= pd.to_datetime(cxc_agg['Fecha de pago'])
cxc_agg.sort_values(by=['Fecha de la transacción'],inplace=True)
cxc_agg.head()
# Out:
#    Fecha de la transacción Fecha de pago  Número de afiliación del que envía  \
# 0               2022-01-25    2022-01-26                          9351789434
# 26              2022-01-25    2022-01-27                          9351789434
# 25              2022-01-25    2022-01-27                          9351789434
# 24              2022-01-25    2022-01-27                          9351789434
# 23              2022-01-25    2022-01-27                          9351789434
#
#    Monto del cargo  Número de sucursal que envía Número de tarjetahabiente  \
# 0           880.00                           nan           376702XXXXX4004
# 26          393.30                           nan           376718XXXXX2007
# 25        1,000.00                           nan           376718XXXXX8030
# 24        1,908.00                           nan           376702XXXXX2003
# 23        1,000.00                           nan           376701XXXXX2008
#
#     Tipo de ajuste Número de referencia del cargo Tipo de autorización  \
# 0              nan                   S6KNCHLFAJA3                    Y
# 26             nan                   5E8MSKGYKQ3F                    Y
# 25             nan                   CEIV80LQV7XI                    Y
# 24             nan                   BBS4CZH1E2CF                    Y
# 23             nan                   QEWBWEL4OL5F                    Y
#
#     Código de aprobación  Tipo  Número de terminal  \
# 0                    nan  Sale                 nan
# 26                   nan  Sale                 nan
# 25                   nan  Sale                 nan
# 24                   nan  Sale                 nan
# 23                   nan  Sale                 nan
#
#                                             file_name
# 0   EPA-Resultados_de_la_búsqueda_de_transacciones...
# 26  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 25  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 24  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 23  EPA-Resultados_de_la_búsqueda_de_transacciones...

# %%
cxc_agg.shape
# Out:
# (169, 13)

# %%
cxc_agg_final = cxc_agg[((cxc_agg['Fecha de pago'] > finish_date) & (cxc_agg['Fecha de la transacción'] <= finish_date))]
cxc_agg_final.head()
# Out:
#    Fecha de la transacción Fecha de pago  Número de afiliación del que envía  \
# 86              2022-01-28    2022-02-01                          9351789434
# 93              2022-01-28    2022-02-01                          9351789434
# 92              2022-01-28    2022-02-01                          9351789434
# 90              2022-01-28    2022-02-01                          9351789434
# 89              2022-01-28    2022-02-01                          9351789434
#
#    Monto del cargo  Número de sucursal que envía Número de tarjetahabiente  \
# 86          230.00                           nan           370785XXXXX4007
# 93        1,827.00                           nan           371777XXXXX1002
# 92           60.00                           nan           376679XXXXX1024
# 90        1,720.58                           nan           376680XXXXX1007
# 89        1,040.00                           nan           371772XXXXX1011
#
#     Tipo de ajuste Número de referencia del cargo Tipo de autorización  \
# 86             nan                   NV27SJAGZ7VT                    Y
# 93             nan                   LDSD6HX062J6                    Y
# 92             nan                   A8WX4YTUUZEH                    Y
# 90             nan                   KDKSXXJGGH1O                    Y
# 89             nan                   DJ7XVAYRPHXX                    Y
#
#     Código de aprobación  Tipo  Número de terminal  \
# 86                   nan  Sale                 nan
# 93                   nan  Sale                 nan
# 92                   nan  Sale                 nan
# 90                   nan  Sale                 nan
# 89                   nan  Sale                 nan
#
#                                             file_name
# 86  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 93  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 92  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 90  EPA-Resultados_de_la_búsqueda_de_transacciones...
# 89  EPA-Resultados_de_la_búsqueda_de_transacciones...

# %%
cxc_agg_final.shape
# Out:
# (72, 13)

# %% [markdown]
# # CUENTA POR COBRAR OPTBLUE

# %%
cxc_opt = pd.concat([pd.read_csv(f,skiprows=9,parse_dates=['Fecha de la transacción','Fecha de pago'],dayfirst=True)
                         .assign(file_name=os.path.basename(f)) for f in mov_ban_grrcn])
cxc_opt['Fecha de la transacción']= pd.to_datetime(cxc_opt['Fecha de la transacción'])
cxc_opt['Fecha de pago']= pd.to_datetime(cxc_opt['Fecha de pago'])
cxc_opt.sort_values(by=['Fecha de la transacción'],inplace=True)
cxc_opt.head()
# Out:
#      Fecha de la transacción Fecha de pago  \
# 7030              2022-01-25    2022-01-26
# 828               2022-01-25    2022-01-26
# 827               2022-01-25    2022-01-26
# 826               2022-01-25    2022-01-26
# 825               2022-01-25    2022-01-26
#
#       Número de afiliación del que envía Monto del cargo  \
# 7030                          8138464128          200.00
# 828                           8138464136          352.00
# 827                           8138464136          463.00
# 826                           8138464136          124.20
# 825                           8138464136          726.00
#
#       Número de sucursal que envía Número de tarjetahabiente  Tipo de ajuste  \
# 7030                           nan           377238XXXXX4001             nan
# 828                            nan           371774XXXXX1014             nan
# 827                            nan           376663XXXXX3028             nan
# 826                            nan           370789XXXXX1006             nan
# 825                            nan           374908XXXXX4006             nan
#
#      Número de referencia del cargo Tipo de autorización  \
# 7030                   00YWGUZ2OXKW                    Y
# 828                    ET9YUAHZXEYN                    Y
# 827                    G2LFFCMMVSYW                    Y
# 826                    9MRDM7GCIO1J                    Y
# 825                    YXC1UD7VZAKZ                    Y
#
#       Código de aprobación  Tipo  Número de terminal  \
# 7030                   nan  Sale                 nan
# 828                    nan  Sale                 nan
# 827                    nan  Sale                 nan
# 826                    nan  Sale                 nan
# 825                    nan  Sale                 nan
#
#                                               file_name
# 7030  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 828   GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 827   GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 826   GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 825   GRRCN-Resultados_de_la_búsqueda_de_transaccion...

# %%
cxc_opt.shape
# Out:
# (41874, 13)

# %%
cxc_opt_final = cxc_opt[((cxc_opt['Fecha de pago'] > finish_date) & (cxc_opt['Fecha de la transacción'] <= finish_date))]
cxc_opt_final.head()
# Out:
#      Fecha de la transacción Fecha de pago  \
# 5319              2022-01-26    2022-02-02
# 4583              2022-01-28    2022-02-02
# 1055              2022-01-31    2022-02-01
# 1056              2022-01-31    2022-02-01
# 1057              2022-01-31    2022-02-01
#
#       Número de afiliación del que envía Monto del cargo  \
# 5319                          8138464144     (15,800.00)
# 4583                          8138464227     (40,000.00)
# 1055                          8138464227          500.00
# 1056                          8138464227       20,068.83
# 1057                          8138464227        1,740.00
#
#       Número de sucursal que envía Número de tarjetahabiente  Tipo de ajuste  \
# 5319                           nan           376689XXXXX6001             nan
# 4583                           nan           373969XXXXX2000             nan
# 1055                           nan           376718XXXXX2002             nan
# 1056                           nan           376675XXXXX4000             nan
# 1057                           nan           376670XXXXX3006             nan
#
#      Número de referencia del cargo Tipo de autorización  \
# 5319                   HD7EQLZ83K5R                    Y
# 4583                   ASTACWNEG6GN                    Y
# 1055                   BNEOCQQTZU9M                    Y
# 1056                   1MNCJVNXKHO6                    Y
# 1057                   NZL3I65DAXXZ                    Y
#
#       Código de aprobación    Tipo  Número de terminal  \
# 5319                   nan  Credit                 nan
# 4583                   nan  Credit                 nan
# 1055                   nan    Sale                 nan
# 1056                   nan    Sale                 nan
# 1057                   nan    Sale                 nan
#
#                                               file_name
# 5319  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 4583  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 1055  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 1056  GRRCN-Resultados_de_la_búsqueda_de_transaccion...
# 1057  GRRCN-Resultados_de_la_búsqueda_de_transaccion...

# %%
cxc_opt_final.shape
# Out:
# (3835, 13)

# %% [markdown]
# # EXCEL FINAL

# %%
writer = pd.ExcelWriter('CXC AMEX ENERO 2022.xlsx', engine='xlsxwriter', options={'encoding':'utf-8'})   
cxc_agg_final.to_excel(writer, sheet_name='AGREGADOR',index=False)
cxc_opt_final.to_excel(writer, sheet_name='OPTBLUE',index=False)
writer.save()
writer.close()
