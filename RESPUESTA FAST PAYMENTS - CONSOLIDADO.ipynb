# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook
import glob
import os
from datetime import datetime
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # DISPERSIONES

# %% [markdown]
# ### FAST PAYMENTS

# %%
citi = pd.read_excel(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\11. NOVIEMBRE\ARCHIVO DISPERSIONES FP\CITI\Dispersión-FP-CITI 2021-11-04.xlsx'
                     ,sheet_name='FAST PAYMENTS',converters={'report_id':str,'CLABE':str})
citi.head()
# Out:
#                             merchant_id merchant_name  \
# 0  c961dbaa-146f-47e9-affa-dd7759050655      El choro
# 1  e259d63d-d794-4dd5-8c5f-f9d3fcf20866  Sepublicidad
# 2  17d7e9b1-20e3-439e-afa4-c324d436212e  Zafiro Tours
# 3  1a191788-a724-4794-9924-d065f5f0da3f    Maquech JR
# 4  c961dbaa-146f-47e9-affa-dd7759050655      El choro
#
#                             user_email  report_id report_date_local  \
# 0                 nperezvz@hotmail.com  B9PKLTRS3        2021-11-04
# 1              claudia.espa7@gmail.com  LNTZ7N497        2021-11-04
# 2        worldtriptours@zafirotours.mx  P6Z38XZ5B        2021-11-04
# 3  restaurantemaquechpurpura@gmail.com  HY4N9ZQJC        2021-11-04
# 4                 nperezvz@hotmail.com  RWPGWPK3W        2021-11-04
#
#    total_due          tipo             bank                          swap  \
# 0     215.41  Pago del día  ASP INTEGRA OPC            Nereo Perez Valdez
# 1  47,912.00  Pago del día  ASP INTEGRA OPC        Rafael Santos Martinez
# ...

# %%
citi.shape
# Out:
# (5336, 14)

# %%
bnte = pd.read_excel(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\11. NOVIEMBRE\ARCHIVO DISPERSIONES FP\BNTE\Dispersión-FP-BNTE 2021-11-04.xlsx'
                     ,sheet_name='FAST PAYMENTS',converters={'report_id':str,'CLABE':str})
bnte.head()
# Out:
#                             merchant_id                 merchant_name  \
# 0  0044619f-0662-48cd-9718-cdee897d5f7a                      La Jaula
# 1  00b5d112-ca11-4e51-b06d-3ee30193e383             MARIOS PELUQUERIA
# 2  00de9553-90ca-4c12-b7ba-f5e50f15e267  Sonrisas Mx Shows Infantiles
# 3  0176dbba-b669-4432-b4c4-cfee75d88da2                         Bifit
# 4  018323c8-7eb4-4678-bedb-2d3c0bea3868                        NAMATI
#
#                  user_email  report_id report_date_local  total_due  \
# 0  lajaulasoccer5@gmail.com  3FHR9PCY7        2021-11-04   3,066.36
# 1    mariogonz691@gmail.com  7WJFY8K8M        2021-11-04     118.83
# 2  sonrisas.shows@gmail.com  NNGRWJVYS        2021-11-04   2,970.54
# 3  bifitmarketing@gmail.com  SF7375M95        2021-11-04   1,197.80
# 4     tanialeonhz@gmail.com  F6KNS4NSR        2021-11-04      95.82
#
#            tipo             bank                               swap  \
# ...

# %%
bnte.shape
# Out:
# (647, 14)

# %% [markdown]
# ### ERROR

# %%
citi_error = pd.read_excel(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\11. NOVIEMBRE\ARCHIVO DISPERSIONES FP\CITI\Dispersión-FP-CITI 2021-11-04.xlsx'
                     ,sheet_name='ERROR',converters={'report_id':str})
citi_error.head()
# Out:
#                             merchant_id merchant_name  \
# 0  c961dbaa-146f-47e9-affa-dd7759050655      El choro
# 1  e259d63d-d794-4dd5-8c5f-f9d3fcf20866  Sepublicidad
# 2  17d7e9b1-20e3-439e-afa4-c324d436212e  Zafiro Tours
# 3  1a191788-a724-4794-9924-d065f5f0da3f    Maquech JR
# 4  c961dbaa-146f-47e9-affa-dd7759050655      El choro
#
#                             user_email  report_id report_date_local  \
# 0                 nperezvz@hotmail.com  B9PKLTRS3        2021-11-04
# 1              claudia.espa7@gmail.com  LNTZ7N497        2021-11-04
# 2        worldtriptours@zafirotours.mx  P6Z38XZ5B        2021-11-04
# 3  restaurantemaquechpurpura@gmail.com  HY4N9ZQJC        2021-11-04
# 4                 nperezvz@hotmail.com  RWPGWPK3W        2021-11-04
#
#    total_due          tipo             bank   Time          Check  \
# 0     215.41  Pago del día  ASP INTEGRA OPC  09:00  SPEI DEVUELTO
# 1  47,912.00  Pago del día  ASP INTEGRA OPC  14:00  SPEI DEVUELTO
# ...

# %%
citi_error.shape
# Out:
# (18, 11)

# %%
bnte_error = pd.read_excel(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\11. NOVIEMBRE\ARCHIVO DISPERSIONES FP\BNTE\Dispersión-FP-BNTE 2021-11-04.xlsx'
                     ,sheet_name='ERROR',converters={'report_id':str})
bnte_error.head()
# Out:
# Empty DataFrame
# Columns: [merchant_id, merchant_name, user_email, report_id, report_date_local, total_due, tipo, bank, Time]
# Index: []

# %%
bnte_error.shape
# Out:
# (0, 9)

# %% [markdown]
# # CONSOLIDADO FAST PAYMENTS

# %%
fp_all = pd.concat([citi,bnte])
fp_all.sort_values(by=['status','Time'])
fp_all['report_date_local'] = pd.to_datetime(fp_all['report_date_local'])
fp_all.head()
# Out:
#                             merchant_id merchant_name  \
# 0  c961dbaa-146f-47e9-affa-dd7759050655      El choro
# 1  e259d63d-d794-4dd5-8c5f-f9d3fcf20866  Sepublicidad
# 2  17d7e9b1-20e3-439e-afa4-c324d436212e  Zafiro Tours
# 3  1a191788-a724-4794-9924-d065f5f0da3f    Maquech JR
# 4  c961dbaa-146f-47e9-affa-dd7759050655      El choro
#
#                             user_email  report_id report_date_local  \
# 0                 nperezvz@hotmail.com  B9PKLTRS3        2021-11-04
# 1              claudia.espa7@gmail.com  LNTZ7N497        2021-11-04
# 2        worldtriptours@zafirotours.mx  P6Z38XZ5B        2021-11-04
# 3  restaurantemaquechpurpura@gmail.com  HY4N9ZQJC        2021-11-04
# 4                 nperezvz@hotmail.com  RWPGWPK3W        2021-11-04
#
#    total_due          tipo             bank                          swap  \
# 0     215.41  Pago del día  ASP INTEGRA OPC            Nereo Perez Valdez
# 1  47,912.00  Pago del día  ASP INTEGRA OPC        Rafael Santos Martinez
# ...

# %%
fp_all.shape
# Out:
# (5983, 14)

# %% [markdown]
# # CONSOLIDADO ERROR

# %%
error_all = pd.concat([citi_error,bnte_error])
error_all.sort_values(by=['Time'])
error_all['report_date_local'] = pd.to_datetime(error_all['report_date_local'])
error_all.head()
# Out:
#                             merchant_id merchant_name  \
# 0  c961dbaa-146f-47e9-affa-dd7759050655      El choro
# 1  e259d63d-d794-4dd5-8c5f-f9d3fcf20866  Sepublicidad
# 2  17d7e9b1-20e3-439e-afa4-c324d436212e  Zafiro Tours
# 3  1a191788-a724-4794-9924-d065f5f0da3f    Maquech JR
# 4  c961dbaa-146f-47e9-affa-dd7759050655      El choro
#
#                             user_email  report_id report_date_local  \
# 0                 nperezvz@hotmail.com  B9PKLTRS3        2021-11-04
# 1              claudia.espa7@gmail.com  LNTZ7N497        2021-11-04
# 2        worldtriptours@zafirotours.mx  P6Z38XZ5B        2021-11-04
# 3  restaurantemaquechpurpura@gmail.com  HY4N9ZQJC        2021-11-04
# 4                 nperezvz@hotmail.com  RWPGWPK3W        2021-11-04
#
#    total_due          tipo             bank   Time          Check  \
# 0     215.41  Pago del día  ASP INTEGRA OPC  09:00  SPEI DEVUELTO
# 1  47,912.00  Pago del día  ASP INTEGRA OPC  14:00  SPEI DEVUELTO
# ...

# %%
error_all.shape
# Out:
# (18, 11)

# %% [markdown]
# # ARCHIVOS FINALES

# %% [markdown]
# ### ARCHIVO DISPERSION

# %%
writer = pd.ExcelWriter(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2021\11. NOVIEMBRE\ARCHIVO DISPERSIONES FP\Dispersión-FP 2021-11-04.xlsx', engine='xlsxwriter', options={'encoding':'utf-8'})
fp_all.to_excel(writer, sheet_name='FAST PAYMENTS',index=False)
error_all.to_excel(writer, sheet_name='ERROR',index=False)
writer.save()
writer.close()
