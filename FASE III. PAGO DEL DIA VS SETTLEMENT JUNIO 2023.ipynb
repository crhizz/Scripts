# %%
import pandas as pd
import numpy as np
import glob
import os
from openpyxl import load_workbook
from functools import reduce
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# #### ACUMULADO

# %%
cumfiles = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2023\06. JUNIO\QUERIES\*.csv', recursive=False)
cumfiles
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-01.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-02.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-03.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-04.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-05.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-06.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-07.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-08.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-09.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-10.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-11.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-12.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-13.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-14.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-15.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-16.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-17.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-18.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-19.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-20.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-21.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-22.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-23.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-24.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-25.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-26.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-27.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-28.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-29.csv',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\QUERIES\\SETTLEMENT 2023-06-30.csv']

# %%
cum_1 = pd.concat([pd.read_csv(f).assign(file_name=os.path.basename(f)) for f in cumfiles])
cum_1.columns = cum_1.columns.str.strip().str.lower() 
cum_1['report_date_local']= pd.to_datetime(cum_1['report_date_local']) 
cum_1.head()
# Out:
#                             merchant_id            merchant_name  \
# 0  25c21503-2be4-408c-a36d-6f600c20779b          SIEMPRE CONTIGO
# 1  80e833d7-f2b7-4287-8f73-a0ce262fc691  EVENTOS MESA DIRECTIVA
# 2  5ed3cbc3-eabc-401c-99fd-72120bd17790                TRASPORTE
# 3  a765c180-1a7d-4a4e-9aff-b6d776d2525c    TRANSPORTES VELAZQUEZ
# 4  f51bab5b-ee99-403a-b6da-49116e4b3707               INFLADEPOT
#
#                       user_email  report_id report_date_local  \
# 0        mejiaporras@hotmail.com  GP6JLMT4Q        2023-06-01
# 1       laurachavezmtz@gmail.com  PHYPS55WJ        2023-06-01
# 2        juarezosiel28@gmail.com  V68KNGMSH        2023-06-01
# 3        benitoedu777x@gmail.com  DK5G262B7        2023-06-01
# 4  jorge.pichardo@infladepot.com  554NQF3H7        2023-06-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  total_released  total_retained  tipopago  \
# 0                    0.00  ...       10,540.64            0.00       NaN
# 1                    0.00  ...        1,868.58            0.00       NaN
# 2                    0.00  ...       17,248.32            0.00       NaN
# 3                    0.00  ...          431.21            0.00       NaN
# 4                    0.00  ...       54,205.63            0.00       NaN
#
#    total_due   type  created_date  created_time  updated_date  updated_time  \
# 0  10,540.64  DAILY    2023-06-01      03:02:47    2023-06-01      03:02:47
# 1   1,868.58  DAILY    2023-06-01      03:05:43    2023-06-01      03:05:43
# 2  17,248.32  DAILY    2023-06-01      03:07:46    2023-06-01      03:07:46
# 3     431.21  DAILY    2023-06-01      03:09:39    2023-06-01      03:09:39
# 4  54,205.63  DAILY    2023-06-01      03:09:46    2023-06-01      03:09:46
#
#                    file_name
# 0  SETTLEMENT 2023-06-01.csv
# 1  SETTLEMENT 2023-06-01.csv
# 2  SETTLEMENT 2023-06-01.csv
# 3  SETTLEMENT 2023-06-01.csv
# 4  SETTLEMENT 2023-06-01.csv
#
# [5 rows x 26 columns]

# %%
cum_1.shape
# Out:
# (371, 26)

# %%
cum_distinct_0 = cum_1[(cum_1['total_due'] != 0)]
cum_distinct_0.head()
# Out:
#                             merchant_id            merchant_name  \
# 0  25c21503-2be4-408c-a36d-6f600c20779b          SIEMPRE CONTIGO
# 1  80e833d7-f2b7-4287-8f73-a0ce262fc691  EVENTOS MESA DIRECTIVA
# 2  5ed3cbc3-eabc-401c-99fd-72120bd17790                TRASPORTE
# 3  a765c180-1a7d-4a4e-9aff-b6d776d2525c    TRANSPORTES VELAZQUEZ
# 4  f51bab5b-ee99-403a-b6da-49116e4b3707               INFLADEPOT
#
#                       user_email  report_id report_date_local  \
# 0        mejiaporras@hotmail.com  GP6JLMT4Q        2023-06-01
# 1       laurachavezmtz@gmail.com  PHYPS55WJ        2023-06-01
# 2        juarezosiel28@gmail.com  V68KNGMSH        2023-06-01
# 3        benitoedu777x@gmail.com  DK5G262B7        2023-06-01
# 4  jorge.pichardo@infladepot.com  554NQF3H7        2023-06-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  total_released  total_retained  tipopago  \
# 0                    0.00  ...       10,540.64            0.00       NaN
# 1                    0.00  ...        1,868.58            0.00       NaN
# 2                    0.00  ...       17,248.32            0.00       NaN
# 3                    0.00  ...          431.21            0.00       NaN
# 4                    0.00  ...       54,205.63            0.00       NaN
#
#    total_due   type  created_date  created_time  updated_date  updated_time  \
# 0  10,540.64  DAILY    2023-06-01      03:02:47    2023-06-01      03:02:47
# 1   1,868.58  DAILY    2023-06-01      03:05:43    2023-06-01      03:05:43
# 2  17,248.32  DAILY    2023-06-01      03:07:46    2023-06-01      03:07:46
# 3     431.21  DAILY    2023-06-01      03:09:39    2023-06-01      03:09:39
# 4  54,205.63  DAILY    2023-06-01      03:09:46    2023-06-01      03:09:46
#
#                    file_name
# 0  SETTLEMENT 2023-06-01.csv
# 1  SETTLEMENT 2023-06-01.csv
# 2  SETTLEMENT 2023-06-01.csv
# 3  SETTLEMENT 2023-06-01.csv
# 4  SETTLEMENT 2023-06-01.csv
#
# [5 rows x 26 columns]

# %%
cum_distinct_0.shape
# Out:
# (368, 26)

# %% [markdown]
# #### PAGOS DE DISPERSIONES

# %%
pagos_dia_files_1 = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\DISPERSIONES\2023\06. JUNIO\ARCHIVO DISPERSIONES\Dispersión*.xlsx', recursive=False)
pagos_dia_files_1
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230601.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230602.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230603.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230604.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230605.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230606.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230607.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230608.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230609.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230610.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230611.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230612.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230613.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230614.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230615.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230616.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230617.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230618.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230619.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230620.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230621.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230622.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230623.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230624.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230625.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230626.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230627.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230628.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230629.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\DISPERSIONES\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES\\Dispersión-20230630.xlsx']

# %%
pagos_1 = pd.concat([pd.read_excel(f,sheet_name='Swap del día').assign(file_name=os.path.basename(f)) for f in pagos_dia_files_1])
pagos_1['date_file'] = pagos_1["file_name"].str[-13:-5]
pagos_1['date_file']= pd.to_datetime(pagos_1['date_file'], format='%Y%m%d').dt.date
pagos_1['date_file']= pd.to_datetime(pagos_1['date_file'])
pagos_1.sort_values(by=['date_file'],ascending=True,inplace=True)
pagos_1['report_date_local']= pd.to_datetime(pagos_1['report_date_local']) 
pagos_1.head()
# Out:
#               type                           merchant_id merchant_name  \
# 0      LEDGER_TRAD  06b7e332-184e-4ca8-a6f1-65e6a2ee6673           NaN
# 68992  LEDGER_TRAD  b9dce823-4bbb-4ace-a77e-61d59c5f3ac9           NaN
# 68991  LEDGER_TRAD  b9dcd6e3-9823-479b-a95e-feb41928f022           NaN
# 68990  LEDGER_TRAD  b9dcd593-4a49-442f-9ff1-299fdf76019b           NaN
# 68989  LEDGER_TRAD  b9dc80e6-dad1-404a-8775-505b3e085482           NaN
#
#       user_email  report_id report_date_local  total_due          tipo  \
# 0            NaN  AFS9LJT74        2023-06-01     643.94  Pago del día
# 68992        NaN  ANYPLKH8L        2023-06-01     301.85  Pago del día
# 68991        NaN  AKW3NJVTF        2023-06-01     141.34  Pago del día
# 68990        NaN  ATX6M59TG        2023-06-01     896.18  Pago del día
# 68989        NaN  AVLX8TD9K        2023-06-01     366.05  Pago del día
#
#                 bank        bank_account_owner_name               CLABE  \
# 0      BBVA BANCOMER  Jorge Isaac Medrano Gutierrez  012323004549589931
# 68992      BANCOPPEL     Jos Luis Salinas Contreras  137420102685122042
# 68991         AZTECA     Pedro Yeudiel Olea Morales  127840013643255724
00:00:00.000000000', '2022-01-20T00:00:00.000000000',
#        '2021-02-15T00:00:00.000000000', '2021-02-27T00:00:00.000000000',
#        '2023-06-19T00:00:00.000000000', '2023-06-20T00:00:00.000000000',
#        '2021-12-11T00:00:00.000000000', '2021-10-12T00:00:00.000000000',
#        '2021-10-15T00:00:00.000000000', '2023-06-21T00:00:00.000000000',
#        '2021-10-30T00:00:00.000000000', '2019-12-24T00:00:00.000000000',
#        '2021-03-21T00:00:00.000000000', '2021-12-15T00:00:00.000000000',
#        '2023-06-22T00:00:00.000000000', '2019-09-02T00:00:00.000000000',
#        '2019-06-13T00:00:00.000000000', '2020-02-04T00:00:00.000000000',
#        '2021-04-13T00:00:00.000000000', '2021-06-15T00:00:00.000000000',
#        '2020-09-01T00:00:00.000000000', '2021-01-24T00:00:00.000000000',
#        '2023-06-23T00:00:00.000000000', '2023-06-24T00:00:00.000000000',
#        '2021-11-13T00:00:00.000000000', '2021-10-17T00:00:00.000000000',
#        '2021-10-11T00:00:00.000000000', '2021-11-12T00:00:00.000000000',
#        '2021-11-11T00:00:00.000000000', '2021-11-14T00:00:00.000000000',
#        '2023-06-25T00:00:00.000000000', '2022-04-05T00:00:00.000000000',
#        '2019-01-18T00:00:00.000000000', '2019-11-22T00:00:00.000000000',
#        '2022-12-06T00:00:00.000000000', '2023-06-26T00:00:00.000000000',
#        '2020-11-25T00:00:00.000000000', '2020-11-27T00:00:00.000000000',
#        '2022-01-09T00:00:00.000000000', '2022-01-07T00:00:00.000000000',
#        '2021-08-30T00:00:00.000000000', '2022-01-06T00:00:00.000000000',
#        '2023-06-27T00:00:00.000000000', '2022-01-25T00:00:00.000000000',
#        '2021-12-07T00:00:00.000000000', '2021-06-29T00:00:00.000000000',
#        '2021-06-30T00:00:00.000000000', '2023-06-28T00:00:00.000000000',
#        '2021-12-14T00:00:00.000000000', '2020-12-22T00:00:00.000000000',
#        '2022-08-23T00:00:00.000000000', '2022-01-19T00:00:00.000000000',
#        '2021-12-21T00:00:00.000000000', '2021-08-29T00:00:00.000000000',
#        '2019-08-08T00:00:00.000000000', '2020-06-28T00:00:00.000000000',
#        '2023-06-29T00:00:00.000000000', '2022-04-12T00:00:00.000000000',
#        '2023-06-30T00:00:00.000000000', '2021-12-02T00:00:00.000000000',
#        '2021-06-21T00:00:00.000000000', '2021-02-20T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %% [markdown]
# #### PAGOS DUPLICADOS TRADICIONAL

# %%
duplicates_trad = pagos_1[pagos_1.duplicated(['report_id','date_file'] , keep=False)]
duplicates_trad['INDEX'] = duplicates_trad['report_id'] + '_' + duplicates_trad['date_file'].astype('str')
duplicates_trad.sort_values(by=['date_file','report_id'],inplace=True)
duplicates_trad.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\1112391532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_trad['INDEX'] = duplicates_trad['report_id'] + '_' + duplicates_trad['date_file'].astype('str')
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\1112391532.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_trad.sort_values(by=['date_file','report_id'],inplace=True)
#               type                           merchant_id merchant_name  \
# 2      LEDGER_TRAD  091c324e-3a1c-4642-8532-57b7024b9a98           NaN
# 112    LEDGER_TRAD  091c324e-3a1c-4642-8532-57b7024b9a98           NaN
# 100    LEDGER_TRAD  b5232601-cef0-462a-b1a3-f9b865c810e5           NaN
# 128    LEDGER_TRAD  b5232601-cef0-462a-b1a3-f9b865c810e5           NaN
# 74857  LEDGER_TRAD  501a2b00-fe0b-4b1b-9383-5404ccd6d23e           NaN
#
#       user_email  report_id report_date_local  total_due          tipo  \
# 2            NaN  AHGMS8DV7        2023-06-01  33,538.40  Pago del día
# 112          NaN  AHGMS8DV7        2023-06-01  33,538.40  Pago del día
# 100          NaN  A52PLLG65        2023-06-02   2,025.77  Pago del día
# 128          NaN  A52PLLG65        2023-06-02   2,025.77  Pago del día
# 74857        NaN  A5XYW97F9        2023-06-05  28,457.81  Pago del día
#
#                 bank           bank_account_owner_name               CLABE  \
# 2             AZTECA     DAVID ANTONIO ORTEGA MARTINEZ  127180016112515034
# 112           AZTECA     DAVID ANTONIO ORTEGA MARTINEZ  127180016112515034
# 100             HSBC                      Marco Curiel  021650065872584306
# 128             HSBC                      Marco Curiel  021650065872584306
# 74857  BBVA BANCOMER  Arturo Gamaliel Morales Portillo  012180015552328777
#
#       status                                          LINEA CEP  \
# 2      ERROR                                                NaN
# 112    ERROR                                                NaN
# 100    ERROR                                                NaN
# 128    ERROR                                                NaN
# 74857   PAID  2023-06-05,42644264202306052333293792,40072,40...
#
#              Batch_time Banco_emisor                 file_name  date_file  \
# 2       01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01
# 112     03. Third_batch      BANORTE  Dispersión-20230601.xlsx 2023-06-01
# 100     01. First_batch    SANTANDER  Dispersión-20230602.xlsx 2023-06-02
# 128     03. Third_batch      BANORTE  Dispersión-20230602.xlsx 2023-06-02
# 74857  02. Second_batch      BANORTE  Dispersión-20230605.xlsx 2023-06-05
#
#                       INDEX
# 2      AHGMS8DV7_2023-06-01
# 112    AHGMS8DV7_2023-06-01
# 100    A52PLLG65_2023-06-02
# 128    A52PLLG65_2023-06-02
# 74857  A5XYW97F9_2023-06-05

# %%
duplicates_trad.shape
# Out:
# (4462, 18)

# %%
duplicates_trad['status'].unique()
# Out:
# array(['ERROR', 'PAID'], dtype=object)

# %%
duplicates_trad.drop_duplicates(subset="INDEX", keep='last', inplace=True)
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\494774456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_trad.drop_duplicates(subset="INDEX", keep='last', inplace=True)

# %%
duplicates_trad.head()
# Out:
#               type                           merchant_id merchant_name  \
# 112    LEDGER_TRAD  091c324e-3a1c-4642-8532-57b7024b9a98           NaN
# 128    LEDGER_TRAD  b5232601-cef0-462a-b1a3-f9b865c810e5           NaN
# 23648  LEDGER_TRAD  501a2b00-fe0b-4b1b-9383-5404ccd6d23e           NaN
# 88     LEDGER_TRAD  297eacc7-3685-48c3-9ab4-92089c5b2cf9           NaN
# 1267   LEDGER_TRAD  03361c45-1f67-4dba-bbb0-d6f30a225326           NaN
#
#       user_email  report_id report_date_local  total_due          tipo  \
# 112          NaN  AHGMS8DV7        2023-06-01  33,538.40  Pago del día
# 128          NaN  A52PLLG65        2023-06-02   2,025.77  Pago del día
# 23648        NaN  A5XYW97F9        2023-06-05  28,457.81  Pago del día
# 88           NaN  AKVJM3RNH        2023-06-05   3,842.54  Pago del día
# 1267         NaN  A22JZYQVB        2023-06-06   1,092.41  Pago del día
#
#                 bank           bank_account_owner_name               CLABE  \
# 112           AZTECA     DAVID ANTONIO ORTEGA MARTINEZ  127180016112515034
# 128             HSBC                      Marco Curiel  021650065872584306
# 23648  BBVA BANCOMER  Arturo Gamaliel Morales Portillo  012180015552328777
# 88            AZTECA            1271 8001 3774 9571 14  127180013774957114
# 1267         BANAMEX                       Ana espejel    2180701617518966
#
#       status                                          LINEA CEP  \
# 112    ERROR                                                NaN
# 128    ERROR                                                NaN
# 23648   PAID  2023-06-05,nan,40014,40012,012180015552328777,...
# 88     ERROR                                                NaN
# 1267    PAID  2023-06-06,nan,40014,40002,002180701617518966,...
#
#              Batch_time Banco_emisor                 file_name  date_file  \
# 112     03. Third_batch      BANORTE  Dispersión-20230601.xlsx 2023-06-01
# 128     03. Third_batch      BANORTE  Dispersión-20230602.xlsx 2023-06-02
# 23648   01. First_batch    SANTANDER  Dispersión-20230605.xlsx 2023-06-05
# 88     02. Second_batch      BANORTE  Dispersión-20230605.xlsx 2023-06-05
# 1267    01. First_batch    SANTANDER  Dispersión-20230606.xlsx 2023-06-06
#
#                       INDEX
# 112    AHGMS8DV7_2023-06-01
# 128    A52PLLG65_2023-06-02
# 23648  A5XYW97F9_2023-06-05
# 88     AKVJM3RNH_2023-06-05
# 1267   A22JZYQVB_2023-06-06

# %%
duplicates_trad.shape
# Out:
# (2231, 18)

# %%
pivot_duplicates_trad = pd.pivot_table(duplicates_trad,index=['tipo','date_file'],
                                       columns=['type'],
                                  values=['total_due']
                                  ,aggfunc = ['sum', len],margins=True)
pivot_duplicates_trad.reset_index(drop=False, inplace=True)
pivot_duplicates_trad.head(10)
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\1526277087.py:5: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_duplicates_trad.reset_index(drop=False, inplace=True)
#               tipo  date_file       sum                                 len  \
#                               total_due                           total_due
# type                              DAILY  LEDGER_TRAD          All     DAILY
# 0     Pago del día 2023-06-01       NaN    33,538.40    33,538.40       NaN
# 1     Pago del día 2023-06-02       NaN     2,025.77     2,025.77       NaN
# 2     Pago del día 2023-06-05       NaN    32,300.35    32,300.35       NaN
# 3     Pago del día 2023-06-06       NaN 2,162,842.63 2,162,842.63       NaN
# 4     Pago del día 2023-06-07       NaN 2,331,017.15 2,331,017.15       NaN
# 5     Pago del día 2023-06-09       NaN     6,570.66     6,570.66       NaN
# 6     Pago del día 2023-06-12       NaN    49,825.01    49,825.01       NaN
# 7     Pago del día 2023-06-13       NaN    23,913.12    23,913.12       NaN
# 8     Pago del día 2023-06-14       NaN    22,039.52    22,039.52       NaN
# 9     Pago del día 2023-06-15       NaN     3,269.11     3,269.11       NaN
#
#
#
# type LEDGER_TRAD   All
# 0           1.00     1
# 1           1.00     1
# 2           2.00     2
# 3       1,057.00  1057
# 4       1,109.00  1109
# 5           1.00     1
# 6           4.00     4
# 7           2.00     2
# 8           2.00     2
# 9           1.00     1

# %%
pivot_duplicates_trad.shape
# Out:
# (23, 8)

# %% [markdown]
# #### FAST PAYMENTS

# %%
fp_files_1 = glob.glob(r'C:\Users\Cristian.Aparicio\Documents\FAST PAYMENTS\2023\06. JUNIO\ARCHIVO DISPERSIONES FP\Dispersión-FP*.xlsx', recursive=False)
fp_files_1
# Out:
# ['C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-01.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-02.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-03.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-04.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-05.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-06.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-07.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-08.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-09.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-10.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-11.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-12.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-13.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-14.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-15.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-16.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-17.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-18.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-19.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-20.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-21.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-22.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-23.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-24.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-25.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-26.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-27.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-28.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-29.xlsx',
#  'C:\\Users\\Cristian.Aparicio\\Documents\\FAST PAYMENTS\\2023\\06. JUNIO\\ARCHIVO DISPERSIONES FP\\Dispersión-FP 2023-06-30.xlsx']

# %%
pagos_2 = pd.concat([pd.read_excel(f,sheet_name='FAST PAYMENTS').assign(file_name=os.path.basename(f)) for f in fp_files_1])
pagos_2['date_file'] = pagos_2["file_name"].str[-15:-4]
pagos_2['date_file']= pd.to_datetime(pagos_2['date_file']) 
pagos_2.sort_values(by=['date_file'],ascending=True,inplace=True)
pagos_2['report_date_local']= pd.to_datetime(pagos_2['report_date_local']) 
pagos_2.head()
# Out:
#            type                           merchant_id merchant_name  \
# 0     LEDGER_FP  230ad53e-5fa1-4950-bd96-4f0b453d8598           NaN
# 3055  LEDGER_FP  2b2403bf-0bc7-47d7-8d98-645077ff7d63           NaN
# 3056  LEDGER_FP  2b506a9c-1e2e-4d3b-88e5-de9d8bdd3ff3           NaN
# 3057  LEDGER_FP  2c38069e-1474-48c7-8be8-725dc6fe0ce5           NaN
# 3058  LEDGER_FP  2c440293-c5b1-4931-b5cd-acf8e7a3632a           NaN
#
#      user_email  report_id report_date_local  total_due            tipo  \
# 0           NaN  ASJFX785Z        2023-05-17     595.51  Reprogramación
# 3055        NaN  A4FZNTJVC        2023-06-01     196.54    Pago del día
# 3056        NaN  ANB4J4DNR        2023-06-01     133.67    Pago del día
# 3057        NaN  ALLNV7YC9        2023-06-01     119.78    Pago del día
# 3058        NaN  AB94S82SY        2023-06-01     539.49    Pago del día
#
#                  bank                              swap               CLABE  \
# 0            BANREGIO        Eduardo Isabel Guerra Cruz  058597000011200862
# 3055  ASP INTEGRA OPC           Hilaria Salas Fernandez  659802020000349125
# 3056           AZTECA   Betsaida Jazmin Serrano Negrete  127320013547328604
# 3057  ASP INTEGRA OPC  Oscar Armando Lopez De Labastida  659802020000184212
# 3058  ASP INTEGRA OPC  Angelica Yuriel Tellez Hernandez  659802020000436960
#
#      status                                          LINEA CEP  \
# 0     ERROR                                                NaN
# 3055   PAID  2023-06-01,188798467B6B11A5,40002,90659,659802...
# 3056   PAID  2023-06-01,188798473DBB8FDE,40002,40127,127320...
# 3057   PAID  2023-06-01,188798484169EC1D,40002,90659,659802...
# 3058   PAID  2023-06-01,1887984840B0A55E,40002,90659,659802...
#
#             Batch_time Banco_emisor                      file_name  date_file
# 0     02. Second_batch    SANTANDER  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 3055   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 3056   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 3057   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 3058   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01

# %%
pagos_2.shape
# Out:
# (107453, 17)

# %% [markdown]
# #### PAGOS REPETIDOS FAST PAYMENTS

# %%
duplicates_fp = pagos_2[pagos_2.duplicated(['report_id','date_file'] , keep=False)]
duplicates_fp['INDEX'] = duplicates_fp['report_id'] + '_' + duplicates_fp['date_file'].astype('str')
duplicates_fp.sort_values(by=['date_file','report_id','Batch_time'],inplace=True)
duplicates_fp.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\3928666323.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_fp['INDEX'] = duplicates_fp['report_id'] + '_' + duplicates_fp['date_file'].astype('str')
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\3928666323.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_fp.sort_values(by=['date_file','report_id','Batch_time'],inplace=True)
#           type                           merchant_id merchant_name user_email  \
# 3    LEDGER_FP  230ad53e-5fa1-4950-bd96-4f0b453d8598           NaN        NaN
# 78   LEDGER_FP  230ad53e-5fa1-4950-bd96-4f0b453d8598           NaN        NaN
# 106  LEDGER_FP  a52a362a-a71b-4c32-8ebf-63d9d729cda3           NaN        NaN
# 130  LEDGER_FP  a52a362a-a71b-4c32-8ebf-63d9d729cda3           NaN        NaN
# 18   LEDGER_FP  ff8f3a93-ab04-4e3c-b672-4e210afe844e           NaN        NaN
#
#      report_id report_date_local  total_due            tipo             bank  \
# 3    A42N4CPPZ        2023-05-27   1,209.29  Reprogramación         BANREGIO
# 78   A42N4CPPZ        2023-05-27   1,209.29  Reprogramación         BANREGIO
# 106  ABL2V8G2W        2023-06-01     340.47    Pago del día             HSBC
# 130  ABL2V8G2W        2023-06-01     340.47    Pago del día             HSBC
# 18   AM9DJ2YSX        2023-04-04  24,905.58  Reprogramación  ASP INTEGRA OPC
#
#                               swap               CLABE status LINEA CEP  \
# 3       Eduardo Isabel Guerra Cruz  058597000011200862  ERROR       NaN
# 78      Eduardo Isabel Guerra Cruz  058597000011200862  ERROR       NaN
# 106                   Jesus Takeda  021180065853204971  ERROR       NaN
# 130                   Jesus Takeda  021180065853204971  ERROR       NaN
# 18   Daniela Yessenia Cruz Herbert  659802020000088648  ERROR       NaN
#
#            Batch_time Banco_emisor                      file_name  date_file  \
# 3    02. Second_batch    SANTANDER  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 78    05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 106   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 130   06. Sixth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 18   02. Second_batch    SANTANDER  Dispersión-FP 2023-06-01.xlsx 2023-06-01
#
#                     INDEX
# 3    A42N4CPPZ_2023-06-01
# 78   A42N4CPPZ_2023-06-01
# 106  ABL2V8G2W_2023-06-01
# 130  ABL2V8G2W_2023-06-01
# 18   AM9DJ2YSX_2023-06-01

# %%
duplicates_fp.shape
# Out:
# (1547, 18)

# %%
duplicates_fp.drop_duplicates(subset="INDEX", keep='last', inplace=True)
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\2218390481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_fp.drop_duplicates(subset="INDEX", keep='last', inplace=True)

# %%
duplicates_fp.head()
# Out:
#           type                           merchant_id merchant_name user_email  \
# 78   LEDGER_FP  230ad53e-5fa1-4950-bd96-4f0b453d8598           NaN        NaN
# 130  LEDGER_FP  a52a362a-a71b-4c32-8ebf-63d9d729cda3           NaN        NaN
# 123  LEDGER_FP  ff8f3a93-ab04-4e3c-b672-4e210afe844e           NaN        NaN
# 79   LEDGER_FP  230ad53e-5fa1-4950-bd96-4f0b453d8598           NaN        NaN
# 77   LEDGER_FP  230ad53e-5fa1-4950-bd96-4f0b453d8598           NaN        NaN
#
#      report_id report_date_local  total_due            tipo             bank  \
# 78   A42N4CPPZ        2023-05-27   1,209.29  Reprogramación         BANREGIO
# 130  ABL2V8G2W        2023-06-01     340.47    Pago del día             HSBC
# 123  AM9DJ2YSX        2023-04-04  24,905.58  Reprogramación  ASP INTEGRA OPC
# 79   AQJNNSRS4        2023-05-28   1,800.05  Reprogramación         BANREGIO
# 77   ASBXDGB92        2023-05-20   1,868.56  Reprogramación         BANREGIO
#
#                               swap               CLABE status LINEA CEP  \
# 78      Eduardo Isabel Guerra Cruz  058597000011200862  ERROR       NaN
# 130                   Jesus Takeda  021180065853204971  ERROR       NaN
# 123  Daniela Yessenia Cruz Herbert  659802020000088648  ERROR       NaN
# 79      Eduardo Isabel Guerra Cruz  058597000011200862  ERROR       NaN
# 77      Eduardo Isabel Guerra Cruz  058597000011200862  ERROR       NaN
#
#           Batch_time Banco_emisor                      file_name  date_file  \
# 78   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 130  06. Sixth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 123  05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 79   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
# 77   05. Fifth_batch      BANAMEX  Dispersión-FP 2023-06-01.xlsx 2023-06-01
#
#                     INDEX
# 78   A42N4CPPZ_2023-06-01
# 130  ABL2V8G2W_2023-06-01
# 123  AM9DJ2YSX_2023-06-01
# 79   AQJNNSRS4_2023-06-01
# 77   ASBXDGB92_2023-06-01

# %%
duplicates_fp.shape
# Out:
# (758, 18)

# %%
pivot_duplicates_fp = pd.pivot_table(duplicates_fp,index=['tipo','date_file'],
                                     columns=['type'],
                                  values=['total_due']
                                  ,aggfunc = ['sum', len],margins=True)
pivot_duplicates_fp.reset_index(drop=False, inplace=True)
pivot_duplicates_fp.head()
# Out:
# C:\Users\Cristian.Aparicio\AppData\Local\Temp\ipykernel_19884\2330838624.py:5: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pivot_duplicates_fp.reset_index(drop=False, inplace=True)
#               tipo  date_file       sum                           len  \
#                               total_due                     total_due
# type                            INSTANT LEDGER_FP       All   INSTANT
# 0     Pago del día 2023-06-01       NaN    340.47    340.47       NaN
# 1     Pago del día 2023-06-03       NaN 59,396.28 59,396.28       NaN
# 2     Pago del día 2023-06-04       NaN 71,060.91 71,060.91       NaN
# 3     Pago del día 2023-06-06       NaN  1,504.44  1,504.44       NaN
# 4     Pago del día 2023-06-07       NaN 22,258.56 22,258.56       NaN
#
#
#
# type LEDGER_FP All
# 0         1.00   1
# 1         9.00   9
# 2         3.00   3
# 3         4.00   4
# 4         9.00   9

# %%
pivot_duplicates_fp.shape
# Out:
# (43, 8)

# %%
# pivot_duplicates_fp.to_excel('DUPLICADOS FP JUNIO 2021.xlsx',index=True)

# %% [markdown]
# #### ALL PAGOS

# %%
allpagos = pd.concat([pagos_1,pagos_2])
allpagos.head()
# Out:
#               type                           merchant_id merchant_name  \
# 0      LEDGER_TRAD  06b7e332-184e-4ca8-a6f1-65e6a2ee6673           NaN
# 68992  LEDGER_TRAD  b9dce823-4bbb-4ace-a77e-61d59c5f3ac9           NaN
# 68991  LEDGER_TRAD  b9dcd6e3-9823-479b-a95e-feb41928f022           NaN
# 68990  LEDGER_TRAD  b9dcd593-4a49-442f-9ff1-299fdf76019b           NaN
# 68989  LEDGER_TRAD  b9dc80e6-dad1-404a-8775-505b3e085482           NaN
#
#       user_email  report_id report_date_local  total_due          tipo  \
# 0            NaN  AFS9LJT74        2023-06-01     643.94  Pago del día
# 68992        NaN  ANYPLKH8L        2023-06-01     301.85  Pago del día
# 68991        NaN  AKW3NJVTF        2023-06-01     141.34  Pago del día
# 68990        NaN  ATX6M59TG        2023-06-01     896.18  Pago del día
# 68989        NaN  AVLX8TD9K        2023-06-01     366.05  Pago del día
#
#                 bank        bank_account_owner_name               CLABE  \
# 0      BBVA BANCOMER  Jorge Isaac Medrano Gutierrez  012323004549589931
# 68992      BANCOPPEL     Jos Luis Salinas Contreras  137420102685122042
# 68991         AZTECA     Pedro Yeudiel Olea Morales  127840013643255724
# 68990        INBURSA        Bryan Nael Ruiz Marquez  036010500533566232
# 68989  BBVA BANCOMER       Sandra Hernandez Luviano  012225015585784463
#
#       status                                          LINEA CEP  \
# 0      ERROR                                                NaN
# 68992   PAID  2023-06-01,20230601400140HDH0001440449050,4001...
# 68991   PAID  2023-06-01,20230601400140HDH0001440448980,4001...
# 68990   PAID  2023-06-01,20230601400140HDH0001440448890,4001...
# 68989   PAID  2023-06-01,20230601400140HDH0001440448810,4001...
#
#             Batch_time Banco_emisor                 file_name  date_file swap
# 0      01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68992  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68991  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68990  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68989  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN

# %%
allpagos.shape
# Out:
# (3043940, 18)

# %%
allpagos['tipo'].unique()
# Out:
# array(['Pago del día', 'Reprogramación'], dtype=object)

# %%
group_allpagos = allpagos.groupby(['date_file']).agg({'total_due':sum,'report_id':'count'}).reset_index()
group_allpagos.head()
# Out:
#    date_file      total_due  report_id
# 0 2023-06-01 216,743,711.40     108074
# 1 2023-06-02 220,549,223.36     110607
# 2 2023-06-03 248,709,205.05     114756
# 3 2023-06-04 264,572,732.29     111087
# 4 2023-06-05 187,821,084.55      78422

# %%
group_allpagos.shape
# Out:
# (30, 3)

# %% [markdown]
# #### PAGOS DEL DIA

# %%
pagosdia = allpagos[(allpagos['tipo'].isin(['Pago del día']))]
pagosdia.head()
# Out:
#               type                           merchant_id merchant_name  \
# 0      LEDGER_TRAD  06b7e332-184e-4ca8-a6f1-65e6a2ee6673           NaN
# 68992  LEDGER_TRAD  b9dce823-4bbb-4ace-a77e-61d59c5f3ac9           NaN
# 68991  LEDGER_TRAD  b9dcd6e3-9823-479b-a95e-feb41928f022           NaN
# 68990  LEDGER_TRAD  b9dcd593-4a49-442f-9ff1-299fdf76019b           NaN
# 68989  LEDGER_TRAD  b9dc80e6-dad1-404a-8775-505b3e085482           NaN
#
#       user_email  report_id report_date_local  total_due          tipo  \
# 0            NaN  AFS9LJT74        2023-06-01     643.94  Pago del día
# 68992        NaN  ANYPLKH8L        2023-06-01     301.85  Pago del día
# 68991        NaN  AKW3NJVTF        2023-06-01     141.34  Pago del día
# 68990        NaN  ATX6M59TG        2023-06-01     896.18  Pago del día
# 68989        NaN  AVLX8TD9K        2023-06-01     366.05  Pago del día
#
#                 bank        bank_account_owner_name               CLABE  \
# 0      BBVA BANCOMER  Jorge Isaac Medrano Gutierrez  012323004549589931
# 68992      BANCOPPEL     Jos Luis Salinas Contreras  137420102685122042
# 68991         AZTECA     Pedro Yeudiel Olea Morales  127840013643255724
# 68990        INBURSA        Bryan Nael Ruiz Marquez  036010500533566232
# 68989  BBVA BANCOMER       Sandra Hernandez Luviano  012225015585784463
#
#       status                                          LINEA CEP  \
# 0      ERROR                                                NaN
# 68992   PAID  2023-06-01,20230601400140HDH0001440449050,4001...
# 68991   PAID  2023-06-01,20230601400140HDH0001440448980,4001...
# 68990   PAID  2023-06-01,20230601400140HDH0001440448890,4001...
# 68989   PAID  2023-06-01,20230601400140HDH0001440448810,4001...
#
#             Batch_time Banco_emisor                 file_name  date_file swap
# 0      01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68992  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68991  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68990  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68989  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN

# %%
pagosdia.shape
# Out:
# (3027725, 18)

# %%
group_dia = pagosdia.groupby(['date_file']).agg({'total_due':sum,'report_id':'count'}).reset_index()
group_dia.head()
# Out:
#    date_file      total_due  report_id
# 0 2023-06-01 213,057,392.60     105899
# 1 2023-06-02 219,204,349.04     109532
# 2 2023-06-03 247,559,516.80     113978
# 3 2023-06-04 263,868,364.92     110761
# 4 2023-06-05 186,753,998.95      78009

# %%
group_dia.shape
# Out:
# (30, 3)

# %% [markdown]
# # PRIMER MATCH (SETTLED VS PAGOS DEL DIA)

# %%
check_1 = cum_1.merge(pagosdia[['report_id','total_due','tipo','file_name']] ,on='report_id', how='left')
check_1['total_due_y'].fillna('NO ENCONTRADO')
check_1['tipo'].fillna('NO ENCONTRADO',inplace=True)
check_1['file_name_y'].fillna('NO ENCONTRADO',inplace=True)
# check_1.fillna({'total_due_y':'NO ENCONTRADO', 'tipo':'NO ENCONTRADO', 'file_name_y':'NO ENCONTRADO'}, inplace=True)
check_1.head()
# Out:
#                             merchant_id            merchant_name  \
# 0  25c21503-2be4-408c-a36d-6f600c20779b          SIEMPRE CONTIGO
# 1  80e833d7-f2b7-4287-8f73-a0ce262fc691  EVENTOS MESA DIRECTIVA
# 2  5ed3cbc3-eabc-401c-99fd-72120bd17790                TRASPORTE
# 3  a765c180-1a7d-4a4e-9aff-b6d776d2525c    TRANSPORTES VELAZQUEZ
# 4  f51bab5b-ee99-403a-b6da-49116e4b3707               INFLADEPOT
#
#                       user_email  report_id report_date_local  \
# 0        mejiaporras@hotmail.com  GP6JLMT4Q        2023-06-01
# 1       laurachavezmtz@gmail.com  PHYPS55WJ        2023-06-01
# 2        juarezosiel28@gmail.com  V68KNGMSH        2023-06-01
# 3        benitoedu777x@gmail.com  DK5G262B7        2023-06-01
# 4  jorge.pichardo@infladepot.com  554NQF3H7        2023-06-01
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
# 4                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  total_due_x   type  created_date  \
# 0                    0.00  ...    10,540.64  DAILY    2023-06-01
# 1                    0.00  ...     1,868.58  DAILY    2023-06-01
# 2                    0.00  ...    17,248.32  DAILY    2023-06-01
# 3                    0.00  ...       431.21  DAILY    2023-06-01
# 4                    0.00  ...    54,205.63  DAILY    2023-06-01
#
#    created_time  updated_date  updated_time                file_name_x  \
# 0      03:02:47    2023-06-01      03:02:47  SETTLEMENT 2023-06-01.csv
# 1      03:05:43    2023-06-01      03:05:43  SETTLEMENT 2023-06-01.csv
# 2      03:07:46    2023-06-01      03:07:46  SETTLEMENT 2023-06-01.csv
# 3      03:09:39    2023-06-01      03:09:39  SETTLEMENT 2023-06-01.csv
# 4      03:09:46    2023-06-01      03:09:46  SETTLEMENT 2023-06-01.csv
#
#    total_due_y           tipo               file_name_y
# 0    10,540.64   Pago del día  Dispersión-20230601.xlsx
# 1     1,868.58   Pago del día  Dispersión-20230601.xlsx
# 2    17,248.32   Pago del día  Dispersión-20230601.xlsx
# 3          NaN  NO ENCONTRADO             NO ENCONTRADO
# 4    54,205.63   Pago del día  Dispersión-20230601.xlsx
#
# [5 rows x 29 columns]

# %%
check_1['file_name_y'].unique()
# Out:
# array(['Dispersión-20230601.xlsx', 'NO ENCONTRADO',
#        'Dispersión-20230602.xlsx', 'Dispersión-20230603.xlsx',
#        'Dispersión-20230604.xlsx', 'Dispersión-20230605.xlsx',
#        'Dispersión-20230606.xlsx', 'Dispersión-20230607.xlsx',
#        'Dispersión-20230608.xlsx', 'Dispersión-20230609.xlsx',
#        'Dispersión-20230610.xlsx', 'Dispersión-20230611.xlsx',
#        'Dispersión-20230612.xlsx', 'Dispersión-20230613.xlsx',
#        'Dispersión-20230614.xlsx', 'Dispersión-20230615.xlsx',
#        'Dispersión-20230616.xlsx', 'Dispersión-20230617.xlsx',
#        'Dispersión-20230618.xlsx', 'Dispersión-20230619.xlsx',
#        'Dispersión-20230620.xlsx', 'Dispersión-20230621.xlsx',
#        'Dispersión-20230622.xlsx', 'Dispersión-20230623.xlsx',
#        'Dispersión-20230624.xlsx', 'Dispersión-20230625.xlsx',
#        'Dispersión-20230626.xlsx', 'Dispersión-20230627.xlsx',
#        'Dispersión-20230628.xlsx', 'Dispersión-20230629.xlsx',
#        'Dispersión-20230630.xlsx'], dtype=object)

# %%
not_found_1 = check_1[((check_1['file_name_y'].isnull()) | (check_1['file_name_y'].isin(['NO ENCONTRADO'])))
                        & (check_1['total_due_x'] != 0)]
not_found_1.head()
# Out:
#                               merchant_id           merchant_name  \
# 3    a765c180-1a7d-4a4e-9aff-b6d776d2525c   TRANSPORTES VELAZQUEZ
# 74   288adcd3-b293-48e7-8454-0dc13b68a329                  LISTA
# 289  c0a6da37-2def-4afc-ad4a-a1a41513f37b          ESTETICA SEBAS
# 314  f5c6dd74-d81f-432a-a612-668f57bd634a  VINOS Y LICORES CHAVEZ
#
#                       user_email  report_id report_date_local  \
# 3        benitoedu777x@gmail.com  DK5G262B7        2023-06-01
# 74   azaconenmanuel656@gmail.com  BLM2C5PN2        2023-06-07
# 289        sevaspablo3@gmail.com  SBT3HBR3N        2023-06-24
# 314          je7331351@gmail.com  WRYN9NC8Q        2023-06-25
#
#      total_transactions  total_fees_charged  total_taxes  \
# 3                  0.00                0.00         0.00
# 74                 0.00                0.00         0.00
# 289                0.00                0.00         0.00
# 314                0.00                0.00         0.00
#
#      applied_fees_benefits  applied_taxes_benefits  ...  total_due_x   type  \
# 3                     0.00                    0.00  ...       431.21  DAILY
# 74                    0.00                    0.00  ...    12,265.44  DAILY
# 289                   0.00                    0.00  ...     8,624.16  DAILY
# 314                   0.00                    0.00  ...       287.47  DAILY
#
#      created_date  created_time  updated_date  updated_time  \
# 3      2023-06-01      03:09:39    2023-06-01      03:09:39
# 74     2023-06-07      03:02:43    2023-06-07      03:02:43
# 289    2023-06-24      03:04:03    2023-06-24      03:04:03
# 314    2023-06-25      03:07:55    2023-06-25      03:07:55
#
#                    file_name_x  total_due_y           tipo    file_name_y
# 3    SETTLEMENT 2023-06-01.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 74   SETTLEMENT 2023-06-07.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 289  SETTLEMENT 2023-06-24.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 314  SETTLEMENT 2023-06-25.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
#
# [4 rows x 29 columns]

# %%
not_found_1.shape
# Out:
# (4, 29)

# %%
group_notfound = not_found_1.groupby(['report_date_local']).agg({'total_due_x':sum,'report_id':'count'}).reset_index()
group_notfound.rename(columns={'report_date_local':'date_file'},inplace=True)
group_notfound.head()
# Out:
#    date_file  total_due_x  report_id
# 0 2023-06-01       431.21          1
# 1 2023-06-07    12,265.44          1
# 2 2023-06-24     8,624.16          1
# 3 2023-06-25       287.47          1

# %%
group_notfound.shape
# Out:
# (4, 3)

# %% [markdown]
# #### REPROGRAMACIONES

# %%
repro = allpagos[(allpagos['tipo'].isin(['Reprogramación']))]
repro.head()
# Out:
#               type                           merchant_id merchant_name  \
# 68432  LEDGER_TRAD  b85b0abb-669a-4295-b465-e400c4e5a8fe           NaN
# 68431  LEDGER_TRAD  b85b0abb-669a-4295-b465-e400c4e5a8fe           NaN
# 70700  LEDGER_TRAD  be5bdff0-7320-4b54-9578-7fafd1818930           NaN
# 70653  LEDGER_TRAD  be3e574b-42d0-4dc0-a002-25695cb4e904           NaN
# 70649  LEDGER_TRAD  be39be72-2117-4d29-9931-52e0f9a357f0           NaN
#
#       user_email  report_id report_date_local  total_due            tipo  \
# 68432        NaN  AGS377TVT        2023-05-31   6,318.64  Reprogramación
# 68431        NaN  AXXHDKQYD        2023-05-29   8,259.06  Reprogramación
# 70700        NaN  AKFPTBLNC        2023-05-31       4.79  Reprogramación
# 70653        NaN  AVWVSWKFP        2023-05-30   4,407.90  Reprogramación
# 70649        NaN  AXHDQ9LYN        2023-05-30   8,576.25  Reprogramación
#
#                 bank        bank_account_owner_name               CLABE  \
# 68432  BBVA BANCOMER       Jose Morichi Ponce Itami  012180015358220639
# 68431  BBVA BANCOMER       Jose Morichi Ponce Itami  012180015358220639
# 70700         AZTECA  BRENDA YARELI HERNANDEZ NUÑEZ  127190013629718935
# 70653    BANORTE/IXE      Edgar Omar Flores Sarabia  072580011859212272
# 70649  BBVA BANCOMER               Maday Romn Frost  012180015178039466
#
#       status                                          LINEA CEP  \
# 68432   PAID  2023-06-01,20230601400140HDH0001440404010,4001...
# 68431   PAID  2023-06-01,20230601400140HDH0001440403900,4001...
# 70700   PAID  2023-06-01,20230601400140HDH0001440603230,4001...
# 70653   PAID  2023-06-01,20230601400140HDH0001440599820,4001...
# 70649   PAID  2023-06-01,20230601400140HDH0001440599470,4001...
#
#             Batch_time Banco_emisor                 file_name  date_file swap
# 68432  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 68431  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 70700  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 70653  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN
# 70649  01. First_batch    SANTANDER  Dispersión-20230601.xlsx 2023-06-01  NaN

# %%
repro.shape
# Out:
# (16215, 18)

# %%
group_repro = repro.groupby(['date_file']).agg({'total_due':sum,'report_id':'count'}).reset_index()
group_repro.head()
# Out:
#    date_file    total_due  report_id
# 0 2023-06-01 3,686,318.80       2175
# 1 2023-06-02 1,344,874.32       1075
# 2 2023-06-03 1,149,688.25        778
# 3 2023-06-04   704,367.37        326
# 4 2023-06-05 1,067,085.60        413

# %%
group_repro.shape
# Out:
# (30, 3)

# %% [markdown]
# # SEGUNDO MATCH (IDENTIFICACION DE REPROGRAMACIONES)

# %%
check_2 = not_found_1.merge(repro[['report_id','total_due','tipo','file_name']] ,on='report_id', how='left')
check_2.head()
# Out:
#                             merchant_id           merchant_name  \
# 0  a765c180-1a7d-4a4e-9aff-b6d776d2525c   TRANSPORTES VELAZQUEZ
# 1  288adcd3-b293-48e7-8454-0dc13b68a329                  LISTA
# 2  c0a6da37-2def-4afc-ad4a-a1a41513f37b          ESTETICA SEBAS
# 3  f5c6dd74-d81f-432a-a612-668f57bd634a  VINOS Y LICORES CHAVEZ
#
#                     user_email  report_id report_date_local  \
# 0      benitoedu777x@gmail.com  DK5G262B7        2023-06-01
# 1  azaconenmanuel656@gmail.com  BLM2C5PN2        2023-06-07
# 2        sevaspablo3@gmail.com  SBT3HBR3N        2023-06-24
# 3          je7331351@gmail.com  WRYN9NC8Q        2023-06-25
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  created_time  updated_date  updated_time  \
# 0                    0.00  ...      03:09:39    2023-06-01      03:09:39
# 1                    0.00  ...      03:02:43    2023-06-07      03:02:43
# 2                    0.00  ...      03:04:03    2023-06-24      03:04:03
# 3                    0.00  ...      03:07:55    2023-06-25      03:07:55
#
#                  file_name_x  total_due_y         tipo_x    file_name_y  \
# 0  SETTLEMENT 2023-06-01.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 1  SETTLEMENT 2023-06-07.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 2  SETTLEMENT 2023-06-24.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 3  SETTLEMENT 2023-06-25.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
#
#    total_due  tipo_y  file_name
# 0        NaN     NaN        NaN
# 1        NaN     NaN        NaN
# 2        NaN     NaN        NaN
# 3        NaN     NaN        NaN
#
# [4 rows x 32 columns]

# %%
check_2.shape
# Out:
# (4, 32)

# %%
# writer = pd.ExcelWriter('REPROGRAMACIONES JUNIO 2021.xlsx', engine='xlsxwriter', options={'encoding':'utf-8'})
# check_2.to_excel(writer, sheet_name='DETAIL REPROGRAMACIONES',index=False)
# writer.save()
# writer.close()

# %% [markdown]
# # FECHA DE PAGOS (SETTLED VS PAGOS DEL DIA)

# %%
fecha_pago = not_found_1.merge(repro[['report_id','date_file','tipo','status','file_name']] ,on='report_id', how='left')
fecha_pago.sort_values(by=['date_file'],ascending=True,inplace=True)
fecha_pago.head()
# Out:
#                             merchant_id           merchant_name  \
# 0  a765c180-1a7d-4a4e-9aff-b6d776d2525c   TRANSPORTES VELAZQUEZ
# 1  288adcd3-b293-48e7-8454-0dc13b68a329                  LISTA
# 2  c0a6da37-2def-4afc-ad4a-a1a41513f37b          ESTETICA SEBAS
# 3  f5c6dd74-d81f-432a-a612-668f57bd634a  VINOS Y LICORES CHAVEZ
#
#                     user_email  report_id report_date_local  \
# 0      benitoedu777x@gmail.com  DK5G262B7        2023-06-01
# 1  azaconenmanuel656@gmail.com  BLM2C5PN2        2023-06-07
# 2        sevaspablo3@gmail.com  SBT3HBR3N        2023-06-24
# 3          je7331351@gmail.com  WRYN9NC8Q        2023-06-25
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  updated_date  updated_time  \
# 0                    0.00  ...    2023-06-01      03:09:39
# 1                    0.00  ...    2023-06-07      03:02:43
# 2                    0.00  ...    2023-06-24      03:04:03
# 3                    0.00  ...    2023-06-25      03:07:55
#
#                  file_name_x  total_due_y         tipo_x    file_name_y  \
# 0  SETTLEMENT 2023-06-01.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 1  SETTLEMENT 2023-06-07.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 2  SETTLEMENT 2023-06-24.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 3  SETTLEMENT 2023-06-25.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
#
#    date_file  tipo_y  status  file_name
# 0        NaT     NaN     NaN        NaN
# 1        NaT     NaN     NaN        NaN
# 2        NaT     NaN     NaN        NaN
# 3        NaT     NaN     NaN        NaN
#
# [4 rows x 33 columns]

# %%
fecha_pago.shape
# Out:
# (4, 33)

# %%
fecha_pago.drop_duplicates(subset ='report_id',keep='first',inplace=True)

# %%
fecha_pago.head()
# Out:
#                             merchant_id           merchant_name  \
# 0  a765c180-1a7d-4a4e-9aff-b6d776d2525c   TRANSPORTES VELAZQUEZ
# 1  288adcd3-b293-48e7-8454-0dc13b68a329                  LISTA
# 2  c0a6da37-2def-4afc-ad4a-a1a41513f37b          ESTETICA SEBAS
# 3  f5c6dd74-d81f-432a-a612-668f57bd634a  VINOS Y LICORES CHAVEZ
#
#                     user_email  report_id report_date_local  \
# 0      benitoedu777x@gmail.com  DK5G262B7        2023-06-01
# 1  azaconenmanuel656@gmail.com  BLM2C5PN2        2023-06-07
# 2        sevaspablo3@gmail.com  SBT3HBR3N        2023-06-24
# 3          je7331351@gmail.com  WRYN9NC8Q        2023-06-25
#
#    total_transactions  total_fees_charged  total_taxes  applied_fees_benefits  \
# 0                0.00                0.00         0.00                   0.00
# 1                0.00                0.00         0.00                   0.00
# 2                0.00                0.00         0.00                   0.00
# 3                0.00                0.00         0.00                   0.00
#
#    applied_taxes_benefits  ...  updated_date  updated_time  \
# 0                    0.00  ...    2023-06-01      03:09:39
# 1                    0.00  ...    2023-06-07      03:02:43
# 2                    0.00  ...    2023-06-24      03:04:03
# 3                    0.00  ...    2023-06-25      03:07:55
#
#                  file_name_x  total_due_y         tipo_x    file_name_y  \
# 0  SETTLEMENT 2023-06-01.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 1  SETTLEMENT 2023-06-07.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 2  SETTLEMENT 2023-06-24.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
# 3  SETTLEMENT 2023-06-25.csv          NaN  NO ENCONTRADO  NO ENCONTRADO
#
#    date_file  tipo_y  status  file_name
# 0        NaT     NaN     NaN        NaN
# 1        NaT     NaN     NaN        NaN
# 2        NaT     NaN     NaN        NaN
# 3        NaT     NaN     NaN        NaN
#
# [4 rows x 33 columns]

# %%
fecha_pago.shape
# Out:
# (4, 33)

# %% [markdown]
# ### AGRUPADO POR DÍA

# %%
pivot_fecha_pago = pd.pivot_table(fecha_pago,index=['report_date_local'],
                                  values=['total_due_x'],aggfunc = ['sum', len],margins=True)
pivot_fecha_pago.head()
# Out:
#                             sum         len
#                     total_due_x total_due_x
# report_date_local
# 2023-06-01 00:00:00      431.21           1
# 2023-06-07 00:00:00   12,265.44           1
# 2023-06-24 00:00:00    8,624.16           1
# 2023-06-25 00:00:00      287.47           1
# All                   21,608.28           4

# %%
pivot_fecha_pago.shape
# Out:
# (5, 2)

# %% [markdown]
# # PAGOS MANUALES

# %%
file_manual = glob.glob(r'G:\.shortcut-targets-by-id\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\3.-Settlement\5.-HISTORICO FILES PAGOS\01. TRADICIONAL\2023\06. JUNE\MANUALES\*.xlsx', recursive=False)
file_manual
# Out:
# ['G:\\.shortcut-targets-by-id\\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\\3.-Settlement\\5.-HISTORICO FILES PAGOS\\01. TRADICIONAL\\2023\\06. JUNE\\MANUALES\\Manuales 2023.06.01 - 2023.06.27.xlsx',
#  'G:\\.shortcut-targets-by-id\\1Oe28Mf9uSidMamjllDen2gkNnC59eSUr\\3.-Settlement\\5.-HISTORICO FILES PAGOS\\01. TRADICIONAL\\2023\\06. JUNE\\MANUALES\\Manuales 2023.06.28 - 2023.06.30.xlsx']

# %%
manuales_all = pd.concat([pd.read_excel(f,sheet_name='Formato Pago Manual',skiprows=1
                                      ,converters={'Cta. CLABE de depósito':str,'report_id':str})
                          .assign(file_name=os.path.basename(f)) for f in file_manual])
manuales_all['Date']= pd.to_datetime(manuales_all['Date'])  
manuales_all['Tipo'] = 'MANUAL'

# %%
manuales_final = manuales_all[['Date','ME ID','ME NAME',' (mxn)','Banco','Justificación para el pago','Tipo','Report ID']]
manuales_final.head()
# Out:
#         Date                                  ME ID  \
# 0 2023-06-07   9046aed6-1360-4c20-a70a-b5aa45c7b19a
# 1 2023-06-07   66f70b89-e151-4fd6-888b-cf0488e699e9
# 2 2023-06-20   c19c810d-0c2c-4f82-967b-6642c0bc89be
# 3 2023-06-20   c19c810d-0c2c-4f82-967b-6642c0bc89be
# 4 2023-06-20   ffbcbcbe-23f4-4755-a634-7b4a0b6f2724
#
#                      ME NAME     (mxn)                           Banco  \
# 0 127,180,016,367,228,896.00     16.60     Miguel Alberto Montoya Ruiz
# 1  12,700,004,763,752,358.00     69.95  KARLA LIZETH PACHECO HERNANDEZ
# 2  12,025,004,676,131,564.00 19,316.77            Rosaura Cota Cardona
# 3  12,025,004,676,131,564.00     10.53            Rosaura Cota Cardona
# 4  12,180,001,180,249,288.00  4,676.51           HIZA DISEÑOS SA DE CV
#
#                           Justificación para el pago    Tipo  Report ID
# 0                                   Reembolso Manual  MANUAL        NaN
# 1                                   Reembolso Manual  MANUAL        NaN
# 2  Solicitud de Visto Bueno para depósito manual ...  MANUAL  AQ52D8B37
# 3  Solicitud de Visto Bueno para depósito manual ...  MANUAL  A823ST6G5
# 4                                     Reembolsos MEs  MANUAL        NaN

# %%
manuales_final.shape
# Out:
# (9, 8)

# %%
manuales_final.columns
# Out:
# Index(['Date', 'ME ID', 'ME NAME', ' (mxn)', 'Banco',
#        'Justificación para el pago', 'Tipo', 'Report ID'],
#       dtype='object')

# %%
group_manual = manuales_final.groupby(['Date']).agg({' (mxn)':sum,'Report ID':'count'}).reset_index()
group_manual.rename(columns={'Date':'date_file','Report ID':'report_id'},inplace=True)
group_manual.head()
# Out:
#    date_file     (mxn)  report_id
# 0 2023-06-07     86.55          0
# 1 2023-06-20 29,277.19          2
# 2 2023-06-28  1,816.20          0

# %%
group_manual.shape
# Out:
# (3, 3)

# %% [markdown]
# # ACUMULADOS SETTLEMENT

# %%
conc_disp = cum_distinct_0.groupby(['report_date_local']).agg({'total_due':sum,'report_id':'count'}).reset_index()
conc_disp.rename(columns={'report_date_local':'date_file'}, inplace=True)
conc_disp.head()
# Out:
#    date_file  total_due  report_id
# 0 2023-06-01  84,342.29          6
# 1 2023-06-02 496,723.61         20
# 2 2023-06-03 192,216.21         12
# 3 2023-06-04 243,899.00         17
# 4 2023-06-05 220,905.37         11

# %%
conc_disp.shape
# Out:
# (30, 3)

# %% [markdown]
# # MERGING ALL DATA FRAMES

# %%
total_1 = conc_disp.merge(group_repro[['date_file','total_due','report_id']],on='date_file',how='left') \
.merge(group_manual,on='date_file',how='left')
total_1[' (mxn)'].fillna(0,inplace=True)
total_1['report_id'].fillna(0,inplace=True)
total_1.head()
# Out:
#    date_file  total_due_x  report_id_x  total_due_y  report_id_y   (mxn)  \
# 0 2023-06-01    84,342.29            6 3,686,318.80         2175    0.00
# 1 2023-06-02   496,723.61           20 1,344,874.32         1075    0.00
# 2 2023-06-03   192,216.21           12 1,149,688.25          778    0.00
# 3 2023-06-04   243,899.00           17   704,367.37          326    0.00
# 4 2023-06-05   220,905.37           11 1,067,085.60          413    0.00
#
#    report_id
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00

# %%
total_1['count_total_pago_dia'] = total_1['report_id_x'] + total_1['report_id_y'] + total_1['report_id']
total_1['sum_total_pago_dia'] = total_1['total_due_x'] + total_1['total_due_y'] + total_1[' (mxn)']

# %%
total_1
# Out:
#     date_file  total_due_x  report_id_x  total_due_y  report_id_y     (mxn)  \
# 0  2023-06-01    84,342.29            6 3,686,318.80         2175      0.00
# 1  2023-06-02   496,723.61           20 1,344,874.32         1075      0.00
# 2  2023-06-03   192,216.21           12 1,149,688.25          778      0.00
# 3  2023-06-04   243,899.00           17   704,367.37          326      0.00
# 4  2023-06-05   220,905.37           11 1,067,085.60          413      0.00
# 5  2023-06-06   159,717.59            7   854,926.69          790      0.00
# 6  2023-06-07   183,993.08           14 1,167,812.19          643     86.55
# 7  2023-06-08   545,931.64           14   908,581.99          529      0.00
# 8  2023-06-09   586,857.49           24   787,513.62          324      0.00
# 9  2023-06-10   184,309.62            9   400,681.87          233      0.00
# 10 2023-06-11   325,577.05           13 1,314,165.42          675      0.00
# 11 2023-06-12    85,250.17           16   957,808.95          289      0.00
# 12 2023-06-13   151,004.94            8 1,632,480.44          608      0.00
# 13 2023-06-14   105,138.28           12   558,131.45          402      0.00
# 14 2023-06-15   174,449.35           14   792,679.65          350      0.00
# 15 2023-06-16   346,907.68           16   770,582.62          466      0.00
# 16 2023-06-17   639,005.17           18   612,927.46          298      0.00
# 17 2023-06-18   244,622.46            9   902,812.19          371      0.00
# 18 2023-06-19   846,581.00           14   520,089.79          218      0.00
# 19 2023-06-20   113,676.02            2 1,435,663.22          515 29,277.19
# 20 2023-06-21   122,993.81            6 1,311,944.72          771      0.00
# 21 2023-06-22   706,065.60            8   696,051.44          377      0.00
# 22 2023-06-23   211,097.25           14 1,027,417.77          529      0.00
# 23 2023-06-24   265,345.62           19   678,983.21          391      0.00
# 24 2023-06-25   222,373.10           18   432,224.59          293      0.00
# 25 2023-06-26   406,486.23           11   304,229.46          367      0.00
# 26 2023-06-27   141,783.27            5   797,041.57          329      0.00
# 27 2023-06-28   233,365.44            8   643,752.31          477  1,816.20
# 28 2023-06-29   132,742.12           12   852,175.05          353      0.00
# 29 2023-06-30   138,846.96           11 1,366,791.65          850      0.00
#
#     report_id  count_total_pago_dia  sum_total_pago_dia
# 0        0.00              2,181.00        3,770,661.09
# 1        0.00              1,095.00        1,841,597.93
# 2        0.00                790.00        1,341,904.46
# 3        0.00                343.00          948,266.37
# 4        0.00                424.00        1,287,990.97
# 5        0.00                797.00        1,014,644.28
# 6        0.00                657.00        1,351,891.82
# 7        0.00                543.00        1,454,513.63
# 8        0.00                348.00        1,374,371.11
# 9        0.00                242.00          584,991.49
# 10       0.00                688.00        1,639,742.47
# 11       0.00                305.00        1,043,059.12
# 12       0.00                616.00        1,783,485.38
# 13       0.00                414.00          663,269.73
# 14       0.00                364.00          967,129.00
# 15       0.00                482.00        1,117,490.30
# 16       0.00                316.00        1,251,932.63
# 17       0.00                380.00        1,147,434.65
# 18       0.00                232.00        1,366,670.79
# 19       2.00                519.00        1,578,616.43
# 20       0.00                777.00        1,434,938.53
# 21       0.00                385.00        1,402,117.04
# 22       0.00                543.00        1,238,515.02
# 23       0.00                410.00          944,328.83
# 24       0.00                311.00          654,597.69
# 25       0.00                378.00          710,715.69
# 26       0.00                334.00          938,824.84
# 27       0.00                485.00          878,933.95
# 28       0.00                365.00          984,917.17
# 29       0.00                861.00        1,505,638.61

# %% [markdown]
# # ACUMULADOS PAGO DEL DIA

# %%
total_2 = group_allpagos.merge(group_notfound[['date_file','total_due_x','report_id']],on='date_file',how='left')\
.merge(group_manual,on='date_file',how='left')
total_2[' (mxn)'].fillna(0,inplace=True)
total_2['report_id'].fillna(0,inplace=True)
total_2['total_due_x'].fillna(0,inplace=True)
total_2['report_id_y'].fillna(0,inplace=True)
total_2.head()
# Out:
#    date_file      total_due  report_id_x  total_due_x  report_id_y   (mxn)  \
# 0 2023-06-01 216,743,711.40       108074       431.21         1.00    0.00
# 1 2023-06-02 220,549,223.36       110607         0.00         0.00    0.00
# 2 2023-06-03 248,709,205.05       114756         0.00         0.00    0.00
# 3 2023-06-04 264,572,732.29       111087         0.00         0.00    0.00
# 4 2023-06-05 187,821,084.55        78422         0.00         0.00    0.00
#
#    report_id
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00

# %%
total_2['count_swap_dia'] = total_2['report_id_x'] + total_2['report_id_y'] + total_2['report_id']
total_2['sum_swap_dia'] = total_2['total_due'] + total_2['total_due_x'] + total_2[' (mxn)']

# %%
total_2.head()
# Out:
#    date_file      total_due  report_id_x  total_due_x  report_id_y   (mxn)  \
# 0 2023-06-01 216,743,711.40       108074       431.21         1.00    0.00
# 1 2023-06-02 220,549,223.36       110607         0.00         0.00    0.00
# 2 2023-06-03 248,709,205.05       114756         0.00         0.00    0.00
# 3 2023-06-04 264,572,732.29       111087         0.00         0.00    0.00
# 4 2023-06-05 187,821,084.55        78422         0.00         0.00    0.00
#
#    report_id  count_swap_dia   sum_swap_dia
# 0       0.00      108,075.00 216,744,142.61
# 1       0.00      110,607.00 220,549,223.36
# 2       0.00      114,756.00 248,709,205.05
# 3       0.00      111,087.00 264,572,732.29
# 4       0.00       78,422.00 187,821,084.55

# %%
total_2.shape
# Out:
# (30, 9)

# %% [markdown]
# # COMPARACION FINAL

# %%
final_comparacion = total_1[['date_file','count_total_pago_dia','sum_total_pago_dia']] \
.merge(total_2[['date_file','count_swap_dia','sum_swap_dia']],on='date_file',how='left')
final_comparacion.head()
# Out:
#    date_file  count_total_pago_dia  sum_total_pago_dia  count_swap_dia  \
# 0 2023-06-01              2,181.00        3,770,661.09      108,075.00
# 1 2023-06-02              1,095.00        1,841,597.93      110,607.00
# 2 2023-06-03                790.00        1,341,904.46      114,756.00
# 3 2023-06-04                343.00          948,266.37      111,087.00
# 4 2023-06-05                424.00        1,287,990.97       78,422.00
#
#     sum_swap_dia
# 0 216,744,142.61
# 1 220,549,223.36
# 2 248,709,205.05
# 3 264,572,732.29
# 4 187,821,084.55

# %%
final_comparacion['diff_count'] = final_comparacion['count_total_pago_dia'] - final_comparacion['count_swap_dia']
final_comparacion['diff_sum'] = final_comparacion['sum_total_pago_dia'] - final_comparacion['sum_swap_dia']

# %%
final_comparacion
# Out:
#     date_file  count_total_pago_dia  sum_total_pago_dia  count_swap_dia  \
# 0  2023-06-01              2,181.00        3,770,661.09      108,075.00
# 1  2023-06-02              1,095.00        1,841,597.93      110,607.00
# 2  2023-06-03                790.00        1,341,904.46      114,756.00
# 3  2023-06-04                343.00          948,266.37      111,087.00
# 4  2023-06-05                424.00        1,287,990.97       78,422.00
# 5  2023-06-06                797.00        1,014,644.28       98,435.00
# 6  2023-06-07                657.00        1,351,891.82      100,756.00
# 7  2023-06-08                543.00        1,454,513.63      100,581.00
# 8  2023-06-09                348.00        1,374,371.11      106,711.00
# 9  2023-06-10                242.00          584,991.49      112,058.00
# 10 2023-06-11                688.00        1,639,742.47      110,087.00
# 11 2023-06-12                305.00        1,043,059.12       78,229.00
# 12 2023-06-13                616.00        1,783,485.38       96,353.00
# 13 2023-06-14                414.00          663,269.73       99,423.00
# 14 2023-06-15                364.00          967,129.00      104,442.00
# 15 2023-06-16                482.00        1,117,490.30      111,511.00
# 16 2023-06-17                316.00        1,251,932.63      115,640.00
# 17 2023-06-18                380.00        1,147,434.65      112,318.00
# 18 2023-06-19                232.00        1,366,670.79       77,043.00
# 19 2023-06-20                519.00        1,578,616.43       96,309.00
# 20 2023-06-21                777.00        1,434,938.53       98,957.00
# 21 2023-06-22                385.00        1,402,117.04      100,824.00
# 22 2023-06-23                543.00        1,238,515.02      104,901.00
# 23 2023-06-24                410.00          944,328.83      111,018.00
# 24 2023-06-25                311.00          654,597.69      107,504.00
# 25 2023-06-26                378.00          710,715.69       76,566.00
# 26 2023-06-27                334.00          938,824.84       93,736.00
# 27 2023-06-28                485.00          878,933.95       97,448.00
# 28 2023-06-29                365.00          984,917.17      101,547.00
# 29 2023-06-30                861.00        1,505,638.61      108,602.00
#
#      sum_swap_dia  diff_count        diff_sum
# 0  216,744,142.61 -105,894.00 -212,973,481.52
# 1  220,549,223.36 -109,512.00 -218,707,625.43
# 2  248,709,205.05 -113,966.00 -247,367,300.59
# 3  264,572,732.29 -110,744.00 -263,624,465.92
# 4  187,821,084.55  -77,998.00 -186,533,093.58
# 5  188,977,100.13  -97,638.00 -187,962,455.85
# 6  194,376,716.89 -100,099.00 -193,024,825.07
# 7  190,623,547.05 -100,038.00 -189,169,033.42
# 8  202,383,821.69 -106,363.00 -201,009,450.58
# 9  232,200,117.31 -111,816.00 -231,615,125.82
# 10 258,999,009.96 -109,399.00 -257,359,267.49
# 11 177,503,230.00  -77,924.00 -176,460,170.88
# 12 179,195,806.41  -95,737.00 -177,412,321.03
# 13 186,065,506.57  -99,009.00 -185,402,236.84
# 14 201,996,540.86 -104,078.00 -201,029,411.86
# 15 221,453,516.06 -111,029.00 -220,336,025.76
# 16 253,445,007.62 -115,324.00 -252,193,074.99
# 17 274,319,780.17 -111,938.00 -273,172,345.52
# 18 198,559,528.20  -76,811.00 -197,192,857.41
# 19 183,569,253.72  -95,790.00 -181,990,637.29
# 20 188,348,651.40  -98,180.00 -186,913,712.87
# 21 193,982,326.93 -100,439.00 -192,580,209.89
# 22 204,484,036.70 -104,358.00 -203,245,521.68
# 23 236,506,874.79 -110,608.00 -235,562,545.96
# 24 253,771,095.56 -107,193.00 -253,116,497.87
# 25 176,750,505.61  -76,188.00 -176,039,789.92
# 26 179,825,122.70  -93,402.00 -178,886,297.86
# 27 189,668,862.33  -96,963.00 -188,789,928.38
# 28 203,161,250.35 -101,182.00 -202,176,333.18
# 29 227,797,665.22 -107,741.00 -226,292,026.61

# %%
writer = pd.ExcelWriter('FASE III. SETTLED VS PAGO DIA JUNIO 2023.xlsx',
                        engine='xlsxwriter',
                        engine_kwargs={'options': {'encoding':'utf-8'}})
pivot_fecha_pago.to_excel(writer, sheet_name='ENVIADOS POSTERIOR')
fecha_pago.to_excel(writer, sheet_name='DETAIL NO ENCONTRADO',index=False)
pivot_duplicates_trad.to_excel(writer, sheet_name='PAGOS DUPLICADOS')
pivot_duplicates_fp.to_excel(writer, sheet_name='FP PAGOS DUPLICADOS')
group_manual.to_excel(writer, sheet_name='PAGOS MANUALES')
writer.close()
